# %% [markdown]
# **I import some useful libraries in python.**

# %%
import difflib
import operator as op
import random
import numpy as np
import pandas as pd
import torch
import torch.backends.cudnn
from numpy.random import MT19937
from numpy.random import RandomState, SeedSequence
from torch.optim import Adam
from transformers import get_linear_schedule_with_warmup
import os
from google.colab import drive
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt
import torch.nn as nn
from transformers import BertModel
from transformers import BertTokenizerFast

# %% [markdown]
# **I mount google drive because all the files (for example .csv) that i used for the implementation of my thesis are saved on my google drive.**

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Check of the device that it is used for the implementation of the notebooks of this thesis, that is determined from google colab.**

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Device available for running: ")
print(device)
# Out:
# Device available for running:
# cuda

# %% [markdown]
# **Reading of the created datasets (for both the SimpleQuestions dataset that includes all training and validation questions and the SimpleQuestions subset that includes only answerable over wikidata questions) as .csv file.**

# %%
train_dataset = pd.read_csv("drive/MyDrive/train_dataset.csv", sep = ',')
validation_dataset = pd.read_csv("drive/MyDrive/valid_dataset.csv", sep = ',')
print(train_dataset)
print(validation_dataset)
# Out:
#        entity_id      entity_label relation_id  \
# 0        Q126399       Warner Bros        R272
# 1         Q12439           Detroit         R19
# 2       Q7370831          Q7370831        P162
# 3       Q6817891       Mera Shikar        P364
# 4          Q1297           Chicago        R276
# ...          ...               ...         ...
# 34369  Q16093542    Anthony Bailey         P27
# 34370    Q325741     Homi K Bhabha        P737
# 34371   Q1062702  video game music        R136
# 34372    Q926822  Gaston Filgueira         P21
# 34373    Q336286          defender        R413
#
#                                                 Question
# 0                  what movie is produced by warner bros
# 1                      who is a musician born in detroit
# 2                who produced the film rough house rosie
# 3      what is the language in which mera shikar was ...
# 4      Whats the name of a battle that happened in ch...
# ...                                                  ...
# 34369          What is the nationality of anthony bailey
# 34370    who was homi k bhabha especially influenced by
# 34371             which artist composes video game music
# 34372                    What gender is gaston filgueira
# 34373                      what player played a defender
#
# [34374 rows x 4 columns]
#      entity_id            entity_label relation_id  \
# 0     Q3541144      JW Marriott Panama        P138
# 1      Q318926           Sasha Vujacic         P19
# 2     Q2568216       Wiebke Carolsfeld         R57
# 3     Q2275923  Seymour Parker Gilbert        P106
# 4     Q2856873        Antoine de Fevin         P20
# ...        ...                     ...         ...
# 4862  Q3709870          Herby Fortunat        P413
# 4863   Q150804             The Pianist        P136
# 4864  Q1343857                Jon Seda         P19
# 4865  Q2981169       Nikolaj Frobenius        P106
# 4866      Q174               Sao Paulo         R19
#
#                                                Question
# 0     Who was the trump ocean club international hot...
# 1                          where was sasha vujacic born
# 2          What is a film directed by wiebke carolsfeld
# 3            What was Seymour Parker Gilbert profession
# 4         in what french city did antoine de fevin die
# ...                                                 ...
# 4862  which position did herby fortunat play in foot...
# 4863       what kind of film is the pianist (2002 film)
# 4864                     where was jon seda given birth
# 4865               What is nikolaj frobenius profession
# 4866         who is a person that was born in sao paulo
#
# [4867 rows x 4 columns]

# %% [markdown]
# **Check if  the SimpleQuestions training and validation dataset have at least one line with null value. This issues both for SimpleQuestions dataset that includes only answerable over wikidata questions and for the corresponding dataset that includes all the questions.**

# %%
train_dataset.dropna(inplace = True)
validation_dataset.dropna(inplace = True)
print(train_dataset)
print(validation_dataset)
# Out:
#        entity_id      entity_label relation_id  \
# 0        Q126399       Warner Bros        R272
# 1         Q12439           Detroit         R19
# 2       Q7370831          Q7370831        P162
# 3       Q6817891       Mera Shikar        P364
# 4          Q1297           Chicago        R276
# ...          ...               ...         ...
# 34369  Q16093542    Anthony Bailey         P27
# 34370    Q325741     Homi K Bhabha        P737
# 34371   Q1062702  video game music        R136
# 34372    Q926822  Gaston Filgueira         P21
# 34373    Q336286          defender        R413
#
#                                                 Question
# 0                  what movie is produced by warner bros
# 1                      who is a musician born in detroit
# 2                who produced the film rough house rosie
# 3      what is the language in which mera shikar was ...
# 4      Whats the name of a battle that happened in ch...
# ...                                                  ...
# 34369          What is the nationality of anthony bailey
# 34370    who was homi k bhabha especially influenced by
# 34371             which artist composes video game music
# 34372                    What gender is gaston filgueira
# 34373                      what player played a defender
#
# [34373 rows x 4 columns]
#      entity_id            entity_label relation_id  \
# 0     Q3541144      JW Marriott Panama        P138
# 1      Q318926           Sasha Vujacic         P19
# 2     Q2568216       Wiebke Carolsfeld         R57
# 3     Q2275923  Seymour Parker Gilbert        P106
# 4     Q2856873        Antoine de Fevin         P20
# ...        ...                     ...         ...
# 4862  Q3709870          Herby Fortunat        P413
# 4863   Q150804             The Pianist        P136
# 4864  Q1343857                Jon Seda         P19
# 4865  Q2981169       Nikolaj Frobenius        P106
# 4866      Q174               Sao Paulo         R19
#
#                                                Question
# 0     Who was the trump ocean club international hot...
# 1                          where was sasha vujacic born
# 2          What is a film directed by wiebke carolsfeld
# 3            What was Seymour Parker Gilbert profession
# 4         in what french city did antoine de fevin die
# ...                                                 ...
# 4862  which position did herby fortunat play in foot...
# 4863       what kind of film is the pianist (2002 film)
# 4864                     where was jon seda given birth
# 4865               What is nikolaj frobenius profession
# 4866         who is a person that was born in sao paulo
#
# [4867 rows x 4 columns]

# %% [markdown]
# **Creation of the corresponding lists containing the questions, the entity labels, the relation ids and the entity ids of the corresponding SimpleQuestions datasets (training, validation), either this dataset includes answerable and answerable questions over wikidata questions or only answerable questions over wikidata.**

# %%
train_entity_labels = train_dataset['entity_label'].to_list()
validation_entity_labels = validation_dataset['entity_label'].to_list()
train_entityids = train_dataset['entity_id'].to_list()
validation_entityids = validation_dataset['entity_id'].to_list()
train_questions = train_dataset['Question'].to_list()
validation_questions = validation_dataset['Question'].to_list()
train_relationids = train_dataset['relation_id'].to_list()
validation_relationids = validation_dataset['relation_id'].to_list()
print(len(train_entity_labels), len(train_entityids), len(train_relationids), len(train_questions))
# Out:
# 34373 34373 34373 34373

# %% [markdown]
# **The maximum question length that is observed in SimpleQuestions training and validation dataset is found below.**

# %%
#Below the max questions length is found for all questions.
quests = train_questions + validation_questions
print(len(quests), len(train_questions), len(validation_questions))
# Printing concatenated list
q_lengths = []
for s in range(len(quests)): #padding
    q_lengths.append(len(quests[s].split()))
max_question_length = max(q_lengths)
print(max_question_length)#Max question length
# Out:
# 39240 34373 4867
# 33

# %% [markdown]
# **Creation of the relation vocabulary that includes all the unique entity ids of the SimpleQuestions training and validation dataset through function relation_vocabulary. Also the index of each unique relation id of the relation vocabulary in this vocabulary is found through the function find_relations_index.**

# %%
#Create relation vocabulary for each question of train and validation dataset
def relation_vocabulary(relation_column_dataset):
  relation_vocabulary = []
   #In order to have the unique relation ids it is important to check if an relation id is already in the relation_vocabulary
  for relation in range(len(relation_column_dataset)):
    g = 0
    for i in range(len(relation_vocabulary)):
      if relation_column_dataset[relation] != relation_vocabulary[i]: #relation is not found yet
        g += 1
      else:
       continue
    if g == len(relation_vocabulary) and relation_column_dataset[relation] not in relation_vocabulary:
      relation_vocabulary.append(relation_column_dataset[relation]) #The relation id is not inside the relation vocabulary
      #which has some relations already or the relation vocaulary has no relations
  return relation_vocabulary

def find_relation_index(relation_vocabulary,relation_ids_column):
  relations_count = []
  for relation in range(len(relation_ids_column)):
        relations_count.append(relation_vocabulary.index(relation_ids_column[relation]))

  return relations_count
#relation_ids = pd.concat([train_dataset["relation_id"], validation_dataset["relation_id"]], ignore_index = True)
relation_ids = train_relationids + validation_relationids
print(len(relation_ids))
rel_vocab = relation_vocabulary(relation_ids)
rel_vocab_length = len(rel_vocab)
print(rel_vocab, rel_vocab_length)
train_relations_index = find_relation_index(rel_vocab, train_relationids)
validation_relations_index = find_relation_index(rel_vocab, validation_relationids)
# Out:
# 39240
# ['R272', 'R19', 'P162', 'P364', 'R276', 'R413', 'R607', 'P413', 'R136', 'P27', 'P21', 'P136', 'P738', 'R106', 'P196', 'P175', 'R175', 'R50', 'P344', 'P641', 'P19', 'P421', 'R421', 'R57', 'P170', 'R17', 'P287', 'P86', 'R58', 'R86', 'P1142', 'P20', 'P58', 'P264', 'P131', 'P106', 'P172', 'P495', 'P150', 'R131', 'R509', 'P119', 'R1303', 'P50', 'R40', 'P1303', 'P61', 'R172', 'P57', 'P140', 'P179', 'R344', 'P1040', 'P509', 'P138', 'P397', 'P407', 'P398', 'P272', 'R264', 'P403', 'P31', 'P607', 'R287', 'R162', 'R641', 'R404', 'P1408', 'R178', 'R279', 'P123', 'P59', 'P40', 'P276', 'P1431', 'P178', 'P737', 'R179', 'P17', 'P171', 'R170', 'P144', 'P112', 'R105', 'R676', 'R59', 'P113', 'P155', 'P289', 'R149', 'P404', 'P710', 'P676', 'P149', 'R1040', 'R177', 'R119', 'P279', 'R21', 'R112', 'R31', 'R138', 'P53', 'R123', 'P65', 'P156', 'P177', 'R144', 'R1431', 'P81', 'P115', 'P105', 'P800', 'R171', 'P1029', 'R115', 'P84', 'R1142', 'P376', 'R376', 'P1308', 'P826', 'R161', 'R289', 'R176', 'P189', 'P176', 'P361', 'R361'] 129

# %% [markdown]
# **The function create\_question\_parts, takes as arguments the splitted question splitted into words and the entity label also splitted into words.
# Essentially in this function each question, as well as the corresponding entity label, is splitted into words using python method split() and then, using python method join(), parts of the query are created equal in length to that of their splitted entity label in words.**
#
# **These parts are stored in a list as well as the indexes of the initial word and final word of these question parts are stored in dictionaries with keys the question parts and values the indexes(positions) of the initial words and final words for each question. Finally this function returns the list of question parts and dictionaries containing the indexes(positions) of the initial words and final words for each question part.**

# %%
#The fact that the corresponding question part start index is lower to
#the corresponding question part start index is lower is an indirect efficient way to ensure that all ones that are added in this span are successive.
#That it is very helpful to find entity span start index and entity span end index later.
def create_question_parts(question_splitted, entity_splited_length):
  Quests_Parts = []
  Quest_Parts_Start = {}
  Quest_Parts_End = {}
  for i in range(len(question_splitted)-entity_splited_length+1):
    quest_part = " ".join(question_splitted[i:i+entity_splited_length])
    Quests_Parts.append(quest_part)
    Quest_Parts_Start[quest_part] = i
    Quest_Parts_End[quest_part] = i+entity_splited_length-1
  return Quests_Parts, Quest_Parts_Start, Quest_Parts_End

# %% [markdown]
# **Through the create\_entity\_span function below that takes as arguments the question splitted in words and the indexes of the initial and final word of the part of the question that is equal to the corresponding entity label, the entity span for each question is created.**
#
# **In this entity span because the words that make up the entity label must be in consecutive positions within the question, it is always necessary that when creating the entity span, the index specifying the position of the starting word of the equal question part with the corresponding entity label for the question must be less than or equal to the corresponding index of the ending word of that equal question part. This indirectly ensures that the ones that enter the entity span are consecutive and equal in number to the length of the entity label splitted in words. This function returns the entity span, as well as the number of consecutive ones in it for each question.**

# %%
#Create entity span
def create_entity_span(question_splitted_length, quest_part_start, quest_part_end):
   entity_span = []
   count_successive_ones = 0
   for k in range(question_splitted_length):
     if k >= quest_part_start and k <= quest_part_end:
        entity_span.append(1)
        count_successive_ones += 1
     else:
        entity_span.append(0)

   return entity_span, count_successive_ones

# %% [markdown]
# **Through the find_start_and_end_index function, which takes as arguments the entity span, the entity label, the list of all the parts of the question, the dictionaries with keys the parts for each question and values the indexes of the start words and end words for each question, the length of the question and the number of consecutive ones of the entity span which are counted in this function, the question part that is equal with the entity label, the position of the initial word (index of the first one in the entity span) of the entity label and respectively the position of the final word (index of the last one in the entity span) could be found. If the entity span that is created for a question is not full of zeros, then a logical variable is used to confirm that all ones present are contiguous.**
#
# **In the case, of course, that no word of the entity label is present in the words of the corresponding question, the entity span will consist only of zeros, so there is no word to derive the corresponding indices for entity start and entity end.**
#
# **To deal with this situation, initially from the list of question parts as obtained from the create_question_parts function through difflib.get_close_matches(), it is searched, which part is closest to the entity label and for that question part from the dictionaries containing the indexes(positions) of the initial words and the final words for it obtained from the same function, the corresponding positional indexes of its initial and final words are found.
# Next, if no question part that is found by difflib.get\_close\_matches() is even minimally similar to the entity label, then the positions (indices) of the penultimate (question length-2) and the last word (question length-1) are set as the entity start index and entity end index, respectively.
# In this way the lengths of the train and validation dataset are kept constant.**

# %%
#Create for each question the entity span and find the entity span start index and the entity span end index.
def find_start_and_end_index(entity_label, entity_label_splitted_length, question_parts, question_splitted_length, start_indexes, end_indexes):
  entity_span_start_index = -1
  entity_span_end_index = -1
  quest_part_start_index = -1
  quest_part_end_index = -1
  entity_span = []
  entity_span_with_successive_ones = 0
  for q_p in range(len(question_parts)):
    if question_parts[q_p] == entity_label:
      quest_part = question_parts[q_p]
      quest_part_start_index = start_indexes[quest_part]
      quest_part_end_index = end_indexes[quest_part]
  entity_span, count_successive_ones = create_entity_span(question_splitted_length, quest_part_start_index,  quest_part_end_index)
  if entity_span != [0]*question_splitted_length:
   entity_span_with_successive_ones = 1
   entity_span_start_index = entity_span.index(1)
   entity_span_end_index = entity_span_start_index + count_successive_ones-1
  else:
   Entity = difflib.get_close_matches(entity_label, question_parts, 1)
   if Entity != []:
    entity_span_start_index = start_indexes[Entity[0]]
    entity_span_end_index = end_indexes[Entity[0]]
   else:
    entity_span_start_index = question_splitted_length-2
    entity_span_end_index = question_splitted_length-1

  return entity_span, entity_span_with_successive_ones, entity_span_start_index, entity_span_end_index

# %% [markdown]
# **The entity_span_encoded function takes as arguments the list of all questions of the given SimpleQuestions dataset (training or validation), the list of all entity labels of the SimpleQuestions dataset (training or validation) and returns the list of entity spans, as well as the lists of start and end position indices for each entity label for all questions. It is worth noting that this function counts the number of questions whose entity span consists of 0 and 1, where the ones are contiguous.**

# %%
#Create entity span by create an list which consists of zeros and ones. By checking in which part for each question the correspoding entity
#exists and in these indexes of the span to replace with ones.
#This is applied for each one of the train and validation questions
def entity_span_encoded(question_column_dataset, entity_label_column_dataset):
  entity_spans = []
  span_start_index = []
  span_end_index = []
  count_spans_with_successive_ones = 0
  for q in range(len(question_column_dataset)):
      quest = question_column_dataset[q].lower().split()
      quest_splitted_length  = len(quest)
      ent_label = entity_label_column_dataset[q].lower()
      s = ent_label.split()
      entity_label_splitted_length = len(s)
      Quests_Parts, Quest_Parts_Start, Quest_Parts_End = create_question_parts(quest, entity_label_splitted_length)
      entity_span, span_with_successive_ones, entity_span_start_index, entity_span_end_index = find_start_and_end_index(ent_label, entity_label_splitted_length,  Quests_Parts, quest_splitted_length, Quest_Parts_Start, Quest_Parts_End)
      entity_spans.append(entity_span)
      span_start_index.append(entity_span_start_index)
      span_end_index.append(entity_span_end_index)
      if span_with_successive_ones == 1:#Boolean variable
        count_spans_with_successive_ones += 1
  return entity_spans, span_start_index, span_end_index

train_span, train_entity_span_encoded_start_indexes, train_entity_span_encoded_end_indexes = entity_span_encoded(train_questions, train_entity_labels)
validation_span, validation_entity_span_encoded_start_indexes, validation_entity_span_encoded_end_indexes = entity_span_encoded(validation_questions, validation_entity_labels)
print(train_span[13174])
print(train_questions[13174])
print(train_entity_labels[13174])
print(train_span[2])
print(train_questions[2])
print(train_entity_labels[2])
print(validation_span[3])
print(validation_questions[3])
print(validation_entity_labels[3])
print(train_span[230], train_questions[230], train_entity_labels[230])
# Out:
# [0, 0, 0, 0, 1, 1]
# Which film is a short film
# short film
# [0, 0, 0, 0, 0, 0, 0]
# who produced the film rough house rosie
# Q7370831
# [0, 0, 1, 1, 1, 0]
# What was Seymour Parker Gilbert profession
# Seymour Parker Gilbert
# [0, 0, 1, 1, 0, 0] Where did kurt bolender pass away Kurt Bolender

# %% [markdown]
# **Loading of the Transformers BERT tokenizer BertTokenizerFast.**

# %%
tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased')

# %% [markdown]
# **Creation of a custom dataset for the SimpleQuestions dataset (either for the dataset with only answerable over wikidata questions or for the corresponding dataset including answerable and non-answerable over wikidata questions) through a python class, where its questions are encoded through BertTokenizerFast method encode\_plus(). This custom dataset includes the entity span indexes (start, end), the relation indexes, the questions, the ids and the attention mask occurred from encoding of questions.**
#
# **Also since the span start and end correspond to actual words, but here I use the fast version of BERT tokenizer BertTokenizerFast, i need to locate the corresponding start and end tokens in the BERT tokenized question for each entity.**
#
# **Also in order to create this custom dataset i used the lists of questions, relation, entity span start, entity span end indexes, the maximum question length of all SimpleQuestions training and validation dataset questions.**

# %%
g = torch.Generator()
print(g.device)
# Out:
# cpu

# %%
class BertQuestionAnsweringDataset:
  def __init__(self, questions, tokenizer, entity_starts, entity_ends, relation_indexes, length, generator, shuffle=True):
        self.questions = questions
        self.max_length = length
        self.tokenizer = tokenizer
        self.relation_indexes = relation_indexes
        self.g = generator
        self.shuffle = shuffle
        ids = []
        masks = []
        start_ent = []
        end_ent = []
        # Encode questions
        for question in range(len(self.questions)):
          encoding = self.tokenizer.encode_plus(
             text = self.questions[question],
             max_length=self.max_length,
             truncation=True,
             pad_to_max_length=True,
             return_attention_mask=True,
             padding='max_length',
             add_special_tokens=False
          )
          Question = self.questions[question].split()
          # Locate the corresponding start in the BERT tokenized question
          start_token = tokenizer.encode_plus(
            text = Question[entity_starts[question]],
            return_attention_mask=True,
            add_special_tokens=False
        )
          # Locate the corresponding end in the BERT tokenized question
          end_token = tokenizer.encode_plus(
            text = Question[entity_ends[question]],
            return_attention_mask=True,
            add_special_tokens=False
        )
          ids.append(encoding['input_ids'])
          masks.append(encoding['attention_mask'])
          start_ent.append(encoding['input_ids'].index(start_token['input_ids'][0]))
          end_ent.append(encoding['input_ids'].index(end_token['input_ids'][-1]))
        self.input_ids = ids
        self.attention_masks = masks
        self.entity_start_indexes = start_ent
        self.entity_end_indexes = end_ent

  def __len__(self):
        return len(self.questions)

  def __getitem__(self, idx):
        return { 'input_ids': torch.tensor(self.input_ids[idx]),
                'attention_mask':  torch.tensor(self.attention_masks[idx]),
                'relation_indexes': torch.tensor(self.relation_indexes[idx]),
                'entity_start': torch.tensor(self.entity_start_indexes[idx], dtype = torch.long),
                'entity_end': torch.tensor(self.entity_end_indexes[idx], dtype = torch.long)
               }

  def set_epoch(self, epoch):
      self.epoch = epoch
      if self.shuffle:
         self.g.manual_seed(123456789 + self.epoch)

# %% [markdown]
# **In the above custom dataset class i reseed the workers using worker\_init\_fn() to preserve reproducibility through by creating the following function seed\_worker.**

# %%
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# %% [markdown]
# **Creation of the dataloader through the created custom dataset from pytorch for the training and validation dataset of SimpleQuestions dataset. The batch size is equal to 32.**

# %%
#span_encoded is reffering to the 2nd way of finding entity start and entity end indexes, i.e entity span encoded with 0 and 1.
print(len(train_questions), len(train_entity_span_encoded_start_indexes), len(train_entity_span_encoded_end_indexes), len(train_relations_index))
train_span_encoded_bert_dataset = BertQuestionAnsweringDataset(train_questions, tokenizer, train_entity_span_encoded_start_indexes, train_entity_span_encoded_end_indexes, train_relations_index, max(q_lengths), g)
valid_span_encoded_bert_dataset = BertQuestionAnsweringDataset(validation_questions, tokenizer ,validation_entity_span_encoded_start_indexes, validation_entity_span_encoded_end_indexes, validation_relations_index, max(q_lengths), g)
train_dataloader_span_encoded = torch.utils.data.DataLoader(train_span_encoded_bert_dataset, batch_size=32, num_workers = 0, worker_init_fn=seed_worker, shuffle=True, generator = train_span_encoded_bert_dataset.g)
val_dataloader_span_encoded = torch.utils.data.DataLoader(valid_span_encoded_bert_dataset, batch_size=32, num_workers = 0, worker_init_fn=seed_worker, shuffle=True, generator = valid_span_encoded_bert_dataset.g)
# Out:
# 34373 34373 34373 34373

# %% [markdown]
# **Function that contributes to the preservation of the reproducibility.**

# %%
#To preserve reproducibility
SEED = 42
def set_seed(SEED):
 random.seed(SEED)# Set python seed for custom operators.
 torch.manual_seed(SEED)
 np.random.seed(SEED)
 torch.cuda.manual_seed_all(SEED)
 torch.backends.cudnn.benchmark = False
 torch.backends.cudnn.deterministic = True

# %% [markdown]
# **Through the create\_file function, is created a file in .pt, in which the parameters for each model are stored. This function takes as an argument a name for the folder where the model will be saved (e.g. "drive/MyDrive/") and a name for the name of the file where each model is saved (e.g. "relation\_prediction.pt").**

# %%
def create_file(model_dir, model_save_name):
 if not os.path.exists(model_dir):
    os.makedirs(model_dir)
 model_save_path = os.path.join(model_dir, model_save_name)
 return model_save_path

# %% [markdown]
# ****Construction and initialization of the neural network for the prediction of the relation for each question.****

# %%
class BertRelationsClassifier(nn.Module):
  def __init__(self, activation, dropout_prob, rel_vocab_len):
    super(BertRelationsClassifier, self).__init__()
    activations = {
        "ELU" : nn.ELU,
        "LeakyReLU"    : nn.LeakyReLU,
        "Softplus"     : nn.Softplus,
        "Tanhshrink"     : nn.Tanhshrink
 }
    self.bert_model = BertModel.from_pretrained('bert-base-uncased')
    self.rel_vocab_len = rel_vocab_len
    self.fc = nn.Linear(768, self.rel_vocab_len)
    self.activation_type = activation
    self.dropout_probability = dropout_prob
    self.activation = activations[self.activation_type]()
    self.dropout = nn.Dropout(self.dropout_probability)
    self.softmax = nn.Softmax(dim=1)

  def forward(self, input_ids, attention_mask):
        out = self.bert_model(input_ids, attention_mask)
        out = self.fc(out[1])#CLS token-pooled output
        out = self.activation(out)
        out = self.dropout(out)
        out = self.softmax(out)
        return out

# %% [markdown]
# **Through the function named relation_prediction_function the best possible parameters for the best possible prediction of the relation are found. This function has as arguments the training dataloader, the validation dataloader, the number of epochs, the optimizer, the scheduler, the learning rate, the relation prediction neural network model, the loss function and the dropout probability value.**
#
# **This function returns the best possible model, the list including numbers from 0 to number of training epochs-1, the lists including the values of training losses and validation losses for all epochs respectively and the largest value of f1.**
#
# **The length of the relation vocabulary in the case of training and validating the full SimpleQuestions dataset is equal to 129 and the length of the relation vocabulary for the case of training and validating the SimpleQuestions subset that includes only questions that are answerable over wikidata is equal to 125.
# So the predicted relation index as a number must be either between 0 and 128 or between 0 and 124, where this number correspond to the position of the unique relation ids in the corresponding relation vocabulary.**

# %%
def relation_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, lr, dropout_prob):
 list_loss_train = []
 list_epochs = []
 list_loss = []
 the_last_f1_score = 0
 patience = 3
 max_f1 = -1
 trigger_times = 0
 for epoch in range(epochs):
   train_dataset.set_epoch(epoch)
   valid_dataset.set_epoch(epoch)
   model.train()
   batch_losses = []
   for batch in train_dataloader:
    ids = batch['input_ids'].to(device)
    attention_masks = batch['attention_mask'].to(device)
    relation_indexes = batch['relation_indexes'].to(device)
    y_pred = model(ids, attention_masks)
    loss = loss_func(y_pred.cpu(),relation_indexes.cpu())
    batch_losses.append(loss.detach().numpy())
    #Delete previously stored gradients
    optimizer.zero_grad()

    #Perform backpropagation starting from the loss calculated in this epoch
    loss.backward()
    nn.utils.clip_grad_norm_(model.parameters(), 0.7)
    #Update model's weights based on the gradients calculated during backprop
    optimizer.step()
    scheduler.step()
   print(f"Epoch {epoch:3}: Train Loss = {sum(batch_losses)/len(train_dataloader):.5f}")
   list_loss_train.append(sum(batch_losses)/len(train_dataloader))
   with torch.no_grad():
     model.eval()
     F1 = []
     precision = []
     recall = []
     accuracy = []
     batch_losses_val = []
     for batch in val_dataloader:
       ids = batch['input_ids'].to(device)
       attention_masks = batch['attention_mask'].to(device)
       relation_indexes = batch['relation_indexes'].to(device)
       y_predict = model(ids, attention_masks)
       val_loss = loss_func(y_predict.cpu(),relation_indexes.cpu())
       batch_losses_val.append(val_loss)
       y_pr = torch.argmax(y_predict, dim=1).squeeze()
       Y_p = y_pr.tolist()
       y_val = relation_indexes.tolist()
       F1.append(f1_score(y_val, Y_p, average = 'micro'))
       precision.append(precision_score(y_val, Y_p, average = 'micro'))
       recall.append(recall_score(y_val, Y_p, average = 'micro'))
       accuracy.append(accuracy_score(y_val,Y_p))
     Valid_f1 = sum(F1)/len(val_dataloader)
     Valid_accuracy = sum(accuracy)/len(val_dataloader)
     print(f"Epoch {epoch:3}: Valid Loss = {sum(batch_losses_val)/len(val_dataloader):.5f}")
     print(f"Epoch {epoch:3}: Valid f1_score = {Valid_f1:.5f}")
     print(f"Epoch {epoch:3}: Valid Acurracy = {Valid_accuracy:.5f}")
     print(f"Epoch {epoch:3}: Valid Recall score = {sum(recall)/len(val_dataloader):.5f}")
     print(f"Epoch {epoch:3}: Valid Precision score = {sum(precision)/len(val_dataloader):.5f}")
     list_loss.append(sum(batch_losses_val)/len(val_dataloader))
     list_epochs.append(epoch)
     if Valid_f1 > max_f1:
       max_f1 = Valid_f1
       best_model = model
       print('The current f1 score:', Valid_f1)
     if Valid_f1 < the_last_f1_score:
       trigger_times += 1
       print('trigger times:', trigger_times)
       if trigger_times >= patience:
         print('Early stopping!\nStart to test process.')
         break;
     the_last_f1_score = Valid_f1
 return max_f1, list_loss_train, list_loss, list_epochs, best_model

# %% [markdown]
# **The function named get_relation_results finds results for the neural networks concerning the relation index and the entity span indexes (start,end). These functions have as arguments the corresponding training dataloader, the corresponding validation dataloader, the number of epochs ,the optimizer, the scheduler get_linear_schedule_with_warmup, the corresponding relation prediction neural network model, the loss function, the learning rate and the SEED number.**
#
# **This function returns the list of training losses, the list of validation losses, and the list of how many epochs each model with each activation function needs to be fully trained.**

# %%
learning_rate  = 2e-5
dropout_prob = 0.3
epochs = 20
list_relation_training_losses = []
list_relation_validation_losses = []
list_relation_epochs = []
loss_func = nn.CrossEntropyLoss()
optimizer_name = "Adam"
def get_relation_results(activation, rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_dataset, valid_dataset, train_dataloader, val_dataloader, SEED):
 set_seed(SEED)
 model = BertRelationsClassifier(activation, dropout_prob, rel_vocab_length).to(device)
 print(model)
 loss_func = loss_func.to(device)
 optimizer = getattr(torch.optim, optimizer_name)(model.parameters(), lr=learning_rate)
 scheduler = get_linear_schedule_with_warmup(optimizer, 0, len(train_dataloader)*epochs)
 f1, list_loss_train, list_loss_valid, list_epochs, best_relation_model = relation_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, learning_rate, dropout_prob)
 print(f1)
 torch.save(best_relation_model.state_dict(), create_file(f"drive/MyDrive/Relation_indexes_models_best_parameters/All_Questions/{activation}",f"relation_prediction_span_encoded_not_ignoring_questions_{activation}.pt") )
 print(f"The best parameters are saved for the activation function: {activation}")
 return list_loss_train, list_loss_valid, list_epochs

# %%
list_relation_loss_train_leakyrelu, list_relation_loss_valid_leakyrelu, list_epochs_leakyrelu = get_relation_results("LeakyReLU", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_span_encoded_bert_dataset, valid_span_encoded_bert_dataset, train_dataloader_span_encoded, val_dataloader_span_encoded, SEED)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=129, bias=True)
#   (activation): LeakyReLU(negative_slope=0.01)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.58177
# Epoch   0: Valid Loss = 4.28928
# Epoch   0: Valid f1_score = 0.61370
# Epoch   0: Valid Acurracy = 0.61370
# Epoch   0: Valid Recall score = 0.61370
# Epoch   0: Valid Precision score = 0.61370
# The current f1 score: 0.61369825708061
# Epoch   1: Train Loss = 4.38843
# Epoch   1: Valid Loss = 4.14519
# Epoch   1: Valid f1_score = 0.76185
# Epoch   1: Valid Acurracy = 0.76185
# Epoch   1: Valid Recall score = 0.76185
# Epoch   1: Valid Precision score = 0.76185
# The current f1 score: 0.7618464052287581
# Epoch   2: Train Loss = 4.31823
# Epoch   2: Valid Loss = 4.08194
# Epoch   2: Valid f1_score = 0.82598
# Epoch   2: Valid Acurracy = 0.82598
# Epoch   2: Valid Recall score = 0.82598
# Epoch   2: Valid Precision score = 0.82598
# The current f1 score: 0.8259803921568627
# Epoch   3: Train Loss = 4.27763
# Epoch   3: Valid Loss = 4.02405
# Epoch   3: Valid f1_score = 0.87949
# Epoch   3: Valid Acurracy = 0.87949
# Epoch   3: Valid Recall score = 0.87949
# Epoch   3: Valid Precision score = 0.87949
# The current f1 score: 0.8794934640522876
# Epoch   4: Train Loss = 4.24278
# Epoch   4: Valid Loss = 3.99530
# Epoch   4: Valid f1_score = 0.90237
# Epoch   4: Valid Acurracy = 0.90237
# Epoch   4: Valid Recall score = 0.90237
# Epoch   4: Valid Precision score = 0.90237
# The current f1 score: 0.9023692810457516
# Epoch   5: Train Loss = 4.23357
# Epoch   5: Valid Loss = 3.98529
# Epoch   5: Valid f1_score = 0.91156
# Epoch   5: Valid Acurracy = 0.91156
# Epoch   5: Valid Recall score = 0.91156
# Epoch   5: Valid Precision score = 0.91156
# The current f1 score: 0.9115604575163399
# Epoch   6: Train Loss = 4.22214
# Epoch   6: Valid Loss = 3.96573
# Epoch   6: Valid f1_score = 0.92674
# Epoch   6: Valid Acurracy = 0.92674
# Epoch   6: Valid Recall score = 0.92674
# Epoch   6: Valid Precision score = 0.92674
# The current f1 score: 0.9267429193899781
# Epoch   7: Train Loss = 4.21742
# Epoch   7: Valid Loss = 3.96087
# Epoch   7: Valid f1_score = 0.92790
# Epoch   7: Valid Acurracy = 0.92790
# Epoch   7: Valid Recall score = 0.92790
# Epoch   7: Valid Precision score = 0.92790
# The current f1 score: 0.9279003267973857
# Epoch   8: Train Loss = 4.21168
# Epoch   8: Valid Loss = 3.95159
# Epoch   8: Valid f1_score = 0.93423
# Epoch   8: Valid Acurracy = 0.93423
# Epoch   8: Valid Recall score = 0.93423
# Epoch   8: Valid Precision score = 0.93423
# The current f1 score: 0.9342320261437909
# Epoch   9: Train Loss = 4.20859
# Epoch   9: Valid Loss = 3.94781
# Epoch   9: Valid f1_score = 0.93668
# Epoch   9: Valid Acurracy = 0.93668
# Epoch   9: Valid Recall score = 0.93668
# Epoch   9: Valid Precision score = 0.93668
# The current f1 score: 0.9366830065359477
# Epoch  10: Train Loss = 4.20676
# Epoch  10: Valid Loss = 3.94336
# Epoch  10: Valid f1_score = 0.94158
# Epoch  10: Valid Acurracy = 0.94158
# Epoch  10: Valid Recall score = 0.94158
# Epoch  10: Valid Precision score = 0.94158
# The current f1 score: 0.9415849673202614
# Epoch  11: Train Loss = 4.20326
# Epoch  11: Valid Loss = 3.94012
# Epoch  11: Valid f1_score = 0.94383
# Epoch  11: Valid Acurracy = 0.94383
# Epoch  11: Valid Recall score = 0.94383
# Epoch  11: Valid Precision score = 0.94383
# The current f1 score: 0.9438316993464052
# Epoch  12: Train Loss = 4.19756
# Epoch  12: Valid Loss = 3.93696
# Epoch  12: Valid f1_score = 0.94710
# Epoch  12: Valid Acurracy = 0.94710
# Epoch  12: Valid Recall score = 0.94710
# Epoch  12: Valid Precision score = 0.94710
# The current f1 score: 0.9470996732026143
# Epoch  13: Train Loss = 4.20097
# Epoch  13: Valid Loss = 3.93641
# Epoch  13: Valid f1_score = 0.94594
# Epoch  13: Valid Acurracy = 0.94594
# Epoch  13: Valid Recall score = 0.94594
# Epoch  13: Valid Precision score = 0.94594
# trigger times: 1
# Epoch  14: Train Loss = 4.19494
# Epoch  14: Valid Loss = 3.93364
# Epoch  14: Valid f1_score = 0.94894
# Epoch  14: Valid Acurracy = 0.94894
# Epoch  14: Valid Recall score = 0.94894
# Epoch  14: Valid Precision score = 0.94894
# The current f1 score: 0.948937908496732
# Epoch  15: Train Loss = 4.19588
# Epoch  15: Valid Loss = 3.93304
# Epoch  15: Valid f1_score = 0.95118
# Epoch  15: Valid Acurracy = 0.95118
# Epoch  15: Valid Recall score = 0.95118
# Epoch  15: Valid Precision score = 0.95118
# The current f1 score: 0.9511846405228758
# Epoch  16: Train Loss = 4.19288
# Epoch  16: Valid Loss = 3.93275
# Epoch  16: Valid f1_score = 0.94982
# Epoch  16: Valid Acurracy = 0.94982
# Epoch  16: Valid Recall score = 0.94982
# Epoch  16: Valid Precision score = 0.94982
# trigger times: 2
# Epoch  17: Train Loss = 4.19166
# Epoch  17: Valid Loss = 3.92972
# Epoch  17: Valid f1_score = 0.95241
# Epoch  17: Valid Acurracy = 0.95241
# Epoch  17: Valid Recall score = 0.95241
# Epoch  17: Valid Precision score = 0.95241
# The current f1 score: 0.9524101307189542
# Epoch  18: Train Loss = 4.19091
# Epoch  18: Valid Loss = 3.92996
# Epoch  18: Valid f1_score = 0.95159
# Epoch  18: Valid Acurracy = 0.95159
# Epoch  18: Valid Recall score = 0.95159
# Epoch  18: Valid Precision score = 0.95159
# trigger times: 3
# Early stopping!
# Start to test process.
# 0.9524101307189542
# The best parameters are saved for the activation function: LeakyReLU

# %%
list_relation_loss_train_tanhshrink, list_relation_loss_valid_tanhshrink, list_epochs_tanhshrink = get_relation_results("Tanhshrink", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_span_encoded_bert_dataset, valid_span_encoded_bert_dataset, train_dataloader_span_encoded, val_dataloader_span_encoded, SEED)
# Out:
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=129, bias=True)
#   (activation): Tanhshrink()
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.62767
# Epoch   0: Valid Loss = 4.35202
# Epoch   0: Valid f1_score = 0.53853
# Epoch   0: Valid Acurracy = 0.53853
# Epoch   0: Valid Recall score = 0.53853
# Epoch   0: Valid Precision score = 0.53853
# The current f1 score: 0.5385348583877996
# Epoch   1: Train Loss = 4.45339
# Epoch   1: Valid Loss = 4.22871
# Epoch   1: Valid f1_score = 0.67320
# Epoch   1: Valid Acurracy = 0.67320
# Epoch   1: Valid Recall score = 0.67320
# Epoch   1: Valid Precision score = 0.67320
# The current f1 score: 0.673202614379085
# Epoch   2: Train Loss = 4.35552
# Epoch   2: Valid Loss = 4.11948
# Epoch   2: Valid f1_score = 0.78418
# Epoch   2: Valid Acurracy = 0.78418
# Epoch   2: Valid Recall score = 0.78418
# Epoch   2: Valid Precision score = 0.78418
# The current f1 score: 0.7841775599128541
# Epoch   3: Train Loss = 4.30754
# Epoch   3: Valid Loss = 4.05771
# Epoch   3: Valid f1_score = 0.84681
# Epoch   3: Valid Acurracy = 0.84681
# Epoch   3: Valid Recall score = 0.84681
# Epoch   3: Valid Precision score = 0.84681
# The current f1 score: 0.8468137254901961
# Epoch   4: Train Loss = 4.26189
# Epoch   4: Valid Loss = 4.01586
# Epoch   4: Valid f1_score = 0.88583
# Epoch   4: Valid Acurracy = 0.88583
# Epoch   4: Valid Recall score = 0.88583
# Epoch   4: Valid Precision score = 0.88583
# The current f1 score: 0.8858251633986928
# Epoch   5: Train Loss = 4.24432
# Epoch   5: Valid Loss = 3.99164
# Epoch   5: Valid f1_score = 0.90829
# Epoch   5: Valid Acurracy = 0.90829
# Epoch   5: Valid Recall score = 0.90829
# Epoch   5: Valid Precision score = 0.90829
# The current f1 score: 0.9082924836601307
# Epoch   6: Train Loss = 4.22957
# Epoch   6: Valid Loss = 3.98157
# Epoch   6: Valid f1_score = 0.91020
# Epoch   6: Valid Acurracy = 0.91020
# Epoch   6: Valid Recall score = 0.91020
# Epoch   6: Valid Precision score = 0.91020
# The current f1 score: 0.9101988017429193
# Epoch   7: Train Loss = 4.22612
# Epoch   7: Valid Loss = 3.97392
# Epoch   7: Valid f1_score = 0.91360
# Epoch   7: Valid Acurracy = 0.91360
# Epoch   7: Valid Recall score = 0.91360
# Epoch   7: Valid Precision score = 0.91360
# The current f1 score: 0.9136029411764706
# Epoch   8: Train Loss = 4.21755
# Epoch   8: Valid Loss = 3.96153
# Epoch   8: Valid f1_score = 0.92994
# Epoch   8: Valid Acurracy = 0.92994
# Epoch   8: Valid Recall score = 0.92994
# Epoch   8: Valid Precision score = 0.92994
# The current f1 score: 0.9299428104575164
# Epoch   9: Train Loss = 4.21032
# Epoch   9: Valid Loss = 3.95236
# Epoch   9: Valid f1_score = 0.93505
# Epoch   9: Valid Acurracy = 0.93505
# Epoch   9: Valid Recall score = 0.93505
# Epoch   9: Valid Precision score = 0.93505
# The current f1 score: 0.9350490196078431
# Epoch  10: Train Loss = 4.20783
# Epoch  10: Valid Loss = 3.94748
# Epoch  10: Valid f1_score = 0.93934
# Epoch  10: Valid Acurracy = 0.93934
# Epoch  10: Valid Recall score = 0.93934
# Epoch  10: Valid Precision score = 0.93934
# The current f1 score: 0.9393382352941176
# Epoch  11: Train Loss = 4.20396
# Epoch  11: Valid Loss = 3.94252
# Epoch  11: Valid f1_score = 0.94485
# Epoch  11: Valid Acurracy = 0.94485
# Epoch  11: Valid Recall score = 0.94485
# Epoch  11: Valid Precision score = 0.94485
# The current f1 score: 0.9448529411764706
# Epoch  12: Train Loss = 4.19707
# Epoch  12: Valid Loss = 3.94065
# Epoch  12: Valid f1_score = 0.94404
# Epoch  12: Valid Acurracy = 0.94404
# Epoch  12: Valid Recall score = 0.94404
# Epoch  12: Valid Precision score = 0.94404
# trigger times: 1
# Epoch  13: Train Loss = 4.19990
# Epoch  13: Valid Loss = 3.93925
# Epoch  13: Valid f1_score = 0.94465
# Epoch  13: Valid Acurracy = 0.94465
# Epoch  13: Valid Recall score = 0.94465
# Epoch  13: Valid Precision score = 0.94465
# Epoch  14: Train Loss = 4.19207
# Epoch  14: Valid Loss = 3.93423
# Epoch  14: Valid f1_score = 0.95200
# Epoch  14: Valid Acurracy = 0.95200
# Epoch  14: Valid Recall score = 0.95200
# Epoch  14: Valid Precision score = 0.95200
# The current f1 score: 0.952001633986928
# Epoch  15: Train Loss = 4.19337
# Epoch  15: Valid Loss = 3.93160
# Epoch  15: Valid f1_score = 0.95323
# Epoch  15: Valid Acurracy = 0.95323
# Epoch  15: Valid Recall score = 0.95323
# Epoch  15: Valid Precision score = 0.95323
# The current f1 score: 0.9532271241830066
# Epoch  16: Train Loss = 4.19045
# Epoch  16: Valid Loss = 3.93265
# Epoch  16: Valid f1_score = 0.95261
# Epoch  16: Valid Acurracy = 0.95261
# Epoch  16: Valid Recall score = 0.95261
# Epoch  16: Valid Precision score = 0.95261
# trigger times: 2
# Epoch  17: Train Loss = 4.18869
# Epoch  17: Valid Loss = 3.93106
# Epoch  17: Valid f1_score = 0.95221
# Epoch  17: Valid Acurracy = 0.95221
# Epoch  17: Valid Recall score = 0.95221
# Epoch  17: Valid Precision score = 0.95221
# trigger times: 3
# Early stopping!
# Start to test process.
# 0.9532271241830066
# The best parameters are saved for the activation function: Tanhshrink

# %%
list_relation_loss_train_elu, list_relation_loss_valid_elu, list_epochs_elu = get_relation_results("ELU", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_span_encoded_bert_dataset, valid_span_encoded_bert_dataset, train_dataloader_span_encoded, val_dataloader_span_encoded, SEED)
# Out:
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=129, bias=True)
#   (activation): ELU(alpha=1.0)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.55268
# Epoch   0: Valid Loss = 4.26572
# Epoch   0: Valid f1_score = 0.64372
# Epoch   0: Valid Acurracy = 0.64372
# Epoch   0: Valid Recall score = 0.64372
# Epoch   0: Valid Precision score = 0.64372
# The current f1 score: 0.6437227668845316
# Epoch   1: Train Loss = 4.36453
# Epoch   1: Valid Loss = 4.11020
# Epoch   1: Valid f1_score = 0.81924
# Epoch   1: Valid Acurracy = 0.81924
# Epoch   1: Valid Recall score = 0.81924
# Epoch   1: Valid Precision score = 0.81924
# The current f1 score: 0.8192401960784313
# Epoch   2: Train Loss = 4.28451
# Epoch   2: Valid Loss = 4.04692
# Epoch   2: Valid f1_score = 0.85968
# Epoch   2: Valid Acurracy = 0.85968
# Epoch   2: Valid Recall score = 0.85968
# Epoch   2: Valid Precision score = 0.85968
# The current f1 score: 0.8596813725490197
# Epoch   3: Train Loss = 4.25876
# Epoch   3: Valid Loss = 4.00520
# Epoch   3: Valid f1_score = 0.89992
# Epoch   3: Valid Acurracy = 0.89992
# Epoch   3: Valid Recall score = 0.89992
# Epoch   3: Valid Precision score = 0.89992
# The current f1 score: 0.8999183006535948
# Epoch   4: Train Loss = 4.22944
# Epoch   4: Valid Loss = 3.98377
# Epoch   4: Valid f1_score = 0.91258
# Epoch   4: Valid Acurracy = 0.91258
# Epoch   4: Valid Recall score = 0.91258
# Epoch   4: Valid Precision score = 0.91258
# The current f1 score: 0.9125816993464052
# Epoch   5: Train Loss = 4.22215
# Epoch   5: Valid Loss = 3.96231
# Epoch   5: Valid f1_score = 0.93219
# Epoch   5: Valid Acurracy = 0.93219
# Epoch   5: Valid Recall score = 0.93219
# Epoch   5: Valid Precision score = 0.93219
# The current f1 score: 0.9321895424836601
# Epoch   6: Train Loss = 4.21261
# Epoch   6: Valid Loss = 3.96158
# Epoch   6: Valid f1_score = 0.92674
# Epoch   6: Valid Acurracy = 0.92674
# Epoch   6: Valid Recall score = 0.92674
# Epoch   6: Valid Precision score = 0.92674
# trigger times: 1
# Epoch   7: Train Loss = 4.21015
# Epoch   7: Valid Loss = 3.95143
# Epoch   7: Valid f1_score = 0.93546
# Epoch   7: Valid Acurracy = 0.93546
# Epoch   7: Valid Recall score = 0.93546
# Epoch   7: Valid Precision score = 0.93546
# The current f1 score: 0.9354575163398693
# Epoch   8: Train Loss = 4.20633
# Epoch   8: Valid Loss = 3.94560
# Epoch   8: Valid f1_score = 0.94158
# Epoch   8: Valid Acurracy = 0.94158
# Epoch   8: Valid Recall score = 0.94158
# Epoch   8: Valid Precision score = 0.94158
# The current f1 score: 0.9415849673202614
# Epoch   9: Train Loss = 4.20236
# Epoch   9: Valid Loss = 3.93966
# Epoch   9: Valid f1_score = 0.94608
# Epoch   9: Valid Acurracy = 0.94608
# Epoch   9: Valid Recall score = 0.94608
# Epoch   9: Valid Precision score = 0.94608
# The current f1 score: 0.946078431372549
# Epoch  10: Train Loss = 4.19950
# Epoch  10: Valid Loss = 3.93569
# Epoch  10: Valid f1_score = 0.95037
# Epoch  10: Valid Acurracy = 0.95037
# Epoch  10: Valid Recall score = 0.95037
# Epoch  10: Valid Precision score = 0.95037
# The current f1 score: 0.9503676470588235
# Epoch  11: Train Loss = 4.19668
# Epoch  11: Valid Loss = 3.93236
# Epoch  11: Valid f1_score = 0.95282
# Epoch  11: Valid Acurracy = 0.95282
# Epoch  11: Valid Recall score = 0.95282
# Epoch  11: Valid Precision score = 0.95282
# The current f1 score: 0.9528186274509803
# Epoch  12: Train Loss = 4.19129
# Epoch  12: Valid Loss = 3.93227
# Epoch  12: Valid f1_score = 0.95261
# Epoch  12: Valid Acurracy = 0.95261
# Epoch  12: Valid Recall score = 0.95261
# Epoch  12: Valid Precision score = 0.95261
# trigger times: 2
# Epoch  13: Train Loss = 4.19475
# Epoch  13: Valid Loss = 3.93031
# Epoch  13: Valid f1_score = 0.95364
# Epoch  13: Valid Acurracy = 0.95364
# Epoch  13: Valid Recall score = 0.95364
# Epoch  13: Valid Precision score = 0.95364
# The current f1 score: 0.9536356209150327
# Epoch  14: Train Loss = 4.18741
# Epoch  14: Valid Loss = 3.92920
# Epoch  14: Valid f1_score = 0.95466
# Epoch  14: Valid Acurracy = 0.95466
# Epoch  14: Valid Recall score = 0.95466
# Epoch  14: Valid Precision score = 0.95466
# The current f1 score: 0.9546568627450981
# Epoch  15: Train Loss = 4.18848
# Epoch  15: Valid Loss = 3.92690
# Epoch  15: Valid f1_score = 0.95690
# Epoch  15: Valid Acurracy = 0.95690
# Epoch  15: Valid Recall score = 0.95690
# Epoch  15: Valid Precision score = 0.95690
# The current f1 score: 0.9569035947712419
# Epoch  16: Train Loss = 4.18573
# Epoch  16: Valid Loss = 3.92565
# Epoch  16: Valid f1_score = 0.95895
# Epoch  16: Valid Acurracy = 0.95895
# Epoch  16: Valid Recall score = 0.95895
# Epoch  16: Valid Precision score = 0.95895
# The current f1 score: 0.9589460784313726
# Epoch  17: Train Loss = 4.18406
# Epoch  17: Valid Loss = 3.92409
# Epoch  17: Valid f1_score = 0.96058
# Epoch  17: Valid Acurracy = 0.96058
# Epoch  17: Valid Recall score = 0.96058
# Epoch  17: Valid Precision score = 0.96058
# The current f1 score: 0.9605800653594772
# Epoch  18: Train Loss = 4.18348
# Epoch  18: Valid Loss = 3.92403
# Epoch  18: Valid f1_score = 0.96038
# Epoch  18: Valid Acurracy = 0.96038
# Epoch  18: Valid Recall score = 0.96038
# Epoch  18: Valid Precision score = 0.96038
# trigger times: 3
# Early stopping!
# Start to test process.
# 0.9605800653594772
# The best parameters are saved for the activation function: ELU

# %%
list_relation_loss_train_softplus, list_relation_loss_valid_softplus, list_epochs_softplus = get_relation_results("Softplus", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_span_encoded_bert_dataset, valid_span_encoded_bert_dataset, train_dataloader_span_encoded, val_dataloader_span_encoded, SEED)
# Out:
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=129, bias=True)
#   (activation): Softplus(beta=1, threshold=20)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.58354
# Epoch   0: Valid Loss = 4.29041
# Epoch   0: Valid f1_score = 0.61676
# Epoch   0: Valid Acurracy = 0.61676
# Epoch   0: Valid Recall score = 0.61676
# Epoch   0: Valid Precision score = 0.61676
# The current f1 score: 0.616761982570806
# Epoch   1: Train Loss = 4.38090
# Epoch   1: Valid Loss = 4.13784
# Epoch   1: Valid f1_score = 0.77655
# Epoch   1: Valid Acurracy = 0.77655
# Epoch   1: Valid Recall score = 0.77655
# Epoch   1: Valid Precision score = 0.77655
# The current f1 score: 0.7765522875816994
# Epoch   2: Train Loss = 4.30190
# Epoch   2: Valid Loss = 4.06504
# Epoch   2: Valid f1_score = 0.85029
# Epoch   2: Valid Acurracy = 0.85029
# Epoch   2: Valid Recall score = 0.85029
# Epoch   2: Valid Precision score = 0.85029
# The current f1 score: 0.8502859477124183
# Epoch   3: Train Loss = 4.26632
# Epoch   3: Valid Loss = 4.01815
# Epoch   3: Valid f1_score = 0.88644
# Epoch   3: Valid Acurracy = 0.88644
# Epoch   3: Valid Recall score = 0.88644
# Epoch   3: Valid Precision score = 0.88644
# The current f1 score: 0.886437908496732
# Epoch   4: Train Loss = 4.23693
# Epoch   4: Valid Loss = 3.99596
# Epoch   4: Valid f1_score = 0.90952
# Epoch   4: Valid Acurracy = 0.90952
# Epoch   4: Valid Recall score = 0.90952
# Epoch   4: Valid Precision score = 0.90952
# The current f1 score: 0.9095179738562091
# Epoch   5: Train Loss = 4.22899
# Epoch   5: Valid Loss = 3.97717
# Epoch   5: Valid f1_score = 0.92014
# Epoch   5: Valid Acurracy = 0.92014
# Epoch   5: Valid Recall score = 0.92014
# Epoch   5: Valid Precision score = 0.92014
# The current f1 score: 0.9201388888888888
# Epoch   6: Train Loss = 4.22022
# Epoch   6: Valid Loss = 3.96668
# Epoch   6: Valid f1_score = 0.92531
# Epoch   6: Valid Acurracy = 0.92531
# Epoch   6: Valid Recall score = 0.92531
# Epoch   6: Valid Precision score = 0.92531
# The current f1 score: 0.9253131808278866
# Epoch   7: Train Loss = 4.21608
# Epoch   7: Valid Loss = 3.95849
# Epoch   7: Valid f1_score = 0.92994
# Epoch   7: Valid Acurracy = 0.92994
# Epoch   7: Valid Recall score = 0.92994
# Epoch   7: Valid Precision score = 0.92994
# The current f1 score: 0.9299428104575164
# Epoch   8: Train Loss = 4.20850
# Epoch   8: Valid Loss = 3.95223
# Epoch   8: Valid f1_score = 0.93750
# Epoch   8: Valid Acurracy = 0.93750
# Epoch   8: Valid Recall score = 0.93750
# Epoch   8: Valid Precision score = 0.93750
# The current f1 score: 0.9375
# Epoch   9: Train Loss = 4.20482
# Epoch   9: Valid Loss = 3.94753
# Epoch   9: Valid f1_score = 0.93920
# Epoch   9: Valid Acurracy = 0.93920
# Epoch   9: Valid Recall score = 0.93920
# Epoch   9: Valid Precision score = 0.93920
# The current f1 score: 0.9392020697167756
# Epoch  10: Train Loss = 4.20345
# Epoch  10: Valid Loss = 3.94390
# Epoch  10: Valid f1_score = 0.94158
# Epoch  10: Valid Acurracy = 0.94158
# Epoch  10: Valid Recall score = 0.94158
# Epoch  10: Valid Precision score = 0.94158
# The current f1 score: 0.9415849673202614
# Epoch  11: Train Loss = 4.20119
# Epoch  11: Valid Loss = 3.93953
# Epoch  11: Valid f1_score = 0.94751
# Epoch  11: Valid Acurracy = 0.94751
# Epoch  11: Valid Recall score = 0.94751
# Epoch  11: Valid Precision score = 0.94751
# The current f1 score: 0.9475081699346405
# Epoch  12: Train Loss = 4.19525
# Epoch  12: Valid Loss = 3.93629
# Epoch  12: Valid f1_score = 0.94792
# Epoch  12: Valid Acurracy = 0.94792
# Epoch  12: Valid Recall score = 0.94792
# Epoch  12: Valid Precision score = 0.94792
# The current f1 score: 0.9479166666666666
# Epoch  13: Train Loss = 4.19770
# Epoch  13: Valid Loss = 3.93400
# Epoch  13: Valid f1_score = 0.95146
# Epoch  13: Valid Acurracy = 0.95146
# Epoch  13: Valid Recall score = 0.95146
# Epoch  13: Valid Precision score = 0.95146
# The current f1 score: 0.9514569716775598
# Epoch  14: Train Loss = 4.19014
# Epoch  14: Valid Loss = 3.93037
# Epoch  14: Valid f1_score = 0.95466
# Epoch  14: Valid Acurracy = 0.95466
# Epoch  14: Valid Recall score = 0.95466
# Epoch  14: Valid Precision score = 0.95466
# The current f1 score: 0.9546568627450981
# Epoch  15: Train Loss = 4.19183
# Epoch  15: Valid Loss = 3.92838
# Epoch  15: Valid f1_score = 0.95568
# Epoch  15: Valid Acurracy = 0.95568
# Epoch  15: Valid Recall score = 0.95568
# Epoch  15: Valid Precision score = 0.95568
# The current f1 score: 0.9556781045751634
# Epoch  16: Train Loss = 4.18919
# Epoch  16: Valid Loss = 3.93046
# Epoch  16: Valid f1_score = 0.95370
# Epoch  16: Valid Acurracy = 0.95370
# Epoch  16: Valid Recall score = 0.95370
# Epoch  16: Valid Precision score = 0.95370
# trigger times: 1
# Epoch  17: Train Loss = 4.18819
# Epoch  17: Valid Loss = 3.92680
# Epoch  17: Valid f1_score = 0.95650
# Epoch  17: Valid Acurracy = 0.95650
# Epoch  17: Valid Recall score = 0.95650
# Epoch  17: Valid Precision score = 0.95650
# The current f1 score: 0.9564950980392157
# Epoch  18: Train Loss = 4.18711
# Epoch  18: Valid Loss = 3.92614
# Epoch  18: Valid f1_score = 0.95854
# Epoch  18: Valid Acurracy = 0.95854
# Epoch  18: Valid Recall score = 0.95854
# Epoch  18: Valid Precision score = 0.95854
# The current f1 score: 0.9585375816993464
# Epoch  19: Train Loss = 4.18843
# Epoch  19: Valid Loss = 3.92626
# Epoch  19: Valid f1_score = 0.95833
# Epoch  19: Valid Acurracy = 0.95833
# Epoch  19: Valid Recall score = 0.95833
# Epoch  19: Valid Precision score = 0.95833
# trigger times: 2
# 0.9585375816993464
# The best parameters are saved for the activation function: Softplus

# %%
list_relation_training_losses.append(list_relation_loss_train_leakyrelu)
list_relation_validation_losses.append(list_relation_loss_valid_leakyrelu)
list_relation_epochs.append(list_epochs_leakyrelu)
list_relation_training_losses.append(list_relation_loss_train_tanhshrink)
list_relation_validation_losses.append(list_relation_loss_valid_tanhshrink)
list_relation_epochs.append(list_epochs_tanhshrink)
list_relation_training_losses.append(list_relation_loss_train_softplus)
list_relation_validation_losses.append(list_relation_loss_valid_softplus)
list_relation_epochs.append(list_epochs_softplus)
list_relation_training_losses.append(list_relation_loss_train_elu)
list_relation_validation_losses.append(list_relation_loss_valid_elu)
list_relation_epochs.append(list_epochs_elu)

# %% [markdown]
# **Through the function plot_losses the learning curves for losses (relation prediction losses, entity span prediction losses) are plotted.**

# %%
def plot_losses(list_epochs, list_training_losses, list_validation_losses, activations, lr, dropout_prob):
 for activation in range(len(activations)):
  plt.plot(list_epochs[activation], list_training_losses[activation], label = f"{activations[activation]},{lr},{dropout_prob}-Training")
  plt.plot(list_epochs[activation], list_validation_losses[activation], label = f"{activations[activation]},{lr},{dropout_prob}-Validation")
  plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize = 'small')
  plt.xlabel('Number of epochs')
  plt.ylabel('Loss')
  plt.title("loss-score")
  plt.ylim(ymin = 3.5)
activations = ['LeakyReLU','Tanhshrink', 'Softplus','ELU']

# %%
plot_losses(list_relation_epochs, list_relation_training_losses, list_relation_validation_losses, activations, learning_rate, dropout_prob)

# %% [markdown]
# ****Construction and initialization of the neural network for the prediction of the entity span start and entity span end indexes for each question.****

# %%
class BertEntitySpanClassifier(nn.Module):
  def __init__(self, activation, dropout_prob, max_quest_len):
    super(BertEntitySpanClassifier, self).__init__()
    self.bert_model = BertModel.from_pretrained('bert-base-uncased')
# Whether the model returns all hidden-states.
    activations = {
        "ELU" : nn.ELU,
        "LeakyReLU"    : nn.LeakyReLU,
        "Softplus"     : nn.Softplus,
        "Tanhshrink"     : nn.Tanhshrink
 }
    self.activation_type = activation
    self.activation = activations[self.activation_type]()
    self.max_length = max_quest_len
    self.dropout_probability = dropout_prob
    self.start_head = nn.Sequential(
          nn.Linear(768, self.max_length),
          self.activation,
          nn.Dropout(p=self.dropout_probability),
          nn.Flatten(),
          nn.Softmax(dim=1)
    )

    self.end_head = nn.Sequential(
          nn.Linear(768, self.max_length),
          self.activation,
          nn.Dropout(p=self.dropout_probability),
          nn.Flatten(),
          nn.Softmax(dim=1)
    )

  def forward(self, input_ids, att_mask):
    out = self.bert_model(input_ids, att_mask)
    out = out[0]
    out_start = self.start_head(out)
    out_end = self.end_head(out)
    return out_start , out_end

# %% [markdown]
# **Through the function named entity_prediction_function the best possible parameters for the best possible prediction of the entity span are found. This function has as arguments the corresponding training dataloader, the corresponding validation dataloader, the number of epochs, the optimizer, the scheduler, the learning rate, the entity span prediction neural network model, the loss function and the dropout probability value.**
#
# **This function returns the best possible model, the list including numbers from 0 to number of training epochs-1, the lists including the values of training losses and validation losses for all epochs respectively, the largest value of f1 for entity span start and the largest value of f1 for entity span end.**
#
# **The biggest length of a question in words that is observed in SimpleQuestions dataset is equal to 33. Thus these predicted indexes as numbers must be either between 0 and 32, where these numbers correspond to the position of these words in their question for each question.**

# %%
def entity_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, lr, dropout_prob):
 list_loss_train = []
 list_loss = []
 list_epochs = []
 the_last_f1_start_score = 0
 the_last_f1_end_score = 0
 patience = 3
 max_f1_start = -1
 max_f1_end = -1
 trigger_times = 0
 for epoch in range(epochs):
  train_dataset.set_epoch(epoch)
  valid_dataset.set_epoch(epoch)
  model.train()
  batch_losses = []
  for batch in train_dataloader:
   input_ids = batch['input_ids'].to(device)
   attention_masks = batch['attention_mask'].to(device)
   entity_span_start_indexes = batch['entity_start'].to(device)
   entity_span_end_indexes = batch['entity_end'].to(device)
   y_pred_start, y_pred_end = model(input_ids, attention_masks)
   y_pred_start = y_pred_start.squeeze()
   y_pred_end = y_pred_end.squeeze()
   start_preds = torch.argmax(y_pred_start,dim = 1)
   loss = loss_func(y_pred_start.cpu(),entity_span_start_indexes.cpu())+loss_func(y_pred_end.cpu(),entity_span_end_indexes.cpu())
   batch_losses.append(loss.detach().numpy())
    #Delete previously stored gradients
   nn.utils.clip_grad_norm_(model.parameters(), 0.7)
   optimizer.zero_grad()

    #Perform backpropagation starting from the loss calculated in this epoch
   loss.backward()

    #Update model's weights based on the gradients calculated during backprop
   optimizer.step()
   scheduler.step()
  print(f"Epoch {epoch:3}: Train Loss = {sum(batch_losses)/len(train_dataloader):.5f}")
  list_loss_train.append(sum(batch_losses)/len(train_dataloader))
  with torch.no_grad():
    model.eval()
    F1_start = []
    F1_end = []
    accuracy_start = []
    accuracy_end = []
    precision_start = []
    precision_end = []
    recall_start = []
    recall_end = []
    batch_losses_val = []
    for batch in val_dataloader:
      input_ids = batch['input_ids'].to(device)
      attention_masks = batch['attention_mask'].to(device)
      entity_span_start_indexes = batch['entity_start'].to(device)
      entity_span_end_indexes = batch['entity_end'].to(device)
      y_predict_start, y_predict_end = model(input_ids, attention_masks)
      y_predict_start = y_predict_start.squeeze()
      y_predict_end = y_predict_end.squeeze()
      val_loss = loss_func(y_predict_start.cpu(),entity_span_start_indexes.cpu())+loss_func(y_predict_end.cpu(),entity_span_end_indexes.cpu())
      batch_losses_val.append(val_loss)
      y_pr_start = torch.argmax(y_predict_start, dim=1)
      y_pr_end = torch.argmax(y_predict_end, dim=1)
      Y_p_start = y_pr_start.tolist()
      Y_p_end = y_pr_end.tolist()
      y_val_start = entity_span_start_indexes.tolist()
      y_val_end = entity_span_end_indexes.tolist()
      F1_start.append(f1_score(y_val_start, Y_p_start, average = 'micro'))
      F1_end.append(f1_score(y_val_end, Y_p_end, average = 'micro'))
      accuracy_start.append(accuracy_score(y_val_start, Y_p_start))
      accuracy_end.append(accuracy_score(y_val_end, Y_p_end))
      precision_start.append(precision_score(y_val_start, Y_p_start, average = 'micro'))
      precision_end.append(precision_score(y_val_end, Y_p_end, average = 'micro'))
      recall_start.append(recall_score(y_val_start, Y_p_start, average = 'micro'))
      recall_end.append(recall_score(y_val_end, Y_p_end, average = 'micro'))
    Valid_f1_start = sum(F1_start)/len(val_dataloader)
    Valid_f1_end = sum(F1_end)/len(val_dataloader)
    print(f"Epoch {epoch:3}: Valid Loss = {sum(batch_losses_val)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid f1_score for entity start span = {Valid_f1_start:.5f}")
    print(f"Epoch {epoch:3}: Valid Acurracy for entity start span = {sum(accuracy_start)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Recall for entity start span = {sum(recall_start)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Precision for entity start span = {sum(precision_start)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid f1_score for entity end span = {Valid_f1_end:.5f}")
    print(f"Epoch {epoch:3}: Valid Acurracy for entity end span = {sum(accuracy_end)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Recall for entity end span = {sum(recall_end)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Precision for entity end span = {sum(precision_end)/len(val_dataloader):.5f}")
    list_loss.append(sum(batch_losses_val)/len(val_dataloader))
    list_epochs.append(epoch)
    if Valid_f1_start >= max_f1_start and Valid_f1_end >= max_f1_end:
      max_f1_start = Valid_f1_start
      max_f1_end = Valid_f1_end
      best_model = model
      print('The current f1 score for entity start:', Valid_f1_start)
      print('The current f1 score for entity end:', Valid_f1_end)
    if Valid_f1_start < the_last_f1_start_score and Valid_f1_end < the_last_f1_end_score:
      trigger_times += 1
      print('trigger times:', trigger_times)
      if trigger_times >= patience:
        print('Early stopping!\nStart to test process.')
        break;
    the_last_f1_start_score = Valid_f1_start
    the_last_f1_end_score = Valid_f1_end

 return max_f1_start, max_f1_end, list_loss_train, list_loss, list_epochs, best_model

# %% [markdown]
# **The function named get_entity_results finds results for the neural networks concerning the relation index and the entity span indexes (start,end). These functions have as arguments the corresponding training dataloader, the corresponding validation dataloader, the number of epochs ,the optimizer, the scheduler get_linear_schedule_with_warmup, the corresponding entity span prediction neural network model, the loss function, the learning rate and the SEED number.**
#
# **This function returns the list of training losses, the list of validation losses, and the list of how many epochs each model with each activation function needs to be fully trained.**

# %%
learning_rate  = 2e-5
dropout_prob = 0.3
epochs = 20
list_entity_training_losses = []
list_entity_validation_losses = []
list_entity_span_encoded_epochs = []
loss_func = nn.CrossEntropyLoss()
optimizer_name = "Adam"
def get_entity_results(activation, max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_dataset, valid_dataset, train_dataloader, val_dataloader, SEED):
 set_seed(SEED)
 model = BertEntitySpanClassifier(activation, dropout_prob, max_question_length).to(device)
 print(model)
 loss_func = loss_func.to(device)
 optimizer = getattr(torch.optim, optimizer_name)(model.parameters(), lr=learning_rate)
 scheduler = get_linear_schedule_with_warmup(optimizer, 0, len(train_dataloader)*epochs)
 f1_start, f1_end, list_loss_train, list_loss_valid, list_epochs, best_entity_model = entity_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, learning_rate, dropout_prob)
 print(f1_start,f1_end)
 torch.save(best_entity_model.state_dict(), create_file(f"drive/MyDrive/Entity_span_indexes_models_best_parameters/All_Questions/{activation}",f"entity_span_encoded_prediction_not_ignoring_questions_{activation}.pt") )
 print(f"The best parameters are saved for the activation function: {activation}")
 return list_loss_train, list_loss_valid, list_epochs

# %%
list_entity_loss_train_leakyrelu_span_encoded, list_entity_loss_valid_leakyrelu_span_encoded, list_epochs_leakyrelu_span_encoded = get_entity_results("LeakyReLU", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_span_encoded_bert_dataset, valid_span_encoded_bert_dataset, train_dataloader_span_encoded, val_dataloader_span_encoded, SEED)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): LeakyReLU(negative_slope=0.01)
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.56887
# Epoch   0: Valid Loss = 13.25241
# Epoch   0: Valid f1_score for entity start span = 0.49401
# Epoch   0: Valid Acurracy for entity start span = 0.49401
# Epoch   0: Valid Recall for entity start span = 0.49401
# Epoch   0: Valid Precision for entity start span = 0.49401
# Epoch   0: Valid f1_score for entity end span = 0.33388
# Epoch   0: Valid Acurracy for entity end span = 0.33388
# Epoch   0: Valid Recall for entity end span = 0.33388
# Epoch   0: Valid Precision for entity end span = 0.33388
# The current f1 score for entity start: 0.49400871459694984
# The current f1 score for entity end: 0.33387799564270154
# Epoch   1: Train Loss = 13.11714
# Epoch   1: Valid Loss = 12.65810
# Epoch   1: Valid f1_score for entity start span = 0.78071
# Epoch   1: Valid Acurracy for entity start span = 0.78071
# Epoch   1: Valid Recall for entity start span = 0.78071
# Epoch   1: Valid Precision for entity start span = 0.78071
# Epoch   1: Valid f1_score for entity end span = 0.69662
# Epoch   1: Valid Acurracy for entity end span = 0.69662
# Epoch   1: Valid Recall for entity end span = 0.69662
# Epoch   1: Valid Precision for entity end span = 0.69662
# The current f1 score for entity start: 0.7807053376906319
# The current f1 score for entity end: 0.6966230936819172
# Epoch   2: Train Loss = 12.88144
# Epoch   2: Valid Loss = 12.45041
# Epoch   2: Valid f1_score for entity start span = 0.84130
# Epoch   2: Valid Acurracy for entity start span = 0.84130
# Epoch   2: Valid Recall for entity start span = 0.84130
# Epoch   2: Valid Precision for entity start span = 0.84130
# Epoch   2: Valid f1_score for entity end span = 0.79031
# Epoch   2: Valid Acurracy for entity end span = 0.79031
# Epoch   2: Valid Recall for entity end span = 0.79031
# Epoch   2: Valid Precision for entity end span = 0.79031
# The current f1 score for entity start: 0.8412990196078431
# The current f1 score for entity end: 0.7903050108932462
# Epoch   3: Train Loss = 12.81793
# Epoch   3: Valid Loss = 12.37254
# Epoch   3: Valid f1_score for entity start span = 0.85519
# Epoch   3: Valid Acurracy for entity start span = 0.85519
# Epoch   3: Valid Recall for entity start span = 0.85519
# Epoch   3: Valid Precision for entity start span = 0.85519
# Epoch   3: Valid f1_score for entity end span = 0.83007
# Epoch   3: Valid Acurracy for entity end span = 0.83007
# Epoch   3: Valid Recall for entity end span = 0.83007
# Epoch   3: Valid Precision for entity end span = 0.83007
# The current f1 score for entity start: 0.855187908496732
# The current f1 score for entity end: 0.8300653594771242
# Epoch   4: Train Loss = 12.77232
# Epoch   4: Valid Loss = 12.32548
# Epoch   4: Valid f1_score for entity start span = 0.86091
# Epoch   4: Valid Acurracy for entity start span = 0.86091
# Epoch   4: Valid Recall for entity start span = 0.86091
# Epoch   4: Valid Precision for entity start span = 0.86091
# Epoch   4: Valid f1_score for entity end span = 0.85233
# Epoch   4: Valid Acurracy for entity end span = 0.85233
# Epoch   4: Valid Recall for entity end span = 0.85233
# Epoch   4: Valid Precision for entity end span = 0.85233
# The current f1 score for entity start: 0.8609068627450981
# The current f1 score for entity end: 0.852328431372549
# Epoch   5: Train Loss = 12.76109
# Epoch   5: Valid Loss = 12.30044
# Epoch   5: Valid f1_score for entity start span = 0.87561
# Epoch   5: Valid Acurracy for entity start span = 0.87561
# Epoch   5: Valid Recall for entity start span = 0.87561
# Epoch   5: Valid Precision for entity start span = 0.87561
# Epoch   5: Valid f1_score for entity end span = 0.86417
# Epoch   5: Valid Acurracy for entity end span = 0.86417
# Epoch   5: Valid Recall for entity end span = 0.86417
# Epoch   5: Valid Precision for entity end span = 0.86417
# The current f1 score for entity start: 0.8756127450980392
# The current f1 score for entity end: 0.8641748366013072
# Epoch   6: Train Loss = 12.74301
# Epoch   6: Valid Loss = 12.24945
# Epoch   6: Valid f1_score for entity start span = 0.88256
# Epoch   6: Valid Acurracy for entity start span = 0.88256
# Epoch   6: Valid Recall for entity start span = 0.88256
# Epoch   6: Valid Precision for entity start span = 0.88256
# Epoch   6: Valid f1_score for entity end span = 0.89134
# Epoch   6: Valid Acurracy for entity end span = 0.89134
# Epoch   6: Valid Recall for entity end span = 0.89134
# Epoch   6: Valid Precision for entity end span = 0.89134
# The current f1 score for entity start: 0.8825571895424836
# The current f1 score for entity end: 0.8913398692810458
# Epoch   7: Train Loss = 12.72434
# Epoch   7: Valid Loss = 12.22877
# Epoch   7: Valid f1_score for entity start span = 0.88848
# Epoch   7: Valid Acurracy for entity start span = 0.88848
# Epoch   7: Valid Recall for entity start span = 0.88848
# Epoch   7: Valid Precision for entity start span = 0.88848
# Epoch   7: Valid f1_score for entity end span = 0.89869
# Epoch   7: Valid Acurracy for entity end span = 0.89869
# Epoch   7: Valid Recall for entity end span = 0.89869
# Epoch   7: Valid Precision for entity end span = 0.89869
# The current f1 score for entity start: 0.8884803921568627
# The current f1 score for entity end: 0.8986928104575164
# Epoch   8: Train Loss = 12.71449
# Epoch   8: Valid Loss = 12.22367
# Epoch   8: Valid f1_score for entity start span = 0.88828
# Epoch   8: Valid Acurracy for entity start span = 0.88828
# Epoch   8: Valid Recall for entity start span = 0.88828
# Epoch   8: Valid Precision for entity start span = 0.88828
# Epoch   8: Valid f1_score for entity end span = 0.90462
# Epoch   8: Valid Acurracy for entity end span = 0.90462
# Epoch   8: Valid Recall for entity end span = 0.90462
# Epoch   8: Valid Precision for entity end span = 0.90462
# Epoch   9: Train Loss = 12.69901
# Epoch   9: Valid Loss = 12.20409
# Epoch   9: Valid f1_score for entity start span = 0.90428
# Epoch   9: Valid Acurracy for entity start span = 0.90428
# Epoch   9: Valid Recall for entity start span = 0.90428
# Epoch   9: Valid Precision for entity start span = 0.90428
# Epoch   9: Valid f1_score for entity end span = 0.91027
# Epoch   9: Valid Acurracy for entity end span = 0.91027
# Epoch   9: Valid Recall for entity end span = 0.91027
# Epoch   9: Valid Precision for entity end span = 0.91027
# The current f1 score for entity start: 0.9042755991285403
# The current f1 score for entity end: 0.9102668845315904
# Epoch  10: Train Loss = 12.68114
# Epoch  10: Valid Loss = 12.19504
# Epoch  10: Valid f1_score for entity start span = 0.90979
# Epoch  10: Valid Acurracy for entity start span = 0.90979
# Epoch  10: Valid Recall for entity start span = 0.90979
# Epoch  10: Valid Precision for entity start span = 0.90979
# Epoch  10: Valid f1_score for entity end span = 0.91510
# Epoch  10: Valid Acurracy for entity end span = 0.91510
# Epoch  10: Valid Recall for entity end span = 0.91510
# Epoch  10: Valid Precision for entity end span = 0.91510
# The current f1 score for entity start: 0.9097903050108932
# The current f1 score for entity end: 0.915100762527233
# Epoch  11: Train Loss = 12.68150
# Epoch  11: Valid Loss = 12.18030
# Epoch  11: Valid f1_score for entity start span = 0.91673
# Epoch  11: Valid Acurracy for entity start span = 0.91673
# Epoch  11: Valid Recall for entity start span = 0.91673
# Epoch  11: Valid Precision for entity start span = 0.91673
# Epoch  11: Valid f1_score for entity end span = 0.91755
# Epoch  11: Valid Acurracy for entity end span = 0.91755
# Epoch  11: Valid Recall for entity end span = 0.91755
# Epoch  11: Valid Precision for entity end span = 0.91755
# The current f1 score for entity start: 0.9167347494553376
# The current f1 score for entity end: 0.9175517429193899
# Epoch  12: Train Loss = 12.67392
# Epoch  12: Valid Loss = 12.17009
# Epoch  12: Valid f1_score for entity start span = 0.92000
# Epoch  12: Valid Acurracy for entity start span = 0.92000
# Epoch  12: Valid Recall for entity start span = 0.92000
# Epoch  12: Valid Precision for entity start span = 0.92000
# Epoch  12: Valid f1_score for entity end span = 0.92300
# Epoch  12: Valid Acurracy for entity end span = 0.92300
# Epoch  12: Valid Recall for entity end span = 0.92300
# Epoch  12: Valid Precision for entity end span = 0.92300
# The current f1 score for entity start: 0.9200027233115468
# The current f1 score for entity end: 0.922998366013072
# Epoch  13: Train Loss = 12.67368
# Epoch  13: Valid Loss = 12.16419
# Epoch  13: Valid f1_score for entity start span = 0.92361
# Epoch  13: Valid Acurracy for entity start span = 0.92361
# Epoch  13: Valid Recall for entity start span = 0.92361
# Epoch  13: Valid Precision for entity start span = 0.92361
# Epoch  13: Valid f1_score for entity end span = 0.92586
# Epoch  13: Valid Acurracy for entity end span = 0.92586
# Epoch  13: Valid Recall for entity end span = 0.92586
# Epoch  13: Valid Precision for entity end span = 0.92586
# The current f1 score for entity start: 0.9236111111111112
# The current f1 score for entity end: 0.9258578431372549
# Epoch  14: Train Loss = 12.67607
# Epoch  14: Valid Loss = 12.15665
# Epoch  14: Valid f1_score for entity start span = 0.92463
# Epoch  14: Valid Acurracy for entity start span = 0.92463
# Epoch  14: Valid Recall for entity start span = 0.92463
# Epoch  14: Valid Precision for entity start span = 0.92463
# Epoch  14: Valid f1_score for entity end span = 0.92770
# Epoch  14: Valid Acurracy for entity end span = 0.92770
# Epoch  14: Valid Recall for entity end span = 0.92770
# Epoch  14: Valid Precision for entity end span = 0.92770
# The current f1 score for entity start: 0.9246323529411765
# The current f1 score for entity end: 0.9276960784313726
# Epoch  15: Train Loss = 12.66489
# Epoch  15: Valid Loss = 12.15553
# Epoch  15: Valid f1_score for entity start span = 0.92531
# Epoch  15: Valid Acurracy for entity start span = 0.92531
# Epoch  15: Valid Recall for entity start span = 0.92531
# Epoch  15: Valid Precision for entity start span = 0.92531
# Epoch  15: Valid f1_score for entity end span = 0.92899
# Epoch  15: Valid Acurracy for entity end span = 0.92899
# Epoch  15: Valid Recall for entity end span = 0.92899
# Epoch  15: Valid Precision for entity end span = 0.92899
# The current f1 score for entity start: 0.9253131808278866
# The current f1 score for entity end: 0.928989651416122
# Epoch  16: Train Loss = 12.67157
# Epoch  16: Valid Loss = 12.14978
# Epoch  16: Valid f1_score for entity start span = 0.92695
# Epoch  16: Valid Acurracy for entity start span = 0.92695
# Epoch  16: Valid Recall for entity start span = 0.92695
# Epoch  16: Valid Precision for entity start span = 0.92695
# Epoch  16: Valid f1_score for entity end span = 0.93199
# Epoch  16: Valid Acurracy for entity end span = 0.93199
# Epoch  16: Valid Recall for entity end span = 0.93199
# Epoch  16: Valid Precision for entity end span = 0.93199
# The current f1 score for entity start: 0.9269471677559912
# The current f1 score for entity end: 0.9319852941176471
# Epoch  17: Train Loss = 12.65996
# Epoch  17: Valid Loss = 12.14623
# Epoch  17: Valid f1_score for entity start span = 0.92892
# Epoch  17: Valid Acurracy for entity start span = 0.92892
# Epoch  17: Valid Recall for entity start span = 0.92892
# Epoch  17: Valid Precision for entity start span = 0.92892
# Epoch  17: Valid f1_score for entity end span = 0.93239
# Epoch  17: Valid Acurracy for entity end span = 0.93239
# Epoch  17: Valid Recall for entity end span = 0.93239
# Epoch  17: Valid Precision for entity end span = 0.93239
# The current f1 score for entity start: 0.928921568627451
# The current f1 score for entity end: 0.9323937908496732
# Epoch  18: Train Loss = 12.66036
# Epoch  18: Valid Loss = 12.14701
# Epoch  18: Valid f1_score for entity start span = 0.92715
# Epoch  18: Valid Acurracy for entity start span = 0.92715
# Epoch  18: Valid Recall for entity start span = 0.92715
# Epoch  18: Valid Precision for entity start span = 0.92715
# Epoch  18: Valid f1_score for entity end span = 0.93301
# Epoch  18: Valid Acurracy for entity end span = 0.93301
# Epoch  18: Valid Recall for entity end span = 0.93301
# Epoch  18: Valid Precision for entity end span = 0.93301
# Epoch  19: Train Loss = 12.65847
# Epoch  19: Valid Loss = 12.14428
# Epoch  19: Valid f1_score for entity start span = 0.92933
# Epoch  19: Valid Acurracy for entity start span = 0.92933
# Epoch  19: Valid Recall for entity start span = 0.92933
# Epoch  19: Valid Precision for entity start span = 0.92933
# Epoch  19: Valid f1_score for entity end span = 0.93382
# Epoch  19: Valid Acurracy for entity end span = 0.93382
# Epoch  19: Valid Recall for entity end span = 0.93382
# Epoch  19: Valid Precision for entity end span = 0.93382
# The current f1 score for entity start: 0.9293300653594772
# The current f1 score for entity end: 0.9338235294117647
# 0.9293300653594772 0.9338235294117647
# The best parameters are saved for the activation function: LeakyReLU

# %%
list_entity_loss_train_tanhshrink_span_encoded, list_entity_loss_valid_tanhshrink_span_encoded, list_epochs_tanhshrink_span_encoded = get_entity_results("Tanhshrink", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_span_encoded_bert_dataset, valid_span_encoded_bert_dataset, train_dataloader_span_encoded, val_dataloader_span_encoded, SEED)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): Tanhshrink()
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Tanhshrink()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Tanhshrink()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.49034
# Epoch   0: Valid Loss = 12.97651
# Epoch   0: Valid f1_score for entity start span = 0.70486
# Epoch   0: Valid Acurracy for entity start span = 0.70486
# Epoch   0: Valid Recall for entity start span = 0.70486
# Epoch   0: Valid Precision for entity start span = 0.70486
# Epoch   0: Valid f1_score for entity end span = 0.39726
# Epoch   0: Valid Acurracy for entity end span = 0.39726
# Epoch   0: Valid Recall for entity end span = 0.39726
# Epoch   0: Valid Precision for entity end span = 0.39726
# The current f1 score for entity start: 0.7048611111111112
# The current f1 score for entity end: 0.3972630718954248
# Epoch   1: Train Loss = 13.05322
# Epoch   1: Valid Loss = 12.62307
# Epoch   1: Valid f1_score for entity start span = 0.81168
# Epoch   1: Valid Acurracy for entity start span = 0.81168
# Epoch   1: Valid Recall for entity start span = 0.81168
# Epoch   1: Valid Precision for entity start span = 0.81168
# Epoch   1: Valid f1_score for entity end span = 0.61063
# Epoch   1: Valid Acurracy for entity end span = 0.61063
# Epoch   1: Valid Recall for entity end span = 0.61063
# Epoch   1: Valid Precision for entity end span = 0.61063
# The current f1 score for entity start: 0.8116830065359477
# The current f1 score for entity end: 0.6106345315904139
# Epoch   2: Train Loss = 12.89313
# Epoch   2: Valid Loss = 12.40014
# Epoch   2: Valid f1_score for entity start span = 0.86295
# Epoch   2: Valid Acurracy for entity start span = 0.86295
# Epoch   2: Valid Recall for entity start span = 0.86295
# Epoch   2: Valid Precision for entity start span = 0.86295
# Epoch   2: Valid f1_score for entity end span = 0.77151
# Epoch   2: Valid Acurracy for entity end span = 0.77151
# Epoch   2: Valid Recall for entity end span = 0.77151
# Epoch   2: Valid Precision for entity end span = 0.77151
# The current f1 score for entity start: 0.8629493464052288
# The current f1 score for entity end: 0.7715141612200436
# Epoch   3: Train Loss = 12.81120
# Epoch   3: Valid Loss = 12.30732
# Epoch   3: Valid f1_score for entity start span = 0.87255
# Epoch   3: Valid Acurracy for entity start span = 0.87255
# Epoch   3: Valid Recall for entity start span = 0.87255
# Epoch   3: Valid Precision for entity start span = 0.87255
# Epoch   3: Valid f1_score for entity end span = 0.83701
# Epoch   3: Valid Acurracy for entity end span = 0.83701
# Epoch   3: Valid Recall for entity end span = 0.83701
# Epoch   3: Valid Precision for entity end span = 0.83701
# The current f1 score for entity start: 0.8725490196078431
# The current f1 score for entity end: 0.8370098039215687
# Epoch   4: Train Loss = 12.76226
# Epoch   4: Valid Loss = 12.27953
# Epoch   4: Valid f1_score for entity start span = 0.87643
# Epoch   4: Valid Acurracy for entity start span = 0.87643
# Epoch   4: Valid Recall for entity start span = 0.87643
# Epoch   4: Valid Precision for entity start span = 0.87643
# Epoch   4: Valid f1_score for entity end span = 0.85355
# Epoch   4: Valid Acurracy for entity end span = 0.85355
# Epoch   4: Valid Recall for entity end span = 0.85355
# Epoch   4: Valid Precision for entity end span = 0.85355
# The current f1 score for entity start: 0.8764297385620915
# The current f1 score for entity end: 0.8535539215686274
# Epoch   5: Train Loss = 12.74903
# Epoch   5: Valid Loss = 12.24154
# Epoch   5: Valid f1_score for entity start span = 0.90319
# Epoch   5: Valid Acurracy for entity start span = 0.90319
# Epoch   5: Valid Recall for entity start span = 0.90319
# Epoch   5: Valid Precision for entity start span = 0.90319
# Epoch   5: Valid f1_score for entity end span = 0.86867
# Epoch   5: Valid Acurracy for entity end span = 0.86867
# Epoch   5: Valid Recall for entity end span = 0.86867
# Epoch   5: Valid Precision for entity end span = 0.86867
# The current f1 score for entity start: 0.9031862745098039
# The current f1 score for entity end: 0.8686683006535948
# Epoch   6: Train Loss = 12.72749
# Epoch   6: Valid Loss = 12.22221
# Epoch   6: Valid f1_score for entity start span = 0.91238
# Epoch   6: Valid Acurracy for entity start span = 0.91238
# Epoch   6: Valid Recall for entity start span = 0.91238
# Epoch   6: Valid Precision for entity start span = 0.91238
# Epoch   6: Valid f1_score for entity end span = 0.87337
# Epoch   6: Valid Acurracy for entity end span = 0.87337
# Epoch   6: Valid Recall for entity end span = 0.87337
# Epoch   6: Valid Precision for entity end span = 0.87337
# The current f1 score for entity start: 0.9123774509803921
# The current f1 score for entity end: 0.8733660130718954
# Epoch   7: Train Loss = 12.71126
# Epoch   7: Valid Loss = 12.19372
# Epoch   7: Valid f1_score for entity start span = 0.91544
# Epoch   7: Valid Acurracy for entity start span = 0.91544
# Epoch   7: Valid Recall for entity start span = 0.91544
# Epoch   7: Valid Precision for entity start span = 0.91544
# Epoch   7: Valid f1_score for entity end span = 0.90012
# Epoch   7: Valid Acurracy for entity end span = 0.90012
# Epoch   7: Valid Recall for entity end span = 0.90012
# Epoch   7: Valid Precision for entity end span = 0.90012
# The current f1 score for entity start: 0.9154411764705882
# The current f1 score for entity end: 0.9001225490196079
# Epoch   8: Train Loss = 12.69586
# Epoch   8: Valid Loss = 12.17014
# Epoch   8: Valid f1_score for entity start span = 0.92177
# Epoch   8: Valid Acurracy for entity start span = 0.92177
# Epoch   8: Valid Recall for entity start span = 0.92177
# Epoch   8: Valid Precision for entity start span = 0.92177
# Epoch   8: Valid f1_score for entity end span = 0.91422
# Epoch   8: Valid Acurracy for entity end span = 0.91422
# Epoch   8: Valid Recall for entity end span = 0.91422
# Epoch   8: Valid Precision for entity end span = 0.91422
# The current f1 score for entity start: 0.9217728758169934
# The current f1 score for entity end: 0.9142156862745098
# Epoch   9: Train Loss = 12.68261
# Epoch   9: Valid Loss = 12.16716
# Epoch   9: Valid f1_score for entity start span = 0.92225
# Epoch   9: Valid Acurracy for entity start span = 0.92225
# Epoch   9: Valid Recall for entity start span = 0.92225
# Epoch   9: Valid Precision for entity start span = 0.92225
# Epoch   9: Valid f1_score for entity end span = 0.91408
# Epoch   9: Valid Acurracy for entity end span = 0.91408
# Epoch   9: Valid Recall for entity end span = 0.91408
# Epoch   9: Valid Precision for entity end span = 0.91408
# Epoch  10: Train Loss = 12.66693
# Epoch  10: Valid Loss = 12.15592
# Epoch  10: Valid f1_score for entity start span = 0.92450
# Epoch  10: Valid Acurracy for entity start span = 0.92450
# Epoch  10: Valid Recall for entity start span = 0.92450
# Epoch  10: Valid Precision for entity start span = 0.92450
# Epoch  10: Valid f1_score for entity end span = 0.92259
# Epoch  10: Valid Acurracy for entity end span = 0.92259
# Epoch  10: Valid Recall for entity end span = 0.92259
# Epoch  10: Valid Precision for entity end span = 0.92259
# The current f1 score for entity start: 0.9244961873638343
# The current f1 score for entity end: 0.9225898692810458
# Epoch  11: Train Loss = 12.67271
# Epoch  11: Valid Loss = 12.15197
# Epoch  11: Valid f1_score for entity start span = 0.92613
# Epoch  11: Valid Acurracy for entity start span = 0.92613
# Epoch  11: Valid Recall for entity start span = 0.92613
# Epoch  11: Valid Precision for entity start span = 0.92613
# Epoch  11: Valid f1_score for entity end span = 0.92143
# Epoch  11: Valid Acurracy for entity end span = 0.92143
# Epoch  11: Valid Recall for entity end span = 0.92143
# Epoch  11: Valid Precision for entity end span = 0.92143
# Epoch  12: Train Loss = 12.66581
# Epoch  12: Valid Loss = 12.14714
# Epoch  12: Valid f1_score for entity start span = 0.92797
# Epoch  12: Valid Acurracy for entity start span = 0.92797
# Epoch  12: Valid Recall for entity start span = 0.92797
# Epoch  12: Valid Precision for entity start span = 0.92797
# Epoch  12: Valid f1_score for entity end span = 0.92327
# Epoch  12: Valid Acurracy for entity end span = 0.92327
# Epoch  12: Valid Recall for entity end span = 0.92327
# Epoch  12: Valid Precision for entity end span = 0.92327
# The current f1 score for entity start: 0.9279684095860565
# The current f1 score for entity end: 0.9232706971677559
# Epoch  13: Train Loss = 12.66852
# Epoch  13: Valid Loss = 12.14598
# Epoch  13: Valid f1_score for entity start span = 0.92749
# Epoch  13: Valid Acurracy for entity start span = 0.92749
# Epoch  13: Valid Recall for entity start span = 0.92749
# Epoch  13: Valid Precision for entity start span = 0.92749
# Epoch  13: Valid f1_score for entity end span = 0.92463
# Epoch  13: Valid Acurracy for entity end span = 0.92463
# Epoch  13: Valid Recall for entity end span = 0.92463
# Epoch  13: Valid Precision for entity end span = 0.92463
# Epoch  14: Train Loss = 12.67190
# Epoch  14: Valid Loss = 12.14348
# Epoch  14: Valid f1_score for entity start span = 0.92674
# Epoch  14: Valid Acurracy for entity start span = 0.92674
# Epoch  14: Valid Recall for entity start span = 0.92674
# Epoch  14: Valid Precision for entity start span = 0.92674
# Epoch  14: Valid f1_score for entity end span = 0.92606
# Epoch  14: Valid Acurracy for entity end span = 0.92606
# Epoch  14: Valid Recall for entity end span = 0.92606
# Epoch  14: Valid Precision for entity end span = 0.92606
# Epoch  15: Train Loss = 12.66319
# Epoch  15: Valid Loss = 12.14548
# Epoch  15: Valid f1_score for entity start span = 0.92633
# Epoch  15: Valid Acurracy for entity start span = 0.92633
# Epoch  15: Valid Recall for entity start span = 0.92633
# Epoch  15: Valid Precision for entity start span = 0.92633
# Epoch  15: Valid f1_score for entity end span = 0.92511
# Epoch  15: Valid Acurracy for entity end span = 0.92511
# Epoch  15: Valid Recall for entity end span = 0.92511
# Epoch  15: Valid Precision for entity end span = 0.92511
# trigger times: 1
# Epoch  16: Train Loss = 12.67092
# Epoch  16: Valid Loss = 12.14173
# Epoch  16: Valid f1_score for entity start span = 0.92838
# Epoch  16: Valid Acurracy for entity start span = 0.92838
# Epoch  16: Valid Recall for entity start span = 0.92838
# Epoch  16: Valid Precision for entity start span = 0.92838
# Epoch  16: Valid f1_score for entity end span = 0.92627
# Epoch  16: Valid Acurracy for entity end span = 0.92627
# Epoch  16: Valid Recall for entity end span = 0.92627
# Epoch  16: Valid Precision for entity end span = 0.92627
# The current f1 score for entity start: 0.9283769063180827
# The current f1 score for entity end: 0.9262663398692811
# Epoch  17: Train Loss = 12.65986
# Epoch  17: Valid Loss = 12.13930
# Epoch  17: Valid f1_score for entity start span = 0.92953
# Epoch  17: Valid Acurracy for entity start span = 0.92953
# Epoch  17: Valid Recall for entity start span = 0.92953
# Epoch  17: Valid Precision for entity start span = 0.92953
# Epoch  17: Valid f1_score for entity end span = 0.92770
# Epoch  17: Valid Acurracy for entity end span = 0.92770
# Epoch  17: Valid Recall for entity end span = 0.92770
# Epoch  17: Valid Precision for entity end span = 0.92770
# The current f1 score for entity start: 0.9295343137254902
# The current f1 score for entity end: 0.9276960784313726
# Epoch  18: Train Loss = 12.66149
# Epoch  18: Valid Loss = 12.13802
# Epoch  18: Valid f1_score for entity start span = 0.93056
# Epoch  18: Valid Acurracy for entity start span = 0.93056
# Epoch  18: Valid Recall for entity start span = 0.93056
# Epoch  18: Valid Precision for entity start span = 0.93056
# Epoch  18: Valid f1_score for entity end span = 0.92749
# Epoch  18: Valid Acurracy for entity end span = 0.92749
# Epoch  18: Valid Recall for entity end span = 0.92749
# Epoch  18: Valid Precision for entity end span = 0.92749
# Epoch  19: Train Loss = 12.66030
# Epoch  19: Valid Loss = 12.13769
# Epoch  19: Valid f1_score for entity start span = 0.93056
# Epoch  19: Valid Acurracy for entity start span = 0.93056
# Epoch  19: Valid Recall for entity start span = 0.93056
# Epoch  19: Valid Precision for entity start span = 0.93056
# Epoch  19: Valid f1_score for entity end span = 0.92790
# Epoch  19: Valid Acurracy for entity end span = 0.92790
# Epoch  19: Valid Recall for entity end span = 0.92790
# Epoch  19: Valid Precision for entity end span = 0.92790
# The current f1 score for entity start: 0.9305555555555556
# The current f1 score for entity end: 0.9279003267973857
# 0.9305555555555556 0.9279003267973857
# The best parameters are saved for the activation function: Tanhshrink

# %%
list_entity_loss_train_elu_span_encoded, list_entity_loss_valid_elu_span_encoded, list_epochs_elu_span_encoded  = get_entity_results("ELU", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_span_encoded_bert_dataset, valid_span_encoded_bert_dataset, train_dataloader_span_encoded, val_dataloader_span_encoded, SEED)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): ELU(alpha=1.0)
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.44777
# Epoch   0: Valid Loss = 12.90797
# Epoch   0: Valid f1_score for entity start span = 0.72937
# Epoch   0: Valid Acurracy for entity start span = 0.72937
# Epoch   0: Valid Recall for entity start span = 0.72937
# Epoch   0: Valid Precision for entity start span = 0.72937
# Epoch   0: Valid f1_score for entity end span = 0.51389
# Epoch   0: Valid Acurracy for entity end span = 0.51389
# Epoch   0: Valid Recall for entity end span = 0.51389
# Epoch   0: Valid Precision for entity end span = 0.51389
# The current f1 score for entity start: 0.7293709150326797
# The current f1 score for entity end: 0.5138888888888888
# Epoch   1: Train Loss = 12.97108
# Epoch   1: Valid Loss = 12.60283
# Epoch   1: Valid f1_score for entity start span = 0.79616
# Epoch   1: Valid Acurracy for entity start span = 0.79616
# Epoch   1: Valid Recall for entity start span = 0.79616
# Epoch   1: Valid Precision for entity start span = 0.79616
# Epoch   1: Valid f1_score for entity end span = 0.70561
# Epoch   1: Valid Acurracy for entity end span = 0.70561
# Epoch   1: Valid Recall for entity end span = 0.70561
# Epoch   1: Valid Precision for entity end span = 0.70561
# The current f1 score for entity start: 0.7961601307189542
# The current f1 score for entity end: 0.7056100217864923
# Epoch   2: Train Loss = 12.83773
# Epoch   2: Valid Loss = 12.41144
# Epoch   2: Valid f1_score for entity start span = 0.84702
# Epoch   2: Valid Acurracy for entity start span = 0.84702
# Epoch   2: Valid Recall for entity start span = 0.84702
# Epoch   2: Valid Precision for entity start span = 0.84702
# Epoch   2: Valid f1_score for entity end span = 0.80828
# Epoch   2: Valid Acurracy for entity end span = 0.80828
# Epoch   2: Valid Recall for entity end span = 0.80828
# Epoch   2: Valid Precision for entity end span = 0.80828
# The current f1 score for entity start: 0.8470179738562091
# The current f1 score for entity end: 0.8082788671023965
# Epoch   3: Train Loss = 12.78505
# Epoch   3: Valid Loss = 12.31993
# Epoch   3: Valid f1_score for entity start span = 0.85886
# Epoch   3: Valid Acurracy for entity start span = 0.85886
# Epoch   3: Valid Recall for entity start span = 0.85886
# Epoch   3: Valid Precision for entity start span = 0.85886
# Epoch   3: Valid f1_score for entity end span = 0.87092
# Epoch   3: Valid Acurracy for entity end span = 0.87092
# Epoch   3: Valid Recall for entity end span = 0.87092
# Epoch   3: Valid Precision for entity end span = 0.87092
# The current f1 score for entity start: 0.8588643790849673
# The current f1 score for entity end: 0.8709150326797386
# Epoch   4: Train Loss = 12.74323
# Epoch   4: Valid Loss = 12.28460
# Epoch   4: Valid f1_score for entity start span = 0.86744
# Epoch   4: Valid Acurracy for entity start span = 0.86744
# Epoch   4: Valid Recall for entity start span = 0.86744
# Epoch   4: Valid Precision for entity start span = 0.86744
# Epoch   4: Valid f1_score for entity end span = 0.88378
# Epoch   4: Valid Acurracy for entity end span = 0.88378
# Epoch   4: Valid Recall for entity end span = 0.88378
# Epoch   4: Valid Precision for entity end span = 0.88378
# The current f1 score for entity start: 0.8674428104575164
# The current f1 score for entity end: 0.8837826797385621
# Epoch   5: Train Loss = 12.73480
# Epoch   5: Valid Loss = 12.25186
# Epoch   5: Valid f1_score for entity start span = 0.89093
# Epoch   5: Valid Acurracy for entity start span = 0.89093
# Epoch   5: Valid Recall for entity start span = 0.89093
# Epoch   5: Valid Precision for entity start span = 0.89093
# Epoch   5: Valid f1_score for entity end span = 0.89931
# Epoch   5: Valid Acurracy for entity end span = 0.89931
# Epoch   5: Valid Recall for entity end span = 0.89931
# Epoch   5: Valid Precision for entity end span = 0.89931
# The current f1 score for entity start: 0.8909313725490197
# The current f1 score for entity end: 0.8993055555555556
# Epoch   6: Train Loss = 12.71770
# Epoch   6: Valid Loss = 12.21522
# Epoch   6: Valid f1_score for entity start span = 0.90278
# Epoch   6: Valid Acurracy for entity start span = 0.90278
# Epoch   6: Valid Recall for entity start span = 0.90278
# Epoch   6: Valid Precision for entity start span = 0.90278
# Epoch   6: Valid f1_score for entity end span = 0.90482
# Epoch   6: Valid Acurracy for entity end span = 0.90482
# Epoch   6: Valid Recall for entity end span = 0.90482
# Epoch   6: Valid Precision for entity end span = 0.90482
# The current f1 score for entity start: 0.9027777777777778
# The current f1 score for entity end: 0.9048202614379085
# Epoch   7: Train Loss = 12.70292
# Epoch   7: Valid Loss = 12.20595
# Epoch   7: Valid f1_score for entity start span = 0.90625
# Epoch   7: Valid Acurracy for entity start span = 0.90625
# Epoch   7: Valid Recall for entity start span = 0.90625
# Epoch   7: Valid Precision for entity start span = 0.90625
# Epoch   7: Valid f1_score for entity end span = 0.90339
# Epoch   7: Valid Acurracy for entity end span = 0.90339
# Epoch   7: Valid Recall for entity end span = 0.90339
# Epoch   7: Valid Precision for entity end span = 0.90339
# Epoch   8: Train Loss = 12.69702
# Epoch   8: Valid Loss = 12.17652
# Epoch   8: Valid f1_score for entity start span = 0.90972
# Epoch   8: Valid Acurracy for entity start span = 0.90972
# Epoch   8: Valid Recall for entity start span = 0.90972
# Epoch   8: Valid Precision for entity start span = 0.90972
# Epoch   8: Valid f1_score for entity end span = 0.92606
# Epoch   8: Valid Acurracy for entity end span = 0.92606
# Epoch   8: Valid Recall for entity end span = 0.92606
# Epoch   8: Valid Precision for entity end span = 0.92606
# The current f1 score for entity start: 0.9097222222222222
# The current f1 score for entity end: 0.926062091503268
# Epoch   9: Train Loss = 12.68250
# Epoch   9: Valid Loss = 12.16576
# Epoch   9: Valid f1_score for entity start span = 0.91776
# Epoch   9: Valid Acurracy for entity start span = 0.91776
# Epoch   9: Valid Recall for entity start span = 0.91776
# Epoch   9: Valid Precision for entity start span = 0.91776
# Epoch   9: Valid f1_score for entity end span = 0.92531
# Epoch   9: Valid Acurracy for entity end span = 0.92531
# Epoch   9: Valid Recall for entity end span = 0.92531
# Epoch   9: Valid Precision for entity end span = 0.92531
# Epoch  10: Train Loss = 12.66652
# Epoch  10: Valid Loss = 12.16387
# Epoch  10: Valid f1_score for entity start span = 0.91816
# Epoch  10: Valid Acurracy for entity start span = 0.91816
# Epoch  10: Valid Recall for entity start span = 0.91816
# Epoch  10: Valid Precision for entity start span = 0.91816
# Epoch  10: Valid f1_score for entity end span = 0.92593
# Epoch  10: Valid Acurracy for entity end span = 0.92593
# Epoch  10: Valid Recall for entity end span = 0.92593
# Epoch  10: Valid Precision for entity end span = 0.92593
# Epoch  11: Train Loss = 12.67146
# Epoch  11: Valid Loss = 12.15512
# Epoch  11: Valid f1_score for entity start span = 0.92245
# Epoch  11: Valid Acurracy for entity start span = 0.92245
# Epoch  11: Valid Recall for entity start span = 0.92245
# Epoch  11: Valid Precision for entity start span = 0.92245
# Epoch  11: Valid f1_score for entity end span = 0.92817
# Epoch  11: Valid Acurracy for entity end span = 0.92817
# Epoch  11: Valid Recall for entity end span = 0.92817
# Epoch  11: Valid Precision for entity end span = 0.92817
# The current f1 score for entity start: 0.9224537037037036
# The current f1 score for entity end: 0.9281726579520696
# Epoch  12: Train Loss = 12.66483
# Epoch  12: Valid Loss = 12.15172
# Epoch  12: Valid f1_score for entity start span = 0.92450
# Epoch  12: Valid Acurracy for entity start span = 0.92450
# Epoch  12: Valid Recall for entity start span = 0.92450
# Epoch  12: Valid Precision for entity start span = 0.92450
# Epoch  12: Valid f1_score for entity end span = 0.92817
# Epoch  12: Valid Acurracy for entity end span = 0.92817
# Epoch  12: Valid Recall for entity end span = 0.92817
# Epoch  12: Valid Precision for entity end span = 0.92817
# The current f1 score for entity start: 0.9244961873638343
# The current f1 score for entity end: 0.9281726579520696
# Epoch  13: Train Loss = 12.66504
# Epoch  13: Valid Loss = 12.14762
# Epoch  13: Valid f1_score for entity start span = 0.92531
# Epoch  13: Valid Acurracy for entity start span = 0.92531
# Epoch  13: Valid Recall for entity start span = 0.92531
# Epoch  13: Valid Precision for entity start span = 0.92531
# Epoch  13: Valid f1_score for entity end span = 0.92940
# Epoch  13: Valid Acurracy for entity end span = 0.92940
# Epoch  13: Valid Recall for entity end span = 0.92940
# Epoch  13: Valid Precision for entity end span = 0.92940
# The current f1 score for entity start: 0.9253131808278866
# The current f1 score for entity end: 0.9293981481481481
# Epoch  14: Train Loss = 12.66975
# Epoch  14: Valid Loss = 12.14255
# Epoch  14: Valid f1_score for entity start span = 0.92790
# Epoch  14: Valid Acurracy for entity start span = 0.92790
# Epoch  14: Valid Recall for entity start span = 0.92790
# Epoch  14: Valid Precision for entity start span = 0.92790
# Epoch  14: Valid f1_score for entity end span = 0.93301
# Epoch  14: Valid Acurracy for entity end span = 0.93301
# Epoch  14: Valid Recall for entity end span = 0.93301
# Epoch  14: Valid Precision for entity end span = 0.93301
# The current f1 score for entity start: 0.9279003267973857
# The current f1 score for entity end: 0.9330065359477124
# Epoch  15: Train Loss = 12.66086
# Epoch  15: Valid Loss = 12.14580
# Epoch  15: Valid f1_score for entity start span = 0.92552
# Epoch  15: Valid Acurracy for entity start span = 0.92552
# Epoch  15: Valid Recall for entity start span = 0.92552
# Epoch  15: Valid Precision for entity start span = 0.92552
# Epoch  15: Valid f1_score for entity end span = 0.93042
# Epoch  15: Valid Acurracy for entity end span = 0.93042
# Epoch  15: Valid Recall for entity end span = 0.93042
# Epoch  15: Valid Precision for entity end span = 0.93042
# trigger times: 1
# Epoch  16: Train Loss = 12.66861
# Epoch  16: Valid Loss = 12.14130
# Epoch  16: Valid f1_score for entity start span = 0.92736
# Epoch  16: Valid Acurracy for entity start span = 0.92736
# Epoch  16: Valid Recall for entity start span = 0.92736
# Epoch  16: Valid Precision for entity start span = 0.92736
# Epoch  16: Valid f1_score for entity end span = 0.93301
# Epoch  16: Valid Acurracy for entity end span = 0.93301
# Epoch  16: Valid Recall for entity end span = 0.93301
# Epoch  16: Valid Precision for entity end span = 0.93301
# Epoch  17: Train Loss = 12.65717
# Epoch  17: Valid Loss = 12.13742
# Epoch  17: Valid f1_score for entity start span = 0.92953
# Epoch  17: Valid Acurracy for entity start span = 0.92953
# Epoch  17: Valid Recall for entity start span = 0.92953
# Epoch  17: Valid Precision for entity start span = 0.92953
# Epoch  17: Valid f1_score for entity end span = 0.93301
# Epoch  17: Valid Acurracy for entity end span = 0.93301
# Epoch  17: Valid Recall for entity end span = 0.93301
# Epoch  17: Valid Precision for entity end span = 0.93301
# The current f1 score for entity start: 0.9295343137254902
# The current f1 score for entity end: 0.9330065359477124
# Epoch  18: Train Loss = 12.65768
# Epoch  18: Valid Loss = 12.13702
# Epoch  18: Valid f1_score for entity start span = 0.92817
# Epoch  18: Valid Acurracy for entity start span = 0.92817
# Epoch  18: Valid Recall for entity start span = 0.92817
# Epoch  18: Valid Precision for entity start span = 0.92817
# Epoch  18: Valid f1_score for entity end span = 0.93382
# Epoch  18: Valid Acurracy for entity end span = 0.93382
# Epoch  18: Valid Recall for entity end span = 0.93382
# Epoch  18: Valid Precision for entity end span = 0.93382
# Epoch  19: Train Loss = 12.65613
# Epoch  19: Valid Loss = 12.13560
# Epoch  19: Valid f1_score for entity start span = 0.93015
# Epoch  19: Valid Acurracy for entity start span = 0.93015
# Epoch  19: Valid Recall for entity start span = 0.93015
# Epoch  19: Valid Precision for entity start span = 0.93015
# Epoch  19: Valid f1_score for entity end span = 0.93342
# Epoch  19: Valid Acurracy for entity end span = 0.93342
# Epoch  19: Valid Recall for entity end span = 0.93342
# Epoch  19: Valid Precision for entity end span = 0.93342
# The current f1 score for entity start: 0.9301470588235294
# The current f1 score for entity end: 0.9334150326797386
# 0.9301470588235294 0.9334150326797386
# The best parameters are saved for the activation function: ELU

# %%
list_entity_loss_train_softplus_span_encoded, list_entity_loss_valid_softplus_span_encoded, list_epochs_softplus_span_encoded = get_entity_results("Softplus", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_span_encoded_bert_dataset, valid_span_encoded_bert_dataset, train_dataloader_span_encoded, val_dataloader_span_encoded, SEED)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): Softplus(beta=1, threshold=20)
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Softplus(beta=1, threshold=20)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Softplus(beta=1, threshold=20)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.49036
# Epoch   0: Valid Loss = 12.98631
# Epoch   0: Valid f1_score for entity start span = 0.70404
# Epoch   0: Valid Acurracy for entity start span = 0.70404
# Epoch   0: Valid Recall for entity start span = 0.70404
# Epoch   0: Valid Precision for entity start span = 0.70404
# Epoch   0: Valid f1_score for entity end span = 0.53888
# Epoch   0: Valid Acurracy for entity end span = 0.53888
# Epoch   0: Valid Recall for entity end span = 0.53888
# Epoch   0: Valid Precision for entity end span = 0.53888
# The current f1 score for entity start: 0.7040441176470589
# The current f1 score for entity end: 0.5388752723311547
# Epoch   1: Train Loss = 12.95914
# Epoch   1: Valid Loss = 12.51464
# Epoch   1: Valid f1_score for entity start span = 0.85662
# Epoch   1: Valid Acurracy for entity start span = 0.85662
# Epoch   1: Valid Recall for entity start span = 0.85662
# Epoch   1: Valid Precision for entity start span = 0.85662
# Epoch   1: Valid f1_score for entity end span = 0.73278
# Epoch   1: Valid Acurracy for entity end span = 0.73278
# Epoch   1: Valid Recall for entity end span = 0.73278
# Epoch   1: Valid Precision for entity end span = 0.73278
# The current f1 score for entity start: 0.8566176470588235
# The current f1 score for entity end: 0.7327750544662309
# Epoch   2: Train Loss = 12.82681
# Epoch   2: Valid Loss = 12.36270
# Epoch   2: Valid f1_score for entity start span = 0.87459
# Epoch   2: Valid Acurracy for entity start span = 0.87459
# Epoch   2: Valid Recall for entity start span = 0.87459
# Epoch   2: Valid Precision for entity start span = 0.87459
# Epoch   2: Valid f1_score for entity end span = 0.85090
# Epoch   2: Valid Acurracy for entity end span = 0.85090
# Epoch   2: Valid Recall for entity end span = 0.85090
# Epoch   2: Valid Precision for entity end span = 0.85090
# The current f1 score for entity start: 0.8745915032679739
# The current f1 score for entity end: 0.8508986928104575
# Epoch   3: Train Loss = 12.75792
# Epoch   3: Valid Loss = 12.27822
# Epoch   3: Valid f1_score for entity start span = 0.89788
# Epoch   3: Valid Acurracy for entity start span = 0.89788
# Epoch   3: Valid Recall for entity start span = 0.89788
# Epoch   3: Valid Precision for entity start span = 0.89788
# Epoch   3: Valid f1_score for entity end span = 0.87561
# Epoch   3: Valid Acurracy for entity end span = 0.87561
# Epoch   3: Valid Recall for entity end span = 0.87561
# Epoch   3: Valid Precision for entity end span = 0.87561
# The current f1 score for entity start: 0.8978758169934641
# The current f1 score for entity end: 0.8756127450980392
# Epoch   4: Train Loss = 12.71743
# Epoch   4: Valid Loss = 12.22935
# Epoch   4: Valid f1_score for entity start span = 0.91115
# Epoch   4: Valid Acurracy for entity start span = 0.91115
# Epoch   4: Valid Recall for entity start span = 0.91115
# Epoch   4: Valid Precision for entity start span = 0.91115
# Epoch   4: Valid f1_score for entity end span = 0.90114
# Epoch   4: Valid Acurracy for entity end span = 0.90114
# Epoch   4: Valid Recall for entity end span = 0.90114
# Epoch   4: Valid Precision for entity end span = 0.90114
# The current f1 score for entity start: 0.9111519607843137
# The current f1 score for entity end: 0.9011437908496732
# Epoch   5: Train Loss = 12.71056
# Epoch   5: Valid Loss = 12.20863
# Epoch   5: Valid f1_score for entity start span = 0.91830
# Epoch   5: Valid Acurracy for entity start span = 0.91830
# Epoch   5: Valid Recall for entity start span = 0.91830
# Epoch   5: Valid Precision for entity start span = 0.91830
# Epoch   5: Valid f1_score for entity end span = 0.90441
# Epoch   5: Valid Acurracy for entity end span = 0.90441
# Epoch   5: Valid Recall for entity end span = 0.90441
# Epoch   5: Valid Precision for entity end span = 0.90441
# The current f1 score for entity start: 0.9183006535947712
# The current f1 score for entity end: 0.9044117647058824
# Epoch   6: Train Loss = 12.70142
# Epoch   6: Valid Loss = 12.19926
# Epoch   6: Valid f1_score for entity start span = 0.91728
# Epoch   6: Valid Acurracy for entity start span = 0.91728
# Epoch   6: Valid Recall for entity start span = 0.91728
# Epoch   6: Valid Precision for entity start span = 0.91728
# Epoch   6: Valid f1_score for entity end span = 0.90523
# Epoch   6: Valid Acurracy for entity end span = 0.90523
# Epoch   6: Valid Recall for entity end span = 0.90523
# Epoch   6: Valid Precision for entity end span = 0.90523
# Epoch   7: Train Loss = 12.69301
# Epoch   7: Valid Loss = 12.18765
# Epoch   7: Valid f1_score for entity start span = 0.91953
# Epoch   7: Valid Acurracy for entity start span = 0.91953
# Epoch   7: Valid Recall for entity start span = 0.91953
# Epoch   7: Valid Precision for entity start span = 0.91953
# Epoch   7: Valid f1_score for entity end span = 0.90686
# Epoch   7: Valid Acurracy for entity end span = 0.90686
# Epoch   7: Valid Recall for entity end span = 0.90686
# Epoch   7: Valid Precision for entity end span = 0.90686
# The current f1 score for entity start: 0.9195261437908496
# The current f1 score for entity end: 0.9068627450980392
# Epoch   8: Train Loss = 12.68997
# Epoch   8: Valid Loss = 12.17797
# Epoch   8: Valid f1_score for entity start span = 0.92218
# Epoch   8: Valid Acurracy for entity start span = 0.92218
# Epoch   8: Valid Recall for entity start span = 0.92218
# Epoch   8: Valid Precision for entity start span = 0.92218
# Epoch   8: Valid f1_score for entity end span = 0.90911
# Epoch   8: Valid Acurracy for entity end span = 0.90911
# Epoch   8: Valid Recall for entity end span = 0.90911
# Epoch   8: Valid Precision for entity end span = 0.90911
# The current f1 score for entity start: 0.9221813725490197
# The current f1 score for entity end: 0.909109477124183
# Epoch   9: Train Loss = 12.67953
# Epoch   9: Valid Loss = 12.16913
# Epoch   9: Valid f1_score for entity start span = 0.92123
# Epoch   9: Valid Acurracy for entity start span = 0.92123
# Epoch   9: Valid Recall for entity start span = 0.92123
# Epoch   9: Valid Precision for entity start span = 0.92123
# Epoch   9: Valid f1_score for entity end span = 0.91959
# Epoch   9: Valid Acurracy for entity end span = 0.91959
# Epoch   9: Valid Recall for entity end span = 0.91959
# Epoch   9: Valid Precision for entity end span = 0.91959
# Epoch  10: Train Loss = 12.66456
# Epoch  10: Valid Loss = 12.15917
# Epoch  10: Valid f1_score for entity start span = 0.92450
# Epoch  10: Valid Acurracy for entity start span = 0.92450
# Epoch  10: Valid Recall for entity start span = 0.92450
# Epoch  10: Valid Precision for entity start span = 0.92450
# Epoch  10: Valid f1_score for entity end span = 0.92470
# Epoch  10: Valid Acurracy for entity end span = 0.92470
# Epoch  10: Valid Recall for entity end span = 0.92470
# Epoch  10: Valid Precision for entity end span = 0.92470
# The current f1 score for entity start: 0.9244961873638343
# The current f1 score for entity end: 0.9247004357298474
# Epoch  11: Train Loss = 12.66847
# Epoch  11: Valid Loss = 12.15288
# Epoch  11: Valid f1_score for entity start span = 0.92919
# Epoch  11: Valid Acurracy for entity start span = 0.92919
# Epoch  11: Valid Recall for entity start span = 0.92919
# Epoch  11: Valid Precision for entity start span = 0.92919
# Epoch  11: Valid f1_score for entity end span = 0.92490
# Epoch  11: Valid Acurracy for entity end span = 0.92490
# Epoch  11: Valid Recall for entity end span = 0.92490
# Epoch  11: Valid Precision for entity end span = 0.92490
# The current f1 score for entity start: 0.9291938997821351
# The current f1 score for entity end: 0.9249046840958605
# Epoch  12: Train Loss = 12.66179
# Epoch  12: Valid Loss = 12.14764
# Epoch  12: Valid f1_score for entity start span = 0.93001
# Epoch  12: Valid Acurracy for entity start span = 0.93001
# Epoch  12: Valid Recall for entity start span = 0.93001
# Epoch  12: Valid Precision for entity start span = 0.93001
# Epoch  12: Valid f1_score for entity end span = 0.92647
# Epoch  12: Valid Acurracy for entity end span = 0.92647
# Epoch  12: Valid Recall for entity end span = 0.92647
# Epoch  12: Valid Precision for entity end span = 0.92647
# The current f1 score for entity start: 0.9300108932461874
# The current f1 score for entity end: 0.9264705882352942
# Epoch  13: Train Loss = 12.66403
# Epoch  13: Valid Loss = 12.14646
# Epoch  13: Valid f1_score for entity start span = 0.92913
# Epoch  13: Valid Acurracy for entity start span = 0.92913
# Epoch  13: Valid Recall for entity start span = 0.92913
# Epoch  13: Valid Precision for entity start span = 0.92913
# Epoch  13: Valid f1_score for entity end span = 0.93076
# Epoch  13: Valid Acurracy for entity end span = 0.93076
# Epoch  13: Valid Recall for entity end span = 0.93076
# Epoch  13: Valid Precision for entity end span = 0.93076
# Epoch  14: Train Loss = 12.66945
# Epoch  14: Valid Loss = 12.14459
# Epoch  14: Valid f1_score for entity start span = 0.93117
# Epoch  14: Valid Acurracy for entity start span = 0.93117
# Epoch  14: Valid Recall for entity start span = 0.93117
# Epoch  14: Valid Precision for entity start span = 0.93117
# Epoch  14: Valid f1_score for entity end span = 0.92872
# Epoch  14: Valid Acurracy for entity end span = 0.92872
# Epoch  14: Valid Recall for entity end span = 0.92872
# Epoch  14: Valid Precision for entity end span = 0.92872
# The current f1 score for entity start: 0.9311683006535948
# The current f1 score for entity end: 0.9287173202614379
# Epoch  15: Train Loss = 12.65830
# Epoch  15: Valid Loss = 12.14034
# Epoch  15: Valid f1_score for entity start span = 0.93144
# Epoch  15: Valid Acurracy for entity start span = 0.93144
# Epoch  15: Valid Recall for entity start span = 0.93144
# Epoch  15: Valid Precision for entity start span = 0.93144
# Epoch  15: Valid f1_score for entity end span = 0.93267
# Epoch  15: Valid Acurracy for entity end span = 0.93267
# Epoch  15: Valid Recall for entity end span = 0.93267
# Epoch  15: Valid Precision for entity end span = 0.93267
# The current f1 score for entity start: 0.9314406318082789
# The current f1 score for entity end: 0.9326661220043573
# Epoch  16: Train Loss = 12.66533
# Epoch  16: Valid Loss = 12.13792
# Epoch  16: Valid f1_score for entity start span = 0.93103
# Epoch  16: Valid Acurracy for entity start span = 0.93103
# Epoch  16: Valid Recall for entity start span = 0.93103
# Epoch  16: Valid Precision for entity start span = 0.93103
# Epoch  16: Valid f1_score for entity end span = 0.93226
# Epoch  16: Valid Acurracy for entity end span = 0.93226
# Epoch  16: Valid Recall for entity end span = 0.93226
# Epoch  16: Valid Precision for entity end span = 0.93226
# trigger times: 1
# Epoch  17: Train Loss = 12.65430
# Epoch  17: Valid Loss = 12.13248
# Epoch  17: Valid f1_score for entity start span = 0.93382
# Epoch  17: Valid Acurracy for entity start span = 0.93382
# Epoch  17: Valid Recall for entity start span = 0.93382
# Epoch  17: Valid Precision for entity start span = 0.93382
# Epoch  17: Valid f1_score for entity end span = 0.93627
# Epoch  17: Valid Acurracy for entity end span = 0.93627
# Epoch  17: Valid Recall for entity end span = 0.93627
# Epoch  17: Valid Precision for entity end span = 0.93627
# The current f1 score for entity start: 0.9338235294117647
# The current f1 score for entity end: 0.9362745098039216
# Epoch  18: Train Loss = 12.65513
# Epoch  18: Valid Loss = 12.13160
# Epoch  18: Valid f1_score for entity start span = 0.93423
# Epoch  18: Valid Acurracy for entity start span = 0.93423
# Epoch  18: Valid Recall for entity start span = 0.93423
# Epoch  18: Valid Precision for entity start span = 0.93423
# Epoch  18: Valid f1_score for entity end span = 0.93546
# Epoch  18: Valid Acurracy for entity end span = 0.93546
# Epoch  18: Valid Recall for entity end span = 0.93546
# Epoch  18: Valid Precision for entity end span = 0.93546
# Epoch  19: Train Loss = 12.65397
# Epoch  19: Valid Loss = 12.13070
# Epoch  19: Valid f1_score for entity start span = 0.93403
# Epoch  19: Valid Acurracy for entity start span = 0.93403
# Epoch  19: Valid Recall for entity start span = 0.93403
# Epoch  19: Valid Precision for entity start span = 0.93403
# Epoch  19: Valid f1_score for entity end span = 0.93648
# Epoch  19: Valid Acurracy for entity end span = 0.93648
# Epoch  19: Valid Recall for entity end span = 0.93648
# Epoch  19: Valid Precision for entity end span = 0.93648
# The current f1 score for entity start: 0.9340277777777778
# The current f1 score for entity end: 0.9364787581699346
# 0.9340277777777778 0.9364787581699346
# The best parameters are saved for the activation function: Softplus

# %%
list_entity_training_losses.append(list_entity_loss_train_leakyrelu_span_encoded)
list_entity_validation_losses.append(list_entity_loss_valid_leakyrelu_span_encoded)
list_entity_span_encoded_epochs.append(list_epochs_leakyrelu_span_encoded)
list_entity_training_losses.append(list_entity_loss_train_tanhshrink_span_encoded)
list_entity_validation_losses.append(list_entity_loss_valid_tanhshrink_span_encoded)
list_entity_span_encoded_epochs.append(list_epochs_tanhshrink_span_encoded)
list_entity_training_losses.append(list_entity_loss_train_softplus_span_encoded)
list_entity_validation_losses.append(list_entity_loss_valid_softplus_span_encoded)
list_entity_span_encoded_epochs.append(list_epochs_softplus_span_encoded)
list_entity_training_losses.append(list_entity_loss_train_elu_span_encoded)
list_entity_validation_losses.append(list_entity_loss_valid_elu_span_encoded)
list_entity_span_encoded_epochs.append(list_epochs_elu_span_encoded)

# %%
plot_losses(list_entity_span_encoded_epochs, list_entity_training_losses, list_entity_validation_losses, activations, learning_rate, dropout_prob)
