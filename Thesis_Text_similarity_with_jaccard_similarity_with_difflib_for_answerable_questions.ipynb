# %% [markdown]
# **I import some useful libraries in python.**

# %%
import difflib
import operator as op
import random
import numpy as np
import pandas as pd
import torch
import torch.backends.cudnn
from numpy.random import MT19937
from numpy.random import RandomState, SeedSequence
from torch.optim import Adam
from transformers import get_linear_schedule_with_warmup
import os
from google.colab import drive
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt
import torch.nn as nn
from transformers import BertModel
from transformers import BertTokenizerFast

# %% [markdown]
# **I mount google drive because all the files (for example .csv) that i used for the implementation of my thesis are saved on my google drive.**

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Check of the device that it is used for the implementation of the notebooks of this thesis, that is determined from google colab.**

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Device available for running: ")
print(device)
# Out:
# Device available for running:
# cuda

# %% [markdown]
# **Reading of the created datasets (for both the SimpleQuestions dataset that includes all training and validation questions and the SimpleQuestions subset that includes only answerable over wikidata questions) as .csv file.**

# %%
train_dataset = pd.read_csv("drive/MyDrive/train_answerable_questions_dataset.csv", sep = ',')
validation_dataset = pd.read_csv("drive/MyDrive/valid_answerable_questions_dataset.csv", sep = ',')
print(train_dataset)
print(validation_dataset)
# Out:
#        entity_id      entity_label relation_id  \
# 0         Q12439           Detroit         R19
# 1       Q6817891       Mera Shikar        P364
# 2          Q1297           Chicago        R276
# 3        Q193592        midfielder        R413
# 4       Q6849115     Mike Twellman        P413
# ...          ...               ...         ...
# 19476    Q223960    mountain tapir        P171
# 19477   Q1535153    superhero film        R136
# 19478    Q157443       comedy film        R136
# 19479  Q16093542    Anthony Bailey         P27
# 19480    Q926822  Gaston Filgueira         P21
#
#                                                 Question
# 0                      who is a musician born in detroit
# 1      what is the language in which mera shikar was ...
# 2      Whats the name of a battle that happened in ch...
# 3              what player plays the position midfielder
# 4         what is the position that  mike twellman plays
# ...                                                  ...
# 19476  what classification does  mountain tapir come ...
# 19477   What a superhero movie that premiered on toonami
# 19478  What is the name of a comedy film that is also...
# 19479          What is the nationality of anthony bailey
# 19480                    What gender is gaston filgueira
#
# [19481 rows x 4 columns]
#      entity_id            entity_label relation_id  \
# 0      Q318926           Sasha Vujacic         P19
# 1     Q2568216       Wiebke Carolsfeld         R57
# 2     Q2275923  Seymour Parker Gilbert        P106
# 3     Q2856873        Antoine de Fevin         P20
# 4      Q522966           Jamie Hewlett        P106
# ...        ...                     ...         ...
# 2816  Q7111404             OutNumbered        P178
# 2817  Q3480757          Seumas O'Kelly         P21
# 2818  Q3709870          Herby Fortunat        P413
# 2819  Q2981169       Nikolaj Frobenius        P106
# 2820      Q174               Sao Paulo         R19
#
#                                                Question
# 0                          where was sasha vujacic born
# 1          What is a film directed by wiebke carolsfeld
# 2            What was Seymour Parker Gilbert profession
# 3         in what french city did antoine de fevin die
# 4                      What job does jamie hewlett have
# ...                                                 ...
# 2816                          who developed outnumbered
# 2817                  what is the sex of seumas o'kelly
# 2818  which position did herby fortunat play in foot...
# 2819               What is nikolaj frobenius profession
# 2820         who is a person that was born in sao paulo
#
# [2821 rows x 4 columns]

# %% [markdown]
# **Check if  the SimpleQuestions training and validation dataset have at least one line with null value. This issues both for SimpleQuestions dataset that includes only answerable over wikidata questions and for the corresponding dataset that includes all the questions.**

# %%
train_dataset.dropna(inplace = True)
validation_dataset.dropna(inplace = True)
print(train_dataset)
print(validation_dataset)
# Out:
#        entity_id      entity_label relation_id  \
# 0         Q12439           Detroit         R19
# 1       Q6817891       Mera Shikar        P364
# 2          Q1297           Chicago        R276
# 3        Q193592        midfielder        R413
# 4       Q6849115     Mike Twellman        P413
# ...          ...               ...         ...
# 19476    Q223960    mountain tapir        P171
# 19477   Q1535153    superhero film        R136
# 19478    Q157443       comedy film        R136
# 19479  Q16093542    Anthony Bailey         P27
# 19480    Q926822  Gaston Filgueira         P21
#
#                                                 Question
# 0                      who is a musician born in detroit
# 1      what is the language in which mera shikar was ...
# 2      Whats the name of a battle that happened in ch...
# 3              what player plays the position midfielder
# 4         what is the position that  mike twellman plays
# ...                                                  ...
# 19476  what classification does  mountain tapir come ...
# 19477   What a superhero movie that premiered on toonami
# 19478  What is the name of a comedy film that is also...
# 19479          What is the nationality of anthony bailey
# 19480                    What gender is gaston filgueira
#
# [19481 rows x 4 columns]
#      entity_id            entity_label relation_id  \
# 0      Q318926           Sasha Vujacic         P19
# 1     Q2568216       Wiebke Carolsfeld         R57
# 2     Q2275923  Seymour Parker Gilbert        P106
# 3     Q2856873        Antoine de Fevin         P20
# 4      Q522966           Jamie Hewlett        P106
# ...        ...                     ...         ...
# 2816  Q7111404             OutNumbered        P178
# 2817  Q3480757          Seumas O'Kelly         P21
# 2818  Q3709870          Herby Fortunat        P413
# 2819  Q2981169       Nikolaj Frobenius        P106
# 2820      Q174               Sao Paulo         R19
#
#                                                Question
# 0                          where was sasha vujacic born
# 1          What is a film directed by wiebke carolsfeld
# 2            What was Seymour Parker Gilbert profession
# 3         in what french city did antoine de fevin die
# 4                      What job does jamie hewlett have
# ...                                                 ...
# 2816                          who developed outnumbered
# 2817                  what is the sex of seumas o'kelly
# 2818  which position did herby fortunat play in foot...
# 2819               What is nikolaj frobenius profession
# 2820         who is a person that was born in sao paulo
#
# [2821 rows x 4 columns]

# %% [markdown]
# **Creation of the corresponding lists containing the questions, the entity labels, the relation ids and the entity ids of the corresponding SimpleQuestions datasets (training, validation), either this dataset includes answerable and answerable questions over wikidata questions or only answerable questions over wikidata.**

# %%
train_entity_labels = train_dataset['entity_label'].to_list()
validation_entity_labels = validation_dataset['entity_label'].to_list()
train_entityids = train_dataset['entity_id'].to_list()
validation_entityids = validation_dataset['entity_id'].to_list()
train_questions = train_dataset['Question'].to_list()
validation_questions = validation_dataset['Question'].to_list()
train_relationids = train_dataset['relation_id'].to_list()
validation_relationids = validation_dataset['relation_id'].to_list()
print(len(train_entity_labels), len(train_entityids), len(train_relationids), len(train_questions))
# Out:
# 19481 19481 19481 19481

# %% [markdown]
# **The maximum question length that is observed in SimpleQuestions training and validation dataset is found below.**

# %%
#Below the max questions length is found for all questions.
quests = train_questions + validation_questions
print(len(quests), len(train_questions), len(validation_questions))
# Printing concatenated list
q_lengths = []
for s in range(len(quests)): #padding
    q_lengths.append(len(quests[s].split()))
max_question_length = max(q_lengths)
print(max_question_length)#Max question length
# Out:
# 22302 19481 2821
# 33

# %% [markdown]
# **Creation of the relation vocabulary that includes all the unique entity ids of the SimpleQuestions training and validation dataset through function relation_vocabulary. Also the index of each unique relation id of the relation vocabulary in this vocabulary is found through the function find_relations_index.**

# %%
#Create relation vocabulary for each question of train and validation dataset
def relation_vocabulary(relation_column_dataset):
  relation_vocabulary = []
   #In order to have the unique relation ids it is important to check if an relation id is already in the relation_vocabulary
  for relation in range(len(relation_column_dataset)):
    g = 0
    for i in range(len(relation_vocabulary)):
      if relation_column_dataset[relation] != relation_vocabulary[i]: #relation is not found yet
        g += 1
      else:
       continue
    if g == len(relation_vocabulary) and relation_column_dataset[relation] not in relation_vocabulary:
      relation_vocabulary.append(relation_column_dataset[relation]) #The relation id is not inside the relation vocabulary
      #which has some relations already or the relation vocaulary has no relations
  return relation_vocabulary

def find_relation_index(relation_vocabulary,relation_ids_column):
  relations_count = []
  for relation in range(len(relation_ids_column)):
        relations_count.append(relation_vocabulary.index(relation_ids_column[relation]))

  return relations_count
#relation_ids = pd.concat([train_dataset["relation_id"], validation_dataset["relation_id"]], ignore_index = True)
relation_ids = train_relationids + validation_relationids
print(len(relation_ids))
rel_vocab = relation_vocabulary(relation_ids)
rel_vocab_length = len(rel_vocab)
print(rel_vocab, rel_vocab_length)
train_relations_index = find_relation_index(rel_vocab, train_relationids)
validation_relations_index = find_relation_index(rel_vocab, validation_relationids)
# Out:
# 22302
# ['R19', 'P364', 'R276', 'R413', 'P413', 'R136', 'P27', 'P21', 'R106', 'P196', 'P175', 'R175', 'R50', 'P344', 'P136', 'P641', 'P19', 'P421', 'R57', 'P170', 'R17', 'P86', 'R58', 'R86', 'P1142', 'P58', 'P131', 'P495', 'P150', 'R131', 'P119', 'R1303', 'P50', 'R40', 'P61', 'R172', 'P264', 'P57', 'P179', 'P509', 'R509', 'P20', 'P138', 'P397', 'R344', 'P106', 'P272', 'P403', 'P31', 'P607', 'P407', 'P140', 'R162', 'R641', 'R404', 'P172', 'R178', 'R421', 'P123', 'P59', 'P40', 'P276', 'P178', 'R272', 'P737', 'R179', 'P398', 'P17', 'P1303', 'P144', 'P112', 'R170', 'R105', 'R59', 'P113', 'R607', 'P155', 'P162', 'R149', 'P404', 'R1040', 'R177', 'P710', 'P1408', 'R119', 'R21', 'R112', 'R138', 'P676', 'R123', 'P149', 'R264', 'P65', 'P177', 'R144', 'P53', 'R31', 'R287', 'P115', 'P105', 'P1040', 'P156', 'P289', 'R171', 'P1029', 'R115', 'P171', 'R1431', 'P1431', 'P376', 'R676', 'R1142', 'P84', 'R376', 'P826', 'R161', 'P287', 'P81', 'P800', 'P279', 'R176', 'R289', 'P189', 'P176', 'R279'] 125

# %% [markdown]
# **The function create\_question\_parts, takes as arguments the splitted question splitted into words and the entity label also splitted into words.
# Essentially in this function each question, as well as the corresponding entity label, is splitted into words using python method split() and then, using python method join(), parts of the query are created equal in length to that of their splitted entity label in words.**
#
# **These parts are stored in a list as well as the indexes of the initial word and final word of these question parts are stored in dictionaries with keys the question parts and values the indexes(positions) of the initial words and final words for each question. Finally this function returns the list of question parts and dictionaries containing the indexes(positions) of the initial words and final words for each question part.**

# %%
def create_question_parts(question_splitted, entity_splited_length):
  Quests_Parts = []
  Quest_Parts_Start = {}
  Quest_Parts_End = {}
  for i in range(len(question_splitted)-entity_splited_length+1):
    quest_part = " ".join(question_splitted[i:i+entity_splited_length])
    Quests_Parts.append(quest_part)
    Quest_Parts_Start[quest_part] = i
    Quest_Parts_End[quest_part] = i+entity_splited_length-1
  return Quests_Parts, Quest_Parts_Start, Quest_Parts_End

# %% [markdown]
# **Custom function for the jaccard similarity metric between two lists of words.**

# %%
def jaccard_similarity(encoding1, encoding2):
  """ returns the jaccard similarity between two encodings """
  intersection_cardinality = len(set.intersection(*[set(encoding1), set(encoding2)]))
  union_cardinality = len(set.union(*[set(encoding1), set(encoding2)]))
  return intersection_cardinality/float(union_cardinality) if union_cardinality != 0 else 0

# %% [markdown]
# **The function through which the embeddings are created via Sentence Transformer and uses the cosine similarity function is the function best_match_with_jaccard_similarity, which takes as arguments the entity label, the list of query segments, the dictionaries containing the indexes(positions) of the start words and end words for each question part mentioned above, as well as the similarity model of Sentence Transformer and returns the question part that has the highest similarity and the position of the initial and final word of that question part, otherwise if there is no such question part it returns None as the question part and as the index and for the initial and final word of the entity label the value -1.**

# %%
# Finds best match based on their similarity
def best_match_with_jaccard_similarity(entity, question_parts, Start_Indexes, End_Indexes):
           similarity_scores = {}
           for q in range(len(question_parts)):
    # Find similarity scores between entity and each question part in question
            similarity_scores[question_parts[q]] = jaccard_similarity(entity, question_parts[q].split())
    # Return the highest similarity score from all question parts as a list
           if similarity_scores == {}:
            return None, -1, -1
           Q = dict(sorted(similarity_scores.items(), key = lambda x: x[1], reverse = True))
           EntitiesList = [key for key in Q]
           return EntitiesList[0], Start_Indexes[EntitiesList[0]], End_Indexes[EntitiesList[0]]

# %% [markdown]
# **The entity_span function where the entity span start and entity span end indexes are found for each question, takes as arguments the list of all questions of SimpleQuestions training or validation dataset, the list of all entity labels of SimpleQuestions training or validation dataset in question and the similarity model of Sentence Transformer.**
#
# **This function calls the functions create_question_parts and best_match_with_jaccard_similarity in order to create the parts of each question and find the question part that is equal to the entity label of the question with its start word index and end word index and returns the list of indexes (positions) of the initial words of the entity labels within the query (entity span start indexes) and the list of indexes (positions) of the final words of the entity labels within the query (entity span end indexes).**
#
# **Finally for the questions where no question part identical or similar to the corresponding entity label has been found, the positions (indices) of the penultimate (question length-2) and the last word (question length-1) are set as entity start index and entity end index respectively.**

# %%
def entity_span(question_column, entity_label_column):
  entity_start_column = []
  entity_end_column = []
  #Count for how many questions there is no question part that is equal or similar(finding with difflib.get_close_matches() or jaccard similarity metric)
  #to the corresponding entity label.
  count_entity_with_no_similarity = 0
  for q in range(len(question_column)):
    # Find the word that performs the biggest similarity
      quest = question_column[q].lower().split()
      entity_label = entity_label_column[q].lower()
      ent_label = entity_label.split()
      entity_label_splited_length = len(ent_label)
      Quests_Parts, Quest_Parts_Start, Quest_Parts_End = create_question_parts(quest, entity_label_splited_length)
      Entity = difflib.get_close_matches(entity_label, Quests_Parts, 1)
      if (Entity != []):
        # Beginning and end of span
        Entity_start_index = Quest_Parts_Start[Entity[0]]
        Entity_end_index = Quest_Parts_End[Entity[0]]
        entity_start_column.append(Entity_start_index)
        entity_end_column.append(Entity_end_index)
      else:
        Entity, Entity_start_index, Entity_end_index = best_match_with_jaccard_similarity(ent_label, Quests_Parts, Quest_Parts_Start, Quest_Parts_End)
        if Entity is None:
        # Beginning and end of span
         entity_start_column.append(len(quest)-2)
         entity_end_column.append(len(quest)-1)
         count_entity_with_no_similarity += 1
        else:
         print(q, Entity, Entity_start_index, Entity_end_index)
         entity_start_column.append(Entity_start_index)
         entity_end_column.append(Entity_end_index)
  print(count_entity_with_no_similarity)
  return entity_start_column, entity_end_column

# %%
train_entity_span_start, train_entity_span_end = entity_span(train_questions, train_entity_labels)
# Out:
# 46 of zou 5 6
# 111 is tet 4 5
# 113 what does 0 1
# 148 which nation filmed then and now 0 5
# 317 what are 0 1
# 385 what coast 0 1
# 393 what is 0 1
# 408 what 0 0
# 436 film drama 3 4
# 648 is seraphin: un homme 0 3
# 676 is menachem meiri male 0 3
# 678 what kind of 0 2
# 775 produced the film illusions 2 5
# 777 what time zone 0 2
# 988 dynasty is abbas 1 3
# 1009 which language 0 1
# 1011 what title 0 1
# 1016 what genre is blade of the 0 5
# 1027 what gender 0 1
# 1190 where does chinese connection 0 3
# 1234 providence is halle 1 3
# 1235 game with single-player 2 4
# 1265 what country 0 1
# 1283 division evros 5 6
# 1360 stadium does astros 1 3
# 1387 where did lord hawke pass 0 4
# 1420 where does crooked river originate 0 4
# 1426 what 0 0
# 1490 what 0 0
# 1509 in 0 0
# 1547 what label 0 1
# 1566 who directed the movie 0 3
# 1634 name an 0 1
# 1886 the drama 6 7
# 2048 family film 6 7
# 2158 game features multiplayer 2 4
# 2188 are produced by dileep 2 5
# 2210 where was 0 1
# 2216 where is charles leclerc 0 3
# 2235 country is antwerp 1 3
# 2368 what is 0 1
# 2395 in what country was 0 3
# 2412 which 0 0
# 2429 who is 0 1
# 2444 which country did the film 0 4
# 2480 position does sergi 1 3
# 2495 in what city 0 2
# 2497 what 0 0
# 2541 what 0 0
# 2623 which genre 0 1
# 2626 netflix drama 8 9
# 2667 henry viii and his six wives 5 10
# 2684 game requires multiplayer 1 3
# 2709 what is 0 1
# 2917 french drama 4 5
# 2930 is love 2 3
# 2944 what 0 0
# 2960 what 0 0
# 3090 what country 0 1
# 3093 game requires multiplayer 1 3
# 3120 which 0 0
# 3219 what country was the 1 4
# 3293 is florina 2 3
# 3295 what 0 0
# 3311 where 0 0
# 3369 what type 0 1
# 3398 plays keyboard 2 3
# 3410 netflix drama 5 6
# 3454 is lyja 0 1
# 3484 film is maradona 3 5
# 3491 which country was freedom 0 3
# 3511 (11463) 1981 0 1
# 3516 is nana 1 2
# 3567 who produced 0 1
# 3769 what country 0 1
# 3786 name a game 0 2
# 3828 was frank holl 4 6
# 3909 what are 0 1
# 3970 parent of walter mantell 3 6
# 3999 what film 0 1
# 4012 what is 0 1
# 4031 in what country 0 2
# 4119 what game can 0 2
# 4185 what language was 0 2
# 4273 what 0 0
# 4315 what 0 0
# 4346 what 0 0
# 4349 what 0 0
# 4351 what kind of 0 2
# 4411 city was john herschel 2 5
# 4448 what 0 0
# 4503 what is 0 1
# 4524 is the 1 2
# 4543 where was fathers estate filmed 0 4
# 4607 is 0 0
# 4696 what type of 0 2
# 4797 which record 0 1
# 4805 what country filmed my 0 3
# 4916 what 0 0
# 4942 in the united states 3 6
# 4952 what type of videogame 0 3
# 4977 theodore roosevelt 1905 presidential inauguration 2 6
# 4987 what is the 0 2
# 5045 what 0 0
# 5047 what does 0 1
# 5110 which gender 0 1
# 5200 who directed the 0 2
# 5299 which 0 0
# 5361 love by 0 1
# 5428 what 0 0
# 5459 what is 0 1
# 5480 which language is kolejnosc 0 3
# 5613 what language is 0 2
# 5621 what is the 0 2
# 5627 morrowind is under what genre 0 4
# 5650 what games have 0 2
# 5770 netflix drama 9 10
# 5925 what country 0 1
# 6046 what type 0 1
# 6050 what 0 0
# 6091 is fanny 0 1
# 6134 dong bin 3 4
# 6205 what 0 0
# 6211 what instruments 0 1
# 6336 in the united states 5 8
# 6370 seven up 3 4
# 6587 what is 0 1
# 6661 name a 0 1
# 6669 what instrument 0 1
# 6783 what are 0 1
# 6859 what country was 203 kochi 0 4
# 6866 of a game 4 6
# 6881 the genre specification of 2 5
# 6903 the streets of the 3 6
# 6920 of mistral air 4 6
# 6987 genre drama 10 11
# 7036 who 0 0
# 7040 a computer game 2 4
# 7100 country places cochiti 1 3
# 7127 game requires single-player 1 3
# 7223 gameplay modes in crazy taxi 5 9
# 7256 experimental metal 3 4
# 7294 what rank 0 1
# 7335 who 0 0
# 7379 what 0 0
# 7458 who developed 0 1
# 7491 name a 0 1
# 7597 what 0 0
# 7602 what 0 0
# 7845 where was 0 1
# 7876 what 0 0
# 8054 what is 0 1
# 8127 action video game 4 6
# 8138 what kind of book 0 3
# 8181 what 0 0
# 8184 sam-yuk yoon 2 3
# 8245 what 0 0
# 8363 which 0 0
# 8390 what 0 0
# 8407 which nation filmed 0 2
# 8472 what 0 0
# 8508 who wrote the film 0 3
# 8665 video game 6 7
# 8691 what is 0 1
# 8758 what kind of tv program 0 4
# 9006 which astrological 0 1
# 9016 in the united states 3 6
# 9036 who is 0 1
# 9041 the 0 0
# 9049 which 0 0
# 9117 daniel williams king 4 6
# 9118 is the cinematographer for pirates of the 1 7
# 9129 what is 0 1
# 9135 born in mercia 2 4
# 9138 what kind of 0 2
# 9168 where was 0 1
# 9250 what language 0 1
# 9263 what country is 0 2
# 9376 black-bellied plover 6 7
# 9389 anatolyevich davydov 3 4
# 9417 a brazilian popular 2 4
# 9452 what type 0 1
# 9478 what team plays 0 2
# 9505 what types of gameplay is 0 4
# 9538 what does 0 1
# 9593 where 0 0
# 9612 game by legendo 3 5
# 9721 who is responsible 0 2
# 9771 that namco bandai 5 7
# 9778 is the manager 1 3
# 9789 who developed the cvg fire emblem: seisen 0 6
# 9935 artist of the painting portrait of maffeo barberini 3 10
# 10123 where is 0 1
# 10134 whats 0 0
# 10264 which 0 0
# 10324 the 0 0
# 10335 what genre is saturday morning 0 4
# 10386 what religion does karan singh follow 0 5
# 10389 what is 0 1
# 10432 what country did the 0 3
# 10435 what artist is on perry como love 0 6
# 10451 where 0 0
# 10458 which film 0 1
# 10462 what 0 0
# 10468 who played 0 1
# 10482 what is aleksandar karadordevic gender 0 4
# 10490 of a game 4 6
# 10498 by the united states 5 8
# 10513 what language is 0 2
# 10521 what an 0 1
# 10535 book is fables 3 5
# 10545 what is the 0 2
# 10598 what type of 0 2
# 10677 what title 0 1
# 10686 what category 0 1
# 10740 which latin american country 0 3
# 10840 what 0 0
# 10946 what language was 0 2
# 10959 where was 0 1
# 10960 what language is 0 2
# 10986 of musical album was the godfather 2 7
# 11057 which gender 0 1
# 11071 who created the 0 2
# 11073 what is the 0 2
# 11099 live in pittsburgh 5 7
# 11123 1992 film 1 2
# 11134 which 0 0
# 11172 what subject is by the artist 0 5
# 11359 was shane 1 2
# 11377 what type 0 1
# 11434 is 0 0
# 11566 who 0 0
# 11607 what language 0 1
# 11642 what country is the 0 3
# 11692 that features single-player 5 7
# 11742 which fictional 0 1
# 11763 of waikato 5 6
# 11789 which 0 0
# 11826 what is the architectural style of 33 0 6
# 11870 what 0 0
# 11888 which country was 0 2
# 11920 of somnath 5 6
# 11980 what 0 0
# 12005 form activision 3 4
# 12060 where 0 0
# 12125 did saheb qiblah fultali 1 4
# 12191 is daviddevantandhisspiritwife indie rock or classical 0 5
# 12228 name a 0 1
# 12262 what county did la 0 3
# 12286 does charles 0 1
# 12316 which language is as-salam al-malaki 0 4
# 12387 what 0 0
# 12429 what religion is 0 2
# 12497 what country 0 1
# 12517 which country 0 1
# 12555 what is 0 1
# 12557 the song poison 5 7
# 12598 of sybil 4 5
# 12625 is 0 0
# 12709 harrison coon 3 4
# 12743 is a game 1 3
# 12798 what is the mode that kings quest 0 6
# 12835 netflix drama 4 5
# 12837 what type of movie 0 3
# 12849 which 0 0
# 12851 what kind of film 0 3
# 12882 what 0 0
# 12887 what is 0 1
# 12895 what is 0 1
# 12922 in the series socom 3 6
# 13006 what 0 0
# 13014 1994 drama 6 7
# 13037 where was 0 1
# 13072 what 0 0
# 13077 which label 0 1
# 13197 what game was 0 2
# 13284 a drama 3 4
# 13296 what is the 0 2
# 13319 in the united states 5 8
# 13350 what 0 0
# 13351 where did 0 1
# 13357 who is 0 1
# 13365 game has single-player 1 3
# 13408 what 0 0
# 13470 in gilan 3 4
# 13486 what 0 0
# 13596 what observatory 0 1
# 13666 where was 0 1
# 13698 what 0 0
# 13754 maruf mohammadi plays 0 2
# 13805 in laconia 5 6
# 13848 location in united states 3 6
# 13892 is the 2 3
# 13946 which country 0 1
# 14009 artist that released lullaby 3 6
# 14028 what is the country samson and 0 5
# 14089 easy money ii 6 8
# 14156 name an 0 1
# 14202 game requires single-player 1 3
# 14313 what genre is gremlins 2 0 4
# 14418 which language is the 0 3
# 14515 is drama 2 3
# 14612 the composer of the fair melusine 2 7
# 14621 what country 0 1
# 14663 what 0 0
# 14674 exclusive racing game 3 5
# 14685 what is the place 0 3
# 14708 what 0 0
# 14720 what film 0 1
# 14724 famous jewish 3 4
# 14735 which type 0 1
# 14877 is drama 2 3
# 14913 manaus iranduba bridge 6 8
# 15021 which 0 0
# 15030 who 0 0
# 15087 in the united states 4 7
# 15088 was alfonso duke of anjou and cadiz 1 7
# 15089 what 0 0
# 15155 what is 0 1
# 15280 who directed the 0 2
# 15308 who was anne cecil mom 0 4
# 15323 what kinds of 0 2
# 15347 to bira 4 5
# 15485 what title 0 1
# 15503 what 0 0
# 15504 what 0 0
# 15545 what american 0 1
# 15799 blind date in 3 5
# 15931 what type 0 1
# 15945 which game has 0 2
# 16126 which artist 0 1
# 16147 publisher activision 9 10
# 16267 under what 0 1
# 16287 what is a 0 2
# 16322 by activision 5 6
# 16411 what is 0 1
# 16428 what amadeo i of spain male 0 5
# 16436 what genre 0 1
# 16516 of the united states 6 9
# 16525 what is 0 1
# 16634 of a game 4 6
# 16638 chase the woman 4 6
# 16661 where was 0 1
# 16761 what east 0 1
# 16777 where was 0 1
# 16784 what 0 0
# 16797 was 0 0
# 16802 is mo 4 5
# 16824 for 80 0 1
# 16872 what 0 0
# 17010 what 0 0
# 17057 what region 0 1
# 17078 which album was 0 2
# 17105 in the united states 9 12
# 17107 what 0 0
# 17109 is featured in 2 4
# 17132 is intellivision world series baseball 5 9
# 17166 what 0 0
# 17238 what movie 0 1
# 17249 where was 0 1
# 17271 position does rhayner 1 3
# 17277 what genre of music 0 3
# 17325 a computer game 2 4
# 17347 what is 0 1
# 17353 made the music for the 1 5
# 17370 was cry of the penguins 2 6
# 17395 describe lucia 6 7
# 17469 where was proto nekrotafio 0 3
# 17589 which country is anglagard - andra sommaren 0 6
# 17637 which 0 0
# 17640 what type of music 0 3
# 17698 what country is enter zombie king from 0 6
# 17721 where is located 0 2
# 17788 what 0 0
# 17798 which nordic country 0 2
# 17847 what artist is 0 2
# 18100 the artist in the film edward scissorhands 2 8
# 18111 namesake of john herschel 3 6
# 18165 which country is lunguinha from 0 4
# 18206 of bridge is the 2 5
# 18260 which european nation 0 2
# 18274 what film genre is 0 3
# 18306 language is transit 1 3
# 18399 is spoken in the 2 5
# 18411 what kind 0 1
# 18535 plays percussion 1 2
# 18539 netflix drama 6 7
# 18559 what is the 0 2
# 18684 which 0 0
# 18733 what 0 0
# 18778 what movie 0 1
# 18802 which 0 0
# 18821 what 0 0
# 18873 what language 0 1
# 19006 is a game 1 3
# 19016 what is 0 1
# 19059 what 0 0
# 19125 game allows single-player 1 3
# 19138 in nescopeck 3 4
# 19149 was pritam 2 3
# 19183 born in cartagena 2 4
# 19186 what artists are 0 2
# 19212 what 0 0
# 19309 where 0 0
# 19338 game with multiplayer 2 4
# 19355 what 0 0
# 19386 born in freiburg 3 5
# 10

# %%
validation_entity_span_start, validation_entity_span_end = entity_span(validation_questions, validation_entity_labels)
# Out:
# 11 produce by spyglass 8 10
# 223 what record label worked 0 3
# 295 is a game 1 3
# 320 what is 0 1
# 342 what 0 0
# 359 name one 0 1
# 364 of birth of isabella neville 4 8
# 366 game requires single-player 1 3
# 472 a drama 8 9
# 490 what ethnicity 0 1
# 638 what is 0 1
# 718 which family is cosimo iii de medici from 0 7
# 789 is the 2 3
# 825 did microsoft studios 2 4
# 853 what type 0 1
# 914 the album paris 3 5
# 981 what gender is ancilla 0 3
# 989 which country 0 1
# 996 is vital aza 1 3
# 1067 which person 0 1
# 1074 what 0 0
# 1124 what language was 0 2
# 1130 musical key for symphony no 1 3 8
# 1147 what is 0 1
# 1198 what 0 0
# 1226 which observatory 0 1
# 1255 what 0 0
# 1270 which country 0 1
# 1368 country did the 1 3
# 1454 a drama 1 2
# 1498 kwan-hun lee 1 2
# 1566 of anna 4 5
# 1717 what 0 0
# 1745 what type of 0 2
# 1766 where 0 0
# 1789 what 0 0
# 1828 which actor 0 1
# 1831 what genre 0 1
# 1884 what is 0 1
# 1904 which 0 0
# 1906 what a 0 1
# 1924 what is 0 1
# 1998 what book 0 1
# 2010 is drama 2 3
# 2035 in the united states 7 10
# 2059 netflix drama 7 8
# 2086 what 0 0
# 2093 under what 0 1
# 2107 which country is the 0 3
# 2149 where is 0 1
# 2153 of brig 6 7
# 2154 what 0 0
# 2156 what are 0 1
# 2219 the developer of 2 4
# 2280 musial bridge 7 8
# 2352 which 0 0
# 2358 of the album everybody needs 4 8
# 2418 what baseball 0 1
# 2426 what artist 0 1
# 2489 by rca 5 6
# 2495 the location of elizabeth 2 5
# 2511 what country 0 1
# 2527 family film 4 5
# 2584 netflix drama 6 7
# 2588 what 0 0
# 2654 name a game 0 2
# 2696 published the computer game lego star wars 1 7
# 2726 division in united states 7 10
# 2743 in drammen 3 4
# 2

# %% [markdown]
# **Loading of the Transformers BERT tokenizer BertTokenizerFast.**

# %%
tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
print(train_entity_span_start)
print(train_entity_span_end)
# Out:
# [6, 6, 9, 5, 5, 2, 2, 5, 5, 3, 6, 3, 4, 5, 7, 3, 4, 3, 4, 4, 3, 2, 3, 6, 2, 2, 5, 7, 3, 5, 5, 5, 5, 6, 3, 7, 5, 4, 6, 2, 2, 5, 5, 3, 5, 3, 5, 2, 5, 6, 6, 5, 6, 3, 2, 4, 0, 3, 7, 4, 5, 0, 5, 2, 2, 2, 2, 3, 3, 5, 5, 2, 6, 2, 4, 3, 5, 6, 3, 3, 5, 2, 6, 5, 5, 3, 3, 5, 2, 7, 5, 3, 3, 1, 5, 6, 5, 9, 2, 3, 2, 3, 3, 2, 5, 5, 4, 2, 5, 4, 5, 4, 4, 0, 5, 5, 5, 2, 3, 3, 3, 3, 2, 6, 4, 6, 2, 5, 4, 6, 2, 5, 4, 3, 8, 5, 5, 2, 3, 2, 3, 7, 6, 2, 4, 3, 3, 2, 0, 5, 7, 3, 2, 2, 4, 6, 2, 6, 3, 3, 1, 3, 7, 1, 2, 10, 4, 4, 2, 3, 5, 2, 4, 5, 5, 2, 8, 3, 2, 2, 7, 6, 2, 2, 3, 8, 0, 3, 8, 2, 4, 5, 5, 3, 2, 3, 4, 4, 4, 9, 4, 4, 2, 7, 5, 5, 6, 7, 3, 3, 8, 5, 3, 2, 5, 3, 1, 5, 2, 3, 6, 5, 6, 2, 8, 5, 4, 5, 5, 3, 3, 3, 5, 4, 3, 2, 4, 3, 6, 1, 4, 2, 2, 5, 5, 6, 0, 7, 3, 5, 5, 5, 2, 2, 2, 5, 6, 5, 3, 3, 2, 3, 3, 3, 5, 2, 3, 3, 2, 5, 2, 4, 2, 3, 2, 4, 2, 4, 5, 3, 2, 2, 3, 9, 2, 4, 4, 2, 2, 7, 3, 5, 2, 3, 3, 2, 5, 5, 4, 1, 8, 8, 3, 4, 5, 2, 0, 5, 4, 5, 3, 6, 5, 7, 2, 4, 3, 0, 6, 6, 5, 5, 3, 3, 0, 5, 5, 3, 4, 5, 6, 2, 2, 5, 5, 2, 8, 4, 6, 6, 5, 6, 3, 4, 5, 5, 3, 5, 2, 1, 3, 6, 2, 3, 3, 3, 5, 3, 3, 4, 5, 3, 5, 6, 2, 3, 2, 3, 4, 3, 7, 3, 1, 4, 2, 4, 1, 2, 7, 5, 2, 9, 3, 4, 9, 0, 3, 3, 3, 2, 8, 2, 5, 0, 3, 2, 4, 7, 4, 2, 3, 4, 5, 2, 3, 2, 0, 2, 0, 3, 2, 7, 5, 5, 3, 3, 5, 5, 2, 5, 4, 5, 2, 8, 5, 5, 9, 4, 2, 6, 2, 8, 3, 3, 3, 6, 3, 6, 4, 5, 3, 1, 5, 4, 4, 3, 5, 5, 3, 3, 2, 5, 6, 5, 2, 6, 3, 2, 4, 2, 3, 3, 3, 3, 5, 6, 5, 3, 5, 6, 1, 2, 2, 3, 4, 2, 1, 5, 4, 5, 2, 6, 4, 4, 6, 2, 3, 4, 7, 8, 2, 3, 2, 5, 2, 9, 5, 2, 3, 4, 3, 2, 2, 3, 2, 7, 3, 4, 2, 2, 3, 3, 5, 5, 5, 2, 7, 3, 5, 3, 5, 4, 6, 5, 5, 3, 6, 6, 7, 2, 3, 5, 2, 2, 6, 1, 5, 5, 4, 5, 0, 3, 3, 5, 7, 3, 2, 5, 2, 5, 2, 2, 2, 3, 4, 6, 5, 4, 3, 5, 3, 6, 3, 1, 6, 6, 4, 4, 5, 5, 3, 4, 7, 6, 2, 4, 4, 3, 3, 3, 2, 4, 6, 4, 2, 0, 2, 3, 2, 3, 3, 4, 5, 6, 3, 9, 3, 5, 5, 3, 2, 4, 0, 3, 3, 3, 2, 2, 4, 6, 4, 6, 2, 6, 3, 2, 3, 2, 2, 7, 3, 5, 3, 3, 3, 2, 2, 5, 2, 4, 5, 6, 2, 5, 3, 3, 2, 5, 5, 2, 8, 5, 4, 2, 4, 4, 6, 4, 0, 1, 2, 5, 10, 5, 7, 2, 7, 6, 4, 3, 3, 2, 3, 3, 1, 2, 4, 5, 4, 4, 5, 3, 5, 2, 0, 3, 0, 5, 0, 5, 3, 2, 4, 7, 2, 4, 5, 6, 2, 5, 2, 3, 3, 2, 3, 3, 3, 4, 4, 4, 7, 4, 5, 2, 6, 2, 3, 3, 2, 3, 3, 2, 3, 3, 1, 9, 5, 3, 3, 2, 4, 7, 5, 4, 5, 3, 9, 4, 5, 3, 3, 3, 6, 5, 6, 6, 4, 2, 6, 2, 3, 2, 3, 3, 9, 2, 2, 7, 7, 4, 3, 5, 3, 2, 5, 7, 5, 2, 4, 3, 2, 5, 6, 3, 6, 5, 4, 5, 5, 7, 3, 6, 6, 5, 2, 2, 3, 0, 2, 2, 0, 5, 4, 6, 2, 2, 3, 2, 3, 6, 2, 1, 4, 3, 4, 6, 5, 4, 6, 2, 3, 3, 2, 3, 6, 2, 4, 6, 6, 3, 3, 2, 5, 3, 5, 4, 3, 4, 2, 3, 5, 7, 3, 0, 3, 3, 1, 3, 3, 6, 3, 7, 4, 2, 5, 4, 2, 8, 4, 3, 1, 5, 5, 2, 3, 5, 5, 0, 2, 0, 2, 6, 4, 3, 7, 2, 4, 4, 1, 4, 7, 3, 4, 6, 3, 3, 5, 7, 4, 7, 5, 4, 3, 5, 5, 3, 2, 4, 6, 4, 2, 1, 3, 6, 9, 4, 3, 2, 3, 6, 2, 1, 2, 7, 2, 6, 3, 5, 3, 3, 5, 3, 2, 10, 4, 4, 2, 2, 5, 2, 5, 1, 2, 5, 5, 5, 7, 4, 6, 2, 2, 4, 2, 6, 4, 6, 6, 4, 1, 7, 7, 6, 2, 6, 2, 5, 0, 4, 5, 5, 8, 3, 3, 3, 7, 5, 5, 8, 3, 3, 6, 3, 6, 2, 0, 4, 3, 1, 3, 2, 2, 6, 2, 3, 2, 5, 3, 4, 3, 5, 5, 5, 3, 3, 2, 0, 3, 3, 5, 3, 2, 4, 6, 9, 6, 3, 3, 3, 1, 2, 5, 4, 3, 2, 3, 5, 5, 2, 5, 3, 5, 5, 3, 4, 5, 3, 5, 7, 2, 0, 0, 0, 5, 6, 4, 2, 0, 5, 4, 9, 4, 4, 2, 5, 5, 2, 2, 0, 5, 5, 7, 2, 3, 2, 2, 2, 5, 7, 2, 5, 5, 2, 4, 10, 2, 5, 4, 7, 2, 7, 6, 6, 3, 5, 5, 6, 5, 3, 5, 2, 4, 2, 3, 5, 4, 7, 5, 5, 2, 6, 2, 9, 2, 7, 3, 3, 4, 2, 3, 5, 5, 5, 5, 4, 3, 9, 8, 5, 3, 5, 2, 2, 5, 2, 5, 3, 4, 2, 5, 3, 5, 5, 2, 3, 6, 4, 2, 5, 5, 2, 5, 3, 5, 5, 3, 2, 7, 6, 2, 3, 5, 5, 4, 5, 4, 2, 6, 0, 2, 5, 5, 7, 5, 2, 3, 2, 3, 3, 3, 2, 4, 7, 3, 3, 5, 2, 4, 3, 2, 5, 3, 3, 2, 3, 2, 6, 3, 1, 2, 5, 2, 2, 7, 4, 5, 5, 2, 3, 6, 2, 4, 5, 2, 5, 3, 5, 5, 2, 7, 2, 5, 3, 6, 3, 4, 3, 0, 2, 3, 2, 0, 2, 5, 7, 3, 5, 4, 5, 3, 3, 5, 5, 3, 5, 4, 4, 2, 2, 2, 5, 5, 5, 2, 4, 5, 5, 5, 9, 4, 5, 6, 6, 4, 2, 3, 3, 3, 3, 4, 2, 5, 5, 5, 4, 1, 2, 2, 2, 6, 5, 3, 0, 3, 2, 5, 3, 4, 3, 5, 3, 3, 3, 4, 1, 2, 0, 5, 5, 5, 3, 5, 3, 2, 11, 2, 0, 4, 6, 5, 8, 5, 1, 8, 5, 5, 3, 2, 5, 2, 5, 2, 5, 4, 5, 5, 3, 5, 9, 2, 5, 4, 7, 4, 6, 3, 3, 2, 6, 3, 6, 8, 3, 5, 2, 3, 0, 10, 5, 6, 5, 2, 2, 2, 2, 2, 2, 7, 2, 5, 5, 3, 6, 3, 5, 4, 3, 4, 4, 5, 8, 8,  ...
# [6, 7, 9, 5, 6, 3, 4, 5, 6, 4, 7, 9, 5, 7, 8, 4, 5, 8, 5, 4, 5, 3, 4, 8, 6, 3, 6, 7, 4, 5, 6, 8, 6, 7, 5, 10, 5, 6, 8, 3, 3, 6, 5, 4, 5, 4, 6, 3, 6, 7, 7, 5, 7, 4, 3, 4, 1, 4, 7, 9, 7, 1, 9, 3, 4, 2, 3, 4, 4, 5, 8, 3, 6, 3, 4, 4, 7, 7, 4, 4, 5, 2, 9, 6, 6, 5, 4, 6, 3, 8, 6, 4, 5, 2, 5, 6, 7, 11, 3, 4, 2, 4, 4, 3, 7, 6, 7, 3, 8, 4, 7, 5, 5, 1, 6, 6, 10, 3, 4, 9, 5, 4, 3, 6, 5, 7, 3, 6, 4, 8, 3, 7, 8, 3, 8, 5, 6, 3, 4, 3, 4, 8, 7, 3, 5, 3, 5, 3, 5, 6, 8, 3, 3, 3, 4, 7, 8, 7, 4, 4, 2, 4, 9, 2, 3, 11, 4, 5, 2, 4, 6, 4, 4, 10, 7, 3, 9, 4, 3, 3, 8, 7, 3, 3, 4, 8, 1, 4, 8, 3, 8, 6, 7, 4, 4, 4, 5, 4, 6, 11, 6, 5, 4, 9, 6, 10, 8, 9, 4, 4, 10, 7, 4, 3, 5, 5, 2, 6, 4, 4, 7, 6, 8, 3, 8, 6, 4, 8, 8, 4, 4, 4, 5, 5, 4, 3, 5, 4, 6, 3, 8, 3, 3, 8, 6, 7, 1, 7, 8, 5, 5, 6, 3, 4, 3, 9, 8, 8, 5, 4, 3, 4, 4, 4, 5, 4, 5, 3, 3, 6, 3, 5, 3, 4, 3, 5, 4, 6, 7, 4, 3, 3, 3, 10, 2, 5, 4, 3, 2, 7, 4, 6, 3, 4, 4, 3, 6, 6, 4, 2, 8, 8, 4, 4, 6, 4, 2, 6, 5, 8, 4, 7, 5, 8, 2, 5, 4, 1, 7, 6, 7, 8, 4, 3, 1, 6, 6, 4, 5, 6, 9, 3, 2, 6, 8, 6, 8, 6, 8, 6, 6, 7, 3, 5, 6, 5, 4, 6, 3, 2, 4, 7, 3, 3, 4, 4, 6, 4, 4, 6, 8, 4, 7, 8, 3, 5, 3, 4, 5, 4, 8, 4, 2, 7, 3, 5, 2, 4, 8, 7, 3, 9, 4, 5, 11, 1, 6, 4, 4, 5, 9, 3, 7, 1, 5, 3, 5, 10, 4, 3, 4, 5, 6, 2, 4, 3, 1, 3, 0, 4, 3, 9, 6, 5, 5, 3, 5, 6, 3, 6, 5, 6, 3, 10, 6, 7, 12, 5, 5, 7, 3, 8, 4, 4, 4, 7, 4, 7, 5, 9, 4, 2, 7, 6, 6, 5, 5, 6, 4, 4, 3, 5, 7, 6, 3, 8, 4, 3, 4, 3, 4, 4, 5, 4, 8, 7, 5, 4, 6, 7, 3, 3, 3, 4, 4, 3, 2, 7, 4, 12, 4, 7, 5, 6, 7, 3, 4, 5, 7, 9, 3, 4, 3, 6, 3, 10, 7, 4, 4, 6, 5, 3, 2, 6, 3, 8, 4, 5, 3, 3, 6, 4, 6, 7, 9, 2, 8, 3, 5, 3, 8, 5, 7, 9, 8, 4, 7, 7, 9, 3, 4, 7, 3, 3, 6, 3, 6, 9, 4, 6, 1, 4, 3, 6, 8, 4, 3, 9, 4, 6, 3, 3, 3, 4, 5, 6, 5, 5, 5, 6, 3, 6, 3, 3, 6, 8, 8, 7, 5, 5, 9, 4, 9, 10, 3, 5, 8, 6, 3, 4, 4, 4, 6, 4, 3, 3, 3, 4, 3, 5, 6, 4, 7, 7, 4, 9, 4, 8, 7, 5, 3, 6, 1, 4, 5, 4, 3, 3, 4, 6, 5, 6, 3, 6, 4, 3, 4, 3, 3, 9, 4, 5, 6, 5, 5, 4, 3, 7, 3, 9, 7, 6, 3, 6, 4, 4, 3, 6, 6, 2, 9, 6, 4, 2, 6, 5, 7, 4, 3, 2, 3, 6, 10, 7, 10, 3, 7, 7, 4, 3, 4, 3, 4, 4, 4, 3, 5, 7, 6, 5, 5, 4, 5, 3, 2, 3, 3, 6, 2, 6, 4, 3, 8, 8, 3, 4, 8, 6, 3, 6, 4, 4, 4, 3, 4, 8, 4, 5, 5, 5, 9, 6, 6, 4, 7, 3, 4, 4, 3, 6, 4, 3, 4, 3, 2, 10, 5, 3, 9, 2, 8, 9, 6, 5, 6, 4, 9, 4, 6, 4, 4, 4, 7, 6, 7, 7, 4, 3, 7, 3, 5, 3, 5, 3, 11, 3, 4, 13, 12, 4, 3, 8, 5, 3, 8, 12, 6, 2, 7, 3, 3, 6, 9, 4, 7, 5, 6, 11, 6, 9, 3, 9, 7, 8, 3, 5, 4, 2, 3, 3, 0, 8, 6, 8, 3, 3, 4, 3, 4, 7, 2, 2, 8, 4, 5, 7, 6, 5, 7, 3, 4, 3, 3, 4, 6, 3, 5, 7, 10, 4, 4, 3, 6, 4, 5, 4, 4, 5, 3, 4, 6, 9, 4, 1, 5, 4, 2, 4, 5, 7, 4, 11, 4, 5, 10, 4, 4, 10, 5, 4, 7, 6, 5, 4, 5, 6, 7, 1, 4, 1, 3, 6, 4, 5, 8, 4, 4, 5, 3, 7, 7, 4, 4, 6, 4, 3, 6, 8, 5, 11, 7, 5, 5, 6, 6, 3, 3, 7, 8, 4, 3, 2, 4, 7, 13, 4, 4, 3, 4, 7, 3, 3, 4, 8, 3, 7, 4, 9, 5, 9, 7, 4, 3, 11, 8, 5, 2, 3, 7, 3, 7, 2, 5, 6, 6, 6, 8, 4, 6, 3, 4, 5, 4, 7, 5, 11, 7, 5, 3, 8, 8, 10, 3, 6, 4, 5, 1, 5, 7, 6, 8, 4, 4, 4, 9, 6, 6, 9, 3, 6, 6, 4, 10, 3, 1, 6, 4, 3, 6, 3, 2, 7, 5, 5, 3, 7, 4, 6, 3, 6, 7, 7, 4, 4, 3, 1, 4, 4, 6, 6, 3, 6, 6, 10, 8, 4, 5, 4, 3, 3, 6, 5, 4, 3, 10, 6, 7, 3, 6, 4, 6, 5, 4, 5, 6, 4, 6, 7, 3, 1, 1, 1, 6, 8, 5, 3, 5, 7, 6, 9, 8, 4, 3, 6, 6, 3, 3, 1, 9, 6, 9, 2, 4, 3, 4, 3, 6, 11, 3, 6, 5, 3, 5, 12, 2, 6, 5, 8, 3, 8, 7, 7, 4, 5, 7, 6, 6, 3, 6, 3, 6, 3, 4, 7, 5, 7, 6, 6, 3, 8, 3, 10, 3, 8, 6, 4, 5, 3, 4, 7, 6, 6, 8, 5, 4, 10, 9, 6, 4, 7, 3, 5, 8, 3, 6, 4, 5, 3, 7, 4, 6, 6, 2, 4, 7, 5, 3, 7, 6, 3, 7, 5, 5, 10, 4, 3, 9, 6, 3, 4, 7, 6, 6, 6, 5, 3, 8, 0, 3, 10, 7, 8, 6, 3, 4, 3, 4, 4, 4, 3, 4, 7, 4, 4, 5, 3, 5, 4, 2, 6, 5, 3, 3, 4, 3, 7, 4, 2, 3, 9, 3, 4, 8, 6, 7, 6, 3, 4, 7, 3, 4, 7, 3, 7, 4, 8, 12, 3, 10, 3, 7, 4, 7, 4, 5, 4, 1, 3, 3, 2, 3, 3, 7, 9, 3, 7, 5, 6, 4, 4, 6, 6, 4, 5, 4, 5, 3, 3, 5, 6, 6, 6, 3, 4, 6, 7, 5, 11, 4, 6, 6, 7, 7, 3, 5, 3, 5, 4, 5, 3, 5, 6, 8, 5, 3, 4, 3, 3, 6, 8, 4, 2, 3, 3, 6, 6, 6, 4, 11, 4, 3, 4, 5, 2, 3, 1, 6, 7, 10, 4, 6, 5, 3, 11, 3, 1, 4, 7, 5, 8, 6, 2, 10, 5, 6, 4, 3, 6, 5, 5, 3, 6, 6, 6, 6, 4, 6, 11, 3, 7, 5, 8, 4, 10, 4, 3, 3, 8, 3, 7, 9, 3, 6, 3, 5, 1, 11, 7, 7, 6, 3, 3, 3, 3, 3, 3, ...

# %% [markdown]
# **Creation of a custom dataset for the SimpleQuestions dataset (either for the dataset with only answerable over wikidata questions or for the corresponding dataset including answerable and non-answerable over wikidata questions) through a python class, where its questions are encoded through BertTokenizerFast method encode\_plus(). This custom dataset includes the entity span indexes (start, end), the relation indexes, the questions, the ids and the attention mask occurred from encoding of questions.**
#
# **Also since the span start and end correspond to actual words, but here I use the fast version of BERT tokenizer BertTokenizerFast, i need to locate the corresponding start and end tokens in the BERT tokenized question for each entity.**
#
# **Also in order to create this custom dataset i used the lists of questions, relation, entity span start, entity span end indexes, the maximum question length of all SimpleQuestions training and validation dataset questions.**

# %%
g = torch.Generator()
print(g.device)
# Out:
# cpu

# %%
class BertQuestionAnsweringDataset:
  def __init__(self, questions, tokenizer, entity_starts, entity_ends, relation_indexes, length, generator, shuffle=True):
        self.questions = questions
        self.max_length = length
        self.tokenizer = tokenizer
        self.relation_indexes = relation_indexes
        self.g = generator
        self.shuffle = shuffle
        ids = []
        masks = []
        start_ent = []
        end_ent = []
        # Encode questions
        for question in range(len(self.questions)):
          encoding = self.tokenizer.encode_plus(
             text = self.questions[question],
             max_length=self.max_length,
             truncation=True,
             pad_to_max_length=True,
             return_attention_mask=True,
             padding='max_length',
             add_special_tokens=False
          )
          Question = self.questions[question].split()
          # Locate the corresponding start in the BERT tokenized question
          start_token = tokenizer.encode_plus(
            text = Question[entity_starts[question]],
            return_attention_mask=True,
            add_special_tokens=False
        )
          # Locate the corresponding end in the BERT tokenized question
          end_token = tokenizer.encode_plus(
            text = Question[entity_ends[question]],
            return_attention_mask=True,
            add_special_tokens=False
        )
          ids.append(encoding['input_ids'])
          masks.append(encoding['attention_mask'])
          start_ent.append(encoding['input_ids'].index(start_token['input_ids'][0]))
          end_ent.append(encoding['input_ids'].index(end_token['input_ids'][-1]))
        self.input_ids = ids
        self.attention_masks = masks
        self.entity_start_indexes = start_ent
        self.entity_end_indexes = end_ent

  def __len__(self):
        return len(self.questions)

  def __getitem__(self, idx):
        return { 'input_ids': torch.tensor(self.input_ids[idx]),
                'attention_mask':  torch.tensor(self.attention_masks[idx]),
                'relation_indexes': torch.tensor(self.relation_indexes[idx]),
                'entity_start': torch.tensor(self.entity_start_indexes[idx], dtype = torch.long),
                'entity_end': torch.tensor(self.entity_end_indexes[idx], dtype = torch.long)
               }

  def set_epoch(self, epoch):
      self.epoch = epoch
      if self.shuffle:
         self.g.manual_seed(123456789 + self.epoch)

# %% [markdown]
# **In the above custom dataset class i reseed the workers using worker\_init\_fn() to preserve reproducibility through by creating the following function seed\_worker.**

# %%
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# %% [markdown]
# **Creation of the dataloader through the created custom dataset from pytorch for the training and validation dataset of SimpleQuestions dataset. The batch size is equal to 32.**

# %%
print(len(train_questions), len(train_entity_span_start), len(train_entity_span_end), len(train_relations_index))
train_bert_dataset = BertQuestionAnsweringDataset(train_questions, tokenizer, train_entity_span_start, train_entity_span_end, train_relations_index, max(q_lengths), g)
valid_bert_dataset = BertQuestionAnsweringDataset(validation_questions, tokenizer, validation_entity_span_start, validation_entity_span_end, validation_relations_index, max(q_lengths), g)
train_dataloader = torch.utils.data.DataLoader(train_bert_dataset, batch_size = 32, num_workers = 0, worker_init_fn=seed_worker, shuffle=True, generator = train_bert_dataset.g)
val_dataloader = torch.utils.data.DataLoader(valid_bert_dataset, batch_size= 32, num_workers = 0, worker_init_fn=seed_worker, shuffle=True, generator = valid_bert_dataset.g)
# Out:
# 19481 19481 19481 19481

# %% [markdown]
# **Function that contributes to the preservation of the reproducibility.**

# %%
#To preserve reproducibility
import random
import numpy as np
import torch.backends.cudnn
from numpy.random import MT19937
from numpy.random import RandomState, SeedSequence
SEED = 42
def set_seed(SEED):
 random.seed(SEED)# Set python seed for custom operators.
 torch.manual_seed(SEED)
 #rs = RandomState(MT19937(SeedSequence(SEED))) # If any of the libraries or code rely on NumPy seed the global NumPy RNG.
 np.random.seed(SEED)
 torch.cuda.manual_seed_all(SEED)
 torch.backends.cudnn.benchmark = False
 torch.backends.cudnn.deterministic = True

# %% [markdown]
# **Through the create\_file function, is created a file in .pt, in which the parameters for each model are stored. This function takes as an argument a name for the folder where the model will be saved (e.g. "drive/MyDrive/") and a name for the name of the file where each model is saved (e.g. "relation\_prediction.pt").**

# %%
def create_file(model_dir, model_save_name):
 if not os.path.exists(model_dir):
    os.makedirs(model_dir)
 model_save_path = os.path.join(model_dir, model_save_name)
 return model_save_path

# %% [markdown]
# ****Construction and initialization of the neural network for the prediction of the relation for each question.****

# %%
class BertRelationsClassifier(nn.Module):
  def __init__(self, activation, dropout_prob, rel_vocab_len):
    super(BertRelationsClassifier, self).__init__()
    activations = {
        "ELU" : nn.ELU,
        "LeakyReLU"    : nn.LeakyReLU,
        "Softplus"     : nn.Softplus,
        "Tanhshrink"     : nn.Tanhshrink
 }
    self.bert_model = BertModel.from_pretrained('bert-base-uncased')
    self.rel_vocab_len = rel_vocab_len
    self.fc = nn.Linear(768, self.rel_vocab_len)
    self.activation_type = activation
    self.dropout_probability = dropout_prob
    self.activation = activations[self.activation_type]()
    self.dropout = nn.Dropout(self.dropout_probability)
    self.softmax = nn.Softmax(dim=1)

  def forward(self, input_ids, attention_mask):
        out = self.bert_model(input_ids, attention_mask)
        out = self.fc(out[1])#CLS token-pooled output
        out = self.activation(out)
        out = self.dropout(out)
        out = self.softmax(out)
        return out

# %% [markdown]
# **Through the function named relation_prediction_function the best possible parameters for the best possible prediction of the relation are found. This function has as arguments the training dataloader, the validation dataloader, the number of epochs, the optimizer, the scheduler, the learning rate, the relation prediction neural network model, the loss function and the dropout probability value.**
#
# **This function returns the best possible model, the list including numbers from 0 to number of training epochs-1, the lists including the values of training losses and validation losses for all epochs respectively and the largest value of f1.**
#
# **The length of the relation vocabulary in the case of training and validating the full SimpleQuestions dataset is equal to 129 and the length of the relation vocabulary for the case of training and validating the SimpleQuestions subset that includes only questions that are answerable over wikidata is equal to 125.
# So the predicted relation index as a number must be either between 0 and 128 or between 0 and 124, where this number correspond to the position of the unique relation ids in the corresponding relation vocabulary.**

# %%
def relation_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, lr, dropout_prob):
 list_loss_train = []
 list_epochs = []
 list_loss = []
 the_last_f1_score = 0
 patience = 3
 max_f1 = -1
 trigger_times = 0
 for epoch in range(epochs):
   train_dataset.set_epoch(epoch)
   valid_dataset.set_epoch(epoch)
   model.train()
   batch_losses = []
   F1 = []
   precision = []
   recall = []
   accuracy = []
   for batch in train_dataloader:
    ids = batch['input_ids'].to(device)
    attention_masks = batch['attention_mask'].to(device)
    relation_indexes = batch['relation_indexes'].to(device)
    y_pred = model(ids, attention_masks)
    loss = loss_func(y_pred.cpu(),relation_indexes.cpu())
    batch_losses.append(loss.detach().numpy())
    #Delete previously stored gradients
    optimizer.zero_grad()

    #Perform backpropagation starting from the loss calculated in this epoch
    loss.backward()
    nn.utils.clip_grad_norm_(model.parameters(), 0.7)
    #Update model's weights based on the gradients calculated during backprop
    optimizer.step()
    scheduler.step()
   print(f"Epoch {epoch:3}: Train Loss = {sum(batch_losses)/len(train_dataloader):.5f}")
   list_loss_train.append(sum(batch_losses)/len(train_dataloader))
   with torch.no_grad():
     model.eval()
     batch_F1 = []
     batch_precision = []
     batch_recall = []
     batch_accuracy = []
     batch_losses_val = []
     for batch in val_dataloader:
       ids = batch['input_ids'].to(device)
       attention_masks = batch['attention_mask'].to(device)
       relation_indexes = batch['relation_indexes'].to(device)
       y_predict = model(ids, attention_masks)
       val_loss = loss_func(y_predict.cpu(),relation_indexes.cpu())
       batch_losses_val.append(val_loss)
       y_pr = torch.argmax(y_predict, dim=1).squeeze()
       Y_p = y_pr.tolist()
       y_val = relation_indexes.tolist()
       batch_F1.append(f1_score(y_val, Y_p, average = 'micro'))
       batch_precision.append(precision_score(y_val, Y_p, average = 'micro'))
       batch_recall.append(recall_score(y_val, Y_p, average = 'micro'))
       batch_accuracy.append(accuracy_score(y_val,Y_p))
     Valid_f1 = sum(batch_F1)/len(val_dataloader)
     Valid_accuracy = sum(batch_accuracy)/len(val_dataloader)
     print(f"Epoch {epoch:3}: Valid Loss = {sum(batch_losses_val)/len(val_dataloader):.5f}")
     print(f"Epoch {epoch:3}: Valid f1_score = {Valid_f1:.5f}")
     print(f"Epoch {epoch:3}: Valid Acurracy = {Valid_accuracy:.5f}")
     print(f"Epoch {epoch:3}: Valid Recall score = {sum(batch_recall)/len(val_dataloader):.5f}")
     print(f"Epoch {epoch:3}: Valid Precision score = {sum(batch_precision)/len(val_dataloader):.5f}")
     #list_f1_scores.append(sum(F1)/len(val_dataloader))
     list_loss.append(sum(batch_losses_val)/len(val_dataloader))
     list_epochs.append(epoch)
     if Valid_f1 > max_f1:
       max_f1 = Valid_f1
       best_model = model
       print('The current f1 score:', Valid_f1)
     if Valid_f1 < the_last_f1_score:
       trigger_times += 1
       print('trigger times:', trigger_times)
       if trigger_times >= patience:
         print('Early stopping!\nStart to test process.')
         break;
     the_last_f1_score = Valid_f1
 return max_f1, list_loss_train, list_loss, list_epochs, best_model

# %% [markdown]
# **The function named get_relation_results finds results for the neural networks concerning the relation index and the entity span indexes (start,end). These functions have as arguments the corresponding training dataloader, the corresponding validation dataloader, the number of epochs ,the optimizer, the scheduler get_linear_schedule_with_warmup, the corresponding relation prediction neural network model, the loss function, the learning rate and the SEED number.**
#
# **This function returns the list of training losses, the list of validation losses, and the list of how many epochs each model with each activation function needs to be fully trained.**

# %%
learning_rate  = 2e-5
dropout_prob = 0.3
epochs = 20
list_relation_training_losses = []
list_relation_validation_losses = []
list_relation_epochs = []
loss_func = nn.CrossEntropyLoss()
optimizer_name = "Adam"
def get_relation_results(activation, rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_dataset, valid_dataset, train_dataloader, val_dataloader, SEED):
 set_seed(SEED)
 model = BertRelationsClassifier(activation, dropout_prob, rel_vocab_length).to(device)
 print(model)
 loss_func = loss_func.to(device)
 optimizer = getattr(torch.optim, optimizer_name)(model.parameters(), lr=learning_rate)
 scheduler = get_linear_schedule_with_warmup(optimizer, 0, len(train_dataloader)*epochs)
 f1, list_loss_train, list_loss_valid, list_epochs, best_relation_model = relation_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, learning_rate, dropout_prob)
 print(f1)
 torch.save(best_relation_model.state_dict(), create_file(f"drive/MyDrive/Relation_indexes_models_best_parameters/Answerable_Questions/{activation}",f"relation_prediction_jaccard_similarity_answerable_questions_{activation}.pt") )
 print(f"The best parameters are saved for the activation function: {activation}")
 return list_loss_train, list_loss_valid, list_epochs

# %%
list_relation_loss_train_leakyrelu, list_relation_loss_valid_leakyrelu, list_epochs_leakyrelu = get_relation_results("LeakyReLU", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=125, bias=True)
#   (activation): LeakyReLU(negative_slope=0.01)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.58557
# Epoch   0: Valid Loss = 4.29605
# Epoch   0: Valid f1_score = 0.60681
# Epoch   0: Valid Acurracy = 0.60681
# Epoch   0: Valid Recall score = 0.60681
# Epoch   0: Valid Precision score = 0.60681
# The current f1 score: 0.606811797752809
# Epoch   1: Train Loss = 4.38414
# Epoch   1: Valid Loss = 4.18262
# Epoch   1: Valid f1_score = 0.69874
# Epoch   1: Valid Acurracy = 0.69874
# Epoch   1: Valid Recall score = 0.69874
# Epoch   1: Valid Precision score = 0.69874
# The current f1 score: 0.6987359550561798
# Epoch   2: Train Loss = 4.32955
# Epoch   2: Valid Loss = 4.11188
# Epoch   2: Valid f1_score = 0.77317
# Epoch   2: Valid Acurracy = 0.77317
# Epoch   2: Valid Recall score = 0.77317
# Epoch   2: Valid Precision score = 0.77317
# The current f1 score: 0.7731741573033708
# Epoch   3: Train Loss = 4.28584
# Epoch   3: Valid Loss = 4.05285
# Epoch   3: Valid f1_score = 0.83483
# Epoch   3: Valid Acurracy = 0.83483
# Epoch   3: Valid Recall score = 0.83483
# Epoch   3: Valid Precision score = 0.83483
# The current f1 score: 0.8348314606741573
# Epoch   4: Train Loss = 4.25209
# Epoch   4: Valid Loss = 4.01386
# Epoch   4: Valid f1_score = 0.86166
# Epoch   4: Valid Acurracy = 0.86166
# Epoch   4: Valid Recall score = 0.86166
# Epoch   4: Valid Precision score = 0.86166
# The current f1 score: 0.8616573033707865
# Epoch   5: Train Loss = 4.23681
# Epoch   5: Valid Loss = 3.99371
# Epoch   5: Valid f1_score = 0.87956
# Epoch   5: Valid Acurracy = 0.87956
# Epoch   5: Valid Recall score = 0.87956
# Epoch   5: Valid Precision score = 0.87956
# The current f1 score: 0.879564606741573
# Epoch   6: Train Loss = 4.22724
# Epoch   6: Valid Loss = 3.98067
# Epoch   6: Valid f1_score = 0.88975
# Epoch   6: Valid Acurracy = 0.88975
# Epoch   6: Valid Recall score = 0.88975
# Epoch   6: Valid Precision score = 0.88975
# The current f1 score: 0.889747191011236
# Epoch   7: Train Loss = 4.21475
# Epoch   7: Valid Loss = 3.97203
# Epoch   7: Valid f1_score = 0.89242
# Epoch   7: Valid Acurracy = 0.89242
# Epoch   7: Valid Recall score = 0.89242
# Epoch   7: Valid Precision score = 0.89242
# The current f1 score: 0.8924157303370787
# Epoch   8: Train Loss = 4.20855
# Epoch   8: Valid Loss = 3.95998
# Epoch   8: Valid f1_score = 0.90365
# Epoch   8: Valid Acurracy = 0.90365
# Epoch   8: Valid Recall score = 0.90365
# Epoch   8: Valid Precision score = 0.90365
# The current f1 score: 0.9036516853932584
# Epoch   9: Train Loss = 4.20225
# Epoch   9: Valid Loss = 3.95318
# Epoch   9: Valid f1_score = 0.90695
# Epoch   9: Valid Acurracy = 0.90695
# Epoch   9: Valid Recall score = 0.90695
# Epoch   9: Valid Precision score = 0.90695
# The current f1 score: 0.9069522471910112
# Epoch  10: Train Loss = 4.19432
# Epoch  10: Valid Loss = 3.94627
# Epoch  10: Valid f1_score = 0.91699
# Epoch  10: Valid Acurracy = 0.91699
# Epoch  10: Valid Recall score = 0.91699
# Epoch  10: Valid Precision score = 0.91699
# The current f1 score: 0.9169943820224719
# Epoch  11: Train Loss = 4.18972
# Epoch  11: Valid Loss = 3.94268
# Epoch  11: Valid f1_score = 0.91875
# Epoch  11: Valid Acurracy = 0.91875
# Epoch  11: Valid Recall score = 0.91875
# Epoch  11: Valid Precision score = 0.91875
# The current f1 score: 0.91875
# Epoch  12: Train Loss = 4.19240
# Epoch  12: Valid Loss = 3.93338
# Epoch  12: Valid f1_score = 0.92767
# Epoch  12: Valid Acurracy = 0.92767
# Epoch  12: Valid Recall score = 0.92767
# Epoch  12: Valid Precision score = 0.92767
# The current f1 score: 0.9276685393258427
# Epoch  13: Train Loss = 4.18204
# Epoch  13: Valid Loss = 3.93296
# Epoch  13: Valid f1_score = 0.93055
# Epoch  13: Valid Acurracy = 0.93055
# Epoch  13: Valid Recall score = 0.93055
# Epoch  13: Valid Precision score = 0.93055
# The current f1 score: 0.9305477528089887
# Epoch  14: Train Loss = 4.18161
# Epoch  14: Valid Loss = 3.92232
# Epoch  14: Valid f1_score = 0.94031
# Epoch  14: Valid Acurracy = 0.94031
# Epoch  14: Valid Recall score = 0.94031
# Epoch  14: Valid Precision score = 0.94031
# The current f1 score: 0.9403089887640449
# Epoch  15: Train Loss = 4.17594
# Epoch  15: Valid Loss = 3.92043
# Epoch  15: Valid f1_score = 0.94171
# Epoch  15: Valid Acurracy = 0.94171
# Epoch  15: Valid Recall score = 0.94171
# Epoch  15: Valid Precision score = 0.94171
# The current f1 score: 0.9417134831460674
# Epoch  16: Train Loss = 4.16948
# Epoch  16: Valid Loss = 3.92093
# Epoch  16: Valid f1_score = 0.93876
# Epoch  16: Valid Acurracy = 0.93876
# Epoch  16: Valid Recall score = 0.93876
# Epoch  16: Valid Precision score = 0.93876
# trigger times: 1
# Epoch  17: Train Loss = 4.16249
# Epoch  17: Valid Loss = 3.91697
# Epoch  17: Valid f1_score = 0.94136
# Epoch  17: Valid Acurracy = 0.94136
# Epoch  17: Valid Recall score = 0.94136
# Epoch  17: Valid Precision score = 0.94136
# Epoch  18: Train Loss = 4.16237
# Epoch  18: Valid Loss = 3.91801
# Epoch  18: Valid f1_score = 0.94333
# Epoch  18: Valid Acurracy = 0.94333
# Epoch  18: Valid Recall score = 0.94333
# Epoch  18: Valid Precision score = 0.94333
# The current f1 score: 0.9433286516853933
# Epoch  19: Train Loss = 4.16876
# Epoch  19: Valid Loss = 3.91520
# Epoch  19: Valid f1_score = 0.94663
# Epoch  19: Valid Acurracy = 0.94663
# Epoch  19: Valid Recall score = 0.94663
# Epoch  19: Valid Precision score = 0.94663
# The current f1 score: 0.9466292134831461
# 0.9466292134831461
# The best parameters are saved for the activation function: LeakyReLU

# %%
list_relation_loss_train_leakyrelu, list_relation_loss_valid_leakyrelu, list_epochs_leakyrelu = get_relation_results("LeakyReLU", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=125, bias=True)
#   (activation): LeakyReLU(negative_slope=0.01)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.58557
# Epoch   0: Valid Loss = 4.29605
# Epoch   0: Valid f1_score = 0.60681
# Epoch   0: Valid Acurracy = 0.60681
# Epoch   0: Valid Recall score = 0.60681
# Epoch   0: Valid Precision score = 0.60681
# The current f1 score: 0.606811797752809
# Epoch   1: Train Loss = 4.38414
# Epoch   1: Valid Loss = 4.18262
# Epoch   1: Valid f1_score = 0.69874
# Epoch   1: Valid Acurracy = 0.69874
# Epoch   1: Valid Recall score = 0.69874
# Epoch   1: Valid Precision score = 0.69874
# The current f1 score: 0.6987359550561798
# Epoch   2: Train Loss = 4.32955
# Epoch   2: Valid Loss = 4.11188
# Epoch   2: Valid f1_score = 0.77317
# Epoch   2: Valid Acurracy = 0.77317
# Epoch   2: Valid Recall score = 0.77317
# Epoch   2: Valid Precision score = 0.77317
# The current f1 score: 0.7731741573033708
# Epoch   3: Train Loss = 4.28584
# Epoch   3: Valid Loss = 4.05285
# Epoch   3: Valid f1_score = 0.83483
# Epoch   3: Valid Acurracy = 0.83483
# Epoch   3: Valid Recall score = 0.83483
# Epoch   3: Valid Precision score = 0.83483
# The current f1 score: 0.8348314606741573
# Epoch   4: Train Loss = 4.25209
# Epoch   4: Valid Loss = 4.01386
# Epoch   4: Valid f1_score = 0.86166
# Epoch   4: Valid Acurracy = 0.86166
# Epoch   4: Valid Recall score = 0.86166
# Epoch   4: Valid Precision score = 0.86166
# The current f1 score: 0.8616573033707865
# Epoch   5: Train Loss = 4.23681
# Epoch   5: Valid Loss = 3.99371
# Epoch   5: Valid f1_score = 0.87956
# Epoch   5: Valid Acurracy = 0.87956
# Epoch   5: Valid Recall score = 0.87956
# Epoch   5: Valid Precision score = 0.87956
# The current f1 score: 0.879564606741573
# Epoch   6: Train Loss = 4.22724
# Epoch   6: Valid Loss = 3.98067
# Epoch   6: Valid f1_score = 0.88975
# Epoch   6: Valid Acurracy = 0.88975
# Epoch   6: Valid Recall score = 0.88975
# Epoch   6: Valid Precision score = 0.88975
# The current f1 score: 0.889747191011236
# Epoch   7: Train Loss = 4.21475
# Epoch   7: Valid Loss = 3.97203
# Epoch   7: Valid f1_score = 0.89242
# Epoch   7: Valid Acurracy = 0.89242
# Epoch   7: Valid Recall score = 0.89242
# Epoch   7: Valid Precision score = 0.89242
# The current f1 score: 0.8924157303370787
# Epoch   8: Train Loss = 4.20855
# Epoch   8: Valid Loss = 3.95998
# Epoch   8: Valid f1_score = 0.90365
# Epoch   8: Valid Acurracy = 0.90365
# Epoch   8: Valid Recall score = 0.90365
# Epoch   8: Valid Precision score = 0.90365
# The current f1 score: 0.9036516853932584
# Epoch   9: Train Loss = 4.20225
# Epoch   9: Valid Loss = 3.95318
# Epoch   9: Valid f1_score = 0.90695
# Epoch   9: Valid Acurracy = 0.90695
# Epoch   9: Valid Recall score = 0.90695
# Epoch   9: Valid Precision score = 0.90695
# The current f1 score: 0.9069522471910112
# Epoch  10: Train Loss = 4.19432
# Epoch  10: Valid Loss = 3.94627
# Epoch  10: Valid f1_score = 0.91699
# Epoch  10: Valid Acurracy = 0.91699
# Epoch  10: Valid Recall score = 0.91699
# Epoch  10: Valid Precision score = 0.91699
# The current f1 score: 0.9169943820224719
# Epoch  11: Train Loss = 4.18972
# Epoch  11: Valid Loss = 3.94268
# Epoch  11: Valid f1_score = 0.91875
# Epoch  11: Valid Acurracy = 0.91875
# Epoch  11: Valid Recall score = 0.91875
# Epoch  11: Valid Precision score = 0.91875
# The current f1 score: 0.91875
# Epoch  12: Train Loss = 4.19240
# Epoch  12: Valid Loss = 3.93338
# Epoch  12: Valid f1_score = 0.92767
# Epoch  12: Valid Acurracy = 0.92767
# Epoch  12: Valid Recall score = 0.92767
# Epoch  12: Valid Precision score = 0.92767
# The current f1 score: 0.9276685393258427
# Epoch  13: Train Loss = 4.18204
# Epoch  13: Valid Loss = 3.93296
# Epoch  13: Valid f1_score = 0.93055
# Epoch  13: Valid Acurracy = 0.93055
# Epoch  13: Valid Recall score = 0.93055
# Epoch  13: Valid Precision score = 0.93055
# The current f1 score: 0.9305477528089887
# Epoch  14: Train Loss = 4.18161
# Epoch  14: Valid Loss = 3.92232
# Epoch  14: Valid f1_score = 0.94031
# Epoch  14: Valid Acurracy = 0.94031
# Epoch  14: Valid Recall score = 0.94031
# Epoch  14: Valid Precision score = 0.94031
# The current f1 score: 0.9403089887640449
# Epoch  15: Train Loss = 4.17594
# Epoch  15: Valid Loss = 3.92043
# Epoch  15: Valid f1_score = 0.94171
# Epoch  15: Valid Acurracy = 0.94171
# Epoch  15: Valid Recall score = 0.94171
# Epoch  15: Valid Precision score = 0.94171
# The current f1 score: 0.9417134831460674
# Epoch  16: Train Loss = 4.16948
# Epoch  16: Valid Loss = 3.92093
# Epoch  16: Valid f1_score = 0.93876
# Epoch  16: Valid Acurracy = 0.93876
# Epoch  16: Valid Recall score = 0.93876
# Epoch  16: Valid Precision score = 0.93876
# trigger times: 1
# Epoch  17: Train Loss = 4.16249
# Epoch  17: Valid Loss = 3.91697
# Epoch  17: Valid f1_score = 0.94136
# Epoch  17: Valid Acurracy = 0.94136
# Epoch  17: Valid Recall score = 0.94136
# Epoch  17: Valid Precision score = 0.94136
# Epoch  18: Train Loss = 4.16237
# Epoch  18: Valid Loss = 3.91801
# Epoch  18: Valid f1_score = 0.94333
# Epoch  18: Valid Acurracy = 0.94333
# Epoch  18: Valid Recall score = 0.94333
# Epoch  18: Valid Precision score = 0.94333
# The current f1 score: 0.9433286516853933
# Epoch  19: Train Loss = 4.16876
# Epoch  19: Valid Loss = 3.91520
# Epoch  19: Valid f1_score = 0.94663
# Epoch  19: Valid Acurracy = 0.94663
# Epoch  19: Valid Recall score = 0.94663
# Epoch  19: Valid Precision score = 0.94663
# The current f1 score: 0.9466292134831461
# 0.9466292134831461
# The best parameters are saved for the activation function: LeakyReLU

# %%
list_relation_loss_train_tanhshrink, list_relation_loss_valid_tanhshrink, list_epochs_tanhshrink = get_relation_results("Tanhshrink", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=125, bias=True)
#   (activation): Tanhshrink()
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.62163
# Epoch   0: Valid Loss = 4.34043
# Epoch   0: Valid f1_score = 0.54677
# Epoch   0: Valid Acurracy = 0.54677
# Epoch   0: Valid Recall score = 0.54677
# Epoch   0: Valid Precision score = 0.54677
# The current f1 score: 0.5467696629213483
# Epoch   1: Train Loss = 4.40214
# Epoch   1: Valid Loss = 4.17937
# Epoch   1: Valid f1_score = 0.69452
# Epoch   1: Valid Acurracy = 0.69452
# Epoch   1: Valid Recall score = 0.69452
# Epoch   1: Valid Precision score = 0.69452
# The current f1 score: 0.6945224719101124
# Epoch   2: Train Loss = 4.35142
# Epoch   2: Valid Loss = 4.14117
# Epoch   2: Valid f1_score = 0.73947
# Epoch   2: Valid Acurracy = 0.73947
# Epoch   2: Valid Recall score = 0.73947
# Epoch   2: Valid Precision score = 0.73947
# The current f1 score: 0.7394662921348315
# Epoch   3: Train Loss = 4.30877
# Epoch   3: Valid Loss = 4.08785
# Epoch   3: Valid f1_score = 0.78532
# Epoch   3: Valid Acurracy = 0.78532
# Epoch   3: Valid Recall score = 0.78532
# Epoch   3: Valid Precision score = 0.78532
# The current f1 score: 0.7853230337078652
# Epoch   4: Train Loss = 4.27549
# Epoch   4: Valid Loss = 4.04898
# Epoch   4: Valid f1_score = 0.82374
# Epoch   4: Valid Acurracy = 0.82374
# Epoch   4: Valid Recall score = 0.82374
# Epoch   4: Valid Precision score = 0.82374
# The current f1 score: 0.8237359550561798
# Epoch   5: Train Loss = 4.25539
# Epoch   5: Valid Loss = 4.01864
# Epoch   5: Valid f1_score = 0.85358
# Epoch   5: Valid Acurracy = 0.85358
# Epoch   5: Valid Recall score = 0.85358
# Epoch   5: Valid Precision score = 0.85358
# The current f1 score: 0.8535814606741573
# Epoch   6: Train Loss = 4.23704
# Epoch   6: Valid Loss = 3.99913
# Epoch   6: Valid f1_score = 0.87065
# Epoch   6: Valid Acurracy = 0.87065
# Epoch   6: Valid Recall score = 0.87065
# Epoch   6: Valid Precision score = 0.87065
# The current f1 score: 0.8706460674157303
# Epoch   7: Train Loss = 4.21994
# Epoch   7: Valid Loss = 3.97699
# Epoch   7: Valid f1_score = 0.89923
# Epoch   7: Valid Acurracy = 0.89923
# Epoch   7: Valid Recall score = 0.89923
# Epoch   7: Valid Precision score = 0.89923
# The current f1 score: 0.8992275280898876
# Epoch   8: Train Loss = 4.20816
# Epoch   8: Valid Loss = 3.96640
# Epoch   8: Valid f1_score = 0.90098
# Epoch   8: Valid Acurracy = 0.90098
# Epoch   8: Valid Recall score = 0.90098
# Epoch   8: Valid Precision score = 0.90098
# The current f1 score: 0.9009831460674157
# Epoch   9: Train Loss = 4.19878
# Epoch   9: Valid Loss = 3.95423
# Epoch   9: Valid f1_score = 0.90941
# Epoch   9: Valid Acurracy = 0.90941
# Epoch   9: Valid Recall score = 0.90941
# Epoch   9: Valid Precision score = 0.90941
# The current f1 score: 0.9094101123595506
# Epoch  10: Train Loss = 4.19133
# Epoch  10: Valid Loss = 3.95030
# Epoch  10: Valid f1_score = 0.91383
# Epoch  10: Valid Acurracy = 0.91383
# Epoch  10: Valid Recall score = 0.91383
# Epoch  10: Valid Precision score = 0.91383
# The current f1 score: 0.9138342696629214
# Epoch  11: Train Loss = 4.18720
# Epoch  11: Valid Loss = 3.94121
# Epoch  11: Valid f1_score = 0.92367
# Epoch  11: Valid Acurracy = 0.92367
# Epoch  11: Valid Recall score = 0.92367
# Epoch  11: Valid Precision score = 0.92367
# The current f1 score: 0.9236657303370787
# Epoch  12: Train Loss = 4.18948
# Epoch  12: Valid Loss = 3.93454
# Epoch  12: Valid f1_score = 0.92591
# Epoch  12: Valid Acurracy = 0.92591
# Epoch  12: Valid Recall score = 0.92591
# Epoch  12: Valid Precision score = 0.92591
# The current f1 score: 0.9259129213483146
# Epoch  13: Train Loss = 4.17976
# Epoch  13: Valid Loss = 3.93387
# Epoch  13: Valid f1_score = 0.92718
# Epoch  13: Valid Acurracy = 0.92718
# Epoch  13: Valid Recall score = 0.92718
# Epoch  13: Valid Precision score = 0.92718
# The current f1 score: 0.9271769662921348
# Epoch  14: Train Loss = 4.18204
# Epoch  14: Valid Loss = 3.92999
# Epoch  14: Valid f1_score = 0.92963
# Epoch  14: Valid Acurracy = 0.92963
# Epoch  14: Valid Recall score = 0.92963
# Epoch  14: Valid Precision score = 0.92963
# The current f1 score: 0.9296348314606742
# Epoch  15: Train Loss = 4.17672
# Epoch  15: Valid Loss = 3.92329
# Epoch  15: Valid f1_score = 0.93996
# Epoch  15: Valid Acurracy = 0.93996
# Epoch  15: Valid Recall score = 0.93996
# Epoch  15: Valid Precision score = 0.93996
# The current f1 score: 0.9399578651685393
# Epoch  16: Train Loss = 4.17022
# Epoch  16: Valid Loss = 3.92169
# Epoch  16: Valid f1_score = 0.94122
# Epoch  16: Valid Acurracy = 0.94122
# Epoch  16: Valid Recall score = 0.94122
# Epoch  16: Valid Precision score = 0.94122
# The current f1 score: 0.9412219101123596
# Epoch  17: Train Loss = 4.16291
# Epoch  17: Valid Loss = 3.91871
# Epoch  17: Valid f1_score = 0.94347
# Epoch  17: Valid Acurracy = 0.94347
# Epoch  17: Valid Recall score = 0.94347
# Epoch  17: Valid Precision score = 0.94347
# The current f1 score: 0.9434691011235955
# Epoch  18: Train Loss = 4.16295
# Epoch  18: Valid Loss = 3.91888
# Epoch  18: Valid f1_score = 0.94192
# Epoch  18: Valid Acurracy = 0.94192
# Epoch  18: Valid Recall score = 0.94192
# Epoch  18: Valid Precision score = 0.94192
# trigger times: 1
# Epoch  19: Train Loss = 4.16956
# Epoch  19: Valid Loss = 3.91642
# Epoch  19: Valid f1_score = 0.94417
# Epoch  19: Valid Acurracy = 0.94417
# Epoch  19: Valid Recall score = 0.94417
# Epoch  19: Valid Precision score = 0.94417
# The current f1 score: 0.9441713483146067
# 0.9441713483146067
# The best parameters are saved for the activation function: Tanhshrink

# %%
list_relation_loss_train_elu, list_relation_loss_valid_elu, list_epochs_elu = get_relation_results("ELU", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=125, bias=True)
#   (activation): ELU(alpha=1.0)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.56424
# Epoch   0: Valid Loss = 4.28507
# Epoch   0: Valid f1_score = 0.61524
# Epoch   0: Valid Acurracy = 0.61524
# Epoch   0: Valid Recall score = 0.61524
# Epoch   0: Valid Precision score = 0.61524
# The current f1 score: 0.6152387640449438
# Epoch   1: Train Loss = 4.37569
# Epoch   1: Valid Loss = 4.15666
# Epoch   1: Valid f1_score = 0.72121
# Epoch   1: Valid Acurracy = 0.72121
# Epoch   1: Valid Recall score = 0.72121
# Epoch   1: Valid Precision score = 0.72121
# The current f1 score: 0.7212078651685393
# Epoch   2: Train Loss = 4.32004
# Epoch   2: Valid Loss = 4.08926
# Epoch   2: Valid f1_score = 0.80513
# Epoch   2: Valid Acurracy = 0.80513
# Epoch   2: Valid Recall score = 0.80513
# Epoch   2: Valid Precision score = 0.80513
# The current f1 score: 0.805126404494382
# Epoch   3: Train Loss = 4.27049
# Epoch   3: Valid Loss = 4.03302
# Epoch   3: Valid f1_score = 0.84712
# Epoch   3: Valid Acurracy = 0.84712
# Epoch   3: Valid Recall score = 0.84712
# Epoch   3: Valid Precision score = 0.84712
# The current f1 score: 0.8471207865168539
# Epoch   4: Train Loss = 4.24570
# Epoch   4: Valid Loss = 4.01036
# Epoch   4: Valid f1_score = 0.87324
# Epoch   4: Valid Acurracy = 0.87324
# Epoch   4: Valid Recall score = 0.87324
# Epoch   4: Valid Precision score = 0.87324
# The current f1 score: 0.8732443820224719
# Epoch   5: Train Loss = 4.22278
# Epoch   5: Valid Loss = 3.98240
# Epoch   5: Valid f1_score = 0.89607
# Epoch   5: Valid Acurracy = 0.89607
# Epoch   5: Valid Recall score = 0.89607
# Epoch   5: Valid Precision score = 0.89607
# The current f1 score: 0.8960674157303371
# Epoch   6: Train Loss = 4.21076
# Epoch   6: Valid Loss = 3.96410
# Epoch   6: Valid f1_score = 0.91081
# Epoch   6: Valid Acurracy = 0.91081
# Epoch   6: Valid Recall score = 0.91081
# Epoch   6: Valid Precision score = 0.91081
# The current f1 score: 0.910814606741573
# Epoch   7: Train Loss = 4.19717
# Epoch   7: Valid Loss = 3.95316
# Epoch   7: Valid f1_score = 0.91222
# Epoch   7: Valid Acurracy = 0.91222
# Epoch   7: Valid Recall score = 0.91222
# Epoch   7: Valid Precision score = 0.91222
# The current f1 score: 0.9122191011235955
# Epoch   8: Train Loss = 4.19684
# Epoch   8: Valid Loss = 3.95026
# Epoch   8: Valid f1_score = 0.91187
# Epoch   8: Valid Acurracy = 0.91187
# Epoch   8: Valid Recall score = 0.91187
# Epoch   8: Valid Precision score = 0.91187
# trigger times: 1
# Epoch   9: Train Loss = 4.19101
# Epoch   9: Valid Loss = 3.94458
# Epoch   9: Valid f1_score = 0.91749
# Epoch   9: Valid Acurracy = 0.91749
# Epoch   9: Valid Recall score = 0.91749
# Epoch   9: Valid Precision score = 0.91749
# The current f1 score: 0.9174859550561798
# Epoch  10: Train Loss = 4.18394
# Epoch  10: Valid Loss = 3.93975
# Epoch  10: Valid f1_score = 0.92612
# Epoch  10: Valid Acurracy = 0.92612
# Epoch  10: Valid Recall score = 0.92612
# Epoch  10: Valid Precision score = 0.92612
# The current f1 score: 0.926123595505618
# Epoch  11: Train Loss = 4.17860
# Epoch  11: Valid Loss = 3.93338
# Epoch  11: Valid f1_score = 0.93279
# Epoch  11: Valid Acurracy = 0.93279
# Epoch  11: Valid Recall score = 0.93279
# Epoch  11: Valid Precision score = 0.93279
# The current f1 score: 0.9327949438202247
# Epoch  12: Train Loss = 4.17959
# Epoch  12: Valid Loss = 3.92259
# Epoch  12: Valid f1_score = 0.94206
# Epoch  12: Valid Acurracy = 0.94206
# Epoch  12: Valid Recall score = 0.94206
# Epoch  12: Valid Precision score = 0.94206
# The current f1 score: 0.942064606741573
# Epoch  13: Train Loss = 4.16995
# Epoch  13: Valid Loss = 3.91847
# Epoch  13: Valid f1_score = 0.94649
# Epoch  13: Valid Acurracy = 0.94649
# Epoch  13: Valid Recall score = 0.94649
# Epoch  13: Valid Precision score = 0.94649
# The current f1 score: 0.9464887640449438
# Epoch  14: Train Loss = 4.17232
# Epoch  14: Valid Loss = 3.91714
# Epoch  14: Valid f1_score = 0.94579
# Epoch  14: Valid Acurracy = 0.94579
# Epoch  14: Valid Recall score = 0.94579
# Epoch  14: Valid Precision score = 0.94579
# trigger times: 2
# Epoch  15: Train Loss = 4.16783
# Epoch  15: Valid Loss = 3.91372
# Epoch  15: Valid f1_score = 0.94979
# Epoch  15: Valid Acurracy = 0.94979
# Epoch  15: Valid Recall score = 0.94979
# Epoch  15: Valid Precision score = 0.94979
# The current f1 score: 0.9497893258426966
# Epoch  16: Train Loss = 4.16264
# Epoch  16: Valid Loss = 3.91257
# Epoch  16: Valid f1_score = 0.94860
# Epoch  16: Valid Acurracy = 0.94860
# Epoch  16: Valid Recall score = 0.94860
# Epoch  16: Valid Precision score = 0.94860
# trigger times: 3
# Early stopping!
# Start to test process.
# 0.9497893258426966
# The best parameters are saved for the activation function: ELU

# %%
list_relation_loss_train_softplus, list_relation_loss_valid_softplus, list_epochs_softplus = get_relation_results("Softplus", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=125, bias=True)
#   (activation): Softplus(beta=1, threshold=20)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.59772
# Epoch   0: Valid Loss = 4.32446
# Epoch   0: Valid f1_score = 0.57767
# Epoch   0: Valid Acurracy = 0.57767
# Epoch   0: Valid Recall score = 0.57767
# Epoch   0: Valid Precision score = 0.57767
# The current f1 score: 0.5776685393258427
# Epoch   1: Train Loss = 4.40095
# Epoch   1: Valid Loss = 4.19452
# Epoch   1: Valid f1_score = 0.69452
# Epoch   1: Valid Acurracy = 0.69452
# Epoch   1: Valid Recall score = 0.69452
# Epoch   1: Valid Precision score = 0.69452
# The current f1 score: 0.6945224719101124
# Epoch   2: Train Loss = 4.33257
# Epoch   2: Valid Loss = 4.11353
# Epoch   2: Valid f1_score = 0.78125
# Epoch   2: Valid Acurracy = 0.78125
# Epoch   2: Valid Recall score = 0.78125
# Epoch   2: Valid Precision score = 0.78125
# The current f1 score: 0.78125
# Epoch   3: Train Loss = 4.27981
# Epoch   3: Valid Loss = 4.04857
# Epoch   3: Valid f1_score = 0.83764
# Epoch   3: Valid Acurracy = 0.83764
# Epoch   3: Valid Recall score = 0.83764
# Epoch   3: Valid Precision score = 0.83764
# The current f1 score: 0.8376404494382023
# Epoch   4: Train Loss = 4.25313
# Epoch   4: Valid Loss = 4.02092
# Epoch   4: Valid f1_score = 0.86447
# Epoch   4: Valid Acurracy = 0.86447
# Epoch   4: Valid Recall score = 0.86447
# Epoch   4: Valid Precision score = 0.86447
# The current f1 score: 0.8644662921348315
# Epoch   5: Train Loss = 4.23370
# Epoch   5: Valid Loss = 3.98986
# Epoch   5: Valid f1_score = 0.88904
# Epoch   5: Valid Acurracy = 0.88904
# Epoch   5: Valid Recall score = 0.88904
# Epoch   5: Valid Precision score = 0.88904
# The current f1 score: 0.8890449438202247
# Epoch   6: Train Loss = 4.21716
# Epoch   6: Valid Loss = 3.97103
# Epoch   6: Valid f1_score = 0.90555
# Epoch   6: Valid Acurracy = 0.90555
# Epoch   6: Valid Recall score = 0.90555
# Epoch   6: Valid Precision score = 0.90555
# The current f1 score: 0.9055477528089888
# Epoch   7: Train Loss = 4.20216
# Epoch   7: Valid Loss = 3.95946
# Epoch   7: Valid f1_score = 0.91292
# Epoch   7: Valid Acurracy = 0.91292
# Epoch   7: Valid Recall score = 0.91292
# Epoch   7: Valid Precision score = 0.91292
# The current f1 score: 0.9129213483146067
# Epoch   8: Train Loss = 4.19844
# Epoch   8: Valid Loss = 3.95569
# Epoch   8: Valid f1_score = 0.90976
# Epoch   8: Valid Acurracy = 0.90976
# Epoch   8: Valid Recall score = 0.90976
# Epoch   8: Valid Precision score = 0.90976
# trigger times: 1
# Epoch   9: Train Loss = 4.19284
# Epoch   9: Valid Loss = 3.94024
# Epoch   9: Valid f1_score = 0.92521
# Epoch   9: Valid Acurracy = 0.92521
# Epoch   9: Valid Recall score = 0.92521
# Epoch   9: Valid Precision score = 0.92521
# The current f1 score: 0.9252106741573034
# Epoch  10: Train Loss = 4.18484
# Epoch  10: Valid Loss = 3.93596
# Epoch  10: Valid f1_score = 0.93104
# Epoch  10: Valid Acurracy = 0.93104
# Epoch  10: Valid Recall score = 0.93104
# Epoch  10: Valid Precision score = 0.93104
# The current f1 score: 0.9310393258426966
# Epoch  11: Train Loss = 4.18047
# Epoch  11: Valid Loss = 3.93171
# Epoch  11: Valid f1_score = 0.93244
# Epoch  11: Valid Acurracy = 0.93244
# Epoch  11: Valid Recall score = 0.93244
# Epoch  11: Valid Precision score = 0.93244
# The current f1 score: 0.932443820224719
# Epoch  12: Train Loss = 4.18388
# Epoch  12: Valid Loss = 3.92439
# Epoch  12: Valid f1_score = 0.93926
# Epoch  12: Valid Acurracy = 0.93926
# Epoch  12: Valid Recall score = 0.93926
# Epoch  12: Valid Precision score = 0.93926
# The current f1 score: 0.9392556179775281
# Epoch  13: Train Loss = 4.17443
# Epoch  13: Valid Loss = 3.92182
# Epoch  13: Valid f1_score = 0.94017
# Epoch  13: Valid Acurracy = 0.94017
# Epoch  13: Valid Recall score = 0.94017
# Epoch  13: Valid Precision score = 0.94017
# The current f1 score: 0.9401685393258427
# Epoch  14: Train Loss = 4.17819
# Epoch  14: Valid Loss = 3.91787
# Epoch  14: Valid f1_score = 0.94157
# Epoch  14: Valid Acurracy = 0.94157
# Epoch  14: Valid Recall score = 0.94157
# Epoch  14: Valid Precision score = 0.94157
# The current f1 score: 0.9415730337078652
# Epoch  15: Train Loss = 4.17335
# Epoch  15: Valid Loss = 3.91663
# Epoch  15: Valid f1_score = 0.94417
# Epoch  15: Valid Acurracy = 0.94417
# Epoch  15: Valid Recall score = 0.94417
# Epoch  15: Valid Precision score = 0.94417
# The current f1 score: 0.9441713483146067
# Epoch  16: Train Loss = 4.16758
# Epoch  16: Valid Loss = 3.91656
# Epoch  16: Valid f1_score = 0.94508
# Epoch  16: Valid Acurracy = 0.94508
# Epoch  16: Valid Recall score = 0.94508
# Epoch  16: Valid Precision score = 0.94508
# The current f1 score: 0.9450842696629214
# Epoch  17: Train Loss = 4.16018
# Epoch  17: Valid Loss = 3.91322
# Epoch  17: Valid f1_score = 0.94628
# Epoch  17: Valid Acurracy = 0.94628
# Epoch  17: Valid Recall score = 0.94628
# Epoch  17: Valid Precision score = 0.94628
# The current f1 score: 0.9462780898876404
# Epoch  18: Train Loss = 4.16018
# Epoch  18: Valid Loss = 3.91428
# Epoch  18: Valid f1_score = 0.94649
# Epoch  18: Valid Acurracy = 0.94649
# Epoch  18: Valid Recall score = 0.94649
# Epoch  18: Valid Precision score = 0.94649
# The current f1 score: 0.9464887640449438
# Epoch  19: Train Loss = 4.16696
# Epoch  19: Valid Loss = 3.91132
# Epoch  19: Valid f1_score = 0.94909
# Epoch  19: Valid Acurracy = 0.94909
# Epoch  19: Valid Recall score = 0.94909
# Epoch  19: Valid Precision score = 0.94909
# The current f1 score: 0.9490870786516854
# 0.9490870786516854
# The best parameters are saved for the activation function: Softplus

# %%
list_relation_training_losses.append(list_relation_loss_train_leakyrelu)
list_relation_validation_losses.append(list_relation_loss_valid_leakyrelu)
list_relation_epochs.append(list_epochs_leakyrelu)
list_relation_training_losses.append(list_relation_loss_train_tanhshrink)
list_relation_validation_losses.append(list_relation_loss_valid_tanhshrink)
list_relation_epochs.append(list_epochs_tanhshrink)
list_relation_training_losses.append(list_relation_loss_train_softplus)
list_relation_validation_losses.append(list_relation_loss_valid_softplus)
list_relation_epochs.append(list_epochs_softplus)
list_relation_training_losses.append(list_relation_loss_train_elu)
list_relation_validation_losses.append(list_relation_loss_valid_elu)
list_relation_epochs.append(list_epochs_elu)

# %% [markdown]
# **Through the function plot_losses the learning curves for losses (relation prediction losses, entity span prediction losses) are plotted.**

# %%
def plot_losses(list_epochs, list_training_losses, list_validation_losses, activations, lr, dropout_prob):
 for activation in range(len(activations)):
  plt.plot(list_epochs[activation], list_training_losses[activation], label = f"{activations[activation]},{lr},{dropout_prob}-Training")
  plt.plot(list_epochs[activation], list_validation_losses[activation], label = f"{activations[activation]},{lr},{dropout_prob}-Validation")
  plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize = 'small')
  plt.title("loss-score")
  plt.xlabel("Number of epochs")
  plt.ylabel("Loss")
  plt.ylim(ymin = 3.5)
activations = ['LeakyReLU','Tanhshrink', 'Softplus','ELU']

# %%
plot_losses(list_relation_epochs, list_relation_training_losses, list_relation_validation_losses, activations, learning_rate, dropout_prob)

# %% [markdown]
# ****Construction and initialization of the neural network for the prediction of the entity span start and entity span end indexes for each question.****

# %%
class BertEntitySpanClassifier(nn.Module):
  def __init__(self, activation, dropout_prob, max_quest_len):
    super(BertEntitySpanClassifier, self).__init__()
    self.bert_model = BertModel.from_pretrained('bert-base-uncased')
# Whether the model returns all hidden-states.
    activations = {
        "ELU" : nn.ELU,
        "LeakyReLU"    : nn.LeakyReLU,
        "Softplus"     : nn.Softplus,
        "Tanhshrink"     : nn.Tanhshrink
 }
    self.activation_type = activation
    self.activation = activations[self.activation_type]()
    self.max_length = max_quest_len
    self.dropout_probability = dropout_prob
    self.start_head = nn.Sequential(
          nn.Linear(768, self.max_length),
          self.activation,
          nn.Dropout(p=self.dropout_probability),
          nn.Flatten(),
          nn.Softmax(dim=1)
    )

    self.end_head = nn.Sequential(
          nn.Linear(768, self.max_length),
          self.activation,
          nn.Dropout(p=self.dropout_probability),
          nn.Flatten(),
          nn.Softmax(dim=1)
    )

  def forward(self, input_ids, att_mask):
    out = self.bert_model(input_ids, att_mask)
    out = out[0]
    out_start = self.start_head(out)
    out_end = self.end_head(out)
    return out_start , out_end

# %% [markdown]
# **Through the function named entity_prediction_function the best possible parameters for the best possible prediction of the entity span are found. This function has as arguments the corresponding training dataloader, the corresponding validation dataloader, the number of epochs, the optimizer, the scheduler, the learning rate, the entity span prediction neural network model, the loss function and the dropout probability value.**
#
# **This function returns the best possible model, the list including numbers from 0 to number of training epochs-1, the lists including the values of training losses and validation losses for all epochs respectively, the largest value of f1 for entity span start and the largest value of f1 for entity span end.**
#
# **The biggest length of a question in words that is observed in SimpleQuestions dataset is equal to 33. Thus these predicted indexes as numbers must be either between 0 and 32, where these numbers correspond to the position of these words in their question for each question.**

# %%
def entity_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, lr, dropout_prob):
 list_loss_train = []
 list_loss = []
 list_epochs = []
 the_last_f1_start_score = 0
 the_last_f1_end_score = 0
 patience = 3
 max_f1_start = -1
 max_f1_end = -1
 trigger_times = 0
 for epoch in range(epochs):
  train_dataset.set_epoch(epoch)
  valid_dataset.set_epoch(epoch)
  model.train()
  batch_losses = []
  for batch in train_dataloader:
   input_ids = batch['input_ids'].to(device)
   attention_masks = batch['attention_mask'].to(device)
   entity_span_start_indexes = batch['entity_start'].to(device)
   entity_span_end_indexes = batch['entity_end'].to(device)
   y_pred_start, y_pred_end = model(input_ids, attention_masks)
   y_pred_start = y_pred_start.squeeze()
   y_pred_end = y_pred_end.squeeze()
   loss = loss_func(y_pred_start.cpu(),entity_span_start_indexes.cpu())+loss_func(y_pred_end.cpu(),entity_span_end_indexes.cpu())
   batch_losses.append(loss.detach().numpy())
    #Delete previously stored gradients
   nn.utils.clip_grad_norm_(model.parameters(), 0.7)
   optimizer.zero_grad()

    #Perform backpropagation starting from the loss calculated in this epoch
   loss.backward()

    #Update model's weights based on the gradients calculated during backprop
   optimizer.step()
   scheduler.step()
  print(f"Epoch {epoch:3}: Train Loss = {sum(batch_losses)/len(train_dataloader):.5f}")
  list_loss_train.append(sum(batch_losses)/len(train_dataloader))
  with torch.no_grad():
    model.eval()
    #Y_batches = []
    #Y_preds = []
    F1_start = []
    F1_end = []
    accuracy_start = []
    accuracy_end = []
    precision_start = []
    precision_end = []
    recall_start = []
    recall_end = []
    batch_losses_val = []
    for batch in val_dataloader:
      input_ids = batch['input_ids'].to(device)
      attention_masks = batch['attention_mask'].to(device)
      entity_span_start_indexes = batch['entity_start'].to(device)
      entity_span_end_indexes = batch['entity_end'].to(device)
      y_predict_start, y_predict_end = model(input_ids, attention_masks)
      y_predict_start = y_predict_start.squeeze()
      y_predict_end = y_predict_end.squeeze()
      val_loss = loss_func(y_predict_start.cpu(),entity_span_start_indexes.cpu())+loss_func(y_predict_end.cpu(),entity_span_end_indexes.cpu())
      batch_losses_val.append(val_loss)
      y_pr_start = torch.argmax(y_predict_start, dim=1)
      y_pr_end = torch.argmax(y_predict_end, dim=1)
      Y_p_start = y_pr_start.tolist()
      Y_p_end = y_pr_end.tolist()
      y_val_start = entity_span_start_indexes.tolist()
      y_val_end = entity_span_end_indexes.tolist()
      F1_start.append(f1_score(y_val_start, Y_p_start, average = 'micro'))
      F1_end.append(f1_score(y_val_end, Y_p_end, average = 'micro'))
      precision_start.append(precision_score(y_val_start, Y_p_start, average = 'micro'))
      precision_end.append(precision_score(y_val_end, Y_p_end, average = 'micro'))
      recall_start.append(recall_score(y_val_start, Y_p_start, average = 'micro'))
      recall_end.append(recall_score(y_val_end, Y_p_end, average = 'micro'))
      accuracy_start.append(accuracy_score(y_val_start, Y_p_start))
      accuracy_end.append(accuracy_score(y_val_end, Y_p_end))

    #Y_batches = torch.cat(Y_batches)
    #Y_preds = torch.cat(Y_preds)
    Valid_f1_start = sum(F1_start)/len(val_dataloader)
    Valid_f1_end = sum(F1_end)/len(val_dataloader)
    print(f"Epoch {epoch:3}: Valid Loss = {sum(batch_losses_val)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid f1_score for entity start span = {Valid_f1_start:.5f}")
    print(f"Epoch {epoch:3}: Valid Acurracy for entity start span = {sum(accuracy_start)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Recall for entity start span = {sum(recall_start)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Precision for entity start span = {sum(precision_start)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid f1_score for entity end span = {Valid_f1_end:.5f}")
    print(f"Epoch {epoch:3}: Valid Acurracy for entity end span = {sum(accuracy_end)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Recall for entity end span = {sum(recall_end)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Precision for entity end span = {sum(precision_end)/len(val_dataloader):.5f}")
    #print(sum(accuracy_start)/len(val_dataloader), sum(recall_start)/len(val_dataloader), sum(precision_start)/len(val_dataloader))
    #print(sum(accuracy_end)/len(val_dataloader), sum(recall_end)/len(val_dataloader), sum(precision_end)/len(val_dataloader))
    list_loss.append(sum(batch_losses_val)/len(val_dataloader))
    list_epochs.append(epoch)

    if Valid_f1_start >= max_f1_start and Valid_f1_end >= max_f1_end:
      max_f1_start = Valid_f1_start
      max_f1_end = Valid_f1_end
      best_model = model
      print('The current f1 score for entity start:', Valid_f1_start)
      print('The current f1 score for entity end:', Valid_f1_end)
    if Valid_f1_start < the_last_f1_start_score and Valid_f1_end < the_last_f1_end_score:
      trigger_times += 1
      print('trigger times:', trigger_times)
      if trigger_times >= patience:
        print('Early stopping!\nStart to test process.')
        break;
    the_last_f1_start_score = Valid_f1_start
    the_last_f1_end_score = Valid_f1_end

 return max_f1_start, max_f1_end, list_loss_train, list_loss, list_epochs, best_model

# %% [markdown]
# **The function named get_entity_results finds results for the neural networks concerning the relation index and the entity span indexes (start,end). These functions have as arguments the corresponding training dataloader, the corresponding validation dataloader, the number of epochs ,the optimizer, the scheduler get_linear_schedule_with_warmup, the corresponding entity span prediction neural network model, the loss function, the learning rate and the SEED number.**
#
# **This function returns the list of training losses, the list of validation losses, and the list of how many epochs each model with each activation function needs to be fully trained.**

# %%
learning_rate  = 2e-5
dropout_prob = 0.3
epochs = 20
list_entity_training_losses = []
list_entity_validation_losses = []
list_entity_epochs = []
loss_func = nn.CrossEntropyLoss()
optimizer_name = "Adam"
activations_list = ['LeakyReLU','Tanhshrink', 'Softplus','ELU']
def get_entity_results(activation, max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_dataset, valid_dataset, train_dataloader, val_dataloader):
 SEED = 42
 set_seed(SEED)
 model = BertEntitySpanClassifier(activation, dropout_prob, max_question_length).to(device)
 print(model)
 loss_func = loss_func.to(device)
 optimizer = getattr(torch.optim, optimizer_name)(model.parameters(), lr=learning_rate)
 scheduler = get_linear_schedule_with_warmup(optimizer, 0, len(train_dataloader)*epochs)
 f1_start, f1_end, list_loss_train, list_loss_valid, list_epochs, best_entity_model = entity_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, learning_rate, dropout_prob)
 print(f1_start,f1_end)
 torch.save(best_entity_model.state_dict(), create_file(f"drive/MyDrive/Entity_span_indexes_models_best_parameters/Answerable_Questions/{activation}", f"entity_span_prediction_jaccard_similarity_answerable_questions_{activation}.pt") )
 print(f"The best parameters are saved for the activation function: {activation}")
 return list_loss_train, list_loss_valid, list_epochs

# %%
list_entity_loss_train_leakyrelu, list_entity_loss_valid_leakyrelu, list_epochs_leakyrelu = get_entity_results("LeakyReLU", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): LeakyReLU(negative_slope=0.01)
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.64225
# Epoch   0: Valid Loss = 13.36153
# Epoch   0: Valid f1_score for entity start span = 0.44396
# Epoch   0: Valid Acurracy for entity start span = 0.44396
# Epoch   0: Valid Recall for entity start span = 0.44396
# Epoch   0: Valid Precision for entity start span = 0.44396
# Epoch   0: Valid f1_score for entity end span = 0.32879
# Epoch   0: Valid Acurracy for entity end span = 0.32879
# Epoch   0: Valid Recall for entity end span = 0.32879
# Epoch   0: Valid Precision for entity end span = 0.32879
# The current f1 score for entity start: 0.4439606741573034
# The current f1 score for entity end: 0.3287921348314607
# Epoch   1: Train Loss = 13.35385
# Epoch   1: Valid Loss = 13.09215
# Epoch   1: Valid f1_score for entity start span = 0.59663
# Epoch   1: Valid Acurracy for entity start span = 0.59663
# Epoch   1: Valid Recall for entity start span = 0.59663
# Epoch   1: Valid Precision for entity start span = 0.59663
# Epoch   1: Valid f1_score for entity end span = 0.39621
# Epoch   1: Valid Acurracy for entity end span = 0.39621
# Epoch   1: Valid Recall for entity end span = 0.39621
# Epoch   1: Valid Precision for entity end span = 0.39621
# The current f1 score for entity start: 0.5966292134831461
# The current f1 score for entity end: 0.39620786516853934
# Epoch   2: Train Loss = 13.19759
# Epoch   2: Valid Loss = 12.84414
# Epoch   2: Valid f1_score for entity start span = 0.61103
# Epoch   2: Valid Acurracy for entity start span = 0.61103
# Epoch   2: Valid Recall for entity start span = 0.61103
# Epoch   2: Valid Precision for entity start span = 0.61103
# Epoch   2: Valid f1_score for entity end span = 0.69473
# Epoch   2: Valid Acurracy for entity end span = 0.69473
# Epoch   2: Valid Recall for entity end span = 0.69473
# Epoch   2: Valid Precision for entity end span = 0.69473
# The current f1 score for entity start: 0.6110252808988764
# The current f1 score for entity end: 0.6947331460674157
# Epoch   3: Train Loss = 12.91274
# Epoch   3: Valid Loss = 12.52285
# Epoch   3: Valid f1_score for entity start span = 0.80162
# Epoch   3: Valid Acurracy for entity start span = 0.80162
# Epoch   3: Valid Recall for entity start span = 0.80162
# Epoch   3: Valid Precision for entity start span = 0.80162
# Epoch   3: Valid f1_score for entity end span = 0.78848
# Epoch   3: Valid Acurracy for entity end span = 0.78848
# Epoch   3: Valid Recall for entity end span = 0.78848
# Epoch   3: Valid Precision for entity end span = 0.78848
# The current f1 score for entity start: 0.8016151685393258
# The current f1 score for entity end: 0.7884831460674157
# Epoch   4: Train Loss = 12.85520
# Epoch   4: Valid Loss = 12.45642
# Epoch   4: Valid f1_score for entity start span = 0.79993
# Epoch   4: Valid Acurracy for entity start span = 0.79993
# Epoch   4: Valid Recall for entity start span = 0.79993
# Epoch   4: Valid Precision for entity start span = 0.79993
# Epoch   4: Valid f1_score for entity end span = 0.82711
# Epoch   4: Valid Acurracy for entity end span = 0.82711
# Epoch   4: Valid Recall for entity end span = 0.82711
# Epoch   4: Valid Precision for entity end span = 0.82711
# Epoch   5: Train Loss = 12.79786
# Epoch   5: Valid Loss = 12.36082
# Epoch   5: Valid f1_score for entity start span = 0.86117
# Epoch   5: Valid Acurracy for entity start span = 0.86117
# Epoch   5: Valid Recall for entity start span = 0.86117
# Epoch   5: Valid Precision for entity start span = 0.86117
# Epoch   5: Valid f1_score for entity end span = 0.85274
# Epoch   5: Valid Acurracy for entity end span = 0.85274
# Epoch   5: Valid Recall for entity end span = 0.85274
# Epoch   5: Valid Precision for entity end span = 0.85274
# The current f1 score for entity start: 0.8611657303370787
# The current f1 score for entity end: 0.8527387640449438
# Epoch   6: Train Loss = 12.77024
# Epoch   6: Valid Loss = 12.33214
# Epoch   6: Valid f1_score for entity start span = 0.87219
# Epoch   6: Valid Acurracy for entity start span = 0.87219
# Epoch   6: Valid Recall for entity start span = 0.87219
# Epoch   6: Valid Precision for entity start span = 0.87219
# Epoch   6: Valid f1_score for entity end span = 0.85541
# Epoch   6: Valid Acurracy for entity end span = 0.85541
# Epoch   6: Valid Recall for entity end span = 0.85541
# Epoch   6: Valid Precision for entity end span = 0.85541
# The current f1 score for entity start: 0.8721910112359551
# The current f1 score for entity end: 0.8554073033707864
# Epoch   7: Train Loss = 12.75878
# Epoch   7: Valid Loss = 12.30125
# Epoch   7: Valid f1_score for entity start span = 0.88132
# Epoch   7: Valid Acurracy for entity start span = 0.88132
# Epoch   7: Valid Recall for entity start span = 0.88132
# Epoch   7: Valid Precision for entity start span = 0.88132
# Epoch   7: Valid f1_score for entity end span = 0.87079
# Epoch   7: Valid Acurracy for entity end span = 0.87079
# Epoch   7: Valid Recall for entity end span = 0.87079
# Epoch   7: Valid Precision for entity end span = 0.87079
# The current f1 score for entity start: 0.8813202247191011
# The current f1 score for entity end: 0.8707865168539326
# Epoch   8: Train Loss = 12.72926
# Epoch   8: Valid Loss = 12.28348
# Epoch   8: Valid f1_score for entity start span = 0.89958
# Epoch   8: Valid Acurracy for entity start span = 0.89958
# Epoch   8: Valid Recall for entity start span = 0.89958
# Epoch   8: Valid Precision for entity start span = 0.89958
# Epoch   8: Valid f1_score for entity end span = 0.87697
# Epoch   8: Valid Acurracy for entity end span = 0.87697
# Epoch   8: Valid Recall for entity end span = 0.87697
# Epoch   8: Valid Precision for entity end span = 0.87697
# The current f1 score for entity start: 0.8995786516853933
# The current f1 score for entity end: 0.8769662921348315
# Epoch   9: Train Loss = 12.71348
# Epoch   9: Valid Loss = 12.25547
# Epoch   9: Valid f1_score for entity start span = 0.90351
# Epoch   9: Valid Acurracy for entity start span = 0.90351
# Epoch   9: Valid Recall for entity start span = 0.90351
# Epoch   9: Valid Precision for entity start span = 0.90351
# Epoch   9: Valid f1_score for entity end span = 0.89221
# Epoch   9: Valid Acurracy for entity end span = 0.89221
# Epoch   9: Valid Recall for entity end span = 0.89221
# Epoch   9: Valid Precision for entity end span = 0.89221
# The current f1 score for entity start: 0.9035112359550561
# The current f1 score for entity end: 0.8922050561797753
# Epoch  10: Train Loss = 12.70483
# Epoch  10: Valid Loss = 12.23917
# Epoch  10: Valid f1_score for entity start span = 0.90941
# Epoch  10: Valid Acurracy for entity start span = 0.90941
# Epoch  10: Valid Recall for entity start span = 0.90941
# Epoch  10: Valid Precision for entity start span = 0.90941
# Epoch  10: Valid f1_score for entity end span = 0.89277
# Epoch  10: Valid Acurracy for entity end span = 0.89277
# Epoch  10: Valid Recall for entity end span = 0.89277
# Epoch  10: Valid Precision for entity end span = 0.89277
# The current f1 score for entity start: 0.9094101123595506
# The current f1 score for entity end: 0.8927668539325843
# Epoch  11: Train Loss = 12.69708
# Epoch  11: Valid Loss = 12.22054
# Epoch  11: Valid f1_score for entity start span = 0.92065
# Epoch  11: Valid Acurracy for entity start span = 0.92065
# Epoch  11: Valid Recall for entity start span = 0.92065
# Epoch  11: Valid Precision for entity start span = 0.92065
# Epoch  11: Valid f1_score for entity end span = 0.89747
# Epoch  11: Valid Acurracy for entity end span = 0.89747
# Epoch  11: Valid Recall for entity end span = 0.89747
# Epoch  11: Valid Precision for entity end span = 0.89747
# The current f1 score for entity start: 0.9206460674157303
# The current f1 score for entity end: 0.8974719101123596
# Epoch  12: Train Loss = 12.69471
# Epoch  12: Valid Loss = 12.20888
# Epoch  12: Valid f1_score for entity start span = 0.92416
# Epoch  12: Valid Acurracy for entity start span = 0.92416
# Epoch  12: Valid Recall for entity start span = 0.92416
# Epoch  12: Valid Precision for entity start span = 0.92416
# Epoch  12: Valid f1_score for entity end span = 0.90520
# Epoch  12: Valid Acurracy for entity end span = 0.90520
# Epoch  12: Valid Recall for entity end span = 0.90520
# Epoch  12: Valid Precision for entity end span = 0.90520
# The current f1 score for entity start: 0.9241573033707865
# The current f1 score for entity end: 0.9051966292134831
# Epoch  13: Train Loss = 12.67899
# Epoch  13: Valid Loss = 12.20087
# Epoch  13: Valid f1_score for entity start span = 0.92135
# Epoch  13: Valid Acurracy for entity start span = 0.92135
# Epoch  13: Valid Recall for entity start span = 0.92135
# Epoch  13: Valid Precision for entity start span = 0.92135
# Epoch  13: Valid f1_score for entity end span = 0.91573
# Epoch  13: Valid Acurracy for entity end span = 0.91573
# Epoch  13: Valid Recall for entity end span = 0.91573
# Epoch  13: Valid Precision for entity end span = 0.91573
# Epoch  14: Train Loss = 12.67184
# Epoch  14: Valid Loss = 12.19146
# Epoch  14: Valid f1_score for entity start span = 0.92697
# Epoch  14: Valid Acurracy for entity start span = 0.92697
# Epoch  14: Valid Recall for entity start span = 0.92697
# Epoch  14: Valid Precision for entity start span = 0.92697
# Epoch  14: Valid f1_score for entity end span = 0.91713
# Epoch  14: Valid Acurracy for entity end span = 0.91713
# Epoch  14: Valid Recall for entity end span = 0.91713
# Epoch  14: Valid Precision for entity end span = 0.91713
# The current f1 score for entity start: 0.9269662921348315
# The current f1 score for entity end: 0.9171348314606742
# Epoch  15: Train Loss = 12.67504
# Epoch  15: Valid Loss = 12.18087
# Epoch  15: Valid f1_score for entity start span = 0.92907
# Epoch  15: Valid Acurracy for entity start span = 0.92907
# Epoch  15: Valid Recall for entity start span = 0.92907
# Epoch  15: Valid Precision for entity start span = 0.92907
# Epoch  15: Valid f1_score for entity end span = 0.91854
# Epoch  15: Valid Acurracy for entity end span = 0.91854
# Epoch  15: Valid Recall for entity end span = 0.91854
# Epoch  15: Valid Precision for entity end span = 0.91854
# The current f1 score for entity start: 0.9290730337078652
# The current f1 score for entity end: 0.9185393258426966
# Epoch  16: Train Loss = 12.67250
# Epoch  16: Valid Loss = 12.18237
# Epoch  16: Valid f1_score for entity start span = 0.92872
# Epoch  16: Valid Acurracy for entity start span = 0.92872
# Epoch  16: Valid Recall for entity start span = 0.92872
# Epoch  16: Valid Precision for entity start span = 0.92872
# Epoch  16: Valid f1_score for entity end span = 0.91664
# Epoch  16: Valid Acurracy for entity end span = 0.91664
# Epoch  16: Valid Recall for entity end span = 0.91664
# Epoch  16: Valid Precision for entity end span = 0.91664
# trigger times: 1
# Epoch  17: Train Loss = 12.66360
# Epoch  17: Valid Loss = 12.17619
# Epoch  17: Valid f1_score for entity start span = 0.92907
# Epoch  17: Valid Acurracy for entity start span = 0.92907
# Epoch  17: Valid Recall for entity start span = 0.92907
# Epoch  17: Valid Precision for entity start span = 0.92907
# Epoch  17: Valid f1_score for entity end span = 0.91819
# Epoch  17: Valid Acurracy for entity end span = 0.91819
# Epoch  17: Valid Recall for entity end span = 0.91819
# Epoch  17: Valid Precision for entity end span = 0.91819
# Epoch  18: Train Loss = 12.66552
# Epoch  18: Valid Loss = 12.17523
# Epoch  18: Valid f1_score for entity start span = 0.92942
# Epoch  18: Valid Acurracy for entity start span = 0.92942
# Epoch  18: Valid Recall for entity start span = 0.92942
# Epoch  18: Valid Precision for entity start span = 0.92942
# Epoch  18: Valid f1_score for entity end span = 0.91819
# Epoch  18: Valid Acurracy for entity end span = 0.91819
# Epoch  18: Valid Recall for entity end span = 0.91819
# Epoch  18: Valid Precision for entity end span = 0.91819
# Epoch  19: Train Loss = 12.68104
# Epoch  19: Valid Loss = 12.17405
# Epoch  19: Valid f1_score for entity start span = 0.92872
# Epoch  19: Valid Acurracy for entity start span = 0.92872
# Epoch  19: Valid Recall for entity start span = 0.92872
# Epoch  19: Valid Precision for entity start span = 0.92872
# Epoch  19: Valid f1_score for entity end span = 0.91819
# Epoch  19: Valid Acurracy for entity end span = 0.91819
# Epoch  19: Valid Recall for entity end span = 0.91819
# Epoch  19: Valid Precision for entity end span = 0.91819
# 0.9290730337078652 0.9185393258426966
# The best parameters are saved for the activation function: LeakyReLU

# %%
list_entity_loss_train_tanhshrink, list_entity_loss_valid_tanhshrink, list_epochs_tanhshrink = get_entity_results("Tanhshrink", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): Tanhshrink()
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Tanhshrink()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Tanhshrink()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.68905
# Epoch   0: Valid Loss = 13.40838
# Epoch   0: Valid f1_score for entity start span = 0.43904
# Epoch   0: Valid Acurracy for entity start span = 0.43904
# Epoch   0: Valid Recall for entity start span = 0.43904
# Epoch   0: Valid Precision for entity start span = 0.43904
# Epoch   0: Valid f1_score for entity end span = 0.22942
# Epoch   0: Valid Acurracy for entity end span = 0.22942
# Epoch   0: Valid Recall for entity end span = 0.22942
# Epoch   0: Valid Precision for entity end span = 0.22942
# The current f1 score for entity start: 0.43904494382022474
# The current f1 score for entity end: 0.2294241573033708
# Epoch   1: Train Loss = 13.35294
# Epoch   1: Valid Loss = 12.99022
# Epoch   1: Valid f1_score for entity start span = 0.59522
# Epoch   1: Valid Acurracy for entity start span = 0.59522
# Epoch   1: Valid Recall for entity start span = 0.59522
# Epoch   1: Valid Precision for entity start span = 0.59522
# Epoch   1: Valid f1_score for entity end span = 0.46854
# Epoch   1: Valid Acurracy for entity end span = 0.46854
# Epoch   1: Valid Recall for entity end span = 0.46854
# Epoch   1: Valid Precision for entity end span = 0.46854
# The current f1 score for entity start: 0.5952247191011236
# The current f1 score for entity end: 0.46853932584269664
# Epoch   2: Train Loss = 13.20846
# Epoch   2: Valid Loss = 12.82891
# Epoch   2: Valid f1_score for entity start span = 0.77268
# Epoch   2: Valid Acurracy for entity start span = 0.77268
# Epoch   2: Valid Recall for entity start span = 0.77268
# Epoch   2: Valid Precision for entity start span = 0.77268
# Epoch   2: Valid f1_score for entity end span = 0.45653
# Epoch   2: Valid Acurracy for entity end span = 0.45653
# Epoch   2: Valid Recall for entity end span = 0.45653
# Epoch   2: Valid Precision for entity end span = 0.45653
# Epoch   3: Train Loss = 13.00492
# Epoch   3: Valid Loss = 12.56798
# Epoch   3: Valid f1_score for entity start span = 0.83216
# Epoch   3: Valid Acurracy for entity start span = 0.83216
# Epoch   3: Valid Recall for entity start span = 0.83216
# Epoch   3: Valid Precision for entity start span = 0.83216
# Epoch   3: Valid f1_score for entity end span = 0.64347
# Epoch   3: Valid Acurracy for entity end span = 0.64347
# Epoch   3: Valid Recall for entity end span = 0.64347
# Epoch   3: Valid Precision for entity end span = 0.64347
# The current f1 score for entity start: 0.8321629213483146
# The current f1 score for entity end: 0.6434691011235955
# Epoch   4: Train Loss = 12.91560
# Epoch   4: Valid Loss = 12.47661
# Epoch   4: Valid f1_score for entity start span = 0.85274
# Epoch   4: Valid Acurracy for entity start span = 0.85274
# Epoch   4: Valid Recall for entity start span = 0.85274
# Epoch   4: Valid Precision for entity start span = 0.85274
# Epoch   4: Valid f1_score for entity end span = 0.70688
# Epoch   4: Valid Acurracy for entity end span = 0.70688
# Epoch   4: Valid Recall for entity end span = 0.70688
# Epoch   4: Valid Precision for entity end span = 0.70688
# The current f1 score for entity start: 0.8527387640449438
# The current f1 score for entity end: 0.7068820224719101
# Epoch   5: Train Loss = 12.83858
# Epoch   5: Valid Loss = 12.36361
# Epoch   5: Valid f1_score for entity start span = 0.87065
# Epoch   5: Valid Acurracy for entity start span = 0.87065
# Epoch   5: Valid Recall for entity start span = 0.87065
# Epoch   5: Valid Precision for entity start span = 0.87065
# Epoch   5: Valid f1_score for entity end span = 0.79375
# Epoch   5: Valid Acurracy for entity end span = 0.79375
# Epoch   5: Valid Recall for entity end span = 0.79375
# Epoch   5: Valid Precision for entity end span = 0.79375
# The current f1 score for entity start: 0.8706460674157303
# The current f1 score for entity end: 0.79375
# Epoch   6: Train Loss = 12.79770
# Epoch   6: Valid Loss = 12.34134
# Epoch   6: Valid f1_score for entity start span = 0.86973
# Epoch   6: Valid Acurracy for entity start span = 0.86973
# Epoch   6: Valid Recall for entity start span = 0.86973
# Epoch   6: Valid Precision for entity start span = 0.86973
# Epoch   6: Valid f1_score for entity end span = 0.80660
# Epoch   6: Valid Acurracy for entity end span = 0.80660
# Epoch   6: Valid Recall for entity end span = 0.80660
# Epoch   6: Valid Precision for entity end span = 0.80660
# Epoch   7: Train Loss = 12.78845
# Epoch   7: Valid Loss = 12.32922
# Epoch   7: Valid f1_score for entity start span = 0.87676
# Epoch   7: Valid Acurracy for entity start span = 0.87676
# Epoch   7: Valid Recall for entity start span = 0.87676
# Epoch   7: Valid Precision for entity start span = 0.87676
# Epoch   7: Valid f1_score for entity end span = 0.81390
# Epoch   7: Valid Acurracy for entity end span = 0.81390
# Epoch   7: Valid Recall for entity end span = 0.81390
# Epoch   7: Valid Precision for entity end span = 0.81390
# The current f1 score for entity start: 0.8767556179775281
# The current f1 score for entity end: 0.8139044943820225
# Epoch   8: Train Loss = 12.75411
# Epoch   8: Valid Loss = 12.27672
# Epoch   8: Valid f1_score for entity start span = 0.89572
# Epoch   8: Valid Acurracy for entity start span = 0.89572
# Epoch   8: Valid Recall for entity start span = 0.89572
# Epoch   8: Valid Precision for entity start span = 0.89572
# Epoch   8: Valid f1_score for entity end span = 0.85063
# Epoch   8: Valid Acurracy for entity end span = 0.85063
# Epoch   8: Valid Recall for entity end span = 0.85063
# Epoch   8: Valid Precision for entity end span = 0.85063
# The current f1 score for entity start: 0.8957162921348315
# The current f1 score for entity end: 0.85063202247191
# Epoch   9: Train Loss = 12.72932
# Epoch   9: Valid Loss = 12.25134
# Epoch   9: Valid f1_score for entity start span = 0.90084
# Epoch   9: Valid Acurracy for entity start span = 0.90084
# Epoch   9: Valid Recall for entity start span = 0.90084
# Epoch   9: Valid Precision for entity start span = 0.90084
# Epoch   9: Valid f1_score for entity end span = 0.87079
# Epoch   9: Valid Acurracy for entity end span = 0.87079
# Epoch   9: Valid Recall for entity end span = 0.87079
# Epoch   9: Valid Precision for entity end span = 0.87079
# The current f1 score for entity start: 0.9008426966292135
# The current f1 score for entity end: 0.8707865168539326
# Epoch  10: Train Loss = 12.71754
# Epoch  10: Valid Loss = 12.22888
# Epoch  10: Valid f1_score for entity start span = 0.90625
# Epoch  10: Valid Acurracy for entity start span = 0.90625
# Epoch  10: Valid Recall for entity start span = 0.90625
# Epoch  10: Valid Precision for entity start span = 0.90625
# Epoch  10: Valid f1_score for entity end span = 0.87872
# Epoch  10: Valid Acurracy for entity end span = 0.87872
# Epoch  10: Valid Recall for entity end span = 0.87872
# Epoch  10: Valid Precision for entity end span = 0.87872
# The current f1 score for entity start: 0.90625
# The current f1 score for entity end: 0.8787219101123596
# Epoch  11: Train Loss = 12.70717
# Epoch  11: Valid Loss = 12.21642
# Epoch  11: Valid f1_score for entity start span = 0.90660
# Epoch  11: Valid Acurracy for entity start span = 0.90660
# Epoch  11: Valid Recall for entity start span = 0.90660
# Epoch  11: Valid Precision for entity start span = 0.90660
# Epoch  11: Valid f1_score for entity end span = 0.89171
# Epoch  11: Valid Acurracy for entity end span = 0.89171
# Epoch  11: Valid Recall for entity end span = 0.89171
# Epoch  11: Valid Precision for entity end span = 0.89171
# The current f1 score for entity start: 0.9066011235955056
# The current f1 score for entity end: 0.8917134831460674
# Epoch  12: Train Loss = 12.70225
# Epoch  12: Valid Loss = 12.19652
# Epoch  12: Valid f1_score for entity start span = 0.91327
# Epoch  12: Valid Acurracy for entity start span = 0.91327
# Epoch  12: Valid Recall for entity start span = 0.91327
# Epoch  12: Valid Precision for entity start span = 0.91327
# Epoch  12: Valid f1_score for entity end span = 0.90520
# Epoch  12: Valid Acurracy for entity end span = 0.90520
# Epoch  12: Valid Recall for entity end span = 0.90520
# Epoch  12: Valid Precision for entity end span = 0.90520
# The current f1 score for entity start: 0.9132724719101124
# The current f1 score for entity end: 0.9051966292134831
# Epoch  13: Train Loss = 12.68798
# Epoch  13: Valid Loss = 12.19290
# Epoch  13: Valid f1_score for entity start span = 0.91573
# Epoch  13: Valid Acurracy for entity start span = 0.91573
# Epoch  13: Valid Recall for entity start span = 0.91573
# Epoch  13: Valid Precision for entity start span = 0.91573
# Epoch  13: Valid f1_score for entity end span = 0.90133
# Epoch  13: Valid Acurracy for entity end span = 0.90133
# Epoch  13: Valid Recall for entity end span = 0.90133
# Epoch  13: Valid Precision for entity end span = 0.90133
# Epoch  14: Train Loss = 12.68078
# Epoch  14: Valid Loss = 12.18380
# Epoch  14: Valid f1_score for entity start span = 0.91643
# Epoch  14: Valid Acurracy for entity start span = 0.91643
# Epoch  14: Valid Recall for entity start span = 0.91643
# Epoch  14: Valid Precision for entity start span = 0.91643
# Epoch  14: Valid f1_score for entity end span = 0.91081
# Epoch  14: Valid Acurracy for entity end span = 0.91081
# Epoch  14: Valid Recall for entity end span = 0.91081
# Epoch  14: Valid Precision for entity end span = 0.91081
# The current f1 score for entity start: 0.9164325842696629
# The current f1 score for entity end: 0.910814606741573
# Epoch  15: Train Loss = 12.68081
# Epoch  15: Valid Loss = 12.17785
# Epoch  15: Valid f1_score for entity start span = 0.92029
# Epoch  15: Valid Acurracy for entity start span = 0.92029
# Epoch  15: Valid Recall for entity start span = 0.92029
# Epoch  15: Valid Precision for entity start span = 0.92029
# Epoch  15: Valid f1_score for entity end span = 0.91117
# Epoch  15: Valid Acurracy for entity end span = 0.91117
# Epoch  15: Valid Recall for entity end span = 0.91117
# Epoch  15: Valid Precision for entity end span = 0.91117
# The current f1 score for entity start: 0.9202949438202247
# The current f1 score for entity end: 0.9111657303370787
# Epoch  16: Train Loss = 12.67887
# Epoch  16: Valid Loss = 12.17294
# Epoch  16: Valid f1_score for entity start span = 0.92310
# Epoch  16: Valid Acurracy for entity start span = 0.92310
# Epoch  16: Valid Recall for entity start span = 0.92310
# Epoch  16: Valid Precision for entity start span = 0.92310
# Epoch  16: Valid f1_score for entity end span = 0.91419
# Epoch  16: Valid Acurracy for entity end span = 0.91419
# Epoch  16: Valid Recall for entity end span = 0.91419
# Epoch  16: Valid Precision for entity end span = 0.91419
# The current f1 score for entity start: 0.9231039325842697
# The current f1 score for entity end: 0.914185393258427
# Epoch  17: Train Loss = 12.66913
# Epoch  17: Valid Loss = 12.17035
# Epoch  17: Valid f1_score for entity start span = 0.92170
# Epoch  17: Valid Acurracy for entity start span = 0.92170
# Epoch  17: Valid Recall for entity start span = 0.92170
# Epoch  17: Valid Precision for entity start span = 0.92170
# Epoch  17: Valid f1_score for entity end span = 0.91643
# Epoch  17: Valid Acurracy for entity end span = 0.91643
# Epoch  17: Valid Recall for entity end span = 0.91643
# Epoch  17: Valid Precision for entity end span = 0.91643
# Epoch  18: Train Loss = 12.67075
# Epoch  18: Valid Loss = 12.16743
# Epoch  18: Valid f1_score for entity start span = 0.92205
# Epoch  18: Valid Acurracy for entity start span = 0.92205
# Epoch  18: Valid Recall for entity start span = 0.92205
# Epoch  18: Valid Precision for entity start span = 0.92205
# Epoch  18: Valid f1_score for entity end span = 0.91608
# Epoch  18: Valid Acurracy for entity end span = 0.91608
# Epoch  18: Valid Recall for entity end span = 0.91608
# Epoch  18: Valid Precision for entity end span = 0.91608
# Epoch  19: Train Loss = 12.68460
# Epoch  19: Valid Loss = 12.16648
# Epoch  19: Valid f1_score for entity start span = 0.92240
# Epoch  19: Valid Acurracy for entity start span = 0.92240
# Epoch  19: Valid Recall for entity start span = 0.92240
# Epoch  19: Valid Precision for entity start span = 0.92240
# Epoch  19: Valid f1_score for entity end span = 0.91608
# Epoch  19: Valid Acurracy for entity end span = 0.91608
# Epoch  19: Valid Recall for entity end span = 0.91608
# Epoch  19: Valid Precision for entity end span = 0.91608
# 0.9231039325842697 0.914185393258427
# The best parameters are saved for the activation function: Tanhshrink

# %%
list_entity_loss_train_elu, list_entity_loss_valid_elu, list_epochs_elu = get_entity_results("ELU", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): ELU(alpha=1.0)
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.61373
# Epoch   0: Valid Loss = 13.31401
# Epoch   0: Valid f1_score for entity start span = 0.44958
# Epoch   0: Valid Acurracy for entity start span = 0.44958
# Epoch   0: Valid Recall for entity start span = 0.44958
# Epoch   0: Valid Precision for entity start span = 0.44958
# Epoch   0: Valid f1_score for entity end span = 0.30843
# Epoch   0: Valid Acurracy for entity end span = 0.30843
# Epoch   0: Valid Recall for entity end span = 0.30843
# Epoch   0: Valid Precision for entity end span = 0.30843
# The current f1 score for entity start: 0.4495786516853933
# The current f1 score for entity end: 0.30842696629213484
# Epoch   1: Train Loss = 13.19059
# Epoch   1: Valid Loss = 12.84716
# Epoch   1: Valid f1_score for entity start span = 0.75112
# Epoch   1: Valid Acurracy for entity start span = 0.75112
# Epoch   1: Valid Recall for entity start span = 0.75112
# Epoch   1: Valid Precision for entity start span = 0.75112
# Epoch   1: Valid f1_score for entity end span = 0.51608
# Epoch   1: Valid Acurracy for entity end span = 0.51608
# Epoch   1: Valid Recall for entity end span = 0.51608
# Epoch   1: Valid Precision for entity end span = 0.51608
# The current f1 score for entity start: 0.7511235955056179
# The current f1 score for entity end: 0.5160814606741573
# Epoch   2: Train Loss = 12.98816
# Epoch   2: Valid Loss = 12.56209
# Epoch   2: Valid f1_score for entity start span = 0.83322
# Epoch   2: Valid Acurracy for entity start span = 0.83322
# Epoch   2: Valid Recall for entity start span = 0.83322
# Epoch   2: Valid Precision for entity start span = 0.83322
# Epoch   2: Valid f1_score for entity end span = 0.69986
# Epoch   2: Valid Acurracy for entity end span = 0.69986
# Epoch   2: Valid Recall for entity end span = 0.69986
# Epoch   2: Valid Precision for entity end span = 0.69986
# The current f1 score for entity start: 0.8332162921348315
# The current f1 score for entity end: 0.6998595505617977
# Epoch   3: Train Loss = 12.86869
# Epoch   3: Valid Loss = 12.50694
# Epoch   3: Valid f1_score for entity start span = 0.84761
# Epoch   3: Valid Acurracy for entity start span = 0.84761
# Epoch   3: Valid Recall for entity start span = 0.84761
# Epoch   3: Valid Precision for entity start span = 0.84761
# Epoch   3: Valid f1_score for entity end span = 0.74003
# Epoch   3: Valid Acurracy for entity end span = 0.74003
# Epoch   3: Valid Recall for entity end span = 0.74003
# Epoch   3: Valid Precision for entity end span = 0.74003
# The current f1 score for entity start: 0.8476123595505618
# The current f1 score for entity end: 0.7400280898876405
# Epoch   4: Train Loss = 12.82475
# Epoch   4: Valid Loss = 12.39253
# Epoch   4: Valid f1_score for entity start span = 0.86503
# Epoch   4: Valid Acurracy for entity start span = 0.86503
# Epoch   4: Valid Recall for entity start span = 0.86503
# Epoch   4: Valid Precision for entity start span = 0.86503
# Epoch   4: Valid f1_score for entity end span = 0.80555
# Epoch   4: Valid Acurracy for entity end span = 0.80555
# Epoch   4: Valid Recall for entity end span = 0.80555
# Epoch   4: Valid Precision for entity end span = 0.80555
# The current f1 score for entity start: 0.8650280898876405
# The current f1 score for entity end: 0.8055477528089887
# Epoch   5: Train Loss = 12.78138
# Epoch   5: Valid Loss = 12.32863
# Epoch   5: Valid f1_score for entity start span = 0.87044
# Epoch   5: Valid Acurracy for entity start span = 0.87044
# Epoch   5: Valid Recall for entity start span = 0.87044
# Epoch   5: Valid Precision for entity start span = 0.87044
# Epoch   5: Valid f1_score for entity end span = 0.85779
# Epoch   5: Valid Acurracy for entity end span = 0.85779
# Epoch   5: Valid Recall for entity end span = 0.85779
# Epoch   5: Valid Precision for entity end span = 0.85779
# The current f1 score for entity start: 0.870435393258427
# The current f1 score for entity end: 0.8577949438202247
# Epoch   6: Train Loss = 12.75670
# Epoch   6: Valid Loss = 12.29591
# Epoch   6: Valid f1_score for entity start span = 0.88869
# Epoch   6: Valid Acurracy for entity start span = 0.88869
# Epoch   6: Valid Recall for entity start span = 0.88869
# Epoch   6: Valid Precision for entity start span = 0.88869
# Epoch   6: Valid f1_score for entity end span = 0.86594
# Epoch   6: Valid Acurracy for entity end span = 0.86594
# Epoch   6: Valid Recall for entity end span = 0.86594
# Epoch   6: Valid Precision for entity end span = 0.86594
# The current f1 score for entity start: 0.8886938202247191
# The current f1 score for entity end: 0.865941011235955
# Epoch   7: Train Loss = 12.73808
# Epoch   7: Valid Loss = 12.26090
# Epoch   7: Valid f1_score for entity start span = 0.90801
# Epoch   7: Valid Acurracy for entity start span = 0.90801
# Epoch   7: Valid Recall for entity start span = 0.90801
# Epoch   7: Valid Precision for entity start span = 0.90801
# Epoch   7: Valid f1_score for entity end span = 0.87956
# Epoch   7: Valid Acurracy for entity end span = 0.87956
# Epoch   7: Valid Recall for entity end span = 0.87956
# Epoch   7: Valid Precision for entity end span = 0.87956
# The current f1 score for entity start: 0.9080056179775281
# The current f1 score for entity end: 0.879564606741573
# Epoch   8: Train Loss = 12.71383
# Epoch   8: Valid Loss = 12.24213
# Epoch   8: Valid f1_score for entity start span = 0.91117
# Epoch   8: Valid Acurracy for entity start span = 0.91117
# Epoch   8: Valid Recall for entity start span = 0.91117
# Epoch   8: Valid Precision for entity start span = 0.91117
# Epoch   8: Valid f1_score for entity end span = 0.87767
# Epoch   8: Valid Acurracy for entity end span = 0.87767
# Epoch   8: Valid Recall for entity end span = 0.87767
# Epoch   8: Valid Precision for entity end span = 0.87767
# Epoch   9: Train Loss = 12.70081
# Epoch   9: Valid Loss = 12.23888
# Epoch   9: Valid f1_score for entity start span = 0.91545
# Epoch   9: Valid Acurracy for entity start span = 0.91545
# Epoch   9: Valid Recall for entity start span = 0.91545
# Epoch   9: Valid Precision for entity start span = 0.91545
# Epoch   9: Valid f1_score for entity end span = 0.87079
# Epoch   9: Valid Acurracy for entity end span = 0.87079
# Epoch   9: Valid Recall for entity end span = 0.87079
# Epoch   9: Valid Precision for entity end span = 0.87079
# Epoch  10: Train Loss = 12.69339
# Epoch  10: Valid Loss = 12.20814
# Epoch  10: Valid f1_score for entity start span = 0.92029
# Epoch  10: Valid Acurracy for entity start span = 0.92029
# Epoch  10: Valid Recall for entity start span = 0.92029
# Epoch  10: Valid Precision for entity start span = 0.92029
# Epoch  10: Valid f1_score for entity end span = 0.89979
# Epoch  10: Valid Acurracy for entity end span = 0.89979
# Epoch  10: Valid Recall for entity end span = 0.89979
# Epoch  10: Valid Precision for entity end span = 0.89979
# The current f1 score for entity start: 0.9202949438202247
# The current f1 score for entity end: 0.8997893258426966
# Epoch  11: Train Loss = 12.68734
# Epoch  11: Valid Loss = 12.19760
# Epoch  11: Valid f1_score for entity start span = 0.92240
# Epoch  11: Valid Acurracy for entity start span = 0.92240
# Epoch  11: Valid Recall for entity start span = 0.92240
# Epoch  11: Valid Precision for entity start span = 0.92240
# Epoch  11: Valid f1_score for entity end span = 0.90239
# Epoch  11: Valid Acurracy for entity end span = 0.90239
# Epoch  11: Valid Recall for entity end span = 0.90239
# Epoch  11: Valid Precision for entity end span = 0.90239
# The current f1 score for entity start: 0.9224016853932584
# The current f1 score for entity end: 0.9023876404494382
# Epoch  12: Train Loss = 12.68639
# Epoch  12: Valid Loss = 12.18949
# Epoch  12: Valid f1_score for entity start span = 0.92275
# Epoch  12: Valid Acurracy for entity start span = 0.92275
# Epoch  12: Valid Recall for entity start span = 0.92275
# Epoch  12: Valid Precision for entity start span = 0.92275
# Epoch  12: Valid f1_score for entity end span = 0.90660
# Epoch  12: Valid Acurracy for entity end span = 0.90660
# Epoch  12: Valid Recall for entity end span = 0.90660
# Epoch  12: Valid Precision for entity end span = 0.90660
# The current f1 score for entity start: 0.922752808988764
# The current f1 score for entity end: 0.9066011235955056
# Epoch  13: Train Loss = 12.67614
# Epoch  13: Valid Loss = 12.18587
# Epoch  13: Valid f1_score for entity start span = 0.92310
# Epoch  13: Valid Acurracy for entity start span = 0.92310
# Epoch  13: Valid Recall for entity start span = 0.92310
# Epoch  13: Valid Precision for entity start span = 0.92310
# Epoch  13: Valid f1_score for entity end span = 0.90801
# Epoch  13: Valid Acurracy for entity end span = 0.90801
# Epoch  13: Valid Recall for entity end span = 0.90801
# Epoch  13: Valid Precision for entity end span = 0.90801
# The current f1 score for entity start: 0.9231039325842697
# The current f1 score for entity end: 0.9080056179775281
# Epoch  14: Train Loss = 12.67067
# Epoch  14: Valid Loss = 12.17960
# Epoch  14: Valid f1_score for entity start span = 0.92697
# Epoch  14: Valid Acurracy for entity start span = 0.92697
# Epoch  14: Valid Recall for entity start span = 0.92697
# Epoch  14: Valid Precision for entity start span = 0.92697
# Epoch  14: Valid f1_score for entity end span = 0.90906
# Epoch  14: Valid Acurracy for entity end span = 0.90906
# Epoch  14: Valid Recall for entity end span = 0.90906
# Epoch  14: Valid Precision for entity end span = 0.90906
# The current f1 score for entity start: 0.9269662921348315
# The current f1 score for entity end: 0.9090589887640449
# Epoch  15: Train Loss = 12.67405
# Epoch  15: Valid Loss = 12.17558
# Epoch  15: Valid f1_score for entity start span = 0.92802
# Epoch  15: Valid Acurracy for entity start span = 0.92802
# Epoch  15: Valid Recall for entity start span = 0.92802
# Epoch  15: Valid Precision for entity start span = 0.92802
# Epoch  15: Valid f1_score for entity end span = 0.91348
# Epoch  15: Valid Acurracy for entity end span = 0.91348
# Epoch  15: Valid Recall for entity end span = 0.91348
# Epoch  15: Valid Precision for entity end span = 0.91348
# The current f1 score for entity start: 0.9280196629213483
# The current f1 score for entity end: 0.9134831460674157
# Epoch  16: Train Loss = 12.67312
# Epoch  16: Valid Loss = 12.17048
# Epoch  16: Valid f1_score for entity start span = 0.92837
# Epoch  16: Valid Acurracy for entity start span = 0.92837
# Epoch  16: Valid Recall for entity start span = 0.92837
# Epoch  16: Valid Precision for entity start span = 0.92837
# Epoch  16: Valid f1_score for entity end span = 0.91699
# Epoch  16: Valid Acurracy for entity end span = 0.91699
# Epoch  16: Valid Recall for entity end span = 0.91699
# Epoch  16: Valid Precision for entity end span = 0.91699
# The current f1 score for entity start: 0.9283707865168539
# The current f1 score for entity end: 0.9169943820224719
# Epoch  17: Train Loss = 12.66302
# Epoch  17: Valid Loss = 12.16473
# Epoch  17: Valid f1_score for entity start span = 0.92907
# Epoch  17: Valid Acurracy for entity start span = 0.92907
# Epoch  17: Valid Recall for entity start span = 0.92907
# Epoch  17: Valid Precision for entity start span = 0.92907
# Epoch  17: Valid f1_score for entity end span = 0.91994
# Epoch  17: Valid Acurracy for entity end span = 0.91994
# Epoch  17: Valid Recall for entity end span = 0.91994
# Epoch  17: Valid Precision for entity end span = 0.91994
# The current f1 score for entity start: 0.9290730337078652
# The current f1 score for entity end: 0.9199438202247191
# Epoch  18: Train Loss = 12.66477
# Epoch  18: Valid Loss = 12.16268
# Epoch  18: Valid f1_score for entity start span = 0.93013
# Epoch  18: Valid Acurracy for entity start span = 0.93013
# Epoch  18: Valid Recall for entity start span = 0.93013
# Epoch  18: Valid Precision for entity start span = 0.93013
# Epoch  18: Valid f1_score for entity end span = 0.92065
# Epoch  18: Valid Acurracy for entity end span = 0.92065
# Epoch  18: Valid Recall for entity end span = 0.92065
# Epoch  18: Valid Precision for entity end span = 0.92065
# The current f1 score for entity start: 0.930126404494382
# The current f1 score for entity end: 0.9206460674157303
# Epoch  19: Train Loss = 12.67966
# Epoch  19: Valid Loss = 12.16132
# Epoch  19: Valid f1_score for entity start span = 0.92942
# Epoch  19: Valid Acurracy for entity start span = 0.92942
# Epoch  19: Valid Recall for entity start span = 0.92942
# Epoch  19: Valid Precision for entity start span = 0.92942
# Epoch  19: Valid f1_score for entity end span = 0.92135
# Epoch  19: Valid Acurracy for entity end span = 0.92135
# Epoch  19: Valid Recall for entity end span = 0.92135
# Epoch  19: Valid Precision for entity end span = 0.92135
# 0.930126404494382 0.9206460674157303
# The best parameters are saved for the activation function: ELU

# %%
list_entity_loss_train_softplus, list_entity_loss_valid_softplus, list_epochs_softplus = get_entity_results("Softplus", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): Softplus(beta=1, threshold=20)
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Softplus(beta=1, threshold=20)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Softplus(beta=1, threshold=20)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.65532
# Epoch   0: Valid Loss = 13.35610
# Epoch   0: Valid f1_score for entity start span = 0.44431
# Epoch   0: Valid Acurracy for entity start span = 0.44431
# Epoch   0: Valid Recall for entity start span = 0.44431
# Epoch   0: Valid Precision for entity start span = 0.44431
# Epoch   0: Valid f1_score for entity end span = 0.29508
# Epoch   0: Valid Acurracy for entity end span = 0.29508
# Epoch   0: Valid Recall for entity end span = 0.29508
# Epoch   0: Valid Precision for entity end span = 0.29508
# The current f1 score for entity start: 0.44431179775280905
# The current f1 score for entity end: 0.29508426966292134
# Epoch   1: Train Loss = 13.24456
# Epoch   1: Valid Loss = 12.89529
# Epoch   1: Valid f1_score for entity start span = 0.74796
# Epoch   1: Valid Acurracy for entity start span = 0.74796
# Epoch   1: Valid Recall for entity start span = 0.74796
# Epoch   1: Valid Precision for entity start span = 0.74796
# Epoch   1: Valid f1_score for entity end span = 0.51735
# Epoch   1: Valid Acurracy for entity end span = 0.51735
# Epoch   1: Valid Recall for entity end span = 0.51735
# Epoch   1: Valid Precision for entity end span = 0.51735
# The current f1 score for entity start: 0.7479634831460673
# The current f1 score for entity end: 0.5173455056179775
# Epoch   2: Train Loss = 12.99162
# Epoch   2: Valid Loss = 12.64955
# Epoch   2: Valid f1_score for entity start span = 0.79740
# Epoch   2: Valid Acurracy for entity start span = 0.79740
# Epoch   2: Valid Recall for entity start span = 0.79740
# Epoch   2: Valid Precision for entity start span = 0.79740
# Epoch   2: Valid f1_score for entity end span = 0.70864
# Epoch   2: Valid Acurracy for entity end span = 0.70864
# Epoch   2: Valid Recall for entity end span = 0.70864
# Epoch   2: Valid Precision for entity end span = 0.70864
# The current f1 score for entity start: 0.7974016853932584
# The current f1 score for entity end: 0.7086376404494382
# Epoch   3: Train Loss = 12.86433
# Epoch   3: Valid Loss = 12.55338
# Epoch   3: Valid f1_score for entity start span = 0.82900
# Epoch   3: Valid Acurracy for entity start span = 0.82900
# Epoch   3: Valid Recall for entity start span = 0.82900
# Epoch   3: Valid Precision for entity start span = 0.82900
# Epoch   3: Valid f1_score for entity end span = 0.73441
# Epoch   3: Valid Acurracy for entity end span = 0.73441
# Epoch   3: Valid Recall for entity end span = 0.73441
# Epoch   3: Valid Precision for entity end span = 0.73441
# The current f1 score for entity start: 0.829002808988764
# The current f1 score for entity end: 0.7344101123595506
# Epoch   4: Train Loss = 12.81602
# Epoch   4: Valid Loss = 12.39800
# Epoch   4: Valid f1_score for entity start span = 0.85695
# Epoch   4: Valid Acurracy for entity start span = 0.85695
# Epoch   4: Valid Recall for entity start span = 0.85695
# Epoch   4: Valid Precision for entity start span = 0.85695
# Epoch   4: Valid f1_score for entity end span = 0.83083
# Epoch   4: Valid Acurracy for entity end span = 0.83083
# Epoch   4: Valid Recall for entity end span = 0.83083
# Epoch   4: Valid Precision for entity end span = 0.83083
# The current f1 score for entity start: 0.8569522471910112
# The current f1 score for entity end: 0.8308286516853932
# Epoch   5: Train Loss = 12.77488
# Epoch   5: Valid Loss = 12.34743
# Epoch   5: Valid f1_score for entity start span = 0.86854
# Epoch   5: Valid Acurracy for entity start span = 0.86854
# Epoch   5: Valid Recall for entity start span = 0.86854
# Epoch   5: Valid Precision for entity start span = 0.86854
# Epoch   5: Valid f1_score for entity end span = 0.85836
# Epoch   5: Valid Acurracy for entity end span = 0.85836
# Epoch   5: Valid Recall for entity end span = 0.85836
# Epoch   5: Valid Precision for entity end span = 0.85836
# The current f1 score for entity start: 0.8685393258426966
# The current f1 score for entity end: 0.8583567415730337
# Epoch   6: Train Loss = 12.75272
# Epoch   6: Valid Loss = 12.30963
# Epoch   6: Valid f1_score for entity start span = 0.87956
# Epoch   6: Valid Acurracy for entity start span = 0.87956
# Epoch   6: Valid Recall for entity start span = 0.87956
# Epoch   6: Valid Precision for entity start span = 0.87956
# Epoch   6: Valid f1_score for entity end span = 0.86770
# Epoch   6: Valid Acurracy for entity end span = 0.86770
# Epoch   6: Valid Recall for entity end span = 0.86770
# Epoch   6: Valid Precision for entity end span = 0.86770
# The current f1 score for entity start: 0.879564606741573
# The current f1 score for entity end: 0.8676966292134831
# Epoch   7: Train Loss = 12.73928
# Epoch   7: Valid Loss = 12.26957
# Epoch   7: Valid f1_score for entity start span = 0.89853
# Epoch   7: Valid Acurracy for entity start span = 0.89853
# Epoch   7: Valid Recall for entity start span = 0.89853
# Epoch   7: Valid Precision for entity start span = 0.89853
# Epoch   7: Valid f1_score for entity end span = 0.88799
# Epoch   7: Valid Acurracy for entity end span = 0.88799
# Epoch   7: Valid Recall for entity end span = 0.88799
# Epoch   7: Valid Precision for entity end span = 0.88799
# The current f1 score for entity start: 0.8985252808988764
# The current f1 score for entity end: 0.8879915730337079
# Epoch   8: Train Loss = 12.71044
# Epoch   8: Valid Loss = 12.23637
# Epoch   8: Valid f1_score for entity start span = 0.91538
# Epoch   8: Valid Acurracy for entity start span = 0.91538
# Epoch   8: Valid Recall for entity start span = 0.91538
# Epoch   8: Valid Precision for entity start span = 0.91538
# Epoch   8: Valid f1_score for entity end span = 0.90119
# Epoch   8: Valid Acurracy for entity end span = 0.90119
# Epoch   8: Valid Recall for entity end span = 0.90119
# Epoch   8: Valid Precision for entity end span = 0.90119
# The current f1 score for entity start: 0.9153792134831461
# The current f1 score for entity end: 0.901193820224719
# Epoch   9: Train Loss = 12.69400
# Epoch   9: Valid Loss = 12.22399
# Epoch   9: Valid f1_score for entity start span = 0.91594
# Epoch   9: Valid Acurracy for entity start span = 0.91594
# Epoch   9: Valid Recall for entity start span = 0.91594
# Epoch   9: Valid Precision for entity start span = 0.91594
# Epoch   9: Valid f1_score for entity end span = 0.89853
# Epoch   9: Valid Acurracy for entity end span = 0.89853
# Epoch   9: Valid Recall for entity end span = 0.89853
# Epoch   9: Valid Precision for entity end span = 0.89853
# Epoch  10: Train Loss = 12.69003
# Epoch  10: Valid Loss = 12.21084
# Epoch  10: Valid f1_score for entity start span = 0.92240
# Epoch  10: Valid Acurracy for entity start span = 0.92240
# Epoch  10: Valid Recall for entity start span = 0.92240
# Epoch  10: Valid Precision for entity start span = 0.92240
# Epoch  10: Valid f1_score for entity end span = 0.90330
# Epoch  10: Valid Acurracy for entity end span = 0.90330
# Epoch  10: Valid Recall for entity end span = 0.90330
# Epoch  10: Valid Precision for entity end span = 0.90330
# The current f1 score for entity start: 0.9224016853932584
# The current f1 score for entity end: 0.9033005617977528
# Epoch  11: Train Loss = 12.68534
# Epoch  11: Valid Loss = 12.20543
# Epoch  11: Valid f1_score for entity start span = 0.92205
# Epoch  11: Valid Acurracy for entity start span = 0.92205
# Epoch  11: Valid Recall for entity start span = 0.92205
# Epoch  11: Valid Precision for entity start span = 0.92205
# Epoch  11: Valid f1_score for entity end span = 0.90660
# Epoch  11: Valid Acurracy for entity end span = 0.90660
# Epoch  11: Valid Recall for entity end span = 0.90660
# Epoch  11: Valid Precision for entity end span = 0.90660
# Epoch  12: Train Loss = 12.68645
# Epoch  12: Valid Loss = 12.19723
# Epoch  12: Valid f1_score for entity start span = 0.92416
# Epoch  12: Valid Acurracy for entity start span = 0.92416
# Epoch  12: Valid Recall for entity start span = 0.92416
# Epoch  12: Valid Precision for entity start span = 0.92416
# Epoch  12: Valid f1_score for entity end span = 0.91046
# Epoch  12: Valid Acurracy for entity end span = 0.91046
# Epoch  12: Valid Recall for entity end span = 0.91046
# Epoch  12: Valid Precision for entity end span = 0.91046
# The current f1 score for entity start: 0.9241573033707865
# The current f1 score for entity end: 0.9104634831460674
# Epoch  13: Train Loss = 12.67657
# Epoch  13: Valid Loss = 12.19510
# Epoch  13: Valid f1_score for entity start span = 0.92310
# Epoch  13: Valid Acurracy for entity start span = 0.92310
# Epoch  13: Valid Recall for entity start span = 0.92310
# Epoch  13: Valid Precision for entity start span = 0.92310
# Epoch  13: Valid f1_score for entity end span = 0.91187
# Epoch  13: Valid Acurracy for entity end span = 0.91187
# Epoch  13: Valid Recall for entity end span = 0.91187
# Epoch  13: Valid Precision for entity end span = 0.91187
# Epoch  14: Train Loss = 12.66923
# Epoch  14: Valid Loss = 12.18806
# Epoch  14: Valid f1_score for entity start span = 0.92732
# Epoch  14: Valid Acurracy for entity start span = 0.92732
# Epoch  14: Valid Recall for entity start span = 0.92732
# Epoch  14: Valid Precision for entity start span = 0.92732
# Epoch  14: Valid f1_score for entity end span = 0.91538
# Epoch  14: Valid Acurracy for entity end span = 0.91538
# Epoch  14: Valid Recall for entity end span = 0.91538
# Epoch  14: Valid Precision for entity end span = 0.91538
# The current f1 score for entity start: 0.9273174157303371
# The current f1 score for entity end: 0.9153792134831461
# Epoch  15: Train Loss = 12.67215
# Epoch  15: Valid Loss = 12.17909
# Epoch  15: Valid f1_score for entity start span = 0.92767
# Epoch  15: Valid Acurracy for entity start span = 0.92767
# Epoch  15: Valid Recall for entity start span = 0.92767
# Epoch  15: Valid Precision for entity start span = 0.92767
# Epoch  15: Valid f1_score for entity end span = 0.91819
# Epoch  15: Valid Acurracy for entity end span = 0.91819
# Epoch  15: Valid Recall for entity end span = 0.91819
# Epoch  15: Valid Precision for entity end span = 0.91819
# The current f1 score for entity start: 0.9276685393258427
# The current f1 score for entity end: 0.918188202247191
# Epoch  16: Train Loss = 12.67204
# Epoch  16: Valid Loss = 12.17728
# Epoch  16: Valid f1_score for entity start span = 0.92978
# Epoch  16: Valid Acurracy for entity start span = 0.92978
# Epoch  16: Valid Recall for entity start span = 0.92978
# Epoch  16: Valid Precision for entity start span = 0.92978
# Epoch  16: Valid f1_score for entity end span = 0.91770
# Epoch  16: Valid Acurracy for entity end span = 0.91770
# Epoch  16: Valid Recall for entity end span = 0.91770
# Epoch  16: Valid Precision for entity end span = 0.91770
# Epoch  17: Train Loss = 12.66117
# Epoch  17: Valid Loss = 12.17291
# Epoch  17: Valid f1_score for entity start span = 0.92837
# Epoch  17: Valid Acurracy for entity start span = 0.92837
# Epoch  17: Valid Recall for entity start span = 0.92837
# Epoch  17: Valid Precision for entity start span = 0.92837
# Epoch  17: Valid f1_score for entity end span = 0.92135
# Epoch  17: Valid Acurracy for entity end span = 0.92135
# Epoch  17: Valid Recall for entity end span = 0.92135
# Epoch  17: Valid Precision for entity end span = 0.92135
# The current f1 score for entity start: 0.9283707865168539
# The current f1 score for entity end: 0.9213483146067416
# Epoch  18: Train Loss = 12.66261
# Epoch  18: Valid Loss = 12.17165
# Epoch  18: Valid f1_score for entity start span = 0.92872
# Epoch  18: Valid Acurracy for entity start span = 0.92872
# Epoch  18: Valid Recall for entity start span = 0.92872
# Epoch  18: Valid Precision for entity start span = 0.92872
# Epoch  18: Valid f1_score for entity end span = 0.92135
# Epoch  18: Valid Acurracy for entity end span = 0.92135
# Epoch  18: Valid Recall for entity end span = 0.92135
# Epoch  18: Valid Precision for entity end span = 0.92135
# The current f1 score for entity start: 0.9287219101123596
# The current f1 score for entity end: 0.9213483146067416
# Epoch  19: Train Loss = 12.67850
# Epoch  19: Valid Loss = 12.17048
# Epoch  19: Valid f1_score for entity start span = 0.92907
# Epoch  19: Valid Acurracy for entity start span = 0.92907
# Epoch  19: Valid Recall for entity start span = 0.92907
# Epoch  19: Valid Precision for entity start span = 0.92907
# Epoch  19: Valid f1_score for entity end span = 0.92205
# Epoch  19: Valid Acurracy for entity end span = 0.92205
# Epoch  19: Valid Recall for entity end span = 0.92205
# Epoch  19: Valid Precision for entity end span = 0.92205
# The current f1 score for entity start: 0.9290730337078652
# The current f1 score for entity end: 0.9220505617977528
# 0.9290730337078652 0.9220505617977528
# The best parameters are saved for the activation function: Softplus

# %%
list_entity_training_losses.append(list_entity_loss_train_leakyrelu)
list_entity_validation_losses.append(list_entity_loss_valid_leakyrelu)
list_entity_epochs.append(list_epochs_leakyrelu)
list_entity_training_losses.append(list_entity_loss_train_tanhshrink)
list_entity_validation_losses.append(list_entity_loss_valid_tanhshrink)
list_entity_epochs.append(list_epochs_tanhshrink)
list_entity_training_losses.append(list_entity_loss_train_softplus)
list_entity_validation_losses.append(list_entity_loss_valid_softplus)
list_entity_epochs.append(list_epochs_softplus)
list_entity_training_losses.append(list_entity_loss_train_elu)
list_entity_validation_losses.append(list_entity_loss_valid_elu)
list_entity_epochs.append(list_epochs_elu)

# %%
plot_losses(list_entity_epochs, list_entity_training_losses, list_entity_validation_losses, activations, learning_rate, dropout_prob)
