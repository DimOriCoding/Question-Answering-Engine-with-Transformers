# %% [markdown]
# **I import some useful libraries in python.**

# %%
import difflib
import operator as op
import random
import numpy as np
import pandas as pd
import torch
import torch.backends.cudnn
from numpy.random import MT19937
from numpy.random import RandomState, SeedSequence
from torch.optim import Adam
from transformers import get_linear_schedule_with_warmup
import os
from google.colab import drive
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt
import torch.nn as nn
from transformers import BertModel
from transformers import BertTokenizerFast

# %% [markdown]
# **I mount google drive because all the files (for example .csv) that i used for the implementation of my thesis are saved on my google drive.**

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Check of the device that it is used for the implementation of the notebooks of this thesis, that is determined from google colab.**

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Device available for running: ")
print(device)
# Out:
# Device available for running:
# cuda

# %% [markdown]
# **Reading of the created datasets (for both the SimpleQuestions dataset that includes all training and validation questions and the SimpleQuestions subset that includes only answerable over wikidata questions) as .csv file.**

# %%
train_dataset = pd.read_csv("drive/MyDrive/train_answerable_questions_dataset.csv", sep = ',')
validation_dataset = pd.read_csv("drive/MyDrive/valid_answerable_questions_dataset.csv", sep = ',')
print(train_dataset)
print(validation_dataset)
# Out:
#        entity_id      entity_label relation_id  \
# 0         Q12439           Detroit         R19
# 1       Q6817891       Mera Shikar        P364
# 2          Q1297           Chicago        R276
# 3        Q193592        midfielder        R413
# 4       Q6849115     Mike Twellman        P413
# ...          ...               ...         ...
# 19476    Q223960    mountain tapir        P171
# 19477   Q1535153    superhero film        R136
# 19478    Q157443       comedy film        R136
# 19479  Q16093542    Anthony Bailey         P27
# 19480    Q926822  Gaston Filgueira         P21
#
#                                                 Question
# 0                      who is a musician born in detroit
# 1      what is the language in which mera shikar was ...
# 2      Whats the name of a battle that happened in ch...
# 3              what player plays the position midfielder
# 4         what is the position that  mike twellman plays
# ...                                                  ...
# 19476  what classification does  mountain tapir come ...
# 19477   What a superhero movie that premiered on toonami
# 19478  What is the name of a comedy film that is also...
# 19479          What is the nationality of anthony bailey
# 19480                    What gender is gaston filgueira
#
# [19481 rows x 4 columns]
#      entity_id            entity_label relation_id  \
# 0      Q318926           Sasha Vujacic         P19
# 1     Q2568216       Wiebke Carolsfeld         R57
# 2     Q2275923  Seymour Parker Gilbert        P106
# 3     Q2856873        Antoine de Fevin         P20
# 4      Q522966           Jamie Hewlett        P106
# ...        ...                     ...         ...
# 2816  Q7111404             OutNumbered        P178
# 2817  Q3480757          Seumas O'Kelly         P21
# 2818  Q3709870          Herby Fortunat        P413
# 2819  Q2981169       Nikolaj Frobenius        P106
# 2820      Q174               Sao Paulo         R19
#
#                                                Question
# 0                          where was sasha vujacic born
# 1          What is a film directed by wiebke carolsfeld
# 2            What was Seymour Parker Gilbert profession
# 3         in what french city did antoine de fevin die
# 4                      What job does jamie hewlett have
# ...                                                 ...
# 2816                          who developed outnumbered
# 2817                  what is the sex of seumas o'kelly
# 2818  which position did herby fortunat play in foot...
# 2819               What is nikolaj frobenius profession
# 2820         who is a person that was born in sao paulo
#
# [2821 rows x 4 columns]

# %% [markdown]
# **Check if  the SimpleQuestions training and validation dataset have at least one line with null value. This issues both for SimpleQuestions dataset that includes only answerable over wikidata questions and for the corresponding dataset that includes all the questions.**

# %%
train_dataset.dropna(inplace = True)
validation_dataset.dropna(inplace = True)
print(train_dataset)
print(validation_dataset)
# Out:
#        entity_id      entity_label relation_id  \
# 0         Q12439           Detroit         R19
# 1       Q6817891       Mera Shikar        P364
# 2          Q1297           Chicago        R276
# 3        Q193592        midfielder        R413
# 4       Q6849115     Mike Twellman        P413
# ...          ...               ...         ...
# 19476    Q223960    mountain tapir        P171
# 19477   Q1535153    superhero film        R136
# 19478    Q157443       comedy film        R136
# 19479  Q16093542    Anthony Bailey         P27
# 19480    Q926822  Gaston Filgueira         P21
#
#                                                 Question
# 0                      who is a musician born in detroit
# 1      what is the language in which mera shikar was ...
# 2      Whats the name of a battle that happened in ch...
# 3              what player plays the position midfielder
# 4         what is the position that  mike twellman plays
# ...                                                  ...
# 19476  what classification does  mountain tapir come ...
# 19477   What a superhero movie that premiered on toonami
# 19478  What is the name of a comedy film that is also...
# 19479          What is the nationality of anthony bailey
# 19480                    What gender is gaston filgueira
#
# [19481 rows x 4 columns]
#      entity_id            entity_label relation_id  \
# 0      Q318926           Sasha Vujacic         P19
# 1     Q2568216       Wiebke Carolsfeld         R57
# 2     Q2275923  Seymour Parker Gilbert        P106
# 3     Q2856873        Antoine de Fevin         P20
# 4      Q522966           Jamie Hewlett        P106
# ...        ...                     ...         ...
# 2816  Q7111404             OutNumbered        P178
# 2817  Q3480757          Seumas O'Kelly         P21
# 2818  Q3709870          Herby Fortunat        P413
# 2819  Q2981169       Nikolaj Frobenius        P106
# 2820      Q174               Sao Paulo         R19
#
#                                                Question
# 0                          where was sasha vujacic born
# 1          What is a film directed by wiebke carolsfeld
# 2            What was Seymour Parker Gilbert profession
# 3         in what french city did antoine de fevin die
# 4                      What job does jamie hewlett have
# ...                                                 ...
# 2816                          who developed outnumbered
# 2817                  what is the sex of seumas o'kelly
# 2818  which position did herby fortunat play in foot...
# 2819               What is nikolaj frobenius profession
# 2820         who is a person that was born in sao paulo
#
# [2821 rows x 4 columns]

# %% [markdown]
# **Creation of the corresponding lists containing the questions, the entity labels, the relation ids and the entity ids of the corresponding SimpleQuestions datasets (training, validation), either this dataset includes answerable and answerable questions over wikidata questions or only answerable questions over wikidata.**

# %%
train_entity_labels = train_dataset['entity_label'].to_list()
validation_entity_labels = validation_dataset['entity_label'].to_list()
train_entityids = train_dataset['entity_id'].to_list()
validation_entityids = validation_dataset['entity_id'].to_list()
train_questions = train_dataset['Question'].to_list()
validation_questions = validation_dataset['Question'].to_list()
train_relationids = train_dataset['relation_id'].to_list()
validation_relationids = validation_dataset['relation_id'].to_list()
print(len(train_entity_labels), len(train_entityids), len(train_relationids), len(train_questions))
# Out:
# 19481 19481 19481 19481

# %% [markdown]
# **The maximum question length that is observed in SimpleQuestions training and validation dataset is found below.**

# %%
#Below the max questions length is found for all questions.
quests = train_questions + validation_questions
print(len(quests), len(train_questions), len(validation_questions))
# Printing concatenated list
q_lengths = []
for s in range(len(quests)): #padding
    q_lengths.append(len(quests[s].split()))
max_question_length = max(q_lengths)
print(max_question_length)#Max question length
# Out:
# 22302 19481 2821
# 33

# %% [markdown]
# **Creation of the relation vocabulary that includes all the unique entity ids of the SimpleQuestions training and validation dataset through function relation_vocabulary. Also the index of each unique relation id of the relation vocabulary in this vocabulary is found through the function find_relations_index.**

# %%
#Create relation vocabulary for each question of train and validation dataset
def relation_vocabulary(relation_column_dataset):
  relation_vocabulary = []
   #In order to have the unique relation ids it is important to check if an relation id is already in the relation_vocabulary
  for relation in range(len(relation_column_dataset)):
    g = 0
    for i in range(len(relation_vocabulary)):
      if relation_column_dataset[relation] != relation_vocabulary[i]: #relation is not found yet
        g += 1
      else:
       continue
    if g == len(relation_vocabulary) and relation_column_dataset[relation] not in relation_vocabulary:
      relation_vocabulary.append(relation_column_dataset[relation]) #The relation id is not inside the relation vocabulary
      #which has some relations already or the relation vocaulary has no relations
  return relation_vocabulary

def find_relation_index(relation_vocabulary,relation_ids_column):
  relations_count = []
  for relation in range(len(relation_ids_column)):
        relations_count.append(relation_vocabulary.index(relation_ids_column[relation]))

  return relations_count
#relation_ids = pd.concat([train_dataset["relation_id"], validation_dataset["relation_id"]], ignore_index = True)
relation_ids = train_relationids + validation_relationids
print(len(relation_ids))
rel_vocab = relation_vocabulary(relation_ids)
rel_vocab_length = len(rel_vocab)
print(rel_vocab, rel_vocab_length)
train_relations_index = find_relation_index(rel_vocab, train_relationids)
validation_relations_index = find_relation_index(rel_vocab, validation_relationids)
# Out:
# 22302
# ['R19', 'P364', 'R276', 'R413', 'P413', 'R136', 'P27', 'P21', 'R106', 'P196', 'P175', 'R175', 'R50', 'P344', 'P136', 'P641', 'P19', 'P421', 'R57', 'P170', 'R17', 'P86', 'R58', 'R86', 'P1142', 'P58', 'P131', 'P495', 'P150', 'R131', 'P119', 'R1303', 'P50', 'R40', 'P61', 'R172', 'P264', 'P57', 'P179', 'P509', 'R509', 'P20', 'P138', 'P397', 'R344', 'P106', 'P272', 'P403', 'P31', 'P607', 'P407', 'P140', 'R162', 'R641', 'R404', 'P172', 'R178', 'R421', 'P123', 'P59', 'P40', 'P276', 'P178', 'R272', 'P737', 'R179', 'P398', 'P17', 'P1303', 'P144', 'P112', 'R170', 'R105', 'R59', 'P113', 'R607', 'P155', 'P162', 'R149', 'P404', 'R1040', 'R177', 'P710', 'P1408', 'R119', 'R21', 'R112', 'R138', 'P676', 'R123', 'P149', 'R264', 'P65', 'P177', 'R144', 'P53', 'R31', 'R287', 'P115', 'P105', 'P1040', 'P156', 'P289', 'R171', 'P1029', 'R115', 'P171', 'R1431', 'P1431', 'P376', 'R676', 'R1142', 'P84', 'R376', 'P826', 'R161', 'P287', 'P81', 'P800', 'P279', 'R176', 'R289', 'P189', 'P176', 'R279'] 125

# %% [markdown]
# **The function create\_question\_parts, takes as arguments the splitted question splitted into words and the entity label also splitted into words.
# Essentially in this function each question, as well as the corresponding entity label, is splitted into words using python method split() and then, using python method join(), parts of the query are created equal in length to that of their splitted entity label in words.**
#
# **These parts are stored in a list as well as the indexes of the initial word and final word of these question parts are stored in dictionaries with keys the question parts and values the indexes(positions) of the initial words and final words for each question. Finally this function returns the list of question parts and dictionaries containing the indexes(positions) of the initial words and final words for each question part.**

# %%
#The fact that the corresponding question part start index is lower to
#the corresponding question part start index is lower is an indirect efficient way to ensure that all ones that are added in this span are successive.
#That it is very helpful to find entity span start index and entity span end index later.
def create_question_parts(question_splitted, entity_splited_length):
  Quests_Parts = []
  Quest_Parts_Start = {}
  Quest_Parts_End = {}
  for i in range(len(question_splitted)-entity_splited_length+1):
    quest_part = " ".join(question_splitted[i:i+entity_splited_length])
    Quests_Parts.append(quest_part)
    Quest_Parts_Start[quest_part] = i
    Quest_Parts_End[quest_part] = i+entity_splited_length-1
  return Quests_Parts, Quest_Parts_Start, Quest_Parts_End

# %% [markdown]
# **Through the create\_entity\_span function below that takes as arguments the question splitted in words and the indexes of the initial and final word of the part of the question that is equal to the corresponding entity label, the entity span for each question is created.**
#
# **In this entity span because the words that make up the entity label must be in consecutive positions within the question, it is always necessary that when creating the entity span, the index specifying the position of the starting word of the equal question part with the corresponding entity label for the question must be less than or equal to the corresponding index of the ending word of that equal question part. This indirectly ensures that the ones that enter the entity span are consecutive and equal in number to the length of the entity label splitted in words. This function returns the entity span, as well as the number of consecutive ones in it for each question.**

# %%
#Create entity span
def create_entity_span(question_splitted_length, quest_part_start, quest_part_end):
   entity_span = []
   count_successive_ones = 0
   for k in range(question_splitted_length):
     if k >= quest_part_start and k <= quest_part_end:
        entity_span.append(1)
        count_successive_ones += 1
     else:
        entity_span.append(0)

   return entity_span, count_successive_ones

# %% [markdown]
# **Through the find_start_and_end_index function, which takes as arguments the entity span, the entity label, the list of all the parts of the question, the dictionaries with keys the parts for each question and values the indexes of the start words and end words for each question, the length of the question and the number of consecutive ones of the entity span which are counted in this function, the question part that is equal with the entity label, the position of the initial word (index of the first one in the entity span) of the entity label and respectively the position of the final word (index of the last one in the entity span) could be found. If the entity span that is created for a question is not full of zeros, then a logical variable is used to confirm that all ones present are contiguous.**
#
# **In the case, of course, that no word of the entity label is present in the words of the corresponding question, the entity span will consist only of zeros, so there is no word to derive the corresponding indices for entity start and entity end.**
#
# **To deal with this situation, initially from the list of question parts as obtained from the create_question_parts function through difflib.get_close_matches(), it is searched, which part is closest to the entity label and for that question part from the dictionaries containing the indexes(positions) of the initial words and the final words for it obtained from the same function, the corresponding positional indexes of its initial and final words are found.
# Next, if no question part that is found by difflib.get\_close\_matches() is even minimally similar to the entity label, then the positions (indices) of the penultimate (question length-2) and the last word (question length-1) are set as the entity start index and entity end index, respectively.
# In this way the lengths of the train and validation dataset are kept constant.**

# %%
#Create for each question the entity span and find the entity span start index and the entity span end index.
def find_start_and_end_index(entity_label, entity_label_splitted_length, question_parts, question_splitted_length, start_indexes, end_indexes):
  entity_span_start_index = -1
  entity_span_end_index = -1
  quest_part_start_index = -1
  quest_part_end_index = -1
  entity_span = []
  entity_span_with_successive_ones = 0
  for q_p in range(len(question_parts)):
    if question_parts[q_p] == entity_label:
      quest_part = question_parts[q_p]
      quest_part_start_index = start_indexes[quest_part]
      quest_part_end_index = end_indexes[quest_part]
  entity_span, count_successive_ones = create_entity_span(question_splitted_length, quest_part_start_index,  quest_part_end_index)
  if entity_span != [0]*question_splitted_length:
   entity_span_with_successive_ones = 1
   entity_span_start_index = entity_span.index(1)
   entity_span_end_index = entity_span_start_index + count_successive_ones-1
  else:
   Entity = difflib.get_close_matches(entity_label, question_parts, 1)
   if Entity != []:
    entity_span_start_index = start_indexes[Entity[0]]
    entity_span_end_index = end_indexes[Entity[0]]
   else:
    entity_span_start_index = question_splitted_length-2
    entity_span_end_index = question_splitted_length-1

  return entity_span, entity_span_with_successive_ones, entity_span_start_index, entity_span_end_index

# %% [markdown]
# **The entity_span_encoded function takes as arguments the list of all questions of the given SimpleQuestions dataset (training or validation), the list of all entity labels of the SimpleQuestions dataset (training or validation) and returns the list of entity spans, as well as the lists of start and end position indices for each entity label for all questions. It is worth noting that this function counts the number of questions whose entity span consists of 0 and 1, where the ones are contiguous.**

# %%
#Create entity span by create an list which consists of zeros and ones. By checking in which part for each question the correspoding entity
#exists and in these indexes of the span to replace with ones.
#This is applied for each one of the train and validation questions
def entity_span_encoded(question_column_dataset, entity_label_column_dataset):
  entity_spans = []
  span_start_index = []
  span_end_index = []
  count_spans_with_successive_ones = 0
  for q in range(len(question_column_dataset)):
      quest = question_column_dataset[q].lower().split()
      quest_splitted_length  = len(quest)
      ent_label = entity_label_column_dataset[q].lower()
      s = ent_label.split()
      entity_label_splitted_length = len(s)
      Quests_Parts, Quest_Parts_Start, Quest_Parts_End = create_question_parts(quest, entity_label_splitted_length)
      entity_span, span_with_successive_ones, entity_span_start_index, entity_span_end_index = find_start_and_end_index(ent_label, entity_label_splitted_length,  Quests_Parts, quest_splitted_length, Quest_Parts_Start, Quest_Parts_End)
      entity_spans.append(entity_span)
      span_start_index.append(entity_span_start_index)
      span_end_index.append(entity_span_end_index)
      if span_with_successive_ones == 1:#Boolean variable
        count_spans_with_successive_ones += 1
  return entity_spans, span_start_index, span_end_index

train_span, train_entity_span_encoded_start_indexes, train_entity_span_encoded_end_indexes = entity_span_encoded(train_questions, train_entity_labels)
validation_span, validation_entity_span_encoded_start_indexes, validation_entity_span_encoded_end_indexes = entity_span_encoded(validation_questions, validation_entity_labels)
print(train_entity_span_encoded_start_indexes)
print(train_entity_span_encoded_end_indexes)
print(train_span[13174])
print(train_questions[13174])
print(train_entity_labels[13174])
print(train_span[2])
print(train_questions[2])
print(train_entity_labels[2])
print(validation_span[3])
print(validation_questions[3])
print(validation_entity_labels[3])
print(train_span[230], train_questions[230], train_entity_labels[230])
# Out:
# [6, 6, 9, 5, 5, 2, 2, 5, 5, 3, 6, 3, 4, 5, 7, 3, 4, 3, 4, 4, 3, 2, 3, 6, 2, 2, 5, 7, 3, 5, 5, 5, 5, 6, 3, 7, 5, 4, 6, 2, 2, 5, 5, 3, 5, 3, 5, 2, 5, 6, 6, 5, 6, 3, 2, 4, 0, 3, 7, 4, 5, 0, 5, 2, 2, 2, 2, 3, 3, 5, 5, 2, 6, 2, 4, 3, 5, 6, 3, 3, 5, 2, 6, 5, 5, 3, 3, 5, 2, 7, 5, 3, 3, 1, 5, 6, 5, 9, 2, 3, 2, 3, 3, 2, 5, 5, 4, 2, 5, 4, 5, 4, 4, 5, 5, 5, 5, 2, 3, 3, 3, 3, 2, 6
, 4, 8, 12, 3, 10, 3, 7, 4, 7, 4, 5, 4, 1, 3, 3, 2, 6, 3, 7, 9, 3, 7, 5, 6, 4, 4, 6, 6, 4, 5, 4, 5, 3, 3, 5, 6, 6, 6, 3, 4, 6, 7, 5, 11, 4, 6, 6, 7, 7, 3, 5, 3, 5, 4, 5, 3, 5, 6, 8, 5, 6, 4, 3, 3, 6, 8, 4, 2, 3, 3, 6, 6, 6, 4, 11, 4, 3, 4, 5, 2, 3, 1, 6, 7, 10, 4, 6, 5, 3, 11, 3, 4, 4, 7, 5, 8, 6, 2, 10, 5, 6, 4, 3, 6, 5, 5, 3, 6, 6, 7, 6, 4, 6, 11, 3, 7, 5, 8, 4, 10, 4, 3, 3, 8, 3, 7, 9, 3, 6, 3, 5, 1, 11, 7, 7, 6, 3, 3, 3, 3, 3,  ...

# %% [markdown]
# **Creation of a custom dataset for the SimpleQuestions dataset (either for the dataset with only answerable over wikidata questions or for the corresponding dataset including answerable and non-answerable over wikidata questions) through a python class, where its questions are encoded through BertTokenizerFast method encode\_plus(). This custom dataset includes the entity span indexes (start, end), the relation indexes, the questions, the ids and the attention mask occurred from encoding of questions.**
#
# **Also since the span start and end correspond to actual words, but here I use the fast version of BERT tokenizer BertTokenizerFast, i need to locate the corresponding start and end tokens in the BERT tokenized question for each entity.**
#
# **Also in order to create this custom dataset i used the lists of questions, relation, entity span start, entity span end indexes, the maximum question length of all SimpleQuestions training and validation dataset questions.**

# %%
g = torch.Generator()
print(g.device)
# Out:
# cpu

# %%
class BertQuestionAnsweringDataset:
  def __init__(self, questions, tokenizer, entity_starts, entity_ends, relation_indexes, length, generator, shuffle=True):
        self.questions = questions
        self.max_length = length
        self.tokenizer = tokenizer
        self.relation_indexes = relation_indexes
        self.g = generator
        self.shuffle = shuffle
        ids = []
        masks = []
        start_ent = []
        end_ent = []
        # Encode questions
        for question in range(len(self.questions)):
          encoding = self.tokenizer.encode_plus(
             text = self.questions[question],
             max_length=self.max_length,
             truncation=True,
             pad_to_max_length=True,
             return_attention_mask=True,
             padding='max_length',
             add_special_tokens=False
          )
          Question = self.questions[question].split()
          # Locate the corresponding start in the BERT tokenized question
          start_token = tokenizer.encode_plus(
            text = Question[entity_starts[question]],
            return_attention_mask=True,
            add_special_tokens=False
        )
          # Locate the corresponding end in the BERT tokenized question
          end_token = tokenizer.encode_plus(
            text = Question[entity_ends[question]],
            return_attention_mask=True,
            add_special_tokens=False
        )
          ids.append(encoding['input_ids'])
          masks.append(encoding['attention_mask'])
          start_ent.append(encoding['input_ids'].index(start_token['input_ids'][0]))
          end_ent.append(encoding['input_ids'].index(end_token['input_ids'][-1]))
        self.input_ids = ids
        self.attention_masks = masks
        self.entity_start_indexes = start_ent
        self.entity_end_indexes = end_ent

  def __len__(self):
        return len(self.questions)

  def __getitem__(self, idx):
        return { 'input_ids': torch.tensor(self.input_ids[idx]),
                'attention_mask':  torch.tensor(self.attention_masks[idx]),
                'relation_indexes': torch.tensor(self.relation_indexes[idx]),
                'entity_start': torch.tensor(self.entity_start_indexes[idx], dtype = torch.long),
                'entity_end': torch.tensor(self.entity_end_indexes[idx], dtype = torch.long)
               }

  def set_epoch(self, epoch):
      self.epoch = epoch
      if self.shuffle:
         self.g.manual_seed(123456789 + self.epoch)

# %% [markdown]
# **In the above custom dataset class i reseed the workers using worker\_init\_fn() to preserve reproducibility through by creating the following function seed\_worker.**

# %%
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# %% [markdown]
# **Creation of the dataloader through the created custom dataset from pytorch for the training and validation dataset of SimpleQuestions dataset. The batch size is equal to 32.**

# %%
#span_encoded is reffering to the 2nd way of finding entity start and entity end indexes, i.e entity span encoded with 0 and 1.
print(len(train_questions), len(train_entity_span_encoded_start_indexes), len(train_entity_span_encoded_end_indexes), len(train_relations_index))
train_span_encoded_bert_dataset = BertQuestionAnsweringDataset(train_questions, tokenizer, train_entity_span_encoded_start_indexes, train_entity_span_encoded_end_indexes, train_relations_index, max(q_lengths), g)
valid_span_encoded_bert_dataset = BertQuestionAnsweringDataset(validation_questions, tokenizer ,validation_entity_span_encoded_start_indexes, validation_entity_span_encoded_end_indexes, validation_relations_index, max(q_lengths), g)
train_dataloader_span_encoded = torch.utils.data.DataLoader(train_span_encoded_bert_dataset, batch_size=32, num_workers = 0, worker_init_fn=seed_worker, shuffle=True, generator = train_span_encoded_bert_dataset.g)
val_dataloader_span_encoded = torch.utils.data.DataLoader(valid_span_encoded_bert_dataset, batch_size=32, num_workers = 0, worker_init_fn=seed_worker, shuffle=True, generator = valid_span_encoded_bert_dataset.g)
# Out:
# 19481 19481 19481 19481

# %% [markdown]
# **Function that contributes to the preservation of the reproducibility.**

# %%
#To preserve reproducibility
SEED = 42
def set_seed(SEED):
 random.seed(SEED)# Set python seed for custom operators.
 torch.manual_seed(SEED)
 np.random.seed(SEED)
 torch.cuda.manual_seed_all(SEED)
 torch.backends.cudnn.benchmark = False
 torch.backends.cudnn.deterministic = True

# %% [markdown]
# **Through the create\_file function, is created a file in .pt, in which the parameters for each model are stored. This function takes as an argument a name for the folder where the model will be saved (e.g. "drive/MyDrive/") and a name for the name of the file where each model is saved (e.g. "relation\_prediction.pt").**

# %%
def create_file(model_dir, model_save_name):
 if not os.path.exists(model_dir):
    os.makedirs(model_dir)
 model_save_path = os.path.join(model_dir, model_save_name)
 return model_save_path

# %% [markdown]
# ****Construction and initialization of the neural network for the prediction of the relation for each question.****

# %%
class BertRelationsClassifier(nn.Module):
  def __init__(self, activation, dropout_prob, rel_vocab_len):
    super(BertRelationsClassifier, self).__init__()
    activations = {
        "ELU" : nn.ELU,
        "LeakyReLU"    : nn.LeakyReLU,
        "Softplus"     : nn.Softplus,
        "Tanhshrink"     : nn.Tanhshrink
 }
    self.bert_model = BertModel.from_pretrained('bert-base-uncased')
    self.rel_vocab_len = rel_vocab_len
    self.fc = nn.Linear(768, self.rel_vocab_len)
    self.activation_type = activation
    self.dropout_probability = dropout_prob
    self.activation = activations[self.activation_type]()
    self.dropout = nn.Dropout(self.dropout_probability)
    self.softmax = nn.Softmax(dim=1)

  def forward(self, input_ids, attention_mask):
        out = self.bert_model(input_ids, attention_mask)
        out = self.fc(out[1])#CLS token-pooled output
        out = self.activation(out)
        out = self.dropout(out)
        out = self.softmax(out)
        return out

# %% [markdown]
# **Through the function named relation_prediction_function the best possible parameters for the best possible prediction of the relation are found. This function has as arguments the training dataloader, the validation dataloader, the number of epochs, the optimizer, the scheduler, the learning rate, the relation prediction neural network model, the loss function and the dropout probability value.**
#
# **This function returns the best possible model, the list including numbers from 0 to number of training epochs-1, the lists including the values of training losses and validation losses for all epochs respectively and the largest value of f1.**
#
# **The length of the relation vocabulary in the case of training and validating the full SimpleQuestions dataset is equal to 129 and the length of the relation vocabulary for the case of training and validating the SimpleQuestions subset that includes only questions that are answerable over wikidata is equal to 125.
# So the predicted relation index as a number must be either between 0 and 128 or between 0 and 124, where this number correspond to the position of the unique relation ids in the corresponding relation vocabulary.**

# %%
def relation_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, lr, dropout_prob):
 list_loss_train = []
 list_epochs = []
 list_loss = []
 the_last_f1_score = 0
 patience = 3
 max_f1 = -1
 trigger_times = 0
 for epoch in range(epochs):
   train_dataset.set_epoch(epoch)
   valid_dataset.set_epoch(epoch)
   model.train()
   batch_losses = []
   for batch in train_dataloader:
    ids = batch['input_ids'].to(device)
    attention_masks = batch['attention_mask'].to(device)
    relation_indexes = batch['relation_indexes'].to(device)
    y_pred = model(ids, attention_masks)
    loss = loss_func(y_pred.cpu(),relation_indexes.cpu())
    batch_losses.append(loss.detach().numpy())
    #Delete previously stored gradients
    optimizer.zero_grad()

    #Perform backpropagation starting from the loss calculated in this epoch
    loss.backward()
    nn.utils.clip_grad_norm_(model.parameters(), 0.7)
    #Update model's weights based on the gradients calculated during backprop
    optimizer.step()
    scheduler.step()
   print(f"Epoch {epoch:3}: Train Loss = {sum(batch_losses)/len(train_dataloader):.5f}")
   list_loss_train.append(sum(batch_losses)/len(train_dataloader))
   with torch.no_grad():
     model.eval()
     F1 = []
     precision = []
     recall = []
     accuracy = []
     batch_losses_val = []
     for batch in val_dataloader:
       ids = batch['input_ids'].to(device)
       attention_masks = batch['attention_mask'].to(device)
       relation_indexes = batch['relation_indexes'].to(device)
       y_predict = model(ids, attention_masks)
       val_loss = loss_func(y_predict.cpu(),relation_indexes.cpu())
       batch_losses_val.append(val_loss)
       y_pr = torch.argmax(y_predict, dim=1).squeeze()
       Y_p = y_pr.tolist()
       y_val = relation_indexes.tolist()
       F1.append(f1_score(y_val, Y_p, average = 'micro'))
       precision.append(precision_score(y_val, Y_p, average = 'micro'))
       recall.append(recall_score(y_val, Y_p, average = 'micro'))
       accuracy.append(accuracy_score(y_val,Y_p))


     Valid_f1 = sum(F1)/len(val_dataloader)
     Valid_accuracy = sum(accuracy)/len(val_dataloader)
     print(f"Epoch {epoch:3}: Valid Loss = {sum(batch_losses_val)/len(val_dataloader):.5f}")
     print(f"Epoch {epoch:3}: Valid f1_score = {Valid_f1:.5f}")
     print(f"Epoch {epoch:3}: Valid Acurracy = {Valid_accuracy:.5f}")
     print(f"Epoch {epoch:3}: Valid Recall score = {sum(recall)/len(val_dataloader):.5f}")
     print(f"Epoch {epoch:3}: Valid Precision score = {sum(precision)/len(val_dataloader):.5f}")
     list_loss.append(sum(batch_losses_val)/len(val_dataloader))
     list_epochs.append(epoch)
     if Valid_f1 > max_f1:
       max_f1 = Valid_f1
       best_model = model
       print('The current f1 score:', Valid_f1)
     if Valid_f1 < the_last_f1_score:
       trigger_times += 1
       print('trigger times:', trigger_times)
       if trigger_times >= patience:
         print('Early stopping!\nStart to test process.')
         break;
     the_last_f1_score = Valid_f1
 return max_f1, list_loss_train, list_loss, list_epochs, best_model

# %% [markdown]
# **The function named get_relation_results finds results for the neural networks concerning the relation index and the entity span indexes (start,end). These functions have as arguments the corresponding training dataloader, the corresponding validation dataloader, the number of epochs ,the optimizer, the scheduler get_linear_schedule_with_warmup, the corresponding relation prediction neural network model, the loss function, the learning rate and the SEED number.**
#
# **This function returns the list of training losses, the list of validation losses, and the list of how many epochs each model with each activation function needs to be fully trained.**

# %%
learning_rate  = 2e-5
dropout_prob = 0.3
epochs = 20
list_relation_training_losses = []
list_relation_validation_losses = []
list_relation_epochs = []
loss_func = nn.CrossEntropyLoss()
optimizer_name = "Adam"
def get_relation_results(activation, rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_dataset, valid_dataset, train_dataloader, val_dataloader, SEED):
 set_seed(SEED)
 model = BertRelationsClassifier(activation, dropout_prob, rel_vocab_length).to(device)
 print(model)
 loss_func = loss_func.to(device)
 optimizer = getattr(torch.optim, optimizer_name)(model.parameters(), lr=learning_rate)
 scheduler = get_linear_schedule_with_warmup(optimizer, 0, len(train_dataloader)*epochs)
 f1, list_loss_train, list_loss_valid, list_epochs, best_relation_model = relation_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, learning_rate, dropout_prob)
 print(f1)
 torch.save(best_relation_model.state_dict(), create_file(f"drive/MyDrive/Relation_indexes_models_best_parameters/Answerable_Questions/{activation}",f"relation_prediction_span_encoded_not_ignoring_answerable_questions_{activation}.pt") )
 print(f"The best parameters are saved for the activation function: {activation}")
 return list_loss_train, list_loss_valid, list_epochs

# %%
list_relation_loss_train_leakyrelu, list_relation_loss_valid_leakyrelu, list_epochs_leakyrelu = get_relation_results("LeakyReLU", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_span_encoded_bert_dataset, valid_span_encoded_bert_dataset, train_dataloader_span_encoded, val_dataloader_span_encoded, SEED)
# Out:
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=125, bias=True)
#   (activation): LeakyReLU(negative_slope=0.01)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.58557
# Epoch   0: Valid Loss = 4.29605
# Epoch   0: Valid f1_score = 0.60681
# Epoch   0: Valid Acurracy = 0.60681
# Epoch   0: Valid Recall score = 0.60681
# Epoch   0: Valid Precision score = 0.60681
# The current f1 score: 0.606811797752809
# Epoch   1: Train Loss = 4.38414
# Epoch   1: Valid Loss = 4.18262
# Epoch   1: Valid f1_score = 0.69874
# Epoch   1: Valid Acurracy = 0.69874
# Epoch   1: Valid Recall score = 0.69874
# Epoch   1: Valid Precision score = 0.69874
# The current f1 score: 0.6987359550561798
# Epoch   2: Train Loss = 4.32955
# Epoch   2: Valid Loss = 4.11188
# Epoch   2: Valid f1_score = 0.77317
# Epoch   2: Valid Acurracy = 0.77317
# Epoch   2: Valid Recall score = 0.77317
# Epoch   2: Valid Precision score = 0.77317
# The current f1 score: 0.7731741573033708
# Epoch   3: Train Loss = 4.28584
# Epoch   3: Valid Loss = 4.05285
# Epoch   3: Valid f1_score = 0.83483
# Epoch   3: Valid Acurracy = 0.83483
# Epoch   3: Valid Recall score = 0.83483
# Epoch   3: Valid Precision score = 0.83483
# The current f1 score: 0.8348314606741573
# Epoch   4: Train Loss = 4.25209
# Epoch   4: Valid Loss = 4.01386
# Epoch   4: Valid f1_score = 0.86166
# Epoch   4: Valid Acurracy = 0.86166
# Epoch   4: Valid Recall score = 0.86166
# Epoch   4: Valid Precision score = 0.86166
# The current f1 score: 0.8616573033707865
# Epoch   5: Train Loss = 4.23681
# Epoch   5: Valid Loss = 3.99371
# Epoch   5: Valid f1_score = 0.87956
# Epoch   5: Valid Acurracy = 0.87956
# Epoch   5: Valid Recall score = 0.87956
# Epoch   5: Valid Precision score = 0.87956
# The current f1 score: 0.879564606741573
# Epoch   6: Train Loss = 4.22724
# Epoch   6: Valid Loss = 3.98067
# Epoch   6: Valid f1_score = 0.88975
# Epoch   6: Valid Acurracy = 0.88975
# Epoch   6: Valid Recall score = 0.88975
# Epoch   6: Valid Precision score = 0.88975
# The current f1 score: 0.889747191011236
# Epoch   7: Train Loss = 4.21475
# Epoch   7: Valid Loss = 3.97203
# Epoch   7: Valid f1_score = 0.89242
# Epoch   7: Valid Acurracy = 0.89242
# Epoch   7: Valid Recall score = 0.89242
# Epoch   7: Valid Precision score = 0.89242
# The current f1 score: 0.8924157303370787
# Epoch   8: Train Loss = 4.20855
# Epoch   8: Valid Loss = 3.95998
# Epoch   8: Valid f1_score = 0.90365
# Epoch   8: Valid Acurracy = 0.90365
# Epoch   8: Valid Recall score = 0.90365
# Epoch   8: Valid Precision score = 0.90365
# The current f1 score: 0.9036516853932584
# Epoch   9: Train Loss = 4.20225
# Epoch   9: Valid Loss = 3.95318
# Epoch   9: Valid f1_score = 0.90695
# Epoch   9: Valid Acurracy = 0.90695
# Epoch   9: Valid Recall score = 0.90695
# Epoch   9: Valid Precision score = 0.90695
# The current f1 score: 0.9069522471910112
# Epoch  10: Train Loss = 4.19432
# Epoch  10: Valid Loss = 3.94627
# Epoch  10: Valid f1_score = 0.91699
# Epoch  10: Valid Acurracy = 0.91699
# Epoch  10: Valid Recall score = 0.91699
# Epoch  10: Valid Precision score = 0.91699
# The current f1 score: 0.9169943820224719
# Epoch  11: Train Loss = 4.18972
# Epoch  11: Valid Loss = 3.94268
# Epoch  11: Valid f1_score = 0.91875
# Epoch  11: Valid Acurracy = 0.91875
# Epoch  11: Valid Recall score = 0.91875
# Epoch  11: Valid Precision score = 0.91875
# The current f1 score: 0.91875
# Epoch  12: Train Loss = 4.19240
# Epoch  12: Valid Loss = 3.93338
# Epoch  12: Valid f1_score = 0.92767
# Epoch  12: Valid Acurracy = 0.92767
# Epoch  12: Valid Recall score = 0.92767
# Epoch  12: Valid Precision score = 0.92767
# The current f1 score: 0.9276685393258427
# Epoch  13: Train Loss = 4.18204
# Epoch  13: Valid Loss = 3.93296
# Epoch  13: Valid f1_score = 0.93055
# Epoch  13: Valid Acurracy = 0.93055
# Epoch  13: Valid Recall score = 0.93055
# Epoch  13: Valid Precision score = 0.93055
# The current f1 score: 0.9305477528089887
# Epoch  14: Train Loss = 4.18161
# Epoch  14: Valid Loss = 3.92232
# Epoch  14: Valid f1_score = 0.94031
# Epoch  14: Valid Acurracy = 0.94031
# Epoch  14: Valid Recall score = 0.94031
# Epoch  14: Valid Precision score = 0.94031
# The current f1 score: 0.9403089887640449
# Epoch  15: Train Loss = 4.17594
# Epoch  15: Valid Loss = 3.92043
# Epoch  15: Valid f1_score = 0.94171
# Epoch  15: Valid Acurracy = 0.94171
# Epoch  15: Valid Recall score = 0.94171
# Epoch  15: Valid Precision score = 0.94171
# The current f1 score: 0.9417134831460674
# Epoch  16: Train Loss = 4.16948
# Epoch  16: Valid Loss = 3.92093
# Epoch  16: Valid f1_score = 0.93876
# Epoch  16: Valid Acurracy = 0.93876
# Epoch  16: Valid Recall score = 0.93876
# Epoch  16: Valid Precision score = 0.93876
# trigger times: 1
# Epoch  17: Train Loss = 4.16249
# Epoch  17: Valid Loss = 3.91697
# Epoch  17: Valid f1_score = 0.94136
# Epoch  17: Valid Acurracy = 0.94136
# Epoch  17: Valid Recall score = 0.94136
# Epoch  17: Valid Precision score = 0.94136
# Epoch  18: Train Loss = 4.16237
# Epoch  18: Valid Loss = 3.91801
# Epoch  18: Valid f1_score = 0.94333
# Epoch  18: Valid Acurracy = 0.94333
# Epoch  18: Valid Recall score = 0.94333
# Epoch  18: Valid Precision score = 0.94333
# The current f1 score: 0.9433286516853933
# Epoch  19: Train Loss = 4.16876
# Epoch  19: Valid Loss = 3.91520
# Epoch  19: Valid f1_score = 0.94663
# Epoch  19: Valid Acurracy = 0.94663
# Epoch  19: Valid Recall score = 0.94663
# Epoch  19: Valid Precision score = 0.94663
# The current f1 score: 0.9466292134831461
# 0.9466292134831461
# The best parameters are saved for the activation function: LeakyReLU

# %%
list_relation_loss_train_tanhshrink, list_relation_loss_valid_tanhshrink, list_epochs_tanhshrink = get_relation_results("Tanhshrink", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_span_encoded_bert_dataset, valid_span_encoded_bert_dataset, train_dataloader_span_encoded, val_dataloader_span_encoded, SEED)
# Out:
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=125, bias=True)
#   (activation): Tanhshrink()
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.62163
# Epoch   0: Valid Loss = 4.34043
# Epoch   0: Valid f1_score = 0.54677
# Epoch   0: Valid Acurracy = 0.54677
# Epoch   0: Valid Recall score = 0.54677
# Epoch   0: Valid Precision score = 0.54677
# The current f1 score: 0.5467696629213483
# Epoch   1: Train Loss = 4.40214
# Epoch   1: Valid Loss = 4.17937
# Epoch   1: Valid f1_score = 0.69452
# Epoch   1: Valid Acurracy = 0.69452
# Epoch   1: Valid Recall score = 0.69452
# Epoch   1: Valid Precision score = 0.69452
# The current f1 score: 0.6945224719101124
# Epoch   2: Train Loss = 4.35142
# Epoch   2: Valid Loss = 4.14117
# Epoch   2: Valid f1_score = 0.73947
# Epoch   2: Valid Acurracy = 0.73947
# Epoch   2: Valid Recall score = 0.73947
# Epoch   2: Valid Precision score = 0.73947
# The current f1 score: 0.7394662921348315
# Epoch   3: Train Loss = 4.30877
# Epoch   3: Valid Loss = 4.08785
# Epoch   3: Valid f1_score = 0.78532
# Epoch   3: Valid Acurracy = 0.78532
# Epoch   3: Valid Recall score = 0.78532
# Epoch   3: Valid Precision score = 0.78532
# The current f1 score: 0.7853230337078652
# Epoch   4: Train Loss = 4.27549
# Epoch   4: Valid Loss = 4.04898
# Epoch   4: Valid f1_score = 0.82374
# Epoch   4: Valid Acurracy = 0.82374
# Epoch   4: Valid Recall score = 0.82374
# Epoch   4: Valid Precision score = 0.82374
# The current f1 score: 0.8237359550561798
# Epoch   5: Train Loss = 4.25539
# Epoch   5: Valid Loss = 4.01864
# Epoch   5: Valid f1_score = 0.85358
# Epoch   5: Valid Acurracy = 0.85358
# Epoch   5: Valid Recall score = 0.85358
# Epoch   5: Valid Precision score = 0.85358
# The current f1 score: 0.8535814606741573
# Epoch   6: Train Loss = 4.23704
# Epoch   6: Valid Loss = 3.99913
# Epoch   6: Valid f1_score = 0.87065
# Epoch   6: Valid Acurracy = 0.87065
# Epoch   6: Valid Recall score = 0.87065
# Epoch   6: Valid Precision score = 0.87065
# The current f1 score: 0.8706460674157303
# Epoch   7: Train Loss = 4.21994
# Epoch   7: Valid Loss = 3.97699
# Epoch   7: Valid f1_score = 0.89923
# Epoch   7: Valid Acurracy = 0.89923
# Epoch   7: Valid Recall score = 0.89923
# Epoch   7: Valid Precision score = 0.89923
# The current f1 score: 0.8992275280898876
# Epoch   8: Train Loss = 4.20816
# Epoch   8: Valid Loss = 3.96640
# Epoch   8: Valid f1_score = 0.90098
# Epoch   8: Valid Acurracy = 0.90098
# Epoch   8: Valid Recall score = 0.90098
# Epoch   8: Valid Precision score = 0.90098
# The current f1 score: 0.9009831460674157
# Epoch   9: Train Loss = 4.19878
# Epoch   9: Valid Loss = 3.95423
# Epoch   9: Valid f1_score = 0.90941
# Epoch   9: Valid Acurracy = 0.90941
# Epoch   9: Valid Recall score = 0.90941
# Epoch   9: Valid Precision score = 0.90941
# The current f1 score: 0.9094101123595506
# Epoch  10: Train Loss = 4.19133
# Epoch  10: Valid Loss = 3.95030
# Epoch  10: Valid f1_score = 0.91383
# Epoch  10: Valid Acurracy = 0.91383
# Epoch  10: Valid Recall score = 0.91383
# Epoch  10: Valid Precision score = 0.91383
# The current f1 score: 0.9138342696629214
# Epoch  11: Train Loss = 4.18720
# Epoch  11: Valid Loss = 3.94121
# Epoch  11: Valid f1_score = 0.92367
# Epoch  11: Valid Acurracy = 0.92367
# Epoch  11: Valid Recall score = 0.92367
# Epoch  11: Valid Precision score = 0.92367
# The current f1 score: 0.9236657303370787
# Epoch  12: Train Loss = 4.18948
# Epoch  12: Valid Loss = 3.93454
# Epoch  12: Valid f1_score = 0.92591
# Epoch  12: Valid Acurracy = 0.92591
# Epoch  12: Valid Recall score = 0.92591
# Epoch  12: Valid Precision score = 0.92591
# The current f1 score: 0.9259129213483146
# Epoch  13: Train Loss = 4.17976
# Epoch  13: Valid Loss = 3.93387
# Epoch  13: Valid f1_score = 0.92718
# Epoch  13: Valid Acurracy = 0.92718
# Epoch  13: Valid Recall score = 0.92718
# Epoch  13: Valid Precision score = 0.92718
# The current f1 score: 0.9271769662921348
# Epoch  14: Train Loss = 4.18204
# Epoch  14: Valid Loss = 3.92999
# Epoch  14: Valid f1_score = 0.92963
# Epoch  14: Valid Acurracy = 0.92963
# Epoch  14: Valid Recall score = 0.92963
# Epoch  14: Valid Precision score = 0.92963
# The current f1 score: 0.9296348314606742
# Epoch  15: Train Loss = 4.17672
# Epoch  15: Valid Loss = 3.92329
# Epoch  15: Valid f1_score = 0.93996
# Epoch  15: Valid Acurracy = 0.93996
# Epoch  15: Valid Recall score = 0.93996
# Epoch  15: Valid Precision score = 0.93996
# The current f1 score: 0.9399578651685393
# Epoch  16: Train Loss = 4.17022
# Epoch  16: Valid Loss = 3.92169
# Epoch  16: Valid f1_score = 0.94122
# Epoch  16: Valid Acurracy = 0.94122
# Epoch  16: Valid Recall score = 0.94122
# Epoch  16: Valid Precision score = 0.94122
# The current f1 score: 0.9412219101123596
# Epoch  17: Train Loss = 4.16291
# Epoch  17: Valid Loss = 3.91871
# Epoch  17: Valid f1_score = 0.94347
# Epoch  17: Valid Acurracy = 0.94347
# Epoch  17: Valid Recall score = 0.94347
# Epoch  17: Valid Precision score = 0.94347
# The current f1 score: 0.9434691011235955
# Epoch  18: Train Loss = 4.16295
# Epoch  18: Valid Loss = 3.91888
# Epoch  18: Valid f1_score = 0.94192
# Epoch  18: Valid Acurracy = 0.94192
# Epoch  18: Valid Recall score = 0.94192
# Epoch  18: Valid Precision score = 0.94192
# trigger times: 1
# Epoch  19: Train Loss = 4.16956
# Epoch  19: Valid Loss = 3.91642
# Epoch  19: Valid f1_score = 0.94417
# Epoch  19: Valid Acurracy = 0.94417
# Epoch  19: Valid Recall score = 0.94417
# Epoch  19: Valid Precision score = 0.94417
# The current f1 score: 0.9441713483146067
# 0.9441713483146067
# The best parameters are saved for the activation function: Tanhshrink

# %%
list_relation_loss_train_elu, list_relation_loss_valid_elu, list_epochs_elu = get_relation_results("ELU", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_span_encoded_bert_dataset, valid_span_encoded_bert_dataset, train_dataloader_span_encoded, val_dataloader_span_encoded, SEED)
# Out:
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=125, bias=True)
#   (activation): ELU(alpha=1.0)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.56424
# Epoch   0: Valid Loss = 4.28507
# Epoch   0: Valid f1_score = 0.61524
# Epoch   0: Valid Acurracy = 0.61524
# Epoch   0: Valid Recall score = 0.61524
# Epoch   0: Valid Precision score = 0.61524
# The current f1 score: 0.6152387640449438
# Epoch   1: Train Loss = 4.37569
# Epoch   1: Valid Loss = 4.15666
# Epoch   1: Valid f1_score = 0.72121
# Epoch   1: Valid Acurracy = 0.72121
# Epoch   1: Valid Recall score = 0.72121
# Epoch   1: Valid Precision score = 0.72121
# The current f1 score: 0.7212078651685393
# Epoch   2: Train Loss = 4.32004
# Epoch   2: Valid Loss = 4.08926
# Epoch   2: Valid f1_score = 0.80513
# Epoch   2: Valid Acurracy = 0.80513
# Epoch   2: Valid Recall score = 0.80513
# Epoch   2: Valid Precision score = 0.80513
# The current f1 score: 0.805126404494382
# Epoch   3: Train Loss = 4.27049
# Epoch   3: Valid Loss = 4.03302
# Epoch   3: Valid f1_score = 0.84712
# Epoch   3: Valid Acurracy = 0.84712
# Epoch   3: Valid Recall score = 0.84712
# Epoch   3: Valid Precision score = 0.84712
# The current f1 score: 0.8471207865168539
# Epoch   4: Train Loss = 4.24570
# Epoch   4: Valid Loss = 4.01036
# Epoch   4: Valid f1_score = 0.87324
# Epoch   4: Valid Acurracy = 0.87324
# Epoch   4: Valid Recall score = 0.87324
# Epoch   4: Valid Precision score = 0.87324
# The current f1 score: 0.8732443820224719
# Epoch   5: Train Loss = 4.22278
# Epoch   5: Valid Loss = 3.98240
# Epoch   5: Valid f1_score = 0.89607
# Epoch   5: Valid Acurracy = 0.89607
# Epoch   5: Valid Recall score = 0.89607
# Epoch   5: Valid Precision score = 0.89607
# The current f1 score: 0.8960674157303371
# Epoch   6: Train Loss = 4.21076
# Epoch   6: Valid Loss = 3.96410
# Epoch   6: Valid f1_score = 0.91081
# Epoch   6: Valid Acurracy = 0.91081
# Epoch   6: Valid Recall score = 0.91081
# Epoch   6: Valid Precision score = 0.91081
# The current f1 score: 0.910814606741573
# Epoch   7: Train Loss = 4.19717
# Epoch   7: Valid Loss = 3.95316
# Epoch   7: Valid f1_score = 0.91222
# Epoch   7: Valid Acurracy = 0.91222
# Epoch   7: Valid Recall score = 0.91222
# Epoch   7: Valid Precision score = 0.91222
# The current f1 score: 0.9122191011235955
# Epoch   8: Train Loss = 4.19684
# Epoch   8: Valid Loss = 3.95026
# Epoch   8: Valid f1_score = 0.91187
# Epoch   8: Valid Acurracy = 0.91187
# Epoch   8: Valid Recall score = 0.91187
# Epoch   8: Valid Precision score = 0.91187
# trigger times: 1
# Epoch   9: Train Loss = 4.19101
# Epoch   9: Valid Loss = 3.94458
# Epoch   9: Valid f1_score = 0.91749
# Epoch   9: Valid Acurracy = 0.91749
# Epoch   9: Valid Recall score = 0.91749
# Epoch   9: Valid Precision score = 0.91749
# The current f1 score: 0.9174859550561798
# Epoch  10: Train Loss = 4.18394
# Epoch  10: Valid Loss = 3.93975
# Epoch  10: Valid f1_score = 0.92612
# Epoch  10: Valid Acurracy = 0.92612
# Epoch  10: Valid Recall score = 0.92612
# Epoch  10: Valid Precision score = 0.92612
# The current f1 score: 0.926123595505618
# Epoch  11: Train Loss = 4.17860
# Epoch  11: Valid Loss = 3.93338
# Epoch  11: Valid f1_score = 0.93279
# Epoch  11: Valid Acurracy = 0.93279
# Epoch  11: Valid Recall score = 0.93279
# Epoch  11: Valid Precision score = 0.93279
# The current f1 score: 0.9327949438202247
# Epoch  12: Train Loss = 4.17959
# Epoch  12: Valid Loss = 3.92259
# Epoch  12: Valid f1_score = 0.94206
# Epoch  12: Valid Acurracy = 0.94206
# Epoch  12: Valid Recall score = 0.94206
# Epoch  12: Valid Precision score = 0.94206
# The current f1 score: 0.942064606741573
# Epoch  13: Train Loss = 4.16995
# Epoch  13: Valid Loss = 3.91847
# Epoch  13: Valid f1_score = 0.94649
# Epoch  13: Valid Acurracy = 0.94649
# Epoch  13: Valid Recall score = 0.94649
# Epoch  13: Valid Precision score = 0.94649
# The current f1 score: 0.9464887640449438
# Epoch  14: Train Loss = 4.17232
# Epoch  14: Valid Loss = 3.91714
# Epoch  14: Valid f1_score = 0.94579
# Epoch  14: Valid Acurracy = 0.94579
# Epoch  14: Valid Recall score = 0.94579
# Epoch  14: Valid Precision score = 0.94579
# trigger times: 2
# Epoch  15: Train Loss = 4.16783
# Epoch  15: Valid Loss = 3.91372
# Epoch  15: Valid f1_score = 0.94979
# Epoch  15: Valid Acurracy = 0.94979
# Epoch  15: Valid Recall score = 0.94979
# Epoch  15: Valid Precision score = 0.94979
# The current f1 score: 0.9497893258426966
# Epoch  16: Train Loss = 4.16264
# Epoch  16: Valid Loss = 3.91257
# Epoch  16: Valid f1_score = 0.94860
# Epoch  16: Valid Acurracy = 0.94860
# Epoch  16: Valid Recall score = 0.94860
# Epoch  16: Valid Precision score = 0.94860
# trigger times: 3
# Early stopping!
# Start to test process.
# 0.9497893258426966
# The best parameters are saved for the activation function: ELU

# %%
list_relation_loss_train_softplus, list_relation_loss_valid_softplus, list_epochs_softplus = get_relation_results("Softplus", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_span_encoded_bert_dataset, valid_span_encoded_bert_dataset, train_dataloader_span_encoded, val_dataloader_span_encoded, SEED)
# Out:
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=125, bias=True)
#   (activation): Softplus(beta=1, threshold=20)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.59772
# Epoch   0: Valid Loss = 4.32446
# Epoch   0: Valid f1_score = 0.57767
# Epoch   0: Valid Acurracy = 0.57767
# Epoch   0: Valid Recall score = 0.57767
# Epoch   0: Valid Precision score = 0.57767
# The current f1 score: 0.5776685393258427
# Epoch   1: Train Loss = 4.40095
# Epoch   1: Valid Loss = 4.19452
# Epoch   1: Valid f1_score = 0.69452
# Epoch   1: Valid Acurracy = 0.69452
# Epoch   1: Valid Recall score = 0.69452
# Epoch   1: Valid Precision score = 0.69452
# The current f1 score: 0.6945224719101124
# Epoch   2: Train Loss = 4.33257
# Epoch   2: Valid Loss = 4.11353
# Epoch   2: Valid f1_score = 0.78125
# Epoch   2: Valid Acurracy = 0.78125
# Epoch   2: Valid Recall score = 0.78125
# Epoch   2: Valid Precision score = 0.78125
# The current f1 score: 0.78125
# Epoch   3: Train Loss = 4.27981
# Epoch   3: Valid Loss = 4.04857
# Epoch   3: Valid f1_score = 0.83764
# Epoch   3: Valid Acurracy = 0.83764
# Epoch   3: Valid Recall score = 0.83764
# Epoch   3: Valid Precision score = 0.83764
# The current f1 score: 0.8376404494382023
# Epoch   4: Train Loss = 4.25313
# Epoch   4: Valid Loss = 4.02092
# Epoch   4: Valid f1_score = 0.86447
# Epoch   4: Valid Acurracy = 0.86447
# Epoch   4: Valid Recall score = 0.86447
# Epoch   4: Valid Precision score = 0.86447
# The current f1 score: 0.8644662921348315
# Epoch   5: Train Loss = 4.23370
# Epoch   5: Valid Loss = 3.98986
# Epoch   5: Valid f1_score = 0.88904
# Epoch   5: Valid Acurracy = 0.88904
# Epoch   5: Valid Recall score = 0.88904
# Epoch   5: Valid Precision score = 0.88904
# The current f1 score: 0.8890449438202247
# Epoch   6: Train Loss = 4.21716
# Epoch   6: Valid Loss = 3.97103
# Epoch   6: Valid f1_score = 0.90555
# Epoch   6: Valid Acurracy = 0.90555
# Epoch   6: Valid Recall score = 0.90555
# Epoch   6: Valid Precision score = 0.90555
# The current f1 score: 0.9055477528089888
# Epoch   7: Train Loss = 4.20216
# Epoch   7: Valid Loss = 3.95946
# Epoch   7: Valid f1_score = 0.91292
# Epoch   7: Valid Acurracy = 0.91292
# Epoch   7: Valid Recall score = 0.91292
# Epoch   7: Valid Precision score = 0.91292
# The current f1 score: 0.9129213483146067
# Epoch   8: Train Loss = 4.19844
# Epoch   8: Valid Loss = 3.95569
# Epoch   8: Valid f1_score = 0.90976
# Epoch   8: Valid Acurracy = 0.90976
# Epoch   8: Valid Recall score = 0.90976
# Epoch   8: Valid Precision score = 0.90976
# trigger times: 1
# Epoch   9: Train Loss = 4.19284
# Epoch   9: Valid Loss = 3.94024
# Epoch   9: Valid f1_score = 0.92521
# Epoch   9: Valid Acurracy = 0.92521
# Epoch   9: Valid Recall score = 0.92521
# Epoch   9: Valid Precision score = 0.92521
# The current f1 score: 0.9252106741573034
# Epoch  10: Train Loss = 4.18484
# Epoch  10: Valid Loss = 3.93596
# Epoch  10: Valid f1_score = 0.93104
# Epoch  10: Valid Acurracy = 0.93104
# Epoch  10: Valid Recall score = 0.93104
# Epoch  10: Valid Precision score = 0.93104
# The current f1 score: 0.9310393258426966
# Epoch  11: Train Loss = 4.18047
# Epoch  11: Valid Loss = 3.93171
# Epoch  11: Valid f1_score = 0.93244
# Epoch  11: Valid Acurracy = 0.93244
# Epoch  11: Valid Recall score = 0.93244
# Epoch  11: Valid Precision score = 0.93244
# The current f1 score: 0.932443820224719
# Epoch  12: Train Loss = 4.18388
# Epoch  12: Valid Loss = 3.92439
# Epoch  12: Valid f1_score = 0.93926
# Epoch  12: Valid Acurracy = 0.93926
# Epoch  12: Valid Recall score = 0.93926
# Epoch  12: Valid Precision score = 0.93926
# The current f1 score: 0.9392556179775281
# Epoch  13: Train Loss = 4.17443
# Epoch  13: Valid Loss = 3.92182
# Epoch  13: Valid f1_score = 0.94017
# Epoch  13: Valid Acurracy = 0.94017
# Epoch  13: Valid Recall score = 0.94017
# Epoch  13: Valid Precision score = 0.94017
# The current f1 score: 0.9401685393258427
# Epoch  14: Train Loss = 4.17819
# Epoch  14: Valid Loss = 3.91787
# Epoch  14: Valid f1_score = 0.94157
# Epoch  14: Valid Acurracy = 0.94157
# Epoch  14: Valid Recall score = 0.94157
# Epoch  14: Valid Precision score = 0.94157
# The current f1 score: 0.9415730337078652
# Epoch  15: Train Loss = 4.17335
# Epoch  15: Valid Loss = 3.91663
# Epoch  15: Valid f1_score = 0.94417
# Epoch  15: Valid Acurracy = 0.94417
# Epoch  15: Valid Recall score = 0.94417
# Epoch  15: Valid Precision score = 0.94417
# The current f1 score: 0.9441713483146067
# Epoch  16: Train Loss = 4.16758
# Epoch  16: Valid Loss = 3.91656
# Epoch  16: Valid f1_score = 0.94508
# Epoch  16: Valid Acurracy = 0.94508
# Epoch  16: Valid Recall score = 0.94508
# Epoch  16: Valid Precision score = 0.94508
# The current f1 score: 0.9450842696629214
# Epoch  17: Train Loss = 4.16018
# Epoch  17: Valid Loss = 3.91322
# Epoch  17: Valid f1_score = 0.94628
# Epoch  17: Valid Acurracy = 0.94628
# Epoch  17: Valid Recall score = 0.94628
# Epoch  17: Valid Precision score = 0.94628
# The current f1 score: 0.9462780898876404
# Epoch  18: Train Loss = 4.16018
# Epoch  18: Valid Loss = 3.91428
# Epoch  18: Valid f1_score = 0.94649
# Epoch  18: Valid Acurracy = 0.94649
# Epoch  18: Valid Recall score = 0.94649
# Epoch  18: Valid Precision score = 0.94649
# The current f1 score: 0.9464887640449438
# Epoch  19: Train Loss = 4.16696
# Epoch  19: Valid Loss = 3.91132
# Epoch  19: Valid f1_score = 0.94909
# Epoch  19: Valid Acurracy = 0.94909
# Epoch  19: Valid Recall score = 0.94909
# Epoch  19: Valid Precision score = 0.94909
# The current f1 score: 0.9490870786516854
# 0.9490870786516854
# The best parameters are saved for the activation function: Softplus

# %%
list_relation_loss_train_softplus, list_relation_loss_valid_softplus, list_epochs_softplus = get_relation_results("Softplus", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_span_encoded_bert_dataset, valid_span_encoded_bert_dataset, train_dataloader_span_encoded, val_dataloader_span_encoded, SEED)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=125, bias=True)
#   (activation): Softplus(beta=1, threshold=20)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.59772
# Epoch   0: Valid Loss = 4.32446
# Epoch   0: Valid f1_score = 0.57767
# Epoch   0: Valid Acurracy = 0.57767
# Epoch   0: Valid Recall score = 0.57767
# Epoch   0: Valid Precision score = 0.57767
# The current f1 score: 0.5776685393258427
# Epoch   1: Train Loss = 4.40095
# Epoch   1: Valid Loss = 4.19452
# Epoch   1: Valid f1_score = 0.69452
# Epoch   1: Valid Acurracy = 0.69452
# Epoch   1: Valid Recall score = 0.69452
# Epoch   1: Valid Precision score = 0.69452
# The current f1 score: 0.6945224719101124
# Epoch   2: Train Loss = 4.33257
# Epoch   2: Valid Loss = 4.11353
# Epoch   2: Valid f1_score = 0.78125
# Epoch   2: Valid Acurracy = 0.78125
# Epoch   2: Valid Recall score = 0.78125
# Epoch   2: Valid Precision score = 0.78125
# The current f1 score: 0.78125
# Epoch   3: Train Loss = 4.27981
# Epoch   3: Valid Loss = 4.04857
# Epoch   3: Valid f1_score = 0.83764
# Epoch   3: Valid Acurracy = 0.83764
# Epoch   3: Valid Recall score = 0.83764
# Epoch   3: Valid Precision score = 0.83764
# The current f1 score: 0.8376404494382023
# Epoch   4: Train Loss = 4.25313
# Epoch   4: Valid Loss = 4.02092
# Epoch   4: Valid f1_score = 0.86447
# Epoch   4: Valid Acurracy = 0.86447
# Epoch   4: Valid Recall score = 0.86447
# Epoch   4: Valid Precision score = 0.86447
# The current f1 score: 0.8644662921348315
# Epoch   5: Train Loss = 4.23370
# Epoch   5: Valid Loss = 3.98986
# Epoch   5: Valid f1_score = 0.88904
# Epoch   5: Valid Acurracy = 0.88904
# Epoch   5: Valid Recall score = 0.88904
# Epoch   5: Valid Precision score = 0.88904
# The current f1 score: 0.8890449438202247
# Epoch   6: Train Loss = 4.21716
# Epoch   6: Valid Loss = 3.97103
# Epoch   6: Valid f1_score = 0.90555
# Epoch   6: Valid Acurracy = 0.90555
# Epoch   6: Valid Recall score = 0.90555
# Epoch   6: Valid Precision score = 0.90555
# The current f1 score: 0.9055477528089888
# Epoch   7: Train Loss = 4.20216
# Epoch   7: Valid Loss = 3.95946
# Epoch   7: Valid f1_score = 0.91292
# Epoch   7: Valid Acurracy = 0.91292
# Epoch   7: Valid Recall score = 0.91292
# Epoch   7: Valid Precision score = 0.91292
# The current f1 score: 0.9129213483146067
# Epoch   8: Train Loss = 4.19844
# Epoch   8: Valid Loss = 3.95569
# Epoch   8: Valid f1_score = 0.90976
# Epoch   8: Valid Acurracy = 0.90976
# Epoch   8: Valid Recall score = 0.90976
# Epoch   8: Valid Precision score = 0.90976
# trigger times: 1
# Epoch   9: Train Loss = 4.19284
# Epoch   9: Valid Loss = 3.94024
# Epoch   9: Valid f1_score = 0.92521
# Epoch   9: Valid Acurracy = 0.92521
# Epoch   9: Valid Recall score = 0.92521
# Epoch   9: Valid Precision score = 0.92521
# The current f1 score: 0.9252106741573034
# Epoch  10: Train Loss = 4.18484
# Epoch  10: Valid Loss = 3.93596
# Epoch  10: Valid f1_score = 0.93104
# Epoch  10: Valid Acurracy = 0.93104
# Epoch  10: Valid Recall score = 0.93104
# Epoch  10: Valid Precision score = 0.93104
# The current f1 score: 0.9310393258426966
# Epoch  11: Train Loss = 4.18047
# Epoch  11: Valid Loss = 3.93171
# Epoch  11: Valid f1_score = 0.93244
# Epoch  11: Valid Acurracy = 0.93244
# Epoch  11: Valid Recall score = 0.93244
# Epoch  11: Valid Precision score = 0.93244
# The current f1 score: 0.932443820224719
# Epoch  12: Train Loss = 4.18388
# Epoch  12: Valid Loss = 3.92439
# Epoch  12: Valid f1_score = 0.93926
# Epoch  12: Valid Acurracy = 0.93926
# Epoch  12: Valid Recall score = 0.93926
# Epoch  12: Valid Precision score = 0.93926
# The current f1 score: 0.9392556179775281
# Epoch  13: Train Loss = 4.17443
# Epoch  13: Valid Loss = 3.92182
# Epoch  13: Valid f1_score = 0.94017
# Epoch  13: Valid Acurracy = 0.94017
# Epoch  13: Valid Recall score = 0.94017
# Epoch  13: Valid Precision score = 0.94017
# The current f1 score: 0.9401685393258427
# Epoch  14: Train Loss = 4.17819
# Epoch  14: Valid Loss = 3.91787
# Epoch  14: Valid f1_score = 0.94157
# Epoch  14: Valid Acurracy = 0.94157
# Epoch  14: Valid Recall score = 0.94157
# Epoch  14: Valid Precision score = 0.94157
# The current f1 score: 0.9415730337078652
# Epoch  15: Train Loss = 4.17335
# Epoch  15: Valid Loss = 3.91663
# Epoch  15: Valid f1_score = 0.94417
# Epoch  15: Valid Acurracy = 0.94417
# Epoch  15: Valid Recall score = 0.94417
# Epoch  15: Valid Precision score = 0.94417
# The current f1 score: 0.9441713483146067
# Epoch  16: Train Loss = 4.16758
# Epoch  16: Valid Loss = 3.91656
# Epoch  16: Valid f1_score = 0.94508
# Epoch  16: Valid Acurracy = 0.94508
# Epoch  16: Valid Recall score = 0.94508
# Epoch  16: Valid Precision score = 0.94508
# The current f1 score: 0.9450842696629214
# Epoch  17: Train Loss = 4.16018
# Epoch  17: Valid Loss = 3.91322
# Epoch  17: Valid f1_score = 0.94628
# Epoch  17: Valid Acurracy = 0.94628
# Epoch  17: Valid Recall score = 0.94628
# Epoch  17: Valid Precision score = 0.94628
# The current f1 score: 0.9462780898876404
# Epoch  18: Train Loss = 4.16018
# Epoch  18: Valid Loss = 3.91428
# Epoch  18: Valid f1_score = 0.94649
# Epoch  18: Valid Acurracy = 0.94649
# Epoch  18: Valid Recall score = 0.94649
# Epoch  18: Valid Precision score = 0.94649
# The current f1 score: 0.9464887640449438
# Epoch  19: Train Loss = 4.16696
# Epoch  19: Valid Loss = 3.91132
# Epoch  19: Valid f1_score = 0.94909
# Epoch  19: Valid Acurracy = 0.94909
# Epoch  19: Valid Recall score = 0.94909
# Epoch  19: Valid Precision score = 0.94909
# The current f1 score: 0.9490870786516854
# 0.9490870786516854
# The best parameters are saved for the activation function: Softplus

# %%
list_relation_training_losses.append(list_relation_loss_train_leakyrelu)
list_relation_validation_losses.append(list_relation_loss_valid_leakyrelu)
list_relation_epochs.append(list_epochs_leakyrelu)
list_relation_training_losses.append(list_relation_loss_train_tanhshrink)
list_relation_validation_losses.append(list_relation_loss_valid_tanhshrink)
list_relation_epochs.append(list_epochs_tanhshrink)
list_relation_training_losses.append(list_relation_loss_train_softplus)
list_relation_validation_losses.append(list_relation_loss_valid_softplus)
list_relation_epochs.append(list_epochs_softplus)
list_relation_training_losses.append(list_relation_loss_train_elu)
list_relation_validation_losses.append(list_relation_loss_valid_elu)
list_relation_epochs.append(list_epochs_elu)

# %% [markdown]
# **Through the function plot_losses the learning curves for losses (relation prediction losses, entity span prediction losses) are plotted.**

# %%
def plot_losses(list_epochs, list_training_losses, list_validation_losses, activations, lr, dropout_prob):
 for activation in range(len(activations)):
  plt.plot(list_epochs[activation], list_training_losses[activation], label = f"{activations[activation]},{lr},{dropout_prob}-Training")
  plt.plot(list_epochs[activation], list_validation_losses[activation], label = f"{activations[activation]},{lr},{dropout_prob}-Validation")
  plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize = 'small')
  plt.xlabel('Number of epochs')
  plt.ylabel('Loss')
  plt.title("loss-score")
  plt.ylim(ymin = 3.5)
activations = ['LeakyReLU','Tanhshrink', 'Softplus','ELU']

# %%
plot_losses(list_relation_epochs, list_relation_training_losses, list_relation_validation_losses, activations, learning_rate, dropout_prob)

# %% [markdown]
# ****Construction and initialization of the neural network for the prediction of the entity span start and entity span end indexes for each question.****

# %%
class BertEntitySpanClassifier(nn.Module):
  def __init__(self, activation, dropout_prob, max_quest_len):
    super(BertEntitySpanClassifier, self).__init__()
    self.bert_model = BertModel.from_pretrained('bert-base-uncased')
# Whether the model returns all hidden-states.
    activations = {
        "ELU" : nn.ELU,
        "LeakyReLU"    : nn.LeakyReLU,
        "Softplus"     : nn.Softplus,
        "Tanhshrink"     : nn.Tanhshrink
 }
    self.activation_type = activation
    self.activation = activations[self.activation_type]()
    self.max_length = max_quest_len
    self.dropout_probability = dropout_prob
    self.start_head = nn.Sequential(
          nn.Linear(768, self.max_length),
          self.activation,
          nn.Dropout(p=self.dropout_probability),
          nn.Flatten(),
          nn.Softmax(dim=1)
    )

    self.end_head = nn.Sequential(
          nn.Linear(768, self.max_length),
          self.activation,
          nn.Dropout(p=self.dropout_probability),
          nn.Flatten(),
          nn.Softmax(dim=1)
    )

  def forward(self, input_ids, att_mask):
    out = self.bert_model(input_ids, att_mask)
    out = out[0]
    out_start = self.start_head(out)
    out_end = self.end_head(out)
    return out_start , out_end

# %% [markdown]
# **Through the function named entity_prediction_function the best possible parameters for the best possible prediction of the entity span are found. This function has as arguments the corresponding training dataloader, the corresponding validation dataloader, the number of epochs, the optimizer, the scheduler, the learning rate, the entity span prediction neural network model, the loss function and the dropout probability value.**
#
# **This function returns the best possible model, the list including numbers from 0 to number of training epochs-1, the lists including the values of training losses and validation losses for all epochs respectively, the largest value of f1 for entity span start and the largest value of f1 for entity span end.**
#
# **The biggest length of a question in words that is observed in SimpleQuestions dataset is equal to 33. Thus these predicted indexes as numbers must be either between 0 and 32, where these numbers correspond to the position of these words in their question for each question.**

# %%
def entity_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, lr, dropout_prob):
 list_loss_train = []
 list_loss = []
 list_epochs = []
 the_last_f1_start_score = 0
 the_last_f1_end_score = 0
 patience = 3
 max_f1_start = -1
 max_f1_end = -1
 trigger_times = 0
 for epoch in range(epochs):
  train_dataset.set_epoch(epoch)
  valid_dataset.set_epoch(epoch)
  model.train()
  batch_losses = []
  for batch in train_dataloader:
   input_ids = batch['input_ids'].to(device)
   attention_masks = batch['attention_mask'].to(device)
   entity_span_start_indexes = batch['entity_start'].to(device)
   entity_span_end_indexes = batch['entity_end'].to(device)
   y_pred_start, y_pred_end = model(input_ids, attention_masks)
   y_pred_start = y_pred_start.squeeze()
   y_pred_end = y_pred_end.squeeze()
   start_preds = torch.argmax(y_pred_start,dim = 1)
   loss = loss_func(y_pred_start.cpu(),entity_span_start_indexes.cpu())+loss_func(y_pred_end.cpu(),entity_span_end_indexes.cpu())
   batch_losses.append(loss.detach().numpy())
    #Delete previously stored gradients
   nn.utils.clip_grad_norm_(model.parameters(), 0.7)
   optimizer.zero_grad()

    #Perform backpropagation starting from the loss calculated in this epoch
   loss.backward()

    #Update model's weights based on the gradients calculated during backprop
   optimizer.step()
   scheduler.step()
  print(f"Epoch {epoch:3}: Train Loss = {sum(batch_losses)/len(train_dataloader):.5f}")
  list_loss_train.append(sum(batch_losses)/len(train_dataloader))
  with torch.no_grad():
    model.eval()
    F1_start = []
    F1_end = []
    accuracy_start = []
    accuracy_end = []
    precision_start = []
    precision_end = []
    recall_start = []
    recall_end = []
    batch_losses_val = []
    for batch in val_dataloader:
      input_ids = batch['input_ids'].to(device)
      attention_masks = batch['attention_mask'].to(device)
      entity_span_start_indexes = batch['entity_start'].to(device)
      entity_span_end_indexes = batch['entity_end'].to(device)
      y_predict_start, y_predict_end = model(input_ids, attention_masks)
      y_predict_start = y_predict_start.squeeze()
      y_predict_end = y_predict_end.squeeze()
      val_loss = loss_func(y_predict_start.cpu(),entity_span_start_indexes.cpu())+loss_func(y_predict_end.cpu(),entity_span_end_indexes.cpu())
      batch_losses_val.append(val_loss)
      y_pr_start = torch.argmax(y_predict_start, dim=1)
      y_pr_end = torch.argmax(y_predict_end, dim=1)
      Y_p_start = y_pr_start.tolist()
      Y_p_end = y_pr_end.tolist()
      y_val_start = entity_span_start_indexes.tolist()
      y_val_end = entity_span_end_indexes.tolist()
      F1_start.append(f1_score(y_val_start, Y_p_start, average = 'micro'))
      F1_end.append(f1_score(y_val_end, Y_p_end, average = 'micro'))
      accuracy_start.append(accuracy_score(y_val_start, Y_p_start))
      accuracy_end.append(accuracy_score(y_val_end, Y_p_end))
      precision_start.append(precision_score(y_val_start, Y_p_start, average = 'micro'))
      precision_end.append(precision_score(y_val_end, Y_p_end, average = 'micro'))
      recall_start.append(recall_score(y_val_start, Y_p_start, average = 'micro'))
      recall_end.append(recall_score(y_val_end, Y_p_end, average = 'micro'))
    Valid_f1_start = sum(F1_start)/len(val_dataloader)
    Valid_f1_end = sum(F1_end)/len(val_dataloader)
    print(f"Epoch {epoch:3}: Valid Loss = {sum(batch_losses_val)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid f1_score for entity start span = {Valid_f1_start:.5f}")
    print(f"Epoch {epoch:3}: Valid Acurracy for entity start span = {sum(accuracy_start)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Recall for entity start span = {sum(recall_start)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Precision for entity start span = {sum(precision_start)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid f1_score for entity end span = {Valid_f1_end:.5f}")
    print(f"Epoch {epoch:3}: Valid Acurracy for entity end span = {sum(accuracy_end)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Recall for entity end span = {sum(recall_end)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Precision for entity end span = {sum(precision_end)/len(val_dataloader):.5f}")
    list_loss.append(sum(batch_losses_val)/len(val_dataloader))
    list_epochs.append(epoch)
    if Valid_f1_start >= max_f1_start and Valid_f1_end >= max_f1_end:
      max_f1_start = Valid_f1_start
      max_f1_end = Valid_f1_end
      best_model = model
      print('The current f1 score for entity start:', Valid_f1_start)
      print('The current f1 score for entity end:', Valid_f1_end)
    if Valid_f1_start < the_last_f1_start_score and Valid_f1_end < the_last_f1_end_score:
      trigger_times += 1
      print('trigger times:', trigger_times)
      if trigger_times >= patience:
        print('Early stopping!\nStart to test process.')
        break;
    the_last_f1_start_score = Valid_f1_start
    the_last_f1_end_score = Valid_f1_end

 return max_f1_start, max_f1_end, list_loss_train, list_loss, list_epochs, best_model

# %% [markdown]
# **The function named get_entity_results finds results for the neural networks concerning the relation index and the entity span indexes (start,end). These functions have as arguments the corresponding training dataloader, the corresponding validation dataloader, the number of epochs ,the optimizer, the scheduler get_linear_schedule_with_warmup, the corresponding entity span prediction neural network model, the loss function, the learning rate and the SEED number.**
#
# **This function returns the list of training losses, the list of validation losses, and the list of how many epochs each model with each activation function needs to be fully trained.**

# %%
learning_rate  = 2e-5
dropout_prob = 0.3
epochs = 20
list_entity_training_losses = []
list_entity_validation_losses = []
list_entity_span_encoded_epochs = []
loss_func = nn.CrossEntropyLoss()
optimizer_name = "Adam"
activations_list = ['LeakyReLU','Tanhshrink', 'Softplus','ELU']
def get_entity_results(activation, max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_dataset, valid_dataset, train_dataloader, val_dataloader, SEED):
 set_seed(SEED)
 model = BertEntitySpanClassifier(activation, dropout_prob, max_question_length).to(device)
 print(model)
 loss_func = loss_func.to(device)
 optimizer = getattr(torch.optim, optimizer_name)(model.parameters(), lr=learning_rate)
 scheduler = get_linear_schedule_with_warmup(optimizer, 0, len(train_dataloader)*epochs)
 f1_start, f1_end, list_loss_train, list_loss_valid, list_epochs, best_entity_model = entity_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, learning_rate, dropout_prob)
 print(f1_start,f1_end)
 torch.save(best_entity_model.state_dict(), create_file(f"drive/MyDrive/Entity_span_indexes_models_best_parameters/Answerable_Questions/{activation}",f"entity_span_encoded_prediction_not_ignoring_answerable_questions_{activation}.pt") )
 print(f"The best parameters are saved for the activation function: {activation}")
 return list_loss_train, list_loss_valid, list_epochs

# %%
list_entity_loss_train_leakyrelu_span_encoded, list_entity_loss_valid_leakyrelu_span_encoded, list_epochs_leakyrelu_span_encoded = get_entity_results("LeakyReLU", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_span_encoded_bert_dataset, valid_span_encoded_bert_dataset, train_dataloader_span_encoded, val_dataloader_span_encoded, SEED)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): LeakyReLU(negative_slope=0.01)
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.64585
# Epoch   0: Valid Loss = 13.36521
# Epoch   0: Valid f1_score for entity start span = 0.44747
# Epoch   0: Valid Acurracy for entity start span = 0.44747
# Epoch   0: Valid Recall for entity start span = 0.44747
# Epoch   0: Valid Precision for entity start span = 0.44747
# Epoch   0: Valid f1_score for entity end span = 0.28982
# Epoch   0: Valid Acurracy for entity end span = 0.28982
# Epoch   0: Valid Recall for entity end span = 0.28982
# Epoch   0: Valid Precision for entity end span = 0.28982
# The current f1 score for entity start: 0.4474719101123596
# The current f1 score for entity end: 0.2898174157303371
# Epoch   1: Train Loss = 13.34234
# Epoch   1: Valid Loss = 13.09820
# Epoch   1: Valid f1_score for entity start span = 0.60660
# Epoch   1: Valid Acurracy for entity start span = 0.60660
# Epoch   1: Valid Recall for entity start span = 0.60660
# Epoch   1: Valid Precision for entity start span = 0.60660
# Epoch   1: Valid f1_score for entity end span = 0.40744
# Epoch   1: Valid Acurracy for entity end span = 0.40744
# Epoch   1: Valid Recall for entity end span = 0.40744
# Epoch   1: Valid Precision for entity end span = 0.40744
# The current f1 score for entity start: 0.6066011235955056
# The current f1 score for entity end: 0.40744382022471914
# Epoch   2: Train Loss = 13.11794
# Epoch   2: Valid Loss = 12.77496
# Epoch   2: Valid f1_score for entity start span = 0.73511
# Epoch   2: Valid Acurracy for entity start span = 0.73511
# Epoch   2: Valid Recall for entity start span = 0.73511
# Epoch   2: Valid Precision for entity start span = 0.73511
# Epoch   2: Valid f1_score for entity end span = 0.65983
# Epoch   2: Valid Acurracy for entity end span = 0.65983
# Epoch   2: Valid Recall for entity end span = 0.65983
# Epoch   2: Valid Precision for entity end span = 0.65983
# The current f1 score for entity start: 0.7351123595505618
# The current f1 score for entity end: 0.6598314606741573
# Epoch   3: Train Loss = 12.89444
# Epoch   3: Valid Loss = 12.51398
# Epoch   3: Valid f1_score for entity start span = 0.80513
# Epoch   3: Valid Acurracy for entity start span = 0.80513
# Epoch   3: Valid Recall for entity start span = 0.80513
# Epoch   3: Valid Precision for entity start span = 0.80513
# Epoch   3: Valid f1_score for entity end span = 0.79972
# Epoch   3: Valid Acurracy for entity end span = 0.79972
# Epoch   3: Valid Recall for entity end span = 0.79972
# Epoch   3: Valid Precision for entity end span = 0.79972
# The current f1 score for entity start: 0.805126404494382
# The current f1 score for entity end: 0.7997191011235955
# Epoch   4: Train Loss = 12.85166
# Epoch   4: Valid Loss = 12.44548
# Epoch   4: Valid f1_score for entity start span = 0.81152
# Epoch   4: Valid Acurracy for entity start span = 0.81152
# Epoch   4: Valid Recall for entity start span = 0.81152
# Epoch   4: Valid Precision for entity start span = 0.81152
# Epoch   4: Valid f1_score for entity end span = 0.83167
# Epoch   4: Valid Acurracy for entity end span = 0.83167
# Epoch   4: Valid Recall for entity end span = 0.83167
# Epoch   4: Valid Precision for entity end span = 0.83167
# The current f1 score for entity start: 0.8115168539325842
# The current f1 score for entity end: 0.8316713483146068
# Epoch   5: Train Loss = 12.81050
# Epoch   5: Valid Loss = 12.38329
# Epoch   5: Valid f1_score for entity start span = 0.83378
# Epoch   5: Valid Acurracy for entity start span = 0.83378
# Epoch   5: Valid Recall for entity start span = 0.83378
# Epoch   5: Valid Precision for entity start span = 0.83378
# Epoch   5: Valid f1_score for entity end span = 0.86046
# Epoch   5: Valid Acurracy for entity end span = 0.86046
# Epoch   5: Valid Recall for entity end span = 0.86046
# Epoch   5: Valid Precision for entity end span = 0.86046
# The current f1 score for entity start: 0.8337780898876405
# The current f1 score for entity end: 0.8604634831460674
# Epoch   6: Train Loss = 12.77200
# Epoch   6: Valid Loss = 12.34048
# Epoch   6: Valid f1_score for entity start span = 0.86306
# Epoch   6: Valid Acurracy for entity start span = 0.86306
# Epoch   6: Valid Recall for entity start span = 0.86306
# Epoch   6: Valid Precision for entity start span = 0.86306
# Epoch   6: Valid f1_score for entity end span = 0.86383
# Epoch   6: Valid Acurracy for entity end span = 0.86383
# Epoch   6: Valid Recall for entity end span = 0.86383
# Epoch   6: Valid Precision for entity end span = 0.86383
# The current f1 score for entity start: 0.863061797752809
# The current f1 score for entity end: 0.8638342696629213
# Epoch   7: Train Loss = 12.75995
# Epoch   7: Valid Loss = 12.30218
# Epoch   7: Valid f1_score for entity start span = 0.86622
# Epoch   7: Valid Acurracy for entity start span = 0.86622
# Epoch   7: Valid Recall for entity start span = 0.86622
# Epoch   7: Valid Precision for entity start span = 0.86622
# Epoch   7: Valid f1_score for entity end span = 0.87640
# Epoch   7: Valid Acurracy for entity end span = 0.87640
# Epoch   7: Valid Recall for entity end span = 0.87640
# Epoch   7: Valid Precision for entity end span = 0.87640
# The current f1 score for entity start: 0.8662219101123596
# The current f1 score for entity end: 0.8764044943820225
# Epoch   8: Train Loss = 12.73434
# Epoch   8: Valid Loss = 12.28512
# Epoch   8: Valid f1_score for entity start span = 0.87640
# Epoch   8: Valid Acurracy for entity start span = 0.87640
# Epoch   8: Valid Recall for entity start span = 0.87640
# Epoch   8: Valid Precision for entity start span = 0.87640
# Epoch   8: Valid f1_score for entity end span = 0.88329
# Epoch   8: Valid Acurracy for entity end span = 0.88329
# Epoch   8: Valid Recall for entity end span = 0.88329
# Epoch   8: Valid Precision for entity end span = 0.88329
# The current f1 score for entity start: 0.8764044943820225
# The current f1 score for entity end: 0.8832865168539326
# Epoch   9: Train Loss = 12.71847
# Epoch   9: Valid Loss = 12.26859
# Epoch   9: Valid f1_score for entity start span = 0.88996
# Epoch   9: Valid Acurracy for entity start span = 0.88996
# Epoch   9: Valid Recall for entity start span = 0.88996
# Epoch   9: Valid Precision for entity start span = 0.88996
# Epoch   9: Valid f1_score for entity end span = 0.88729
# Epoch   9: Valid Acurracy for entity end span = 0.88729
# Epoch   9: Valid Recall for entity end span = 0.88729
# Epoch   9: Valid Precision for entity end span = 0.88729
# The current f1 score for entity start: 0.8899578651685393
# The current f1 score for entity end: 0.8872893258426966
# Epoch  10: Train Loss = 12.71328
# Epoch  10: Valid Loss = 12.24362
# Epoch  10: Valid f1_score for entity start span = 0.89712
# Epoch  10: Valid Acurracy for entity start span = 0.89712
# Epoch  10: Valid Recall for entity start span = 0.89712
# Epoch  10: Valid Precision for entity start span = 0.89712
# Epoch  10: Valid f1_score for entity end span = 0.89874
# Epoch  10: Valid Acurracy for entity end span = 0.89874
# Epoch  10: Valid Recall for entity end span = 0.89874
# Epoch  10: Valid Precision for entity end span = 0.89874
# The current f1 score for entity start: 0.8971207865168539
# The current f1 score for entity end: 0.8987359550561798
# Epoch  11: Train Loss = 12.70104
# Epoch  11: Valid Loss = 12.23367
# Epoch  11: Valid f1_score for entity start span = 0.89382
# Epoch  11: Valid Acurracy for entity start span = 0.89382
# Epoch  11: Valid Recall for entity start span = 0.89382
# Epoch  11: Valid Precision for entity start span = 0.89382
# Epoch  11: Valid f1_score for entity end span = 0.90836
# Epoch  11: Valid Acurracy for entity end span = 0.90836
# Epoch  11: Valid Recall for entity end span = 0.90836
# Epoch  11: Valid Precision for entity end span = 0.90836
# Epoch  12: Train Loss = 12.69849
# Epoch  12: Valid Loss = 12.21267
# Epoch  12: Valid f1_score for entity start span = 0.90449
# Epoch  12: Valid Acurracy for entity start span = 0.90449
# Epoch  12: Valid Recall for entity start span = 0.90449
# Epoch  12: Valid Precision for entity start span = 0.90449
# Epoch  12: Valid f1_score for entity end span = 0.91257
# Epoch  12: Valid Acurracy for entity end span = 0.91257
# Epoch  12: Valid Recall for entity end span = 0.91257
# Epoch  12: Valid Precision for entity end span = 0.91257
# The current f1 score for entity start: 0.9044943820224719
# The current f1 score for entity end: 0.9125702247191011
# Epoch  13: Train Loss = 12.68713
# Epoch  13: Valid Loss = 12.20540
# Epoch  13: Valid f1_score for entity start span = 0.90976
# Epoch  13: Valid Acurracy for entity start span = 0.90976
# Epoch  13: Valid Recall for entity start span = 0.90976
# Epoch  13: Valid Precision for entity start span = 0.90976
# Epoch  13: Valid f1_score for entity end span = 0.91573
# Epoch  13: Valid Acurracy for entity end span = 0.91573
# Epoch  13: Valid Recall for entity end span = 0.91573
# Epoch  13: Valid Precision for entity end span = 0.91573
# The current f1 score for entity start: 0.9097612359550562
# The current f1 score for entity end: 0.9157303370786517
# Epoch  14: Train Loss = 12.67985
# Epoch  14: Valid Loss = 12.20368
# Epoch  14: Valid f1_score for entity start span = 0.90801
# Epoch  14: Valid Acurracy for entity start span = 0.90801
# Epoch  14: Valid Recall for entity start span = 0.90801
# Epoch  14: Valid Precision for entity start span = 0.90801
# Epoch  14: Valid f1_score for entity end span = 0.91257
# Epoch  14: Valid Acurracy for entity end span = 0.91257
# Epoch  14: Valid Recall for entity end span = 0.91257
# Epoch  14: Valid Precision for entity end span = 0.91257
# trigger times: 1
# Epoch  15: Train Loss = 12.68502
# Epoch  15: Valid Loss = 12.20112
# Epoch  15: Valid f1_score for entity start span = 0.90976
# Epoch  15: Valid Acurracy for entity start span = 0.90976
# Epoch  15: Valid Recall for entity start span = 0.90976
# Epoch  15: Valid Precision for entity start span = 0.90976
# Epoch  15: Valid f1_score for entity end span = 0.91138
# Epoch  15: Valid Acurracy for entity end span = 0.91138
# Epoch  15: Valid Recall for entity end span = 0.91138
# Epoch  15: Valid Precision for entity end span = 0.91138
# Epoch  16: Train Loss = 12.68305
# Epoch  16: Valid Loss = 12.19123
# Epoch  16: Valid f1_score for entity start span = 0.91889
# Epoch  16: Valid Acurracy for entity start span = 0.91889
# Epoch  16: Valid Recall for entity start span = 0.91889
# Epoch  16: Valid Precision for entity start span = 0.91889
# Epoch  16: Valid f1_score for entity end span = 0.91243
# Epoch  16: Valid Acurracy for entity end span = 0.91243
# Epoch  16: Valid Recall for entity end span = 0.91243
# Epoch  16: Valid Precision for entity end span = 0.91243
# Epoch  17: Train Loss = 12.67295
# Epoch  17: Valid Loss = 12.18828
# Epoch  17: Valid f1_score for entity start span = 0.91819
# Epoch  17: Valid Acurracy for entity start span = 0.91819
# Epoch  17: Valid Recall for entity start span = 0.91819
# Epoch  17: Valid Precision for entity start span = 0.91819
# Epoch  17: Valid f1_score for entity end span = 0.91503
# Epoch  17: Valid Acurracy for entity end span = 0.91503
# Epoch  17: Valid Recall for entity end span = 0.91503
# Epoch  17: Valid Precision for entity end span = 0.91503
# Epoch  18: Train Loss = 12.67600
# Epoch  18: Valid Loss = 12.18438
# Epoch  18: Valid f1_score for entity start span = 0.91924
# Epoch  18: Valid Acurracy for entity start span = 0.91924
# Epoch  18: Valid Recall for entity start span = 0.91924
# Epoch  18: Valid Precision for entity start span = 0.91924
# Epoch  18: Valid f1_score for entity end span = 0.91468
# Epoch  18: Valid Acurracy for entity end span = 0.91468
# Epoch  18: Valid Recall for entity end span = 0.91468
# Epoch  18: Valid Precision for entity end span = 0.91468
# Epoch  19: Train Loss = 12.69176
# Epoch  19: Valid Loss = 12.18327
# Epoch  19: Valid f1_score for entity start span = 0.91924
# Epoch  19: Valid Acurracy for entity start span = 0.91924
# Epoch  19: Valid Recall for entity start span = 0.91924
# Epoch  19: Valid Precision for entity start span = 0.91924
# Epoch  19: Valid f1_score for entity end span = 0.91573
# Epoch  19: Valid Acurracy for entity end span = 0.91573
# Epoch  19: Valid Recall for entity end span = 0.91573
# Epoch  19: Valid Precision for entity end span = 0.91573
# The current f1 score for entity start: 0.9192415730337079
# The current f1 score for entity end: 0.9157303370786517
# 0.9192415730337079 0.9157303370786517
# The best parameters are saved for the activation function: LeakyReLU

# %%
list_entity_loss_train_tahnshrink_span_encoded, list_entity_loss_valid_tahnshrink_span_encoded, list_epochs_tanhshrink_span_encoded = get_entity_results("Tanhshrink", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_span_encoded_bert_dataset, valid_span_encoded_bert_dataset, train_dataloader_span_encoded, val_dataloader_span_encoded, SEED)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): Tanhshrink()
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Tanhshrink()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Tanhshrink()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.68732
# Epoch   0: Valid Loss = 13.42726
# Epoch   0: Valid f1_score for entity start span = 0.44256
# Epoch   0: Valid Acurracy for entity start span = 0.44256
# Epoch   0: Valid Recall for entity start span = 0.44256
# Epoch   0: Valid Precision for entity start span = 0.44256
# Epoch   0: Valid f1_score for entity end span = 0.20660
# Epoch   0: Valid Acurracy for entity end span = 0.20660
# Epoch   0: Valid Recall for entity end span = 0.20660
# Epoch   0: Valid Precision for entity end span = 0.20660
# The current f1 score for entity start: 0.44255617977528094
# The current f1 score for entity end: 0.20660112359550561
# Epoch   1: Train Loss = 13.36826
# Epoch   1: Valid Loss = 13.04400
# Epoch   1: Valid f1_score for entity start span = 0.59522
# Epoch   1: Valid Acurracy for entity start span = 0.59522
# Epoch   1: Valid Recall for entity start span = 0.59522
# Epoch   1: Valid Precision for entity start span = 0.59522
# Epoch   1: Valid f1_score for entity end span = 0.41250
# Epoch   1: Valid Acurracy for entity end span = 0.41250
# Epoch   1: Valid Recall for entity end span = 0.41250
# Epoch   1: Valid Precision for entity end span = 0.41250
# The current f1 score for entity start: 0.5952247191011236
# The current f1 score for entity end: 0.4125
# Epoch   2: Train Loss = 13.21794
# Epoch   2: Valid Loss = 12.80756
# Epoch   2: Valid f1_score for entity start span = 0.73371
# Epoch   2: Valid Acurracy for entity start span = 0.73371
# Epoch   2: Valid Recall for entity start span = 0.73371
# Epoch   2: Valid Precision for entity start span = 0.73371
# Epoch   2: Valid f1_score for entity end span = 0.50709
# Epoch   2: Valid Acurracy for entity end span = 0.50709
# Epoch   2: Valid Recall for entity end span = 0.50709
# Epoch   2: Valid Precision for entity end span = 0.50709
# The current f1 score for entity start: 0.7337078651685393
# The current f1 score for entity end: 0.5070926966292135
# Epoch   3: Train Loss = 13.03126
# Epoch   3: Valid Loss = 12.60866
# Epoch   3: Valid f1_score for entity start span = 0.79319
# Epoch   3: Valid Acurracy for entity start span = 0.79319
# Epoch   3: Valid Recall for entity start span = 0.79319
# Epoch   3: Valid Precision for entity start span = 0.79319
# Epoch   3: Valid f1_score for entity end span = 0.64698
# Epoch   3: Valid Acurracy for entity end span = 0.64698
# Epoch   3: Valid Recall for entity end span = 0.64698
# Epoch   3: Valid Precision for entity end span = 0.64698
# The current f1 score for entity start: 0.793188202247191
# The current f1 score for entity end: 0.6469803370786517
# Epoch   4: Train Loss = 12.92761
# Epoch   4: Valid Loss = 12.53399
# Epoch   4: Valid f1_score for entity start span = 0.84853
# Epoch   4: Valid Acurracy for entity start span = 0.84853
# Epoch   4: Valid Recall for entity start span = 0.84853
# Epoch   4: Valid Precision for entity start span = 0.84853
# Epoch   4: Valid f1_score for entity end span = 0.64544
# Epoch   4: Valid Acurracy for entity end span = 0.64544
# Epoch   4: Valid Recall for entity end span = 0.64544
# Epoch   4: Valid Precision for entity end span = 0.64544
# Epoch   5: Train Loss = 12.88642
# Epoch   5: Valid Loss = 12.48814
# Epoch   5: Valid f1_score for entity start span = 0.86819
# Epoch   5: Valid Acurracy for entity start span = 0.86819
# Epoch   5: Valid Recall for entity start span = 0.86819
# Epoch   5: Valid Precision for entity start span = 0.86819
# Epoch   5: Valid f1_score for entity end span = 0.66875
# Epoch   5: Valid Acurracy for entity end span = 0.66875
# Epoch   5: Valid Recall for entity end span = 0.66875
# Epoch   5: Valid Precision for entity end span = 0.66875
# The current f1 score for entity start: 0.868188202247191
# The current f1 score for entity end: 0.66875
# Epoch   6: Train Loss = 12.84783
# Epoch   6: Valid Loss = 12.41235
# Epoch   6: Valid f1_score for entity start span = 0.87640
# Epoch   6: Valid Acurracy for entity start span = 0.87640
# Epoch   6: Valid Recall for entity start span = 0.87640
# Epoch   6: Valid Precision for entity start span = 0.87640
# Epoch   6: Valid f1_score for entity end span = 0.74466
# Epoch   6: Valid Acurracy for entity end span = 0.74466
# Epoch   6: Valid Recall for entity end span = 0.74466
# Epoch   6: Valid Precision for entity end span = 0.74466
# The current f1 score for entity start: 0.8764044943820225
# The current f1 score for entity end: 0.7446629213483147
# Epoch   7: Train Loss = 12.80703
# Epoch   7: Valid Loss = 12.34104
# Epoch   7: Valid f1_score for entity start span = 0.87430
# Epoch   7: Valid Acurracy for entity start span = 0.87430
# Epoch   7: Valid Recall for entity start span = 0.87430
# Epoch   7: Valid Precision for entity start span = 0.87430
# Epoch   7: Valid f1_score for entity end span = 0.81145
# Epoch   7: Valid Acurracy for entity end span = 0.81145
# Epoch   7: Valid Recall for entity end span = 0.81145
# Epoch   7: Valid Precision for entity end span = 0.81145
# Epoch   8: Train Loss = 12.76905
# Epoch   8: Valid Loss = 12.31485
# Epoch   8: Valid f1_score for entity start span = 0.87781
# Epoch   8: Valid Acurracy for entity start span = 0.87781
# Epoch   8: Valid Recall for entity start span = 0.87781
# Epoch   8: Valid Precision for entity start span = 0.87781
# Epoch   8: Valid f1_score for entity end span = 0.82500
# Epoch   8: Valid Acurracy for entity end span = 0.82500
# Epoch   8: Valid Recall for entity end span = 0.82500
# Epoch   8: Valid Precision for entity end span = 0.82500
# The current f1 score for entity start: 0.8778089887640449
# The current f1 score for entity end: 0.825
# Epoch   9: Train Loss = 12.74626
# Epoch   9: Valid Loss = 12.26416
# Epoch   9: Valid f1_score for entity start span = 0.88610
# Epoch   9: Valid Acurracy for entity start span = 0.88610
# Epoch   9: Valid Recall for entity start span = 0.88610
# Epoch   9: Valid Precision for entity start span = 0.88610
# Epoch   9: Valid f1_score for entity end span = 0.87465
# Epoch   9: Valid Acurracy for entity end span = 0.87465
# Epoch   9: Valid Recall for entity end span = 0.87465
# Epoch   9: Valid Precision for entity end span = 0.87465
# The current f1 score for entity start: 0.8860955056179775
# The current f1 score for entity end: 0.8746488764044944
# Epoch  10: Train Loss = 12.72769
# Epoch  10: Valid Loss = 12.23219
# Epoch  10: Valid f1_score for entity start span = 0.90309
# Epoch  10: Valid Acurracy for entity start span = 0.90309
# Epoch  10: Valid Recall for entity start span = 0.90309
# Epoch  10: Valid Precision for entity start span = 0.90309
# Epoch  10: Valid f1_score for entity end span = 0.88434
# Epoch  10: Valid Acurracy for entity end span = 0.88434
# Epoch  10: Valid Recall for entity end span = 0.88434
# Epoch  10: Valid Precision for entity end span = 0.88434
# The current f1 score for entity start: 0.9030898876404494
# The current f1 score for entity end: 0.8843398876404494
# Epoch  11: Train Loss = 12.71146
# Epoch  11: Valid Loss = 12.21998
# Epoch  11: Valid f1_score for entity start span = 0.90787
# Epoch  11: Valid Acurracy for entity start span = 0.90787
# Epoch  11: Valid Recall for entity start span = 0.90787
# Epoch  11: Valid Precision for entity start span = 0.90787
# Epoch  11: Valid f1_score for entity end span = 0.89010
# Epoch  11: Valid Acurracy for entity end span = 0.89010
# Epoch  11: Valid Recall for entity end span = 0.89010
# Epoch  11: Valid Precision for entity end span = 0.89010
# The current f1 score for entity start: 0.9078651685393259
# The current f1 score for entity end: 0.8900983146067416
# Epoch  12: Train Loss = 12.70784
# Epoch  12: Valid Loss = 12.20528
# Epoch  12: Valid f1_score for entity start span = 0.91292
# Epoch  12: Valid Acurracy for entity start span = 0.91292
# Epoch  12: Valid Recall for entity start span = 0.91292
# Epoch  12: Valid Precision for entity start span = 0.91292
# Epoch  12: Valid f1_score for entity end span = 0.90063
# Epoch  12: Valid Acurracy for entity end span = 0.90063
# Epoch  12: Valid Recall for entity end span = 0.90063
# Epoch  12: Valid Precision for entity end span = 0.90063
# The current f1 score for entity start: 0.9129213483146067
# The current f1 score for entity end: 0.9006320224719101
# Epoch  13: Train Loss = 12.69359
# Epoch  13: Valid Loss = 12.19824
# Epoch  13: Valid f1_score for entity start span = 0.91362
# Epoch  13: Valid Acurracy for entity start span = 0.91362
# Epoch  13: Valid Recall for entity start span = 0.91362
# Epoch  13: Valid Precision for entity start span = 0.91362
# Epoch  13: Valid f1_score for entity end span = 0.90063
# Epoch  13: Valid Acurracy for entity end span = 0.90063
# Epoch  13: Valid Recall for entity end span = 0.90063
# Epoch  13: Valid Precision for entity end span = 0.90063
# The current f1 score for entity start: 0.913623595505618
# The current f1 score for entity end: 0.9006320224719101
# Epoch  14: Train Loss = 12.68310
# Epoch  14: Valid Loss = 12.18720
# Epoch  14: Valid f1_score for entity start span = 0.91608
# Epoch  14: Valid Acurracy for entity start span = 0.91608
# Epoch  14: Valid Recall for entity start span = 0.91608
# Epoch  14: Valid Precision for entity start span = 0.91608
# Epoch  14: Valid f1_score for entity end span = 0.90976
# Epoch  14: Valid Acurracy for entity end span = 0.90976
# Epoch  14: Valid Recall for entity end span = 0.90976
# Epoch  14: Valid Precision for entity end span = 0.90976
# The current f1 score for entity start: 0.9160814606741573
# The current f1 score for entity end: 0.9097612359550562
# Epoch  15: Train Loss = 12.68408
# Epoch  15: Valid Loss = 12.18288
# Epoch  15: Valid f1_score for entity start span = 0.91959
# Epoch  15: Valid Acurracy for entity start span = 0.91959
# Epoch  15: Valid Recall for entity start span = 0.91959
# Epoch  15: Valid Precision for entity start span = 0.91959
# Epoch  15: Valid f1_score for entity end span = 0.91103
# Epoch  15: Valid Acurracy for entity end span = 0.91103
# Epoch  15: Valid Recall for entity end span = 0.91103
# Epoch  15: Valid Precision for entity end span = 0.91103
# The current f1 score for entity start: 0.9195926966292135
# The current f1 score for entity end: 0.9110252808988764
# Epoch  16: Train Loss = 12.68081
# Epoch  16: Valid Loss = 12.18020
# Epoch  16: Valid f1_score for entity start span = 0.91784
# Epoch  16: Valid Acurracy for entity start span = 0.91784
# Epoch  16: Valid Recall for entity start span = 0.91784
# Epoch  16: Valid Precision for entity start span = 0.91784
# Epoch  16: Valid f1_score for entity end span = 0.91173
# Epoch  16: Valid Acurracy for entity end span = 0.91173
# Epoch  16: Valid Recall for entity end span = 0.91173
# Epoch  16: Valid Precision for entity end span = 0.91173
# Epoch  17: Train Loss = 12.67166
# Epoch  17: Valid Loss = 12.17058
# Epoch  17: Valid f1_score for entity start span = 0.92240
# Epoch  17: Valid Acurracy for entity start span = 0.92240
# Epoch  17: Valid Recall for entity start span = 0.92240
# Epoch  17: Valid Precision for entity start span = 0.92240
# Epoch  17: Valid f1_score for entity end span = 0.92065
# Epoch  17: Valid Acurracy for entity end span = 0.92065
# Epoch  17: Valid Recall for entity end span = 0.92065
# Epoch  17: Valid Precision for entity end span = 0.92065
# The current f1 score for entity start: 0.9224016853932584
# The current f1 score for entity end: 0.9206460674157303
# Epoch  18: Train Loss = 12.67053
# Epoch  18: Valid Loss = 12.16577
# Epoch  18: Valid f1_score for entity start span = 0.92381
# Epoch  18: Valid Acurracy for entity start span = 0.92381
# Epoch  18: Valid Recall for entity start span = 0.92381
# Epoch  18: Valid Precision for entity start span = 0.92381
# Epoch  18: Valid f1_score for entity end span = 0.92346
# Epoch  18: Valid Acurracy for entity end span = 0.92346
# Epoch  18: Valid Recall for entity end span = 0.92346
# Epoch  18: Valid Precision for entity end span = 0.92346
# The current f1 score for entity start: 0.9238061797752809
# The current f1 score for entity end: 0.9234550561797753
# Epoch  19: Train Loss = 12.68585
# Epoch  19: Valid Loss = 12.16418
# Epoch  19: Valid f1_score for entity start span = 0.92486
# Epoch  19: Valid Acurracy for entity start span = 0.92486
# Epoch  19: Valid Recall for entity start span = 0.92486
# Epoch  19: Valid Precision for entity start span = 0.92486
# Epoch  19: Valid f1_score for entity end span = 0.92416
# Epoch  19: Valid Acurracy for entity end span = 0.92416
# Epoch  19: Valid Recall for entity end span = 0.92416
# Epoch  19: Valid Precision for entity end span = 0.92416
# The current f1 score for entity start: 0.9248595505617978
# The current f1 score for entity end: 0.9241573033707865
# 0.9248595505617978 0.9241573033707865
# The best parameters are saved for the activation function: Tanhshrink

# %%
list_entity_loss_train_elu_span_encoded, list_entity_loss_valid_elu_span_encoded, list_epochs_elu_span_encoded  = get_entity_results("ELU", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_span_encoded_bert_dataset, valid_span_encoded_bert_dataset, train_dataloader_span_encoded, val_dataloader_span_encoded, SEED)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): ELU(alpha=1.0)
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.60757
# Epoch   0: Valid Loss = 13.32510
# Epoch   0: Valid f1_score for entity start span = 0.44853
# Epoch   0: Valid Acurracy for entity start span = 0.44853
# Epoch   0: Valid Recall for entity start span = 0.44853
# Epoch   0: Valid Precision for entity start span = 0.44853
# Epoch   0: Valid f1_score for entity end span = 0.30281
# Epoch   0: Valid Acurracy for entity end span = 0.30281
# Epoch   0: Valid Recall for entity end span = 0.30281
# Epoch   0: Valid Precision for entity end span = 0.30281
# The current f1 score for entity start: 0.44852528089887644
# The current f1 score for entity end: 0.30280898876404494
# Epoch   1: Train Loss = 13.17234
# Epoch   1: Valid Loss = 12.78191
# Epoch   1: Valid f1_score for entity start span = 0.77781
# Epoch   1: Valid Acurracy for entity start span = 0.77781
# Epoch   1: Valid Recall for entity start span = 0.77781
# Epoch   1: Valid Precision for entity start span = 0.77781
# Epoch   1: Valid f1_score for entity end span = 0.57331
# Epoch   1: Valid Acurracy for entity end span = 0.57331
# Epoch   1: Valid Recall for entity end span = 0.57331
# Epoch   1: Valid Precision for entity end span = 0.57331
# The current f1 score for entity start: 0.7778089887640449
# The current f1 score for entity end: 0.573314606741573
# Epoch   2: Train Loss = 12.95899
# Epoch   2: Valid Loss = 12.55509
# Epoch   2: Valid f1_score for entity start span = 0.83638
# Epoch   2: Valid Acurracy for entity start span = 0.83638
# Epoch   2: Valid Recall for entity start span = 0.83638
# Epoch   2: Valid Precision for entity start span = 0.83638
# Epoch   2: Valid f1_score for entity end span = 0.69249
# Epoch   2: Valid Acurracy for entity end span = 0.69249
# Epoch   2: Valid Recall for entity end span = 0.69249
# Epoch   2: Valid Precision for entity end span = 0.69249
# The current f1 score for entity start: 0.836376404494382
# The current f1 score for entity end: 0.6924859550561798
# Epoch   3: Train Loss = 12.86452
# Epoch   3: Valid Loss = 12.45576
# Epoch   3: Valid f1_score for entity start span = 0.84164
# Epoch   3: Valid Acurracy for entity start span = 0.84164
# Epoch   3: Valid Recall for entity start span = 0.84164
# Epoch   3: Valid Precision for entity start span = 0.84164
# Epoch   3: Valid f1_score for entity end span = 0.78532
# Epoch   3: Valid Acurracy for entity end span = 0.78532
# Epoch   3: Valid Recall for entity end span = 0.78532
# Epoch   3: Valid Precision for entity end span = 0.78532
# The current f1 score for entity start: 0.8416432584269663
# The current f1 score for entity end: 0.7853230337078652
# Epoch   4: Train Loss = 12.81183
# Epoch   4: Valid Loss = 12.37870
# Epoch   4: Valid f1_score for entity start span = 0.86994
# Epoch   4: Valid Acurracy for entity start span = 0.86994
# Epoch   4: Valid Recall for entity start span = 0.86994
# Epoch   4: Valid Precision for entity start span = 0.86994
# Epoch   4: Valid f1_score for entity end span = 0.83399
# Epoch   4: Valid Acurracy for entity end span = 0.83399
# Epoch   4: Valid Recall for entity end span = 0.83399
# Epoch   4: Valid Precision for entity end span = 0.83399
# The current f1 score for entity start: 0.869943820224719
# The current f1 score for entity end: 0.8339887640449437
# Epoch   5: Train Loss = 12.76700
# Epoch   5: Valid Loss = 12.33331
# Epoch   5: Valid f1_score for entity start span = 0.89101
# Epoch   5: Valid Acurracy for entity start span = 0.89101
# Epoch   5: Valid Recall for entity start span = 0.89101
# Epoch   5: Valid Precision for entity start span = 0.89101
# Epoch   5: Valid f1_score for entity end span = 0.84059
# Epoch   5: Valid Acurracy for entity end span = 0.84059
# Epoch   5: Valid Recall for entity end span = 0.84059
# Epoch   5: Valid Precision for entity end span = 0.84059
# The current f1 score for entity start: 0.8910112359550562
# The current f1 score for entity end: 0.8405898876404494
# Epoch   6: Train Loss = 12.74019
# Epoch   6: Valid Loss = 12.26574
# Epoch   6: Valid f1_score for entity start span = 0.90028
# Epoch   6: Valid Acurracy for entity start span = 0.90028
# Epoch   6: Valid Recall for entity start span = 0.90028
# Epoch   6: Valid Precision for entity start span = 0.90028
# Epoch   6: Valid f1_score for entity end span = 0.88069
# Epoch   6: Valid Acurracy for entity end span = 0.88069
# Epoch   6: Valid Recall for entity end span = 0.88069
# Epoch   6: Valid Precision for entity end span = 0.88069
# The current f1 score for entity start: 0.9002808988764045
# The current f1 score for entity end: 0.8806882022471909
# Epoch   7: Train Loss = 12.72753
# Epoch   7: Valid Loss = 12.24495
# Epoch   7: Valid f1_score for entity start span = 0.90801
# Epoch   7: Valid Acurracy for entity start span = 0.90801
# Epoch   7: Valid Recall for entity start span = 0.90801
# Epoch   7: Valid Precision for entity start span = 0.90801
# Epoch   7: Valid f1_score for entity end span = 0.88553
# Epoch   7: Valid Acurracy for entity end span = 0.88553
# Epoch   7: Valid Recall for entity end span = 0.88553
# Epoch   7: Valid Precision for entity end span = 0.88553
# The current f1 score for entity start: 0.9080056179775281
# The current f1 score for entity end: 0.8855337078651685
# Epoch   8: Train Loss = 12.70800
# Epoch   8: Valid Loss = 12.23468
# Epoch   8: Valid f1_score for entity start span = 0.90836
# Epoch   8: Valid Acurracy for entity start span = 0.90836
# Epoch   8: Valid Recall for entity start span = 0.90836
# Epoch   8: Valid Precision for entity start span = 0.90836
# Epoch   8: Valid f1_score for entity end span = 0.89277
# Epoch   8: Valid Acurracy for entity end span = 0.89277
# Epoch   8: Valid Recall for entity end span = 0.89277
# Epoch   8: Valid Precision for entity end span = 0.89277
# The current f1 score for entity start: 0.9083567415730337
# The current f1 score for entity end: 0.8927668539325843
# Epoch   9: Train Loss = 12.69063
# Epoch   9: Valid Loss = 12.21494
# Epoch   9: Valid f1_score for entity start span = 0.91966
# Epoch   9: Valid Acurracy for entity start span = 0.91966
# Epoch   9: Valid Recall for entity start span = 0.91966
# Epoch   9: Valid Precision for entity start span = 0.91966
# Epoch   9: Valid f1_score for entity end span = 0.90414
# Epoch   9: Valid Acurracy for entity end span = 0.90414
# Epoch   9: Valid Recall for entity end span = 0.90414
# Epoch   9: Valid Precision for entity end span = 0.90414
# The current f1 score for entity start: 0.9196629213483145
# The current f1 score for entity end: 0.9041432584269663
# Epoch  10: Train Loss = 12.68330
# Epoch  10: Valid Loss = 12.19783
# Epoch  10: Valid f1_score for entity start span = 0.92240
# Epoch  10: Valid Acurracy for entity start span = 0.92240
# Epoch  10: Valid Recall for entity start span = 0.92240
# Epoch  10: Valid Precision for entity start span = 0.92240
# Epoch  10: Valid f1_score for entity end span = 0.90822
# Epoch  10: Valid Acurracy for entity end span = 0.90822
# Epoch  10: Valid Recall for entity end span = 0.90822
# Epoch  10: Valid Precision for entity end span = 0.90822
# The current f1 score for entity start: 0.9224016853932584
# The current f1 score for entity end: 0.9082162921348315
# Epoch  11: Train Loss = 12.67932
# Epoch  11: Valid Loss = 12.18874
# Epoch  11: Valid f1_score for entity start span = 0.92662
# Epoch  11: Valid Acurracy for entity start span = 0.92662
# Epoch  11: Valid Recall for entity start span = 0.92662
# Epoch  11: Valid Precision for entity start span = 0.92662
# Epoch  11: Valid f1_score for entity end span = 0.91187
# Epoch  11: Valid Acurracy for entity end span = 0.91187
# Epoch  11: Valid Recall for entity end span = 0.91187
# Epoch  11: Valid Precision for entity end span = 0.91187
# The current f1 score for entity start: 0.9266151685393258
# The current f1 score for entity end: 0.9118679775280899
# Epoch  12: Train Loss = 12.67927
# Epoch  12: Valid Loss = 12.18108
# Epoch  12: Valid f1_score for entity start span = 0.92521
# Epoch  12: Valid Acurracy for entity start span = 0.92521
# Epoch  12: Valid Recall for entity start span = 0.92521
# Epoch  12: Valid Precision for entity start span = 0.92521
# Epoch  12: Valid f1_score for entity end span = 0.91433
# Epoch  12: Valid Acurracy for entity end span = 0.91433
# Epoch  12: Valid Recall for entity end span = 0.91433
# Epoch  12: Valid Precision for entity end span = 0.91433
# Epoch  13: Train Loss = 12.66873
# Epoch  13: Valid Loss = 12.17672
# Epoch  13: Valid f1_score for entity start span = 0.92486
# Epoch  13: Valid Acurracy for entity start span = 0.92486
# Epoch  13: Valid Recall for entity start span = 0.92486
# Epoch  13: Valid Precision for entity start span = 0.92486
# Epoch  13: Valid f1_score for entity end span = 0.91362
# Epoch  13: Valid Acurracy for entity end span = 0.91362
# Epoch  13: Valid Recall for entity end span = 0.91362
# Epoch  13: Valid Precision for entity end span = 0.91362
# trigger times: 1
# Epoch  14: Train Loss = 12.66371
# Epoch  14: Valid Loss = 12.16943
# Epoch  14: Valid f1_score for entity start span = 0.93048
# Epoch  14: Valid Acurracy for entity start span = 0.93048
# Epoch  14: Valid Recall for entity start span = 0.93048
# Epoch  14: Valid Precision for entity start span = 0.93048
# Epoch  14: Valid f1_score for entity end span = 0.91643
# Epoch  14: Valid Acurracy for entity end span = 0.91643
# Epoch  14: Valid Recall for entity end span = 0.91643
# Epoch  14: Valid Precision for entity end span = 0.91643
# The current f1 score for entity start: 0.9304775280898876
# The current f1 score for entity end: 0.9164325842696629
# Epoch  15: Train Loss = 12.66760
# Epoch  15: Valid Loss = 12.17032
# Epoch  15: Valid f1_score for entity start span = 0.93048
# Epoch  15: Valid Acurracy for entity start span = 0.93048
# Epoch  15: Valid Recall for entity start span = 0.93048
# Epoch  15: Valid Precision for entity start span = 0.93048
# Epoch  15: Valid f1_score for entity end span = 0.91608
# Epoch  15: Valid Acurracy for entity end span = 0.91608
# Epoch  15: Valid Recall for entity end span = 0.91608
# Epoch  15: Valid Precision for entity end span = 0.91608
# Epoch  16: Train Loss = 12.66693
# Epoch  16: Valid Loss = 12.16948
# Epoch  16: Valid f1_score for entity start span = 0.92802
# Epoch  16: Valid Acurracy for entity start span = 0.92802
# Epoch  16: Valid Recall for entity start span = 0.92802
# Epoch  16: Valid Precision for entity start span = 0.92802
# Epoch  16: Valid f1_score for entity end span = 0.91945
# Epoch  16: Valid Acurracy for entity end span = 0.91945
# Epoch  16: Valid Recall for entity end span = 0.91945
# Epoch  16: Valid Precision for entity end span = 0.91945
# Epoch  17: Train Loss = 12.65589
# Epoch  17: Valid Loss = 12.16188
# Epoch  17: Valid f1_score for entity start span = 0.92907
# Epoch  17: Valid Acurracy for entity start span = 0.92907
# Epoch  17: Valid Recall for entity start span = 0.92907
# Epoch  17: Valid Precision for entity start span = 0.92907
# Epoch  17: Valid f1_score for entity end span = 0.92416
# Epoch  17: Valid Acurracy for entity end span = 0.92416
# Epoch  17: Valid Recall for entity end span = 0.92416
# Epoch  17: Valid Precision for entity end span = 0.92416
# Epoch  18: Train Loss = 12.65763
# Epoch  18: Valid Loss = 12.15902
# Epoch  18: Valid f1_score for entity start span = 0.93153
# Epoch  18: Valid Acurracy for entity start span = 0.93153
# Epoch  18: Valid Recall for entity start span = 0.93153
# Epoch  18: Valid Precision for entity start span = 0.93153
# Epoch  18: Valid f1_score for entity end span = 0.92521
# Epoch  18: Valid Acurracy for entity end span = 0.92521
# Epoch  18: Valid Recall for entity end span = 0.92521
# Epoch  18: Valid Precision for entity end span = 0.92521
# The current f1 score for entity start: 0.9315308988764045
# The current f1 score for entity end: 0.9252106741573034
# Epoch  19: Train Loss = 12.67400
# Epoch  19: Valid Loss = 12.15890
# Epoch  19: Valid f1_score for entity start span = 0.93153
# Epoch  19: Valid Acurracy for entity start span = 0.93153
# Epoch  19: Valid Recall for entity start span = 0.93153
# Epoch  19: Valid Precision for entity start span = 0.93153
# Epoch  19: Valid f1_score for entity end span = 0.92521
# Epoch  19: Valid Acurracy for entity end span = 0.92521
# Epoch  19: Valid Recall for entity end span = 0.92521
# Epoch  19: Valid Precision for entity end span = 0.92521
# The current f1 score for entity start: 0.9315308988764045
# The current f1 score for entity end: 0.9252106741573034
# 0.9315308988764045 0.9252106741573034
# The best parameters are saved for the activation function: ELU

# %%
list_entity_loss_train_softplus_span_encoded, list_entity_loss_valid_softplus_span_encoded, list_epochs_softplus_span_encoded = get_entity_results("Softplus", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_span_encoded_bert_dataset, valid_span_encoded_bert_dataset, train_dataloader_span_encoded, val_dataloader_span_encoded, SEED)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): Softplus(beta=1, threshold=20)
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Softplus(beta=1, threshold=20)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Softplus(beta=1, threshold=20)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.65060
# Epoch   0: Valid Loss = 13.35919
# Epoch   0: Valid f1_score for entity start span = 0.43694
# Epoch   0: Valid Acurracy for entity start span = 0.43694
# Epoch   0: Valid Recall for entity start span = 0.43694
# Epoch   0: Valid Precision for entity start span = 0.43694
# Epoch   0: Valid f1_score for entity end span = 0.30983
# Epoch   0: Valid Acurracy for entity end span = 0.30983
# Epoch   0: Valid Recall for entity end span = 0.30983
# Epoch   0: Valid Precision for entity end span = 0.30983
# The current f1 score for entity start: 0.43693820224719104
# The current f1 score for entity end: 0.3098314606741573
# Epoch   1: Train Loss = 13.24333
# Epoch   1: Valid Loss = 12.96175
# Epoch   1: Valid f1_score for entity start span = 0.69459
# Epoch   1: Valid Acurracy for entity start span = 0.69459
# Epoch   1: Valid Recall for entity start span = 0.69459
# Epoch   1: Valid Precision for entity start span = 0.69459
# Epoch   1: Valid f1_score for entity end span = 0.51433
# Epoch   1: Valid Acurracy for entity end span = 0.51433
# Epoch   1: Valid Recall for entity end span = 0.51433
# Epoch   1: Valid Precision for entity end span = 0.51433
# The current f1 score for entity start: 0.6945926966292135
# The current f1 score for entity end: 0.5143258426966292
# Epoch   2: Train Loss = 12.99140
# Epoch   2: Valid Loss = 12.62214
# Epoch   2: Valid f1_score for entity start span = 0.82374
# Epoch   2: Valid Acurracy for entity start span = 0.82374
# Epoch   2: Valid Recall for entity start span = 0.82374
# Epoch   2: Valid Precision for entity start span = 0.82374
# Epoch   2: Valid f1_score for entity end span = 0.67577
# Epoch   2: Valid Acurracy for entity end span = 0.67577
# Epoch   2: Valid Recall for entity end span = 0.67577
# Epoch   2: Valid Precision for entity end span = 0.67577
# The current f1 score for entity start: 0.8237359550561798
# The current f1 score for entity end: 0.6757724719101124
# Epoch   3: Train Loss = 12.87442
# Epoch   3: Valid Loss = 12.50078
# Epoch   3: Valid f1_score for entity start span = 0.83287
# Epoch   3: Valid Acurracy for entity start span = 0.83287
# Epoch   3: Valid Recall for entity start span = 0.83287
# Epoch   3: Valid Precision for entity start span = 0.83287
# Epoch   3: Valid f1_score for entity end span = 0.74529
# Epoch   3: Valid Acurracy for entity end span = 0.74529
# Epoch   3: Valid Recall for entity end span = 0.74529
# Epoch   3: Valid Precision for entity end span = 0.74529
# The current f1 score for entity start: 0.8328651685393258
# The current f1 score for entity end: 0.7452949438202247
# Epoch   4: Train Loss = 12.82934
# Epoch   4: Valid Loss = 12.40112
# Epoch   4: Valid f1_score for entity start span = 0.86573
# Epoch   4: Valid Acurracy for entity start span = 0.86573
# Epoch   4: Valid Recall for entity start span = 0.86573
# Epoch   4: Valid Precision for entity start span = 0.86573
# Epoch   4: Valid f1_score for entity end span = 0.83062
# Epoch   4: Valid Acurracy for entity end span = 0.83062
# Epoch   4: Valid Recall for entity end span = 0.83062
# Epoch   4: Valid Precision for entity end span = 0.83062
# The current f1 score for entity start: 0.8657303370786517
# The current f1 score for entity end: 0.8306179775280899
# Epoch   5: Train Loss = 12.77944
# Epoch   5: Valid Loss = 12.34709
# Epoch   5: Valid f1_score for entity start span = 0.87029
# Epoch   5: Valid Acurracy for entity start span = 0.87029
# Epoch   5: Valid Recall for entity start span = 0.87029
# Epoch   5: Valid Precision for entity start span = 0.87029
# Epoch   5: Valid f1_score for entity end span = 0.85449
# Epoch   5: Valid Acurracy for entity end span = 0.85449
# Epoch   5: Valid Recall for entity end span = 0.85449
# Epoch   5: Valid Precision for entity end span = 0.85449
# The current f1 score for entity start: 0.8702949438202247
# The current f1 score for entity end: 0.8544943820224719
# Epoch   6: Train Loss = 12.75478
# Epoch   6: Valid Loss = 12.30800
# Epoch   6: Valid f1_score for entity start span = 0.89010
# Epoch   6: Valid Acurracy for entity start span = 0.89010
# Epoch   6: Valid Recall for entity start span = 0.89010
# Epoch   6: Valid Precision for entity start span = 0.89010
# Epoch   6: Valid f1_score for entity end span = 0.86770
# Epoch   6: Valid Acurracy for entity end span = 0.86770
# Epoch   6: Valid Recall for entity end span = 0.86770
# Epoch   6: Valid Precision for entity end span = 0.86770
# The current f1 score for entity start: 0.8900983146067416
# The current f1 score for entity end: 0.8676966292134831
# Epoch   7: Train Loss = 12.74474
# Epoch   7: Valid Loss = 12.27287
# Epoch   7: Valid f1_score for entity start span = 0.89642
# Epoch   7: Valid Acurracy for entity start span = 0.89642
# Epoch   7: Valid Recall for entity start span = 0.89642
# Epoch   7: Valid Precision for entity start span = 0.89642
# Epoch   7: Valid f1_score for entity end span = 0.88202
# Epoch   7: Valid Acurracy for entity end span = 0.88202
# Epoch   7: Valid Recall for entity end span = 0.88202
# Epoch   7: Valid Precision for entity end span = 0.88202
# The current f1 score for entity start: 0.8964185393258427
# The current f1 score for entity end: 0.8820224719101124
# Epoch   8: Train Loss = 12.71548
# Epoch   8: Valid Loss = 12.25247
# Epoch   8: Valid f1_score for entity start span = 0.90976
# Epoch   8: Valid Acurracy for entity start span = 0.90976
# Epoch   8: Valid Recall for entity start span = 0.90976
# Epoch   8: Valid Precision for entity start span = 0.90976
# Epoch   8: Valid f1_score for entity end span = 0.88504
# Epoch   8: Valid Acurracy for entity end span = 0.88504
# Epoch   8: Valid Recall for entity end span = 0.88504
# Epoch   8: Valid Precision for entity end span = 0.88504
# The current f1 score for entity start: 0.9097612359550562
# The current f1 score for entity end: 0.8850421348314607
# Epoch   9: Train Loss = 12.70487
# Epoch   9: Valid Loss = 12.23891
# Epoch   9: Valid f1_score for entity start span = 0.91348
# Epoch   9: Valid Acurracy for entity start span = 0.91348
# Epoch   9: Valid Recall for entity start span = 0.91348
# Epoch   9: Valid Precision for entity start span = 0.91348
# Epoch   9: Valid f1_score for entity end span = 0.88680
# Epoch   9: Valid Acurracy for entity end span = 0.88680
# Epoch   9: Valid Recall for entity end span = 0.88680
# Epoch   9: Valid Precision for entity end span = 0.88680
# The current f1 score for entity start: 0.9134831460674157
# The current f1 score for entity end: 0.8867977528089888
# Epoch  10: Train Loss = 12.69793
# Epoch  10: Valid Loss = 12.22297
# Epoch  10: Valid f1_score for entity start span = 0.92170
# Epoch  10: Valid Acurracy for entity start span = 0.92170
# Epoch  10: Valid Recall for entity start span = 0.92170
# Epoch  10: Valid Precision for entity start span = 0.92170
# Epoch  10: Valid f1_score for entity end span = 0.88926
# Epoch  10: Valid Acurracy for entity end span = 0.88926
# Epoch  10: Valid Recall for entity end span = 0.88926
# Epoch  10: Valid Precision for entity end span = 0.88926
# The current f1 score for entity start: 0.9216994382022472
# The current f1 score for entity end: 0.8892556179775281
# Epoch  11: Train Loss = 12.69127
# Epoch  11: Valid Loss = 12.21244
# Epoch  11: Valid f1_score for entity start span = 0.91699
# Epoch  11: Valid Acurracy for entity start span = 0.91699
# Epoch  11: Valid Recall for entity start span = 0.91699
# Epoch  11: Valid Precision for entity start span = 0.91699
# Epoch  11: Valid f1_score for entity end span = 0.90660
# Epoch  11: Valid Acurracy for entity end span = 0.90660
# Epoch  11: Valid Recall for entity end span = 0.90660
# Epoch  11: Valid Precision for entity end span = 0.90660
# Epoch  12: Train Loss = 12.68599
# Epoch  12: Valid Loss = 12.19736
# Epoch  12: Valid f1_score for entity start span = 0.92381
# Epoch  12: Valid Acurracy for entity start span = 0.92381
# Epoch  12: Valid Recall for entity start span = 0.92381
# Epoch  12: Valid Precision for entity start span = 0.92381
# Epoch  12: Valid f1_score for entity end span = 0.91292
# Epoch  12: Valid Acurracy for entity end span = 0.91292
# Epoch  12: Valid Recall for entity end span = 0.91292
# Epoch  12: Valid Precision for entity end span = 0.91292
# The current f1 score for entity start: 0.9238061797752809
# The current f1 score for entity end: 0.9129213483146067
# Epoch  13: Train Loss = 12.67357
# Epoch  13: Valid Loss = 12.18516
# Epoch  13: Valid f1_score for entity start span = 0.92907
# Epoch  13: Valid Acurracy for entity start span = 0.92907
# Epoch  13: Valid Recall for entity start span = 0.92907
# Epoch  13: Valid Precision for entity start span = 0.92907
# Epoch  13: Valid f1_score for entity end span = 0.91187
# Epoch  13: Valid Acurracy for entity end span = 0.91187
# Epoch  13: Valid Recall for entity end span = 0.91187
# Epoch  13: Valid Precision for entity end span = 0.91187
# Epoch  14: Train Loss = 12.66793
# Epoch  14: Valid Loss = 12.17798
# Epoch  14: Valid f1_score for entity start span = 0.93294
# Epoch  14: Valid Acurracy for entity start span = 0.93294
# Epoch  14: Valid Recall for entity start span = 0.93294
# Epoch  14: Valid Precision for entity start span = 0.93294
# Epoch  14: Valid f1_score for entity end span = 0.91503
# Epoch  14: Valid Acurracy for entity end span = 0.91503
# Epoch  14: Valid Recall for entity end span = 0.91503
# Epoch  14: Valid Precision for entity end span = 0.91503
# The current f1 score for entity start: 0.932935393258427
# The current f1 score for entity end: 0.9150280898876404
# Epoch  15: Train Loss = 12.67032
# Epoch  15: Valid Loss = 12.18295
# Epoch  15: Valid f1_score for entity start span = 0.92978
# Epoch  15: Valid Acurracy for entity start span = 0.92978
# Epoch  15: Valid Recall for entity start span = 0.92978
# Epoch  15: Valid Precision for entity start span = 0.92978
# Epoch  15: Valid f1_score for entity end span = 0.91067
# Epoch  15: Valid Acurracy for entity end span = 0.91067
# Epoch  15: Valid Recall for entity end span = 0.91067
# Epoch  15: Valid Precision for entity end span = 0.91067
# trigger times: 1
# Epoch  16: Train Loss = 12.67113
# Epoch  16: Valid Loss = 12.18092
# Epoch  16: Valid f1_score for entity start span = 0.92907
# Epoch  16: Valid Acurracy for entity start span = 0.92907
# Epoch  16: Valid Recall for entity start span = 0.92907
# Epoch  16: Valid Precision for entity start span = 0.92907
# Epoch  16: Valid f1_score for entity end span = 0.91138
# Epoch  16: Valid Acurracy for entity end span = 0.91138
# Epoch  16: Valid Recall for entity end span = 0.91138
# Epoch  16: Valid Precision for entity end span = 0.91138
# Epoch  17: Train Loss = 12.66045
# Epoch  17: Valid Loss = 12.17476
# Epoch  17: Valid f1_score for entity start span = 0.93118
# Epoch  17: Valid Acurracy for entity start span = 0.93118
# Epoch  17: Valid Recall for entity start span = 0.93118
# Epoch  17: Valid Precision for entity start span = 0.93118
# Epoch  17: Valid f1_score for entity end span = 0.91819
# Epoch  17: Valid Acurracy for entity end span = 0.91819
# Epoch  17: Valid Recall for entity end span = 0.91819
# Epoch  17: Valid Precision for entity end span = 0.91819
# Epoch  18: Train Loss = 12.66084
# Epoch  18: Valid Loss = 12.17197
# Epoch  18: Valid f1_score for entity start span = 0.93048
# Epoch  18: Valid Acurracy for entity start span = 0.93048
# Epoch  18: Valid Recall for entity start span = 0.93048
# Epoch  18: Valid Precision for entity start span = 0.93048
# Epoch  18: Valid f1_score for entity end span = 0.92205
# Epoch  18: Valid Acurracy for entity end span = 0.92205
# Epoch  18: Valid Recall for entity end span = 0.92205
# Epoch  18: Valid Precision for entity end span = 0.92205
# Epoch  19: Train Loss = 12.67776
# Epoch  19: Valid Loss = 12.17026
# Epoch  19: Valid f1_score for entity start span = 0.93223
# Epoch  19: Valid Acurracy for entity start span = 0.93223
# Epoch  19: Valid Recall for entity start span = 0.93223
# Epoch  19: Valid Precision for entity start span = 0.93223
# Epoch  19: Valid f1_score for entity end span = 0.92240
# Epoch  19: Valid Acurracy for entity end span = 0.92240
# Epoch  19: Valid Recall for entity end span = 0.92240
# Epoch  19: Valid Precision for entity end span = 0.92240
# 0.932935393258427 0.9150280898876404
# The best parameters are saved for the activation function: Softplus

# %%
list_entity_training_losses.append(list_entity_loss_train_leakyrelu_span_encoded)
list_entity_validation_losses.append(list_entity_loss_valid_leakyrelu_span_encoded)
list_entity_span_encoded_epochs.append(list_epochs_leakyrelu_span_encoded)
list_entity_training_losses.append(list_entity_loss_train_tahnshrink_span_encoded)
list_entity_validation_losses.append(list_entity_loss_valid_tahnshrink_span_encoded)
list_entity_span_encoded_epochs.append(list_epochs_tanhshrink_span_encoded)
list_entity_training_losses.append(list_entity_loss_train_softplus_span_encoded)
list_entity_validation_losses.append(list_entity_loss_valid_softplus_span_encoded)
list_entity_span_encoded_epochs.append(list_epochs_softplus_span_encoded)
list_entity_training_losses.append(list_entity_loss_train_elu_span_encoded)
list_entity_validation_losses.append(list_entity_loss_valid_elu_span_encoded)
list_entity_span_encoded_epochs.append(list_epochs_elu_span_encoded)

# %%
plot_losses(list_entity_span_encoded_epochs, list_entity_training_losses, list_entity_validation_losses, activations, learning_rate, dropout_prob)
