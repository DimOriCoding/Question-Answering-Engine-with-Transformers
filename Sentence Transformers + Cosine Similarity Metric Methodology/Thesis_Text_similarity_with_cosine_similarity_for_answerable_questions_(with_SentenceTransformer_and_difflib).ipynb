# %% [markdown]
# **I import some useful libraries in python.**

# %%
import difflib
import operator as op
import random
import numpy as np
import pandas as pd
import torch
import torch.backends.cudnn
from numpy.random import MT19937
from numpy.random import RandomState, SeedSequence
from torch.optim import Adam
from transformers import get_linear_schedule_with_warmup
import os
from google.colab import drive
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt
import torch.nn as nn
from transformers import BertModel
from transformers import BertTokenizerFast

# %% [markdown]
# **I mount google drive because all the files (for example .csv) that i used for the implementation of my thesis are saved on my google drive.**

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Check of the device that it is used for the implementation of the notebooks of this thesis, that is determined from google colab.**

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Device available for running: ")
print(device)
# Out:
# Device available for running:
# cuda

# %% [markdown]
# **Reading of the created datasets (for both the SimpleQuestions dataset that includes all training and validation questions and the SimpleQuestions subset that includes only answerable over wikidata questions) as .csv file.**

# %%
train_dataset = pd.read_csv("drive/MyDrive/train_answerable_questions_dataset.csv", sep = ',')
validation_dataset = pd.read_csv("drive/MyDrive/valid_answerable_questions_dataset.csv", sep = ',')
print(train_dataset)
print(validation_dataset)
# Out:
#        entity_id      entity_label relation_id  \
# 0         Q12439           Detroit         R19
# 1       Q6817891       Mera Shikar        P364
# 2          Q1297           Chicago        R276
# 3        Q193592        midfielder        R413
# 4       Q6849115     Mike Twellman        P413
# ...          ...               ...         ...
# 19476    Q223960    mountain tapir        P171
# 19477   Q1535153    superhero film        R136
# 19478    Q157443       comedy film        R136
# 19479  Q16093542    Anthony Bailey         P27
# 19480    Q926822  Gaston Filgueira         P21
#
#                                                 Question
# 0                      who is a musician born in detroit
# 1      what is the language in which mera shikar was ...
# 2      Whats the name of a battle that happened in ch...
# 3              what player plays the position midfielder
# 4         what is the position that  mike twellman plays
# ...                                                  ...
# 19476  what classification does  mountain tapir come ...
# 19477   What a superhero movie that premiered on toonami
# 19478  What is the name of a comedy film that is also...
# 19479          What is the nationality of anthony bailey
# 19480                    What gender is gaston filgueira
#
# [19481 rows x 4 columns]
#      entity_id            entity_label relation_id  \
# 0      Q318926           Sasha Vujacic         P19
# 1     Q2568216       Wiebke Carolsfeld         R57
# 2     Q2275923  Seymour Parker Gilbert        P106
# 3     Q2856873        Antoine de Fevin         P20
# 4      Q522966           Jamie Hewlett        P106
# ...        ...                     ...         ...
# 2816  Q7111404             OutNumbered        P178
# 2817  Q3480757          Seumas O'Kelly         P21
# 2818  Q3709870          Herby Fortunat        P413
# 2819  Q2981169       Nikolaj Frobenius        P106
# 2820      Q174               Sao Paulo         R19
#
#                                                Question
# 0                          where was sasha vujacic born
# 1          What is a film directed by wiebke carolsfeld
# 2            What was Seymour Parker Gilbert profession
# 3         in what french city did antoine de fevin die
# 4                      What job does jamie hewlett have
# ...                                                 ...
# 2816                          who developed outnumbered
# 2817                  what is the sex of seumas o'kelly
# 2818  which position did herby fortunat play in foot...
# 2819               What is nikolaj frobenius profession
# 2820         who is a person that was born in sao paulo
#
# [2821 rows x 4 columns]

# %% [markdown]
# **Check if  the SimpleQuestions training and validation dataset have at least one line with null value. This issues both for SimpleQuestions dataset that includes only answerable over wikidata questions and for the corresponding dataset that includes all the questions.**

# %%
train_dataset.dropna(inplace = True)
validation_dataset.dropna(inplace = True)
print(train_dataset)
print(validation_dataset)
# Out:
#        entity_id      entity_label relation_id  \
# 0         Q12439           Detroit         R19
# 1       Q6817891       Mera Shikar        P364
# 2          Q1297           Chicago        R276
# 3        Q193592        midfielder        R413
# 4       Q6849115     Mike Twellman        P413
# ...          ...               ...         ...
# 19476    Q223960    mountain tapir        P171
# 19477   Q1535153    superhero film        R136
# 19478    Q157443       comedy film        R136
# 19479  Q16093542    Anthony Bailey         P27
# 19480    Q926822  Gaston Filgueira         P21
#
#                                                 Question
# 0                      who is a musician born in detroit
# 1      what is the language in which mera shikar was ...
# 2      Whats the name of a battle that happened in ch...
# 3              what player plays the position midfielder
# 4         what is the position that  mike twellman plays
# ...                                                  ...
# 19476  what classification does  mountain tapir come ...
# 19477   What a superhero movie that premiered on toonami
# 19478  What is the name of a comedy film that is also...
# 19479          What is the nationality of anthony bailey
# 19480                    What gender is gaston filgueira
#
# [19481 rows x 4 columns]
#      entity_id            entity_label relation_id  \
# 0      Q318926           Sasha Vujacic         P19
# 1     Q2568216       Wiebke Carolsfeld         R57
# 2     Q2275923  Seymour Parker Gilbert        P106
# 3     Q2856873        Antoine de Fevin         P20
# 4      Q522966           Jamie Hewlett        P106
# ...        ...                     ...         ...
# 2816  Q7111404             OutNumbered        P178
# 2817  Q3480757          Seumas O'Kelly         P21
# 2818  Q3709870          Herby Fortunat        P413
# 2819  Q2981169       Nikolaj Frobenius        P106
# 2820      Q174               Sao Paulo         R19
#
#                                                Question
# 0                          where was sasha vujacic born
# 1          What is a film directed by wiebke carolsfeld
# 2            What was Seymour Parker Gilbert profession
# 3         in what french city did antoine de fevin die
# 4                      What job does jamie hewlett have
# ...                                                 ...
# 2816                          who developed outnumbered
# 2817                  what is the sex of seumas o'kelly
# 2818  which position did herby fortunat play in foot...
# 2819               What is nikolaj frobenius profession
# 2820         who is a person that was born in sao paulo
#
# [2821 rows x 4 columns]

# %% [markdown]
# **Creation of the corresponding lists containing the questions, the entity labels, the relation ids and the entity ids of the corresponding SimpleQuestions datasets (training, validation), either this dataset includes answerable and answerable questions over wikidata questions or only answerable questions over wikidata.**

# %%
train_entity_labels = train_dataset['entity_label'].to_list()
validation_entity_labels = validation_dataset['entity_label'].to_list()
train_entityids = train_dataset['entity_id'].to_list()
validation_entityids = validation_dataset['entity_id'].to_list()
train_questions = train_dataset['Question'].to_list()
validation_questions = validation_dataset['Question'].to_list()
train_relationids = train_dataset['relation_id'].to_list()
validation_relationids = validation_dataset['relation_id'].to_list()
print(len(train_entity_labels), len(train_entityids), len(train_relationids), len(train_questions))
# Out:
# 19481 19481 19481 19481

# %% [markdown]
# **Installation of the library of Sentence Transformers and loading of their models.**

# %%
# !pip install sentence-transformers
from sentence_transformers import SentenceTransformer, util
similarity_model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.6.1-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.3/163.3 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.38.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.13.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.11.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.4.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, sentence-transformers
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 sentence-transformers-2.6.1
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# **The maximum question length that is observed in SimpleQuestions training and validation dataset is found below.**

# %%
#Below the max questions length is found for all questions.
quests = train_questions + validation_questions
print(len(quests), len(train_questions), len(validation_questions))
# Printing concatenated list
q_lengths = []
for s in range(len(quests)): #padding
    q_lengths.append(len(quests[s].split()))
max_question_length = max(q_lengths)
print(max_question_length)#Max question length
# Out:
# 22302 19481 2821
# 33

# %% [markdown]
# **Creation of the relation vocabulary that includes all the unique entity ids of the SimpleQuestions training and validation dataset through function relation_vocabulary. Also the index of each unique relation id of the relation vocabulary in this vocabulary is found through the function find_relations_index.**

# %%
#Create relation vocabulary for each question of train and validation dataset
def relation_vocabulary(relation_column_dataset):
  relation_vocabulary = []
   #In order to have the unique relation ids it is important to check if an relation id is already in the relation_vocabulary
  for relation in range(len(relation_column_dataset)):
    g = 0
    for i in range(len(relation_vocabulary)):
      if relation_column_dataset[relation] != relation_vocabulary[i]: #relation is not found yet
        g += 1
      else:
       continue
    if g == len(relation_vocabulary) and relation_column_dataset[relation] not in relation_vocabulary:
      relation_vocabulary.append(relation_column_dataset[relation]) #The relation id is not inside the relation vocabulary
      #which has some relations already or the relation vocaulary has no relations
  return relation_vocabulary

def find_relation_index(relation_vocabulary,relation_ids_column):
  relations_count = []
  for relation in range(len(relation_ids_column)):
        relations_count.append(relation_vocabulary.index(relation_ids_column[relation]))

  return relations_count
#relation_ids = pd.concat([train_dataset["relation_id"], validation_dataset["relation_id"]], ignore_index = True)
relation_ids = train_relationids + validation_relationids
print(len(relation_ids))
rel_vocab = relation_vocabulary(relation_ids)
rel_vocab_length = len(rel_vocab)
print(rel_vocab, rel_vocab_length)
train_relations_index = find_relation_index(rel_vocab, train_relationids)
validation_relations_index = find_relation_index(rel_vocab, validation_relationids)
# Out:
# 22302
# ['R19', 'P364', 'R276', 'R413', 'P413', 'R136', 'P27', 'P21', 'R106', 'P196', 'P175', 'R175', 'R50', 'P344', 'P136', 'P641', 'P19', 'P421', 'R57', 'P170', 'R17', 'P86', 'R58', 'R86', 'P1142', 'P58', 'P131', 'P495', 'P150', 'R131', 'P119', 'R1303', 'P50', 'R40', 'P61', 'R172', 'P264', 'P57', 'P179', 'P509', 'R509', 'P20', 'P138', 'P397', 'R344', 'P106', 'P272', 'P403', 'P31', 'P607', 'P407', 'P140', 'R162', 'R641', 'R404', 'P172', 'R178', 'R421', 'P123', 'P59', 'P40', 'P276', 'P178', 'R272', 'P737', 'R179', 'P398', 'P17', 'P1303', 'P144', 'P112', 'R170', 'R105', 'R59', 'P113', 'R607', 'P155', 'P162', 'R149', 'P404', 'R1040', 'R177', 'P710', 'P1408', 'R119', 'R21', 'R112', 'R138', 'P676', 'R123', 'P149', 'R264', 'P65', 'P177', 'R144', 'P53', 'R31', 'R287', 'P115', 'P105', 'P1040', 'P156', 'P289', 'R171', 'P1029', 'R115', 'P171', 'R1431', 'P1431', 'P376', 'R676', 'R1142', 'P84', 'R376', 'P826', 'R161', 'P287', 'P81', 'P800', 'P279', 'R176', 'R289', 'P189', 'P176', 'R279'] 125

# %% [markdown]
# **The function create\_question\_parts, takes as arguments the splitted question splitted into words and the entity label also splitted into words.
# Essentially in this function each question, as well as the corresponding entity label, is splitted into words using python method split() and then, using python method join(), parts of the query are created equal in length to that of their splitted entity label in words.**
#
# **These parts are stored in a list as well as the indexes of the initial word and final word of these question parts are stored in dictionaries with keys the question parts and values the indexes(positions) of the initial words and final words for each question. Finally this function returns the list of question parts and dictionaries containing the indexes(positions) of the initial words and final words for each question part.**

# %%
def create_question_parts(question_splitted, entity_splited_length):
  Quests_Parts = []
  Quest_Parts_Start = {}
  Quest_Parts_End = {}
  for i in range(len(question_splitted)-entity_splited_length+1):
    quest_part = " ".join(question_splitted[i:i+entity_splited_length])
    Quests_Parts.append(quest_part)
    Quest_Parts_Start[quest_part] = i
    Quest_Parts_End[quest_part] = i+entity_splited_length-1
  return Quests_Parts, Quest_Parts_Start, Quest_Parts_End

# %% [markdown]
# **Custom function for the cosine similarity metric between two encodings.**

# %%
def cosine_similarity(encoding1, encoding2):
  return np.dot(encoding1, encoding2) / (np.linalg.norm(encoding1) * np.linalg.norm(encoding2)) if np.linalg.norm(encoding1) * np.linalg.norm(encoding2) != 0 else 0

# %% [markdown]
# **The function through which the embeddings are created via Sentence Transformer and uses the cosine similarity function is the function best_match_with_cosine_similarity, which takes as arguments the entity label, the list of query segments, the dictionaries containing the indexes(positions) of the start words and end words for each question part mentioned above, as well as the similarity model of Sentence Transformer and returns the question part that has the highest similarity and the position of the initial and final word of that question part, otherwise if there is no such question part it returns None as the question part and as the index and for the initial and final word of the entity label the value -1.**

# %%
# Finds best match based on their similarity
def best_match_with_cosine_similarity(entity, question_parts, Start_Indexes, End_Indexes, similarity_model):
           similarity_scores = {}
           entity_vector = similarity_model.encode(entity)
           for q in range(len(question_parts)):
    # Find similarity scores between entity and each question part in question
            quest = similarity_model.encode(question_parts[q])
            similarity_scores[question_parts[q]] = cosine_similarity(entity_vector, quest)
    # Return the highest similarity score from all question parts as a list
           if similarity_scores == {}:
            return None, -1, -1
           Q = dict(sorted(similarity_scores.items(), key = lambda x: x[1], reverse = True))
           EntitiesList = [key for key in Q]
           return EntitiesList[0], Start_Indexes[EntitiesList[0]], End_Indexes[EntitiesList[0]]

# %% [markdown]
# **The entity_span function where the entity span start and entity span end indexes are found for each question, takes as arguments the list of all questions of SimpleQuestions training or validation dataset, the list of all entity labels of SimpleQuestions training or validation dataset in question and the similarity model of Sentence Transformer.**
#
# **This function calls the functions create_question_parts and best_match_with_cosine_similarity in order to create the parts of each question and find the question part that is equal to the entity label of the question with its start word index and end word index and returns the list of indexes (positions) of the initial words of the entity labels within the query (entity span start indexes) and the list of indexes (positions) of the final words of the entity labels within the query (entity span end indexes).**
#
# **Finally for the questions where no question part identical or similar to the corresponding entity label has been found, the positions (indices) of the penultimate (question length-2) and the last word (question length-1) are set as entity start index and entity end index respectively.**

# %%
def entity_span(question_column, entity_label_column, similarity_model):
  entity_start_column = []
  entity_end_column = []
  #Count for how many questions there is no question part that is equal or similar(finding with difflib.get_close_matches() or SentenceTransformer)
  #to the corresponding entity label.
  count_entity_with_no_similarity = 0
  for q in range(len(question_column)):
    # Find the word that performs the biggest similarity
      quest = question_column[q].lower().split()
      entity_label = entity_label_column[q].lower()
      ent_label = entity_label.split()
      entity_label_splitted_length = len(ent_label)
      Quests_Parts, Quest_Parts_Start, Quest_Parts_End = create_question_parts(quest, entity_label_splitted_length)
      Entity = difflib.get_close_matches(entity_label, Quests_Parts, 1)
      if (Entity != []):
        # Beginning and end of span
        Entity_start_index = Quest_Parts_Start[Entity[0]]
        Entity_end_index = Quest_Parts_End[Entity[0]]
        entity_start_column.append(Entity_start_index)
        entity_end_column.append(Entity_end_index)
      else:
        Entity, Entity_start_index, Entity_end_index = best_match_with_cosine_similarity(entity_label, Quests_Parts, Quest_Parts_Start, Quest_Parts_End, similarity_model)
        if Entity is None:
        # Beginning and end of span
         entity_start_column.append(len(quest)-2)
         entity_end_column.append(len(quest)-1)
         count_entity_with_no_similarity += 1
        else:
         entity_start_column.append(Entity_start_index)
         entity_end_column.append(Entity_end_index)
  print(count_entity_with_no_similarity)
  return entity_start_column, entity_end_column

# %%
train_entity_span_start, train_entity_span_end = entity_span(train_questions, train_entity_labels, similarity_model)
# Out:
# 10

# %%
validation_entity_span_start, validation_entity_span_end = entity_span(validation_questions, validation_entity_labels, similarity_model)
# Out:
# 2

# %% [markdown]
# **Loading of the Transformers BERT tokenizer BertTokenizerFast.**

# %%
tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased')
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %% [markdown]
# **Creation of a custom dataset for the SimpleQuestions dataset (either for the dataset with only answerable over wikidata questions or for the corresponding dataset including answerable and non-answerable over wikidata questions) through a python class, where its questions are encoded through BertTokenizerFast method encode\_plus(). This custom dataset includes the entity span indexes (start, end), the relation indexes, the questions, the ids and the attention mask occurred from encoding of questions.**
#
# **Also since the span start and end correspond to actual words, but here I use the fast version of BERT tokenizer BertTokenizerFast, i need to locate the corresponding start and end tokens in the BERT tokenized question for each entity.**
#
# **Also in order to create this custom dataset i used the lists of questions, relation, entity span start, entity span end indexes, the maximum question length of all SimpleQuestions training and validation dataset questions.**

# %%
g = torch.Generator()
print(g.device)
# Out:
# cpu

# %%
class BertQuestionAnsweringDataset:
  def __init__(self, questions, tokenizer, entity_starts, entity_ends, relation_indexes, length, generator, shuffle=True):
        self.questions = questions
        self.max_length = length
        self.tokenizer = tokenizer
        self.relation_indexes = relation_indexes
        self.g = generator
        self.shuffle = shuffle
        ids = []
        masks = []
        start_ent = []
        end_ent = []
        # Encode questions
        for question in range(len(self.questions)):
          encoding = self.tokenizer.encode_plus(
             text = self.questions[question],
             max_length=self.max_length,
             truncation=True,
             pad_to_max_length=True,
             return_attention_mask=True,
             padding='max_length',
             add_special_tokens=False
          )
          Question = self.questions[question].split()
          # Locate the corresponding start in the BERT tokenized question
          start_token = tokenizer.encode_plus(
            text = Question[entity_starts[question]],
            return_attention_mask=True,
            add_special_tokens=False
        )
          # Locate the corresponding end in the BERT tokenized question
          end_token = tokenizer.encode_plus(
            text = Question[entity_ends[question]],
            return_attention_mask=True,
            add_special_tokens=False
        )
          ids.append(encoding['input_ids'])
          masks.append(encoding['attention_mask'])
          start_ent.append(encoding['input_ids'].index(start_token['input_ids'][0]))
          end_ent.append(encoding['input_ids'].index(end_token['input_ids'][-1]))
        self.input_ids = ids
        self.attention_masks = masks
        self.entity_start_indexes = start_ent
        self.entity_end_indexes = end_ent

  def __len__(self):
        return len(self.questions)

  def __getitem__(self, idx):
        return { 'input_ids': torch.tensor(self.input_ids[idx]),
                'attention_mask':  torch.tensor(self.attention_masks[idx]),
                'relation_indexes': torch.tensor(self.relation_indexes[idx]),
                'entity_start': torch.tensor(self.entity_start_indexes[idx], dtype = torch.long),
                'entity_end': torch.tensor(self.entity_end_indexes[idx], dtype = torch.long)
               }

  def set_epoch(self, epoch):
      self.epoch = epoch
      if self.shuffle:
         self.g.manual_seed(123456789 + self.epoch)

# %% [markdown]
# **In the above custom dataset class i reseed the workers using worker\_init\_fn() to preserve reproducibility through by creating the following function seed\_worker.**

# %%
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# %% [markdown]
# **Creation of the dataloader through the created custom dataset from pytorch for the training and validation dataset of SimpleQuestions dataset. The batch size is equal to 32.**

# %%
print(len(train_questions), len(train_entity_span_start), len(train_entity_span_end), len(train_relations_index))
train_bert_dataset = BertQuestionAnsweringDataset(train_questions, tokenizer, train_entity_span_start, train_entity_span_end, train_relations_index, max(q_lengths), g)
valid_bert_dataset = BertQuestionAnsweringDataset(validation_questions, tokenizer, validation_entity_span_start, validation_entity_span_end, validation_relations_index, max(q_lengths), g)
train_dataloader = torch.utils.data.DataLoader(train_bert_dataset, batch_size = 32, num_workers = 0, worker_init_fn=seed_worker, shuffle=True, generator = train_bert_dataset.g)
val_dataloader = torch.utils.data.DataLoader(valid_bert_dataset, batch_size= 32, num_workers = 0, worker_init_fn=seed_worker, shuffle=True, generator = valid_bert_dataset.g)
# Out:
# 19481 19481 19481 19481

# %% [markdown]
# **Function that contributes to the preservation of the reproducibility.**

# %%
#To preserve reproducibility
SEED = 42
def set_seed(SEED):
 random.seed(SEED)# Set python seed for custom operators.
 torch.manual_seed(SEED)
 np.random.seed(SEED)
 torch.cuda.manual_seed_all(SEED)
 torch.backends.cudnn.benchmark = False
 torch.backends.cudnn.deterministic = True

# %% [markdown]
# **Through the create\_file function, is created a file in .pt, in which the parameters for each model are stored. This function takes as an argument a name for the folder where the model will be saved (e.g. "drive/MyDrive/") and a name for the name of the file where each model is saved (e.g. "relation\_prediction.pt").**

# %%
def create_file(model_dir, model_save_name):
 if not os.path.exists(model_dir):
    os.makedirs(model_dir)
 model_save_path = os.path.join(model_dir, model_save_name)
 return model_save_path

# %% [markdown]
# ****Construction and initialization of the neural network for the prediction of the relation for each question.****

# %%
class BertRelationsClassifier(nn.Module):
  def __init__(self, activation, dropout_prob, rel_vocab_len):
    super(BertRelationsClassifier, self).__init__()
    activations = {
        "ELU" : nn.ELU,
        "LeakyReLU"    : nn.LeakyReLU,
        "Softplus"     : nn.Softplus,
        "Tanhshrink"     : nn.Tanhshrink
 }
    self.bert_model = BertModel.from_pretrained('bert-base-uncased')
    self.rel_vocab_len = rel_vocab_len
    self.fc = nn.Linear(768, self.rel_vocab_len)
    self.activation_type = activation
    self.dropout_probability = dropout_prob
    self.activation = activations[self.activation_type]()
    self.dropout = nn.Dropout(self.dropout_probability)
    self.softmax = nn.Softmax(dim=1)

  def forward(self, input_ids, attention_mask):
        out = self.bert_model(input_ids, attention_mask)
        out = self.fc(out[1])#CLS token-pooled output
        out = self.activation(out)
        out = self.dropout(out)
        out = self.softmax(out)
        return out

# %% [markdown]
# **Through the function named relation_prediction_function the best possible parameters for the best possible prediction of the relation are found. This function has as arguments the training dataloader, the validation dataloader, the number of epochs, the optimizer, the scheduler, the learning rate, the relation prediction neural network model, the loss function and the dropout probability value.**
#
# **This function returns the best possible model, the list including numbers from 0 to number of training epochs-1, the lists including the values of training losses and validation losses for all epochs respectively and the largest value of f1.**
#
# **The length of the relation vocabulary in the case of training and validating the full SimpleQuestions dataset is equal to 129 and the length of the relation vocabulary for the case of training and validating the SimpleQuestions subset that includes only questions that are answerable over wikidata is equal to 125.
# So the predicted relation index as a number must be either between 0 and 128 or between 0 and 124, where this number correspond to the position of the unique relation ids in the corresponding relation vocabulary.**

# %%
def relation_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, lr, dropout_prob):
 list_loss_train = []
 list_epochs = []
 list_loss = []
 the_last_f1_score = 0
 patience = 3
 max_f1 = -1
 trigger_times = 0
 for epoch in range(epochs):
   train_dataset.set_epoch(epoch)
   valid_dataset.set_epoch(epoch)
   model.train()
   batch_losses = []
   F1 = []
   precision = []
   recall = []
   accuracy = []
   for batch in train_dataloader:
    ids = batch['input_ids'].to(device)
    attention_masks = batch['attention_mask'].to(device)
    relation_indexes = batch['relation_indexes'].to(device)
    y_pred = model(ids, attention_masks)
    loss = loss_func(y_pred.cpu(),relation_indexes.cpu())
    batch_losses.append(loss.detach().numpy())
    #Delete previously stored gradients
    optimizer.zero_grad()

    #Perform backpropagation starting from the loss calculated in this epoch
    loss.backward()
    nn.utils.clip_grad_norm_(model.parameters(), 0.7)
    #Update model's weights based on the gradients calculated during backprop
    optimizer.step()
    scheduler.step()
   print(f"Epoch {epoch:3}: Train Loss = {sum(batch_losses)/len(train_dataloader):.5f}")
   list_loss_train.append(sum(batch_losses)/len(train_dataloader))
   with torch.no_grad():
     model.eval()
     batch_F1 = []
     batch_precision = []
     batch_recall = []
     batch_accuracy = []
     batch_losses_val = []
     for batch in val_dataloader:
       ids = batch['input_ids'].to(device)
       attention_masks = batch['attention_mask'].to(device)
       relation_indexes = batch['relation_indexes'].to(device)
       y_predict = model(ids, attention_masks)
       val_loss = loss_func(y_predict.cpu(),relation_indexes.cpu())
       batch_losses_val.append(val_loss)
       y_pr = torch.argmax(y_predict, dim=1).squeeze()
       Y_p = y_pr.tolist()
       y_val = relation_indexes.tolist()
       batch_F1.append(f1_score(y_val, Y_p, average = 'micro'))
       batch_precision.append(precision_score(y_val, Y_p, average = 'micro'))
       batch_recall.append(recall_score(y_val, Y_p, average = 'micro'))
       batch_accuracy.append(accuracy_score(y_val,Y_p))
     Valid_f1 = sum(batch_F1)/len(val_dataloader)
     Valid_accuracy = sum(batch_accuracy)/len(val_dataloader)
     print(f"Epoch {epoch:3}: Valid Loss = {sum(batch_losses_val)/len(val_dataloader):.5f}")
     print(f"Epoch {epoch:3}: Valid f1_score = {Valid_f1:.5f}")
     print(f"Epoch {epoch:3}: Valid Acurracy = {Valid_accuracy:.5f}")
     print(f"Epoch {epoch:3}: Valid Recall score = {sum(batch_recall)/len(val_dataloader):.5f}")
     print(f"Epoch {epoch:3}: Valid Precision score = {sum(batch_precision)/len(val_dataloader):.5f}")
     #list_f1_scores.append(sum(F1)/len(val_dataloader))
     list_loss.append(sum(batch_losses_val)/len(val_dataloader))
     list_epochs.append(epoch)
     if Valid_f1 > max_f1:
       max_f1 = Valid_f1
       best_model = model
       print('The current f1 score:', Valid_f1)
     if Valid_f1 < the_last_f1_score:
       trigger_times += 1
       print('trigger times:', trigger_times)
       if trigger_times >= patience:
         print('Early stopping!\nStart to test process.')
         break;
     the_last_f1_score = Valid_f1
 return max_f1, list_loss_train, list_loss, list_epochs, best_model

# %% [markdown]
# **The function named get_relation_results finds results for the neural networks concerning the relation index and the entity span indexes (start,end). These functions have as arguments the corresponding training dataloader, the corresponding validation dataloader, the number of epochs ,the optimizer, the scheduler get_linear_schedule_with_warmup, the corresponding relation prediction neural network model, the loss function, the learning rate and the SEED number.**
#
# **This function returns the list of training losses, the list of validation losses, and the list of how many epochs each model with each activation function needs to be fully trained.**

# %%
learning_rate  = 2e-5
dropout_prob = 0.3
epochs = 20
list_relation_training_losses = []
list_relation_validation_losses = []
list_relation_epochs = []
loss_func = nn.CrossEntropyLoss()
optimizer_name = "Adam"
def get_relation_results(activation, rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_dataset, valid_dataset, train_dataloader, val_dataloader, SEED):
 set_seed(SEED)
 model = BertRelationsClassifier(activation, dropout_prob, rel_vocab_length).to(device)
 print(model)
 loss_func = loss_func.to(device)
 optimizer = getattr(torch.optim, optimizer_name)(model.parameters(), lr=learning_rate)
 scheduler = get_linear_schedule_with_warmup(optimizer, 0, len(train_dataloader)*epochs)
 f1, list_loss_train, list_loss_valid, list_epochs, best_relation_model = relation_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, learning_rate, dropout_prob)
 print(f1)
 torch.save(best_relation_model.state_dict(), create_file(f"drive/MyDrive/Relation_indexes_models_best_parameters/Answerable_Questions/{activation}", f"relation_prediction_cosine_similarity_answerable_questions_{activation}.pt") )
 print(f"The best parameters are saved for the activation function: {activation}")
 return list_loss_train, list_loss_valid, list_epochs

# %%
list_relation_loss_train_leakyrelu, list_relation_loss_valid_leakyrelu, list_epochs_leakyrelu = get_relation_results("LeakyReLU", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=125, bias=True)
#   (activation): LeakyReLU(negative_slope=0.01)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.58557
# Epoch   0: Valid Loss = 4.29605
# Epoch   0: Valid f1_score = 0.60681
# Epoch   0: Valid Acurracy = 0.60681
# Epoch   0: Valid Recall score = 0.60681
# Epoch   0: Valid Precision score = 0.60681
# The current f1 score: 0.606811797752809
# Epoch   1: Train Loss = 4.38414
# Epoch   1: Valid Loss = 4.18262
# Epoch   1: Valid f1_score = 0.69874
# Epoch   1: Valid Acurracy = 0.69874
# Epoch   1: Valid Recall score = 0.69874
# Epoch   1: Valid Precision score = 0.69874
# The current f1 score: 0.6987359550561798
# Epoch   2: Train Loss = 4.32955
# Epoch   2: Valid Loss = 4.11188
# Epoch   2: Valid f1_score = 0.77317
# Epoch   2: Valid Acurracy = 0.77317
# Epoch   2: Valid Recall score = 0.77317
# Epoch   2: Valid Precision score = 0.77317
# The current f1 score: 0.7731741573033708
# Epoch   3: Train Loss = 4.28584
# Epoch   3: Valid Loss = 4.05285
# Epoch   3: Valid f1_score = 0.83483
# Epoch   3: Valid Acurracy = 0.83483
# Epoch   3: Valid Recall score = 0.83483
# Epoch   3: Valid Precision score = 0.83483
# The current f1 score: 0.8348314606741573
# Epoch   4: Train Loss = 4.25209
# Epoch   4: Valid Loss = 4.01386
# Epoch   4: Valid f1_score = 0.86166
# Epoch   4: Valid Acurracy = 0.86166
# Epoch   4: Valid Recall score = 0.86166
# Epoch   4: Valid Precision score = 0.86166
# The current f1 score: 0.8616573033707865
# Epoch   5: Train Loss = 4.23681
# Epoch   5: Valid Loss = 3.99371
# Epoch   5: Valid f1_score = 0.87956
# Epoch   5: Valid Acurracy = 0.87956
# Epoch   5: Valid Recall score = 0.87956
# Epoch   5: Valid Precision score = 0.87956
# The current f1 score: 0.879564606741573
# Epoch   6: Train Loss = 4.22724
# Epoch   6: Valid Loss = 3.98067
# Epoch   6: Valid f1_score = 0.88975
# Epoch   6: Valid Acurracy = 0.88975
# Epoch   6: Valid Recall score = 0.88975
# Epoch   6: Valid Precision score = 0.88975
# The current f1 score: 0.889747191011236
# Epoch   7: Train Loss = 4.21475
# Epoch   7: Valid Loss = 3.97203
# Epoch   7: Valid f1_score = 0.89242
# Epoch   7: Valid Acurracy = 0.89242
# Epoch   7: Valid Recall score = 0.89242
# Epoch   7: Valid Precision score = 0.89242
# The current f1 score: 0.8924157303370787
# Epoch   8: Train Loss = 4.20855
# Epoch   8: Valid Loss = 3.95998
# Epoch   8: Valid f1_score = 0.90365
# Epoch   8: Valid Acurracy = 0.90365
# Epoch   8: Valid Recall score = 0.90365
# Epoch   8: Valid Precision score = 0.90365
# The current f1 score: 0.9036516853932584
# Epoch   9: Train Loss = 4.20225
# Epoch   9: Valid Loss = 3.95318
# Epoch   9: Valid f1_score = 0.90695
# Epoch   9: Valid Acurracy = 0.90695
# Epoch   9: Valid Recall score = 0.90695
# Epoch   9: Valid Precision score = 0.90695
# The current f1 score: 0.9069522471910112
# Epoch  10: Train Loss = 4.19432
# Epoch  10: Valid Loss = 3.94627
# Epoch  10: Valid f1_score = 0.91699
# Epoch  10: Valid Acurracy = 0.91699
# Epoch  10: Valid Recall score = 0.91699
# Epoch  10: Valid Precision score = 0.91699
# The current f1 score: 0.9169943820224719
# Epoch  11: Train Loss = 4.18972
# Epoch  11: Valid Loss = 3.94268
# Epoch  11: Valid f1_score = 0.91875
# Epoch  11: Valid Acurracy = 0.91875
# Epoch  11: Valid Recall score = 0.91875
# Epoch  11: Valid Precision score = 0.91875
# The current f1 score: 0.91875
# Epoch  12: Train Loss = 4.19240
# Epoch  12: Valid Loss = 3.93338
# Epoch  12: Valid f1_score = 0.92767
# Epoch  12: Valid Acurracy = 0.92767
# Epoch  12: Valid Recall score = 0.92767
# Epoch  12: Valid Precision score = 0.92767
# The current f1 score: 0.9276685393258427
# Epoch  13: Train Loss = 4.18204
# Epoch  13: Valid Loss = 3.93296
# Epoch  13: Valid f1_score = 0.93055
# Epoch  13: Valid Acurracy = 0.93055
# Epoch  13: Valid Recall score = 0.93055
# Epoch  13: Valid Precision score = 0.93055
# The current f1 score: 0.9305477528089887
# Epoch  14: Train Loss = 4.18161
# Epoch  14: Valid Loss = 3.92232
# Epoch  14: Valid f1_score = 0.94031
# Epoch  14: Valid Acurracy = 0.94031
# Epoch  14: Valid Recall score = 0.94031
# Epoch  14: Valid Precision score = 0.94031
# The current f1 score: 0.9403089887640449
# Epoch  15: Train Loss = 4.17594
# Epoch  15: Valid Loss = 3.92043
# Epoch  15: Valid f1_score = 0.94171
# Epoch  15: Valid Acurracy = 0.94171
# Epoch  15: Valid Recall score = 0.94171
# Epoch  15: Valid Precision score = 0.94171
# The current f1 score: 0.9417134831460674
# Epoch  16: Train Loss = 4.16948
# Epoch  16: Valid Loss = 3.92093
# Epoch  16: Valid f1_score = 0.93876
# Epoch  16: Valid Acurracy = 0.93876
# Epoch  16: Valid Recall score = 0.93876
# Epoch  16: Valid Precision score = 0.93876
# trigger times: 1
# Epoch  17: Train Loss = 4.16249
# Epoch  17: Valid Loss = 3.91697
# Epoch  17: Valid f1_score = 0.94136
# Epoch  17: Valid Acurracy = 0.94136
# Epoch  17: Valid Recall score = 0.94136
# Epoch  17: Valid Precision score = 0.94136
# Epoch  18: Train Loss = 4.16237
# Epoch  18: Valid Loss = 3.91801
# Epoch  18: Valid f1_score = 0.94333
# Epoch  18: Valid Acurracy = 0.94333
# Epoch  18: Valid Recall score = 0.94333
# Epoch  18: Valid Precision score = 0.94333
# The current f1 score: 0.9433286516853933
# Epoch  19: Train Loss = 4.16876
# Epoch  19: Valid Loss = 3.91520
# Epoch  19: Valid f1_score = 0.94663
# Epoch  19: Valid Acurracy = 0.94663
# Epoch  19: Valid Recall score = 0.94663
# Epoch  19: Valid Precision score = 0.94663
# The current f1 score: 0.9466292134831461
# 0.9466292134831461
# The best parameters are saved for the activation function: LeakyReLU

# %%
list_relation_loss_train_tanhshrink, list_relation_loss_valid_tanhshrink, list_epochs_tanhshrink = get_relation_results("Tanhshrink", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=125, bias=True)
#   (activation): Tanhshrink()
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.62163
# Epoch   0: Valid Loss = 4.34043
# Epoch   0: Valid f1_score = 0.54677
# Epoch   0: Valid Acurracy = 0.54677
# Epoch   0: Valid Recall score = 0.54677
# Epoch   0: Valid Precision score = 0.54677
# The current f1 score: 0.5467696629213483
# Epoch   1: Train Loss = 4.40214
# Epoch   1: Valid Loss = 4.17937
# Epoch   1: Valid f1_score = 0.69452
# Epoch   1: Valid Acurracy = 0.69452
# Epoch   1: Valid Recall score = 0.69452
# Epoch   1: Valid Precision score = 0.69452
# The current f1 score: 0.6945224719101124
# Epoch   2: Train Loss = 4.35142
# Epoch   2: Valid Loss = 4.14117
# Epoch   2: Valid f1_score = 0.73947
# Epoch   2: Valid Acurracy = 0.73947
# Epoch   2: Valid Recall score = 0.73947
# Epoch   2: Valid Precision score = 0.73947
# The current f1 score: 0.7394662921348315
# Epoch   3: Train Loss = 4.30877
# Epoch   3: Valid Loss = 4.08785
# Epoch   3: Valid f1_score = 0.78532
# Epoch   3: Valid Acurracy = 0.78532
# Epoch   3: Valid Recall score = 0.78532
# Epoch   3: Valid Precision score = 0.78532
# The current f1 score: 0.7853230337078652
# Epoch   4: Train Loss = 4.27549
# Epoch   4: Valid Loss = 4.04898
# Epoch   4: Valid f1_score = 0.82374
# Epoch   4: Valid Acurracy = 0.82374
# Epoch   4: Valid Recall score = 0.82374
# Epoch   4: Valid Precision score = 0.82374
# The current f1 score: 0.8237359550561798
# Epoch   5: Train Loss = 4.25539
# Epoch   5: Valid Loss = 4.01864
# Epoch   5: Valid f1_score = 0.85358
# Epoch   5: Valid Acurracy = 0.85358
# Epoch   5: Valid Recall score = 0.85358
# Epoch   5: Valid Precision score = 0.85358
# The current f1 score: 0.8535814606741573
# Epoch   6: Train Loss = 4.23704
# Epoch   6: Valid Loss = 3.99913
# Epoch   6: Valid f1_score = 0.87065
# Epoch   6: Valid Acurracy = 0.87065
# Epoch   6: Valid Recall score = 0.87065
# Epoch   6: Valid Precision score = 0.87065
# The current f1 score: 0.8706460674157303
# Epoch   7: Train Loss = 4.21994
# Epoch   7: Valid Loss = 3.97699
# Epoch   7: Valid f1_score = 0.89923
# Epoch   7: Valid Acurracy = 0.89923
# Epoch   7: Valid Recall score = 0.89923
# Epoch   7: Valid Precision score = 0.89923
# The current f1 score: 0.8992275280898876
# Epoch   8: Train Loss = 4.20816
# Epoch   8: Valid Loss = 3.96640
# Epoch   8: Valid f1_score = 0.90098
# Epoch   8: Valid Acurracy = 0.90098
# Epoch   8: Valid Recall score = 0.90098
# Epoch   8: Valid Precision score = 0.90098
# The current f1 score: 0.9009831460674157
# Epoch   9: Train Loss = 4.19878
# Epoch   9: Valid Loss = 3.95423
# Epoch   9: Valid f1_score = 0.90941
# Epoch   9: Valid Acurracy = 0.90941
# Epoch   9: Valid Recall score = 0.90941
# Epoch   9: Valid Precision score = 0.90941
# The current f1 score: 0.9094101123595506
# Epoch  10: Train Loss = 4.19133
# Epoch  10: Valid Loss = 3.95030
# Epoch  10: Valid f1_score = 0.91383
# Epoch  10: Valid Acurracy = 0.91383
# Epoch  10: Valid Recall score = 0.91383
# Epoch  10: Valid Precision score = 0.91383
# The current f1 score: 0.9138342696629214
# Epoch  11: Train Loss = 4.18720
# Epoch  11: Valid Loss = 3.94121
# Epoch  11: Valid f1_score = 0.92367
# Epoch  11: Valid Acurracy = 0.92367
# Epoch  11: Valid Recall score = 0.92367
# Epoch  11: Valid Precision score = 0.92367
# The current f1 score: 0.9236657303370787
# Epoch  12: Train Loss = 4.18948
# Epoch  12: Valid Loss = 3.93454
# Epoch  12: Valid f1_score = 0.92591
# Epoch  12: Valid Acurracy = 0.92591
# Epoch  12: Valid Recall score = 0.92591
# Epoch  12: Valid Precision score = 0.92591
# The current f1 score: 0.9259129213483146
# Epoch  13: Train Loss = 4.17976
# Epoch  13: Valid Loss = 3.93387
# Epoch  13: Valid f1_score = 0.92718
# Epoch  13: Valid Acurracy = 0.92718
# Epoch  13: Valid Recall score = 0.92718
# Epoch  13: Valid Precision score = 0.92718
# The current f1 score: 0.9271769662921348
# Epoch  14: Train Loss = 4.18204
# Epoch  14: Valid Loss = 3.92999
# Epoch  14: Valid f1_score = 0.92963
# Epoch  14: Valid Acurracy = 0.92963
# Epoch  14: Valid Recall score = 0.92963
# Epoch  14: Valid Precision score = 0.92963
# The current f1 score: 0.9296348314606742
# Epoch  15: Train Loss = 4.17672
# Epoch  15: Valid Loss = 3.92329
# Epoch  15: Valid f1_score = 0.93996
# Epoch  15: Valid Acurracy = 0.93996
# Epoch  15: Valid Recall score = 0.93996
# Epoch  15: Valid Precision score = 0.93996
# The current f1 score: 0.9399578651685393
# Epoch  16: Train Loss = 4.17022
# Epoch  16: Valid Loss = 3.92169
# Epoch  16: Valid f1_score = 0.94122
# Epoch  16: Valid Acurracy = 0.94122
# Epoch  16: Valid Recall score = 0.94122
# Epoch  16: Valid Precision score = 0.94122
# The current f1 score: 0.9412219101123596
# Epoch  17: Train Loss = 4.16291
# Epoch  17: Valid Loss = 3.91871
# Epoch  17: Valid f1_score = 0.94347
# Epoch  17: Valid Acurracy = 0.94347
# Epoch  17: Valid Recall score = 0.94347
# Epoch  17: Valid Precision score = 0.94347
# The current f1 score: 0.9434691011235955
# Epoch  18: Train Loss = 4.16295
# Epoch  18: Valid Loss = 3.91888
# Epoch  18: Valid f1_score = 0.94192
# Epoch  18: Valid Acurracy = 0.94192
# Epoch  18: Valid Recall score = 0.94192
# Epoch  18: Valid Precision score = 0.94192
# trigger times: 1
# Epoch  19: Train Loss = 4.16956
# Epoch  19: Valid Loss = 3.91642
# Epoch  19: Valid f1_score = 0.94417
# Epoch  19: Valid Acurracy = 0.94417
# Epoch  19: Valid Recall score = 0.94417
# Epoch  19: Valid Precision score = 0.94417
# The current f1 score: 0.9441713483146067
# 0.9441713483146067
# The best parameters are saved for the activation function: Tanhshrink

# %%
list_relation_loss_train_elu, list_relation_loss_valid_elu, list_epochs_elu = get_relation_results("ELU", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=125, bias=True)
#   (activation): ELU(alpha=1.0)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.56424
# Epoch   0: Valid Loss = 4.28507
# Epoch   0: Valid f1_score = 0.61524
# Epoch   0: Valid Acurracy = 0.61524
# Epoch   0: Valid Recall score = 0.61524
# Epoch   0: Valid Precision score = 0.61524
# The current f1 score: 0.6152387640449438
# Epoch   1: Train Loss = 4.37569
# Epoch   1: Valid Loss = 4.15666
# Epoch   1: Valid f1_score = 0.72121
# Epoch   1: Valid Acurracy = 0.72121
# Epoch   1: Valid Recall score = 0.72121
# Epoch   1: Valid Precision score = 0.72121
# The current f1 score: 0.7212078651685393
# Epoch   2: Train Loss = 4.32004
# Epoch   2: Valid Loss = 4.08926
# Epoch   2: Valid f1_score = 0.80513
# Epoch   2: Valid Acurracy = 0.80513
# Epoch   2: Valid Recall score = 0.80513
# Epoch   2: Valid Precision score = 0.80513
# The current f1 score: 0.805126404494382
# Epoch   3: Train Loss = 4.27049
# Epoch   3: Valid Loss = 4.03302
# Epoch   3: Valid f1_score = 0.84712
# Epoch   3: Valid Acurracy = 0.84712
# Epoch   3: Valid Recall score = 0.84712
# Epoch   3: Valid Precision score = 0.84712
# The current f1 score: 0.8471207865168539
# Epoch   4: Train Loss = 4.24570
# Epoch   4: Valid Loss = 4.01036
# Epoch   4: Valid f1_score = 0.87324
# Epoch   4: Valid Acurracy = 0.87324
# Epoch   4: Valid Recall score = 0.87324
# Epoch   4: Valid Precision score = 0.87324
# The current f1 score: 0.8732443820224719
# Epoch   5: Train Loss = 4.22278
# Epoch   5: Valid Loss = 3.98240
# Epoch   5: Valid f1_score = 0.89607
# Epoch   5: Valid Acurracy = 0.89607
# Epoch   5: Valid Recall score = 0.89607
# Epoch   5: Valid Precision score = 0.89607
# The current f1 score: 0.8960674157303371
# Epoch   6: Train Loss = 4.21076
# Epoch   6: Valid Loss = 3.96410
# Epoch   6: Valid f1_score = 0.91081
# Epoch   6: Valid Acurracy = 0.91081
# Epoch   6: Valid Recall score = 0.91081
# Epoch   6: Valid Precision score = 0.91081
# The current f1 score: 0.910814606741573
# Epoch   7: Train Loss = 4.19717
# Epoch   7: Valid Loss = 3.95316
# Epoch   7: Valid f1_score = 0.91222
# Epoch   7: Valid Acurracy = 0.91222
# Epoch   7: Valid Recall score = 0.91222
# Epoch   7: Valid Precision score = 0.91222
# The current f1 score: 0.9122191011235955
# Epoch   8: Train Loss = 4.19684
# Epoch   8: Valid Loss = 3.95026
# Epoch   8: Valid f1_score = 0.91187
# Epoch   8: Valid Acurracy = 0.91187
# Epoch   8: Valid Recall score = 0.91187
# Epoch   8: Valid Precision score = 0.91187
# trigger times: 1
# Epoch   9: Train Loss = 4.19101
# Epoch   9: Valid Loss = 3.94458
# Epoch   9: Valid f1_score = 0.91749
# Epoch   9: Valid Acurracy = 0.91749
# Epoch   9: Valid Recall score = 0.91749
# Epoch   9: Valid Precision score = 0.91749
# The current f1 score: 0.9174859550561798
# Epoch  10: Train Loss = 4.18394
# Epoch  10: Valid Loss = 3.93975
# Epoch  10: Valid f1_score = 0.92612
# Epoch  10: Valid Acurracy = 0.92612
# Epoch  10: Valid Recall score = 0.92612
# Epoch  10: Valid Precision score = 0.92612
# The current f1 score: 0.926123595505618
# Epoch  11: Train Loss = 4.17860
# Epoch  11: Valid Loss = 3.93338
# Epoch  11: Valid f1_score = 0.93279
# Epoch  11: Valid Acurracy = 0.93279
# Epoch  11: Valid Recall score = 0.93279
# Epoch  11: Valid Precision score = 0.93279
# The current f1 score: 0.9327949438202247
# Epoch  12: Train Loss = 4.17959
# Epoch  12: Valid Loss = 3.92259
# Epoch  12: Valid f1_score = 0.94206
# Epoch  12: Valid Acurracy = 0.94206
# Epoch  12: Valid Recall score = 0.94206
# Epoch  12: Valid Precision score = 0.94206
# The current f1 score: 0.942064606741573
# Epoch  13: Train Loss = 4.16995
# Epoch  13: Valid Loss = 3.91847
# Epoch  13: Valid f1_score = 0.94649
# Epoch  13: Valid Acurracy = 0.94649
# Epoch  13: Valid Recall score = 0.94649
# Epoch  13: Valid Precision score = 0.94649
# The current f1 score: 0.9464887640449438
# Epoch  14: Train Loss = 4.17232
# Epoch  14: Valid Loss = 3.91714
# Epoch  14: Valid f1_score = 0.94579
# Epoch  14: Valid Acurracy = 0.94579
# Epoch  14: Valid Recall score = 0.94579
# Epoch  14: Valid Precision score = 0.94579
# trigger times: 2
# Epoch  15: Train Loss = 4.16783
# Epoch  15: Valid Loss = 3.91372
# Epoch  15: Valid f1_score = 0.94979
# Epoch  15: Valid Acurracy = 0.94979
# Epoch  15: Valid Recall score = 0.94979
# Epoch  15: Valid Precision score = 0.94979
# The current f1 score: 0.9497893258426966
# Epoch  16: Train Loss = 4.16264
# Epoch  16: Valid Loss = 3.91257
# Epoch  16: Valid f1_score = 0.94860
# Epoch  16: Valid Acurracy = 0.94860
# Epoch  16: Valid Recall score = 0.94860
# Epoch  16: Valid Precision score = 0.94860
# trigger times: 3
# Early stopping!
# Start to test process.
# 0.9497893258426966
# The best parameters are saved for the activation function: ELU

# %%
list_relation_loss_train_softplus, list_relation_loss_valid_softplus, list_epochs_softplus = get_relation_results("Softplus", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=125, bias=True)
#   (activation): Softplus(beta=1, threshold=20)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.59772
# Epoch   0: Valid Loss = 4.32446
# Epoch   0: Valid f1_score = 0.57767
# Epoch   0: Valid Acurracy = 0.57767
# Epoch   0: Valid Recall score = 0.57767
# Epoch   0: Valid Precision score = 0.57767
# The current f1 score: 0.5776685393258427
# Epoch   1: Train Loss = 4.40095
# Epoch   1: Valid Loss = 4.19452
# Epoch   1: Valid f1_score = 0.69452
# Epoch   1: Valid Acurracy = 0.69452
# Epoch   1: Valid Recall score = 0.69452
# Epoch   1: Valid Precision score = 0.69452
# The current f1 score: 0.6945224719101124
# Epoch   2: Train Loss = 4.33257
# Epoch   2: Valid Loss = 4.11353
# Epoch   2: Valid f1_score = 0.78125
# Epoch   2: Valid Acurracy = 0.78125
# Epoch   2: Valid Recall score = 0.78125
# Epoch   2: Valid Precision score = 0.78125
# The current f1 score: 0.78125
# Epoch   3: Train Loss = 4.27981
# Epoch   3: Valid Loss = 4.04857
# Epoch   3: Valid f1_score = 0.83764
# Epoch   3: Valid Acurracy = 0.83764
# Epoch   3: Valid Recall score = 0.83764
# Epoch   3: Valid Precision score = 0.83764
# The current f1 score: 0.8376404494382023
# Epoch   4: Train Loss = 4.25313
# Epoch   4: Valid Loss = 4.02092
# Epoch   4: Valid f1_score = 0.86447
# Epoch   4: Valid Acurracy = 0.86447
# Epoch   4: Valid Recall score = 0.86447
# Epoch   4: Valid Precision score = 0.86447
# The current f1 score: 0.8644662921348315
# Epoch   5: Train Loss = 4.23370
# Epoch   5: Valid Loss = 3.98986
# Epoch   5: Valid f1_score = 0.88904
# Epoch   5: Valid Acurracy = 0.88904
# Epoch   5: Valid Recall score = 0.88904
# Epoch   5: Valid Precision score = 0.88904
# The current f1 score: 0.8890449438202247
# Epoch   6: Train Loss = 4.21716
# Epoch   6: Valid Loss = 3.97103
# Epoch   6: Valid f1_score = 0.90555
# Epoch   6: Valid Acurracy = 0.90555
# Epoch   6: Valid Recall score = 0.90555
# Epoch   6: Valid Precision score = 0.90555
# The current f1 score: 0.9055477528089888
# Epoch   7: Train Loss = 4.20216
# Epoch   7: Valid Loss = 3.95946
# Epoch   7: Valid f1_score = 0.91292
# Epoch   7: Valid Acurracy = 0.91292
# Epoch   7: Valid Recall score = 0.91292
# Epoch   7: Valid Precision score = 0.91292
# The current f1 score: 0.9129213483146067
# Epoch   8: Train Loss = 4.19844
# Epoch   8: Valid Loss = 3.95569
# Epoch   8: Valid f1_score = 0.90976
# Epoch   8: Valid Acurracy = 0.90976
# Epoch   8: Valid Recall score = 0.90976
# Epoch   8: Valid Precision score = 0.90976
# trigger times: 1
# Epoch   9: Train Loss = 4.19284
# Epoch   9: Valid Loss = 3.94024
# Epoch   9: Valid f1_score = 0.92521
# Epoch   9: Valid Acurracy = 0.92521
# Epoch   9: Valid Recall score = 0.92521
# Epoch   9: Valid Precision score = 0.92521
# The current f1 score: 0.9252106741573034
# Epoch  10: Train Loss = 4.18484
# Epoch  10: Valid Loss = 3.93596
# Epoch  10: Valid f1_score = 0.93104
# Epoch  10: Valid Acurracy = 0.93104
# Epoch  10: Valid Recall score = 0.93104
# Epoch  10: Valid Precision score = 0.93104
# The current f1 score: 0.9310393258426966
# Epoch  11: Train Loss = 4.18047
# Epoch  11: Valid Loss = 3.93171
# Epoch  11: Valid f1_score = 0.93244
# Epoch  11: Valid Acurracy = 0.93244
# Epoch  11: Valid Recall score = 0.93244
# Epoch  11: Valid Precision score = 0.93244
# The current f1 score: 0.932443820224719
# Epoch  12: Train Loss = 4.18388
# Epoch  12: Valid Loss = 3.92439
# Epoch  12: Valid f1_score = 0.93926
# Epoch  12: Valid Acurracy = 0.93926
# Epoch  12: Valid Recall score = 0.93926
# Epoch  12: Valid Precision score = 0.93926
# The current f1 score: 0.9392556179775281
# Epoch  13: Train Loss = 4.17443
# Epoch  13: Valid Loss = 3.92182
# Epoch  13: Valid f1_score = 0.94017
# Epoch  13: Valid Acurracy = 0.94017
# Epoch  13: Valid Recall score = 0.94017
# Epoch  13: Valid Precision score = 0.94017
# The current f1 score: 0.9401685393258427
# Epoch  14: Train Loss = 4.17819
# Epoch  14: Valid Loss = 3.91787
# Epoch  14: Valid f1_score = 0.94157
# Epoch  14: Valid Acurracy = 0.94157
# Epoch  14: Valid Recall score = 0.94157
# Epoch  14: Valid Precision score = 0.94157
# The current f1 score: 0.9415730337078652
# Epoch  15: Train Loss = 4.17335
# Epoch  15: Valid Loss = 3.91663
# Epoch  15: Valid f1_score = 0.94417
# Epoch  15: Valid Acurracy = 0.94417
# Epoch  15: Valid Recall score = 0.94417
# Epoch  15: Valid Precision score = 0.94417
# The current f1 score: 0.9441713483146067
# Epoch  16: Train Loss = 4.16758
# Epoch  16: Valid Loss = 3.91656
# Epoch  16: Valid f1_score = 0.94508
# Epoch  16: Valid Acurracy = 0.94508
# Epoch  16: Valid Recall score = 0.94508
# Epoch  16: Valid Precision score = 0.94508
# The current f1 score: 0.9450842696629214
# Epoch  17: Train Loss = 4.16018
# Epoch  17: Valid Loss = 3.91322
# Epoch  17: Valid f1_score = 0.94628
# Epoch  17: Valid Acurracy = 0.94628
# Epoch  17: Valid Recall score = 0.94628
# Epoch  17: Valid Precision score = 0.94628
# The current f1 score: 0.9462780898876404
# Epoch  18: Train Loss = 4.16018
# Epoch  18: Valid Loss = 3.91428
# Epoch  18: Valid f1_score = 0.94649
# Epoch  18: Valid Acurracy = 0.94649
# Epoch  18: Valid Recall score = 0.94649
# Epoch  18: Valid Precision score = 0.94649
# The current f1 score: 0.9464887640449438
# Epoch  19: Train Loss = 4.16696
# Epoch  19: Valid Loss = 3.91132
# Epoch  19: Valid f1_score = 0.94909
# Epoch  19: Valid Acurracy = 0.94909
# Epoch  19: Valid Recall score = 0.94909
# Epoch  19: Valid Precision score = 0.94909
# The current f1 score: 0.9490870786516854
# 0.9490870786516854
# The best parameters are saved for the activation function: Softplus

# %%
list_relation_training_losses.append(list_relation_loss_train_leakyrelu)
list_relation_validation_losses.append(list_relation_loss_valid_leakyrelu)
list_relation_epochs.append(list_epochs_leakyrelu)
list_relation_training_losses.append(list_relation_loss_train_tanhshrink)
list_relation_validation_losses.append(list_relation_loss_valid_tanhshrink)
list_relation_epochs.append(list_epochs_tanhshrink)
list_relation_training_losses.append(list_relation_loss_train_softplus)
list_relation_validation_losses.append(list_relation_loss_valid_softplus)
list_relation_epochs.append(list_epochs_softplus)
list_relation_training_losses.append(list_relation_loss_train_elu)
list_relation_validation_losses.append(list_relation_loss_valid_elu)
list_relation_epochs.append(list_epochs_elu)

# %% [markdown]
# **Through the function plot_losses the learning curves for losses (relation prediction losses, entity span prediction losses) are plotted.**

# %%
def plot_losses(list_epochs, list_training_losses, list_validation_losses, activations, lr, dropout_prob):
 for activation in range(len(activations)):
  plt.plot(list_epochs[activation], list_training_losses[activation], label = f"{activations[activation]},{lr},{dropout_prob}-Training")
  plt.plot(list_epochs[activation], list_validation_losses[activation], label = f"{activations[activation]},{lr},{dropout_prob}-Validation")
  plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize = 'small')
  plt.title("loss-score")
  plt.xlabel("Number of epochs")
  plt.ylabel("Loss")
  plt.ylim(ymin = 3.5)
activations = ['LeakyReLU','Tanhshrink', 'Softplus','ELU']

# %%
plot_losses(list_relation_epochs, list_relation_training_losses, list_relation_validation_losses, activations, learning_rate, dropout_prob)

# %% [markdown]
# ****Construction and initialization of the neural network for the prediction of the entity span start and entity span end indexes for each question.****

# %%
class BertEntitySpanClassifier(nn.Module):
  def __init__(self, activation, dropout_prob, max_quest_len):
    super(BertEntitySpanClassifier, self).__init__()
    self.bert_model = BertModel.from_pretrained('bert-base-uncased')
    activations = {
        "ELU" : nn.ELU,
        "LeakyReLU"    : nn.LeakyReLU,
        "Softplus"     : nn.Softplus,
        "Tanhshrink"     : nn.Tanhshrink
 }
    self.activation_type = activation
    self.activation = activations[self.activation_type]()
    self.max_length = max_quest_len
    self.dropout_probability = dropout_prob
    self.start_head = nn.Sequential(
          nn.Linear(768, self.max_length),
          self.activation,
          nn.Dropout(p=self.dropout_probability),
          nn.Flatten(),
          nn.Softmax(dim=1)
    )

    self.end_head = nn.Sequential(
          nn.Linear(768, self.max_length),
          self.activation,
          nn.Dropout(p=self.dropout_probability),
          nn.Flatten(),
          nn.Softmax(dim=1)
    )

  def forward(self, input_ids, att_mask):
    out = self.bert_model(input_ids, att_mask)
    out = out[0]
    out_start = self.start_head(out)
    out_end = self.end_head(out)
    return out_start , out_end

# %% [markdown]
# **Through the function named entity_prediction_function the best possible parameters for the best possible prediction of the entity span are found. This function has as arguments the corresponding training dataloader, the corresponding validation dataloader, the number of epochs, the optimizer, the scheduler, the learning rate, the entity span prediction neural network model, the loss function and the dropout probability value.**
#
# **This function returns the best possible model, the list including numbers from 0 to number of training epochs-1, the lists including the values of training losses and validation losses for all epochs respectively, the largest value of f1 for entity span start and the largest value of f1 for entity span end.**
#
# **The biggest length of a question in words that is observed in SimpleQuestions dataset is equal to 33. Thus these predicted indexes as numbers must be either between 0 and 32, where these numbers correspond to the position of these words in their question for each question.**

# %%
def entity_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, lr, dropout_prob):
 list_loss_train = []
 list_loss = []
 list_epochs = []
 the_last_f1_start_score = 0
 the_last_f1_end_score = 0
 patience = 3
 max_f1_start = -1
 max_f1_end = -1
 trigger_times = 0
 for epoch in range(epochs):
  train_dataset.set_epoch(epoch)
  valid_dataset.set_epoch(epoch)
  model.train()
  batch_losses = []
  for batch in train_dataloader:
   input_ids = batch['input_ids'].to(device)
   attention_masks = batch['attention_mask'].to(device)
   entity_span_start_indexes = batch['entity_start'].to(device)
   entity_span_end_indexes = batch['entity_end'].to(device)
   y_pred_start, y_pred_end = model(input_ids, attention_masks)
   y_pred_start = y_pred_start.squeeze()
   y_pred_end = y_pred_end.squeeze()
   loss = loss_func(y_pred_start.cpu(),entity_span_start_indexes.cpu())+loss_func(y_pred_end.cpu(),entity_span_end_indexes.cpu())
   batch_losses.append(loss.detach().numpy())
  #Delete previously stored gradients
   nn.utils.clip_grad_norm_(model.parameters(), 0.7)
   optimizer.zero_grad()

    #Perform backpropagation starting from the loss calculated in this epoch
   loss.backward()

    #Update model's weights based on the gradients calculated during backprop
   optimizer.step()
   scheduler.step()
  print(f"Epoch {epoch:3}: Train Loss = {sum(batch_losses)/len(train_dataloader):.5f}")
  list_loss_train.append(sum(batch_losses)/len(train_dataloader))
  with torch.no_grad():
    model.eval()
    F1_start = []
    F1_end = []
    accuracy_start = []
    accuracy_end = []
    precision_start = []
    precision_end = []
    recall_start = []
    recall_end = []
    batch_losses_val = []
    for batch in val_dataloader:
      input_ids = batch['input_ids'].to(device)
      attention_masks = batch['attention_mask'].to(device)
      entity_span_start_indexes = batch['entity_start'].to(device)
      entity_span_end_indexes = batch['entity_end'].to(device)
      y_predict_start, y_predict_end = model(input_ids, attention_masks)
      y_predict_start = y_predict_start.squeeze()
      y_predict_end = y_predict_end.squeeze()
      val_loss = loss_func(y_predict_start.cpu(),entity_span_start_indexes.cpu())+loss_func(y_predict_end.cpu(),entity_span_end_indexes.cpu())
      batch_losses_val.append(val_loss)
      y_pr_start = torch.argmax(y_predict_start, dim=1)
      y_pr_end = torch.argmax(y_predict_end, dim=1)
      Y_p_start = y_pr_start.tolist()
      Y_p_end = y_pr_end.tolist()
      y_val_start = entity_span_start_indexes.tolist()
      y_val_end = entity_span_end_indexes.tolist()
      F1_start.append(f1_score(y_val_start, Y_p_start, average = 'micro'))
      F1_end.append(f1_score(y_val_end, Y_p_end, average = 'micro'))
      precision_start.append(precision_score(y_val_start, Y_p_start, average = 'micro'))
      precision_end.append(precision_score(y_val_end, Y_p_end, average = 'micro'))
      recall_start.append(recall_score(y_val_start, Y_p_start, average = 'micro'))
      recall_end.append(recall_score(y_val_end, Y_p_end, average = 'micro'))
      accuracy_start.append(accuracy_score(y_val_start, Y_p_start))
      accuracy_end.append(accuracy_score(y_val_end, Y_p_end))

    #Y_batches = torch.cat(Y_batches)
    #Y_preds = torch.cat(Y_preds)
    Valid_f1_start = sum(F1_start)/len(val_dataloader)
    Valid_f1_end = sum(F1_end)/len(val_dataloader)
    print(f"Epoch {epoch:3}: Valid Loss = {sum(batch_losses_val)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid f1_score for entity start span = {Valid_f1_start:.5f}")
    print(f"Epoch {epoch:3}: Valid Acurracy for entity start span = {sum(accuracy_start)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Recall for entity start span = {sum(recall_start)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Precision for entity start span = {sum(precision_start)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid f1_score for entity end span = {Valid_f1_end:.5f}")
    print(f"Epoch {epoch:3}: Valid Acurracy for entity end span = {sum(accuracy_end)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Recall for entity end span = {sum(recall_end)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Precision for entity end span = {sum(precision_end)/len(val_dataloader):.5f}")
    list_loss.append(sum(batch_losses_val)/len(val_dataloader))
    list_epochs.append(epoch)
    if Valid_f1_start >= max_f1_start and Valid_f1_end >= max_f1_end:
      max_f1_start = Valid_f1_start
      max_f1_end = Valid_f1_end
      best_model = model
      print('The current f1 score for entity start:', Valid_f1_start)
      print('The current f1 score for entity end:', Valid_f1_end)
    if Valid_f1_start < the_last_f1_start_score and Valid_f1_end < the_last_f1_end_score:
      trigger_times += 1
      print('trigger times:', trigger_times)
      if trigger_times >= patience:
        print('Early stopping!\nStart to test process.')
        break;
    the_last_f1_start_score = Valid_f1_start
    the_last_f1_end_score = Valid_f1_end

 return max_f1_start, max_f1_end, list_loss_train, list_loss, list_epochs, best_model

# %% [markdown]
# **The function named get_entity_results finds results for the neural networks concerning the relation index and the entity span indexes (start,end). These functions have as arguments the corresponding training dataloader, the corresponding validation dataloader, the number of epochs ,the optimizer, the scheduler get_linear_schedule_with_warmup, the corresponding entity span prediction neural network model, the loss function, the learning rate and the SEED number.**
#
# **This function returns the list of training losses, the list of validation losses, and the list of how many epochs each model with each activation function needs to be fully trained.**

# %%
learning_rate  = 2e-5
dropout_prob = 0.3
epochs = 20
list_entity_training_losses = []
list_entity_validation_losses = []
list_entity_epochs = []
loss_func = nn.CrossEntropyLoss()
optimizer_name = "Adam"
activations_list = ['LeakyReLU','Tanhshrink', 'Softplus','ELU']
def get_entity_results(activation, max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_dataset, valid_dataset, train_dataloader, val_dataloader, SEED):
 set_seed(SEED)
 model = BertEntitySpanClassifier(activation, dropout_prob, max_question_length).to(device)
 print(model)
 loss_func = loss_func.to(device)
 optimizer = getattr(torch.optim, optimizer_name)(model.parameters(), lr=learning_rate)
 scheduler = get_linear_schedule_with_warmup(optimizer, 0, len(train_dataloader)*epochs)
 f1_start, f1_end, list_loss_train, list_loss_valid, list_epochs, best_entity_model = entity_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, learning_rate, dropout_prob)
 print(f1_start,f1_end)
 torch.save(best_entity_model.state_dict(), create_file(f"drive/MyDrive/Entity_span_indexes_models_best_parameters/Answerable_Questions/{activation}", f"entity_span_prediction_cosine_similarity_answerable_questions_{activation}.pt") )
 print(f"The best parameters are saved for the activation function: {activation}")
 return list_loss_train, list_loss_valid, list_epochs

# %%
list_entity_loss_train_leakyrelu, list_entity_loss_valid_leakyrelu, list_epochs_leakyrelu = get_entity_results("LeakyReLU", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): LeakyReLU(negative_slope=0.01)
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.64546
# Epoch   0: Valid Loss = 13.36132
# Epoch   0: Valid f1_score for entity start span = 0.44572
# Epoch   0: Valid Acurracy for entity start span = 0.44572
# Epoch   0: Valid Recall for entity start span = 0.44572
# Epoch   0: Valid Precision for entity start span = 0.44572
# Epoch   0: Valid f1_score for entity end span = 0.30176
# Epoch   0: Valid Acurracy for entity end span = 0.30176
# Epoch   0: Valid Recall for entity end span = 0.30176
# Epoch   0: Valid Precision for entity end span = 0.30176
# The current f1 score for entity start: 0.4457162921348315
# The current f1 score for entity end: 0.3017556179775281
# Epoch   1: Train Loss = 13.34916
# Epoch   1: Valid Loss = 13.09603
# Epoch   1: Valid f1_score for entity start span = 0.60997
# Epoch   1: Valid Acurracy for entity start span = 0.60997
# Epoch   1: Valid Recall for entity start span = 0.60997
# Epoch   1: Valid Precision for entity start span = 0.60997
# Epoch   1: Valid f1_score for entity end span = 0.40042
# Epoch   1: Valid Acurracy for entity end span = 0.40042
# Epoch   1: Valid Recall for entity end span = 0.40042
# Epoch   1: Valid Precision for entity end span = 0.40042
# The current f1 score for entity start: 0.6099719101123595
# The current f1 score for entity end: 0.4004213483146068
# Epoch   2: Train Loss = 13.17833
# Epoch   2: Valid Loss = 12.82173
# Epoch   2: Valid f1_score for entity start span = 0.61594
# Epoch   2: Valid Acurracy for entity start span = 0.61594
# Epoch   2: Valid Recall for entity start span = 0.61594
# Epoch   2: Valid Precision for entity start span = 0.61594
# Epoch   2: Valid f1_score for entity end span = 0.71566
# Epoch   2: Valid Acurracy for entity end span = 0.71566
# Epoch   2: Valid Recall for entity end span = 0.71566
# Epoch   2: Valid Precision for entity end span = 0.71566
# The current f1 score for entity start: 0.6159410112359551
# The current f1 score for entity end: 0.7156601123595506
# Epoch   3: Train Loss = 12.90629
# Epoch   3: Valid Loss = 12.50538
# Epoch   3: Valid f1_score for entity start span = 0.80513
# Epoch   3: Valid Acurracy for entity start span = 0.80513
# Epoch   3: Valid Recall for entity start span = 0.80513
# Epoch   3: Valid Precision for entity start span = 0.80513
# Epoch   3: Valid f1_score for entity end span = 0.80569
# Epoch   3: Valid Acurracy for entity end span = 0.80569
# Epoch   3: Valid Recall for entity end span = 0.80569
# Epoch   3: Valid Precision for entity end span = 0.80569
# The current f1 score for entity start: 0.805126404494382
# The current f1 score for entity end: 0.805688202247191
# Epoch   4: Train Loss = 12.84412
# Epoch   4: Valid Loss = 12.43590
# Epoch   4: Valid f1_score for entity start span = 0.83694
# Epoch   4: Valid Acurracy for entity start span = 0.83694
# Epoch   4: Valid Recall for entity start span = 0.83694
# Epoch   4: Valid Precision for entity start span = 0.83694
# Epoch   4: Valid f1_score for entity end span = 0.84010
# Epoch   4: Valid Acurracy for entity end span = 0.84010
# Epoch   4: Valid Recall for entity end span = 0.84010
# Epoch   4: Valid Precision for entity end span = 0.84010
# The current f1 score for entity start: 0.836938202247191
# The current f1 score for entity end: 0.8400983146067416
# Epoch   5: Train Loss = 12.79221
# Epoch   5: Valid Loss = 12.36610
# Epoch   5: Valid f1_score for entity start span = 0.85028
# Epoch   5: Valid Acurracy for entity start span = 0.85028
# Epoch   5: Valid Recall for entity start span = 0.85028
# Epoch   5: Valid Precision for entity start span = 0.85028
# Epoch   5: Valid f1_score for entity end span = 0.85590
# Epoch   5: Valid Acurracy for entity end span = 0.85590
# Epoch   5: Valid Recall for entity end span = 0.85590
# Epoch   5: Valid Precision for entity end span = 0.85590
# The current f1 score for entity start: 0.8502808988764045
# The current f1 score for entity end: 0.8558988764044944
# Epoch   6: Train Loss = 12.76658
# Epoch   6: Valid Loss = 12.33909
# Epoch   6: Valid f1_score for entity start span = 0.86060
# Epoch   6: Valid Acurracy for entity start span = 0.86060
# Epoch   6: Valid Recall for entity start span = 0.86060
# Epoch   6: Valid Precision for entity start span = 0.86060
# Epoch   6: Valid f1_score for entity end span = 0.86032
# Epoch   6: Valid Acurracy for entity end span = 0.86032
# Epoch   6: Valid Recall for entity end span = 0.86032
# Epoch   6: Valid Precision for entity end span = 0.86032
# The current f1 score for entity start: 0.8606039325842697
# The current f1 score for entity end: 0.8603230337078651
# Epoch   7: Train Loss = 12.75768
# Epoch   7: Valid Loss = 12.30556
# Epoch   7: Valid f1_score for entity start span = 0.87430
# Epoch   7: Valid Acurracy for entity start span = 0.87430
# Epoch   7: Valid Recall for entity start span = 0.87430
# Epoch   7: Valid Precision for entity start span = 0.87430
# Epoch   7: Valid f1_score for entity end span = 0.86622
# Epoch   7: Valid Acurracy for entity end span = 0.86622
# Epoch   7: Valid Recall for entity end span = 0.86622
# Epoch   7: Valid Precision for entity end span = 0.86622
# The current f1 score for entity start: 0.8742977528089888
# The current f1 score for entity end: 0.8662219101123596
# Epoch   8: Train Loss = 12.73672
# Epoch   8: Valid Loss = 12.28662
# Epoch   8: Valid f1_score for entity start span = 0.88413
# Epoch   8: Valid Acurracy for entity start span = 0.88413
# Epoch   8: Valid Recall for entity start span = 0.88413
# Epoch   8: Valid Precision for entity start span = 0.88413
# Epoch   8: Valid f1_score for entity end span = 0.86749
# Epoch   8: Valid Acurracy for entity end span = 0.86749
# Epoch   8: Valid Recall for entity end span = 0.86749
# Epoch   8: Valid Precision for entity end span = 0.86749
# The current f1 score for entity start: 0.8841292134831461
# The current f1 score for entity end: 0.8674859550561798
# Epoch   9: Train Loss = 12.72306
# Epoch   9: Valid Loss = 12.27073
# Epoch   9: Valid f1_score for entity start span = 0.87858
# Epoch   9: Valid Acurracy for entity start span = 0.87858
# Epoch   9: Valid Recall for entity start span = 0.87858
# Epoch   9: Valid Precision for entity start span = 0.87858
# Epoch   9: Valid f1_score for entity end span = 0.88448
# Epoch   9: Valid Acurracy for entity end span = 0.88448
# Epoch   9: Valid Recall for entity end span = 0.88448
# Epoch   9: Valid Precision for entity end span = 0.88448
# Epoch  10: Train Loss = 12.71508
# Epoch  10: Valid Loss = 12.26318
# Epoch  10: Valid f1_score for entity start span = 0.88553
# Epoch  10: Valid Acurracy for entity start span = 0.88553
# Epoch  10: Valid Recall for entity start span = 0.88553
# Epoch  10: Valid Precision for entity start span = 0.88553
# Epoch  10: Valid f1_score for entity end span = 0.88750
# Epoch  10: Valid Acurracy for entity end span = 0.88750
# Epoch  10: Valid Recall for entity end span = 0.88750
# Epoch  10: Valid Precision for entity end span = 0.88750
# The current f1 score for entity start: 0.8855337078651685
# The current f1 score for entity end: 0.8875
# Epoch  11: Train Loss = 12.71339
# Epoch  11: Valid Loss = 12.25379
# Epoch  11: Valid f1_score for entity start span = 0.88539
# Epoch  11: Valid Acurracy for entity start span = 0.88539
# Epoch  11: Valid Recall for entity start span = 0.88539
# Epoch  11: Valid Precision for entity start span = 0.88539
# Epoch  11: Valid f1_score for entity end span = 0.89185
# Epoch  11: Valid Acurracy for entity end span = 0.89185
# Epoch  11: Valid Recall for entity end span = 0.89185
# Epoch  11: Valid Precision for entity end span = 0.89185
# Epoch  12: Train Loss = 12.71049
# Epoch  12: Valid Loss = 12.23502
# Epoch  12: Valid f1_score for entity start span = 0.89185
# Epoch  12: Valid Acurracy for entity start span = 0.89185
# Epoch  12: Valid Recall for entity start span = 0.89185
# Epoch  12: Valid Precision for entity start span = 0.89185
# Epoch  12: Valid f1_score for entity end span = 0.90730
# Epoch  12: Valid Acurracy for entity end span = 0.90730
# Epoch  12: Valid Recall for entity end span = 0.90730
# Epoch  12: Valid Precision for entity end span = 0.90730
# The current f1 score for entity start: 0.8918539325842697
# The current f1 score for entity end: 0.9073033707865169
# Epoch  13: Train Loss = 12.69694
# Epoch  13: Valid Loss = 12.22408
# Epoch  13: Valid f1_score for entity start span = 0.89185
# Epoch  13: Valid Acurracy for entity start span = 0.89185
# Epoch  13: Valid Recall for entity start span = 0.89185
# Epoch  13: Valid Precision for entity start span = 0.89185
# Epoch  13: Valid f1_score for entity end span = 0.90976
# Epoch  13: Valid Acurracy for entity end span = 0.90976
# Epoch  13: Valid Recall for entity end span = 0.90976
# Epoch  13: Valid Precision for entity end span = 0.90976
# The current f1 score for entity start: 0.8918539325842697
# The current f1 score for entity end: 0.9097612359550562
# Epoch  14: Train Loss = 12.69009
# Epoch  14: Valid Loss = 12.21781
# Epoch  14: Valid f1_score for entity start span = 0.89466
# Epoch  14: Valid Acurracy for entity start span = 0.89466
# Epoch  14: Valid Recall for entity start span = 0.89466
# Epoch  14: Valid Precision for entity start span = 0.89466
# Epoch  14: Valid f1_score for entity end span = 0.91187
# Epoch  14: Valid Acurracy for entity end span = 0.91187
# Epoch  14: Valid Recall for entity end span = 0.91187
# Epoch  14: Valid Precision for entity end span = 0.91187
# The current f1 score for entity start: 0.8946629213483146
# The current f1 score for entity end: 0.9118679775280899
# Epoch  15: Train Loss = 12.69523
# Epoch  15: Valid Loss = 12.21567
# Epoch  15: Valid f1_score for entity start span = 0.89466
# Epoch  15: Valid Acurracy for entity start span = 0.89466
# Epoch  15: Valid Recall for entity start span = 0.89466
# Epoch  15: Valid Precision for entity start span = 0.89466
# Epoch  15: Valid f1_score for entity end span = 0.91173
# Epoch  15: Valid Acurracy for entity end span = 0.91173
# Epoch  15: Valid Recall for entity end span = 0.91173
# Epoch  15: Valid Precision for entity end span = 0.91173
# Epoch  16: Train Loss = 12.69243
# Epoch  16: Valid Loss = 12.21303
# Epoch  16: Valid f1_score for entity start span = 0.89712
# Epoch  16: Valid Acurracy for entity start span = 0.89712
# Epoch  16: Valid Recall for entity start span = 0.89712
# Epoch  16: Valid Precision for entity start span = 0.89712
# Epoch  16: Valid f1_score for entity end span = 0.91278
# Epoch  16: Valid Acurracy for entity end span = 0.91278
# Epoch  16: Valid Recall for entity end span = 0.91278
# Epoch  16: Valid Precision for entity end span = 0.91278
# The current f1 score for entity start: 0.8971207865168539
# The current f1 score for entity end: 0.9127808988764045
# Epoch  17: Train Loss = 12.68383
# Epoch  17: Valid Loss = 12.20898
# Epoch  17: Valid f1_score for entity start span = 0.89487
# Epoch  17: Valid Acurracy for entity start span = 0.89487
# Epoch  17: Valid Recall for entity start span = 0.89487
# Epoch  17: Valid Precision for entity start span = 0.89487
# Epoch  17: Valid f1_score for entity end span = 0.91538
# Epoch  17: Valid Acurracy for entity end span = 0.91538
# Epoch  17: Valid Recall for entity end span = 0.91538
# Epoch  17: Valid Precision for entity end span = 0.91538
# Epoch  18: Train Loss = 12.68650
# Epoch  18: Valid Loss = 12.20470
# Epoch  18: Valid f1_score for entity start span = 0.89712
# Epoch  18: Valid Acurracy for entity start span = 0.89712
# Epoch  18: Valid Recall for entity start span = 0.89712
# Epoch  18: Valid Precision for entity start span = 0.89712
# Epoch  18: Valid f1_score for entity end span = 0.91643
# Epoch  18: Valid Acurracy for entity end span = 0.91643
# Epoch  18: Valid Recall for entity end span = 0.91643
# Epoch  18: Valid Precision for entity end span = 0.91643
# The current f1 score for entity start: 0.8971207865168539
# The current f1 score for entity end: 0.9164325842696629
# Epoch  19: Train Loss = 12.70033
# Epoch  19: Valid Loss = 12.20404
# Epoch  19: Valid f1_score for entity start span = 0.89747
# Epoch  19: Valid Acurracy for entity start span = 0.89747
# Epoch  19: Valid Recall for entity start span = 0.89747
# Epoch  19: Valid Precision for entity start span = 0.89747
# Epoch  19: Valid f1_score for entity end span = 0.91643
# Epoch  19: Valid Acurracy for entity end span = 0.91643
# Epoch  19: Valid Recall for entity end span = 0.91643
# Epoch  19: Valid Precision for entity end span = 0.91643
# The current f1 score for entity start: 0.8974719101123596
# The current f1 score for entity end: 0.9164325842696629
# 0.8974719101123596 0.9164325842696629
# The best parameters are saved for the activation function: LeakyReLU

# %%
list_entity_loss_train_tanhshrink, list_entity_loss_valid_tanhshrink, list_epochs_tanhshrink = get_entity_results("Tanhshrink", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): Tanhshrink()
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Tanhshrink()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Tanhshrink()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.68456
# Epoch   0: Valid Loss = 13.41028
# Epoch   0: Valid f1_score for entity start span = 0.44712
# Epoch   0: Valid Acurracy for entity start span = 0.44712
# Epoch   0: Valid Recall for entity start span = 0.44712
# Epoch   0: Valid Precision for entity start span = 0.44712
# Epoch   0: Valid f1_score for entity end span = 0.19537
# Epoch   0: Valid Acurracy for entity end span = 0.19537
# Epoch   0: Valid Recall for entity end span = 0.19537
# Epoch   0: Valid Precision for entity end span = 0.19537
# The current f1 score for entity start: 0.44712078651685394
# The current f1 score for entity end: 0.19536516853932584
# Epoch   1: Train Loss = 13.34264
# Epoch   1: Valid Loss = 12.99723
# Epoch   1: Valid f1_score for entity start span = 0.59663
# Epoch   1: Valid Acurracy for entity start span = 0.59663
# Epoch   1: Valid Recall for entity start span = 0.59663
# Epoch   1: Valid Precision for entity start span = 0.59663
# Epoch   1: Valid f1_score for entity end span = 0.46152
# Epoch   1: Valid Acurracy for entity end span = 0.46152
# Epoch   1: Valid Recall for entity end span = 0.46152
# Epoch   1: Valid Precision for entity end span = 0.46152
# The current f1 score for entity start: 0.5966292134831461
# The current f1 score for entity end: 0.4615168539325843
# Epoch   2: Train Loss = 13.21309
# Epoch   2: Valid Loss = 12.87388
# Epoch   2: Valid f1_score for entity start span = 0.69473
# Epoch   2: Valid Acurracy for entity start span = 0.69473
# Epoch   2: Valid Recall for entity start span = 0.69473
# Epoch   2: Valid Precision for entity start span = 0.69473
# Epoch   2: Valid f1_score for entity end span = 0.50709
# Epoch   2: Valid Acurracy for entity end span = 0.50709
# Epoch   2: Valid Recall for entity end span = 0.50709
# Epoch   2: Valid Precision for entity end span = 0.50709
# The current f1 score for entity start: 0.6947331460674157
# The current f1 score for entity end: 0.5070926966292135
# Epoch   3: Train Loss = 13.02591
# Epoch   3: Valid Loss = 12.58733
# Epoch   3: Valid f1_score for entity start span = 0.80232
# Epoch   3: Valid Acurracy for entity start span = 0.80232
# Epoch   3: Valid Recall for entity start span = 0.80232
# Epoch   3: Valid Precision for entity start span = 0.80232
# Epoch   3: Valid f1_score for entity end span = 0.65681
# Epoch   3: Valid Acurracy for entity end span = 0.65681
# Epoch   3: Valid Recall for entity end span = 0.65681
# Epoch   3: Valid Precision for entity end span = 0.65681
# The current f1 score for entity start: 0.8023174157303371
# The current f1 score for entity end: 0.656811797752809
# Epoch   4: Train Loss = 12.92868
# Epoch   4: Valid Loss = 12.51032
# Epoch   4: Valid f1_score for entity start span = 0.84923
# Epoch   4: Valid Acurracy for entity start span = 0.84923
# Epoch   4: Valid Recall for entity start span = 0.84923
# Epoch   4: Valid Precision for entity start span = 0.84923
# Epoch   4: Valid f1_score for entity end span = 0.68020
# Epoch   4: Valid Acurracy for entity end span = 0.68020
# Epoch   4: Valid Recall for entity end span = 0.68020
# Epoch   4: Valid Precision for entity end span = 0.68020
# The current f1 score for entity start: 0.8492275280898877
# The current f1 score for entity end: 0.6801966292134831
# Epoch   5: Train Loss = 12.85456
# Epoch   5: Valid Loss = 12.39546
# Epoch   5: Valid f1_score for entity start span = 0.87662
# Epoch   5: Valid Acurracy for entity start span = 0.87662
# Epoch   5: Valid Recall for entity start span = 0.87662
# Epoch   5: Valid Precision for entity start span = 0.87662
# Epoch   5: Valid f1_score for entity end span = 0.75618
# Epoch   5: Valid Acurracy for entity end span = 0.75618
# Epoch   5: Valid Recall for entity end span = 0.75618
# Epoch   5: Valid Precision for entity end span = 0.75618
# The current f1 score for entity start: 0.8766151685393259
# The current f1 score for entity end: 0.7561797752808989
# Epoch   6: Train Loss = 12.80772
# Epoch   6: Valid Loss = 12.35347
# Epoch   6: Valid f1_score for entity start span = 0.87184
# Epoch   6: Valid Acurracy for entity start span = 0.87184
# Epoch   6: Valid Recall for entity start span = 0.87184
# Epoch   6: Valid Precision for entity start span = 0.87184
# Epoch   6: Valid f1_score for entity end span = 0.80414
# Epoch   6: Valid Acurracy for entity end span = 0.80414
# Epoch   6: Valid Recall for entity end span = 0.80414
# Epoch   6: Valid Precision for entity end span = 0.80414
# Epoch   7: Train Loss = 12.78417
# Epoch   7: Valid Loss = 12.31923
# Epoch   7: Valid f1_score for entity start span = 0.87324
# Epoch   7: Valid Acurracy for entity start span = 0.87324
# Epoch   7: Valid Recall for entity start span = 0.87324
# Epoch   7: Valid Precision for entity start span = 0.87324
# Epoch   7: Valid f1_score for entity end span = 0.82971
# Epoch   7: Valid Acurracy for entity end span = 0.82971
# Epoch   7: Valid Recall for entity end span = 0.82971
# Epoch   7: Valid Precision for entity end span = 0.82971
# Epoch   8: Train Loss = 12.75501
# Epoch   8: Valid Loss = 12.29099
# Epoch   8: Valid f1_score for entity start span = 0.89080
# Epoch   8: Valid Acurracy for entity start span = 0.89080
# Epoch   8: Valid Recall for entity start span = 0.89080
# Epoch   8: Valid Precision for entity start span = 0.89080
# Epoch   8: Valid f1_score for entity end span = 0.83624
# Epoch   8: Valid Acurracy for entity end span = 0.83624
# Epoch   8: Valid Recall for entity end span = 0.83624
# Epoch   8: Valid Precision for entity end span = 0.83624
# The current f1 score for entity start: 0.8908005617977528
# The current f1 score for entity end: 0.8362359550561798
# Epoch   9: Train Loss = 12.73594
# Epoch   9: Valid Loss = 12.24481
# Epoch   9: Valid f1_score for entity start span = 0.89824
# Epoch   9: Valid Acurracy for entity start span = 0.89824
# Epoch   9: Valid Recall for entity start span = 0.89824
# Epoch   9: Valid Precision for entity start span = 0.89824
# Epoch   9: Valid f1_score for entity end span = 0.88237
# Epoch   9: Valid Acurracy for entity end span = 0.88237
# Epoch   9: Valid Recall for entity end span = 0.88237
# Epoch   9: Valid Precision for entity end span = 0.88237
# The current f1 score for entity start: 0.8982443820224718
# The current f1 score for entity end: 0.882373595505618
# Epoch  10: Train Loss = 12.71505
# Epoch  10: Valid Loss = 12.22445
# Epoch  10: Valid f1_score for entity start span = 0.91081
# Epoch  10: Valid Acurracy for entity start span = 0.91081
# Epoch  10: Valid Recall for entity start span = 0.91081
# Epoch  10: Valid Precision for entity start span = 0.91081
# Epoch  10: Valid f1_score for entity end span = 0.88610
# Epoch  10: Valid Acurracy for entity end span = 0.88610
# Epoch  10: Valid Recall for entity end span = 0.88610
# Epoch  10: Valid Precision for entity end span = 0.88610
# The current f1 score for entity start: 0.910814606741573
# The current f1 score for entity end: 0.8860955056179775
# Epoch  11: Train Loss = 12.70613
# Epoch  11: Valid Loss = 12.21598
# Epoch  11: Valid f1_score for entity start span = 0.91327
# Epoch  11: Valid Acurracy for entity start span = 0.91327
# Epoch  11: Valid Recall for entity start span = 0.91327
# Epoch  11: Valid Precision for entity start span = 0.91327
# Epoch  11: Valid f1_score for entity end span = 0.88539
# Epoch  11: Valid Acurracy for entity end span = 0.88539
# Epoch  11: Valid Recall for entity end span = 0.88539
# Epoch  11: Valid Precision for entity end span = 0.88539
# Epoch  12: Train Loss = 12.70519
# Epoch  12: Valid Loss = 12.20414
# Epoch  12: Valid f1_score for entity start span = 0.91397
# Epoch  12: Valid Acurracy for entity start span = 0.91397
# Epoch  12: Valid Recall for entity start span = 0.91397
# Epoch  12: Valid Precision for entity start span = 0.91397
# Epoch  12: Valid f1_score for entity end span = 0.89361
# Epoch  12: Valid Acurracy for entity end span = 0.89361
# Epoch  12: Valid Recall for entity end span = 0.89361
# Epoch  12: Valid Precision for entity end span = 0.89361
# The current f1 score for entity start: 0.9139747191011236
# The current f1 score for entity end: 0.8936095505617978
# Epoch  13: Train Loss = 12.69193
# Epoch  13: Valid Loss = 12.19648
# Epoch  13: Valid f1_score for entity start span = 0.91994
# Epoch  13: Valid Acurracy for entity start span = 0.91994
# Epoch  13: Valid Recall for entity start span = 0.91994
# Epoch  13: Valid Precision for entity start span = 0.91994
# Epoch  13: Valid f1_score for entity end span = 0.89466
# Epoch  13: Valid Acurracy for entity end span = 0.89466
# Epoch  13: Valid Recall for entity end span = 0.89466
# Epoch  13: Valid Precision for entity end span = 0.89466
# The current f1 score for entity start: 0.9199438202247191
# The current f1 score for entity end: 0.8946629213483146
# Epoch  14: Train Loss = 12.68227
# Epoch  14: Valid Loss = 12.18192
# Epoch  14: Valid f1_score for entity start span = 0.92065
# Epoch  14: Valid Acurracy for entity start span = 0.92065
# Epoch  14: Valid Recall for entity start span = 0.92065
# Epoch  14: Valid Precision for entity start span = 0.92065
# Epoch  14: Valid f1_score for entity end span = 0.90836
# Epoch  14: Valid Acurracy for entity end span = 0.90836
# Epoch  14: Valid Recall for entity end span = 0.90836
# Epoch  14: Valid Precision for entity end span = 0.90836
# The current f1 score for entity start: 0.9206460674157303
# The current f1 score for entity end: 0.9083567415730337
# Epoch  15: Train Loss = 12.68314
# Epoch  15: Valid Loss = 12.17916
# Epoch  15: Valid f1_score for entity start span = 0.92416
# Epoch  15: Valid Acurracy for entity start span = 0.92416
# Epoch  15: Valid Recall for entity start span = 0.92416
# Epoch  15: Valid Precision for entity start span = 0.92416
# Epoch  15: Valid f1_score for entity end span = 0.90927
# Epoch  15: Valid Acurracy for entity end span = 0.90927
# Epoch  15: Valid Recall for entity end span = 0.90927
# Epoch  15: Valid Precision for entity end span = 0.90927
# The current f1 score for entity start: 0.9241573033707865
# The current f1 score for entity end: 0.9092696629213483
# Epoch  16: Train Loss = 12.68069
# Epoch  16: Valid Loss = 12.17655
# Epoch  16: Valid f1_score for entity start span = 0.92486
# Epoch  16: Valid Acurracy for entity start span = 0.92486
# Epoch  16: Valid Recall for entity start span = 0.92486
# Epoch  16: Valid Precision for entity start span = 0.92486
# Epoch  16: Valid f1_score for entity end span = 0.90892
# Epoch  16: Valid Acurracy for entity end span = 0.90892
# Epoch  16: Valid Recall for entity end span = 0.90892
# Epoch  16: Valid Precision for entity end span = 0.90892
# Epoch  17: Train Loss = 12.66940
# Epoch  17: Valid Loss = 12.16706
# Epoch  17: Valid f1_score for entity start span = 0.92732
# Epoch  17: Valid Acurracy for entity start span = 0.92732
# Epoch  17: Valid Recall for entity start span = 0.92732
# Epoch  17: Valid Precision for entity start span = 0.92732
# Epoch  17: Valid f1_score for entity end span = 0.91327
# Epoch  17: Valid Acurracy for entity end span = 0.91327
# Epoch  17: Valid Recall for entity end span = 0.91327
# Epoch  17: Valid Precision for entity end span = 0.91327
# The current f1 score for entity start: 0.9273174157303371
# The current f1 score for entity end: 0.9132724719101124
# Epoch  18: Train Loss = 12.67125
# Epoch  18: Valid Loss = 12.16701
# Epoch  18: Valid f1_score for entity start span = 0.92662
# Epoch  18: Valid Acurracy for entity start span = 0.92662
# Epoch  18: Valid Recall for entity start span = 0.92662
# Epoch  18: Valid Precision for entity start span = 0.92662
# Epoch  18: Valid f1_score for entity end span = 0.91468
# Epoch  18: Valid Acurracy for entity end span = 0.91468
# Epoch  18: Valid Recall for entity end span = 0.91468
# Epoch  18: Valid Precision for entity end span = 0.91468
# Epoch  19: Train Loss = 12.68541
# Epoch  19: Valid Loss = 12.16610
# Epoch  19: Valid f1_score for entity start span = 0.92802
# Epoch  19: Valid Acurracy for entity start span = 0.92802
# Epoch  19: Valid Recall for entity start span = 0.92802
# Epoch  19: Valid Precision for entity start span = 0.92802
# Epoch  19: Valid f1_score for entity end span = 0.91433
# Epoch  19: Valid Acurracy for entity end span = 0.91433
# Epoch  19: Valid Recall for entity end span = 0.91433
# Epoch  19: Valid Precision for entity end span = 0.91433
# The current f1 score for entity start: 0.9280196629213483
# The current f1 score for entity end: 0.9143258426966292
# 0.9280196629213483 0.9143258426966292
# The best parameters are saved for the activation function: Tanhshrink

# %%
list_entity_loss_train_elu, list_entity_loss_valid_elu, list_epochs_elu = get_entity_results("ELU", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): ELU(alpha=1.0)
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.60437
# Epoch   0: Valid Loss = 13.32569
# Epoch   0: Valid f1_score for entity start span = 0.44923
# Epoch   0: Valid Acurracy for entity start span = 0.44923
# Epoch   0: Valid Recall for entity start span = 0.44923
# Epoch   0: Valid Precision for entity start span = 0.44923
# Epoch   0: Valid f1_score for entity end span = 0.30878
# Epoch   0: Valid Acurracy for entity end span = 0.30878
# Epoch   0: Valid Recall for entity end span = 0.30878
# Epoch   0: Valid Precision for entity end span = 0.30878
# The current f1 score for entity start: 0.4492275280898877
# The current f1 score for entity end: 0.30877808988764044
# Epoch   1: Train Loss = 13.15898
# Epoch   1: Valid Loss = 12.79241
# Epoch   1: Valid f1_score for entity start span = 0.76447
# Epoch   1: Valid Acurracy for entity start span = 0.76447
# Epoch   1: Valid Recall for entity start span = 0.76447
# Epoch   1: Valid Precision for entity start span = 0.76447
# Epoch   1: Valid f1_score for entity end span = 0.59389
# Epoch   1: Valid Acurracy for entity end span = 0.59389
# Epoch   1: Valid Recall for entity end span = 0.59389
# Epoch   1: Valid Precision for entity end span = 0.59389
# The current f1 score for entity start: 0.7644662921348314
# The current f1 score for entity end: 0.5938904494382022
# Epoch   2: Train Loss = 12.94018
# Epoch   2: Valid Loss = 12.52639
# Epoch   2: Valid f1_score for entity start span = 0.82746
# Epoch   2: Valid Acurracy for entity start span = 0.82746
# Epoch   2: Valid Recall for entity start span = 0.82746
# Epoch   2: Valid Precision for entity start span = 0.82746
# Epoch   2: Valid f1_score for entity end span = 0.75302
# Epoch   2: Valid Acurracy for entity end span = 0.75302
# Epoch   2: Valid Recall for entity end span = 0.75302
# Epoch   2: Valid Precision for entity end span = 0.75302
# The current f1 score for entity start: 0.8274578651685393
# The current f1 score for entity end: 0.7530196629213483
# Epoch   3: Train Loss = 12.82973
# Epoch   3: Valid Loss = 12.41910
# Epoch   3: Valid f1_score for entity start span = 0.85077
# Epoch   3: Valid Acurracy for entity start span = 0.85077
# Epoch   3: Valid Recall for entity start span = 0.85077
# Epoch   3: Valid Precision for entity start span = 0.85077
# Epoch   3: Valid f1_score for entity end span = 0.81587
# Epoch   3: Valid Acurracy for entity end span = 0.81587
# Epoch   3: Valid Recall for entity end span = 0.81587
# Epoch   3: Valid Precision for entity end span = 0.81587
# The current f1 score for entity start: 0.8507724719101124
# The current f1 score for entity end: 0.8158707865168539
# Epoch   4: Train Loss = 12.79786
# Epoch   4: Valid Loss = 12.36484
# Epoch   4: Valid f1_score for entity start span = 0.86749
# Epoch   4: Valid Acurracy for entity start span = 0.86749
# Epoch   4: Valid Recall for entity start span = 0.86749
# Epoch   4: Valid Precision for entity start span = 0.86749
# Epoch   4: Valid f1_score for entity end span = 0.85506
# Epoch   4: Valid Acurracy for entity end span = 0.85506
# Epoch   4: Valid Recall for entity end span = 0.85506
# Epoch   4: Valid Precision for entity end span = 0.85506
# The current f1 score for entity start: 0.8674859550561798
# The current f1 score for entity end: 0.8550561797752808
# Epoch   5: Train Loss = 12.75281
# Epoch   5: Valid Loss = 12.29247
# Epoch   5: Valid f1_score for entity start span = 0.89066
# Epoch   5: Valid Acurracy for entity start span = 0.89066
# Epoch   5: Valid Recall for entity start span = 0.89066
# Epoch   5: Valid Precision for entity start span = 0.89066
# Epoch   5: Valid f1_score for entity end span = 0.88027
# Epoch   5: Valid Acurracy for entity end span = 0.88027
# Epoch   5: Valid Recall for entity end span = 0.88027
# Epoch   5: Valid Precision for entity end span = 0.88027
# The current f1 score for entity start: 0.8906601123595506
# The current f1 score for entity end: 0.8802668539325843
# Epoch   6: Train Loss = 12.72903
# Epoch   6: Valid Loss = 12.25947
# Epoch   6: Valid f1_score for entity start span = 0.91117
# Epoch   6: Valid Acurracy for entity start span = 0.91117
# Epoch   6: Valid Recall for entity start span = 0.91117
# Epoch   6: Valid Precision for entity start span = 0.91117
# Epoch   6: Valid f1_score for entity end span = 0.88139
# Epoch   6: Valid Acurracy for entity end span = 0.88139
# Epoch   6: Valid Recall for entity end span = 0.88139
# Epoch   6: Valid Precision for entity end span = 0.88139
# The current f1 score for entity start: 0.9111657303370787
# The current f1 score for entity end: 0.8813904494382022
# Epoch   7: Train Loss = 12.72198
# Epoch   7: Valid Loss = 12.24096
# Epoch   7: Valid f1_score for entity start span = 0.91749
# Epoch   7: Valid Acurracy for entity start span = 0.91749
# Epoch   7: Valid Recall for entity start span = 0.91749
# Epoch   7: Valid Precision for entity start span = 0.91749
# Epoch   7: Valid f1_score for entity end span = 0.88413
# Epoch   7: Valid Acurracy for entity end span = 0.88413
# Epoch   7: Valid Recall for entity end span = 0.88413
# Epoch   7: Valid Precision for entity end span = 0.88413
# The current f1 score for entity start: 0.9174859550561798
# The current f1 score for entity end: 0.8841292134831461
# Epoch   8: Train Loss = 12.70047
# Epoch   8: Valid Loss = 12.21966
# Epoch   8: Valid f1_score for entity start span = 0.92486
# Epoch   8: Valid Acurracy for entity start span = 0.92486
# Epoch   8: Valid Recall for entity start span = 0.92486
# Epoch   8: Valid Precision for entity start span = 0.92486
# Epoch   8: Valid f1_score for entity end span = 0.88715
# Epoch   8: Valid Acurracy for entity end span = 0.88715
# Epoch   8: Valid Recall for entity end span = 0.88715
# Epoch   8: Valid Precision for entity end span = 0.88715
# The current f1 score for entity start: 0.9248595505617978
# The current f1 score for entity end: 0.8871488764044944
# Epoch   9: Train Loss = 12.69159
# Epoch   9: Valid Loss = 12.20865
# Epoch   9: Valid f1_score for entity start span = 0.92612
# Epoch   9: Valid Acurracy for entity start span = 0.92612
# Epoch   9: Valid Recall for entity start span = 0.92612
# Epoch   9: Valid Precision for entity start span = 0.92612
# Epoch   9: Valid f1_score for entity end span = 0.88904
# Epoch   9: Valid Acurracy for entity end span = 0.88904
# Epoch   9: Valid Recall for entity end span = 0.88904
# Epoch   9: Valid Precision for entity end span = 0.88904
# The current f1 score for entity start: 0.926123595505618
# The current f1 score for entity end: 0.8890449438202247
# Epoch  10: Train Loss = 12.68755
# Epoch  10: Valid Loss = 12.19488
# Epoch  10: Valid f1_score for entity start span = 0.92732
# Epoch  10: Valid Acurracy for entity start span = 0.92732
# Epoch  10: Valid Recall for entity start span = 0.92732
# Epoch  10: Valid Precision for entity start span = 0.92732
# Epoch  10: Valid f1_score for entity end span = 0.90611
# Epoch  10: Valid Acurracy for entity end span = 0.90611
# Epoch  10: Valid Recall for entity end span = 0.90611
# Epoch  10: Valid Precision for entity end span = 0.90611
# The current f1 score for entity start: 0.9273174157303371
# The current f1 score for entity end: 0.9061095505617978
# Epoch  11: Train Loss = 12.67830
# Epoch  11: Valid Loss = 12.18418
# Epoch  11: Valid f1_score for entity start span = 0.92662
# Epoch  11: Valid Acurracy for entity start span = 0.92662
# Epoch  11: Valid Recall for entity start span = 0.92662
# Epoch  11: Valid Precision for entity start span = 0.92662
# Epoch  11: Valid f1_score for entity end span = 0.91257
# Epoch  11: Valid Acurracy for entity end span = 0.91257
# Epoch  11: Valid Recall for entity end span = 0.91257
# Epoch  11: Valid Precision for entity end span = 0.91257
# Epoch  12: Train Loss = 12.67881
# Epoch  12: Valid Loss = 12.17572
# Epoch  12: Valid f1_score for entity start span = 0.93083
# Epoch  12: Valid Acurracy for entity start span = 0.93083
# Epoch  12: Valid Recall for entity start span = 0.93083
# Epoch  12: Valid Precision for entity start span = 0.93083
# Epoch  12: Valid f1_score for entity end span = 0.91573
# Epoch  12: Valid Acurracy for entity end span = 0.91573
# Epoch  12: Valid Recall for entity end span = 0.91573
# Epoch  12: Valid Precision for entity end span = 0.91573
# The current f1 score for entity start: 0.9308286516853933
# The current f1 score for entity end: 0.9157303370786517
# Epoch  13: Train Loss = 12.66761
# Epoch  13: Valid Loss = 12.17094
# Epoch  13: Valid f1_score for entity start span = 0.92942
# Epoch  13: Valid Acurracy for entity start span = 0.92942
# Epoch  13: Valid Recall for entity start span = 0.92942
# Epoch  13: Valid Precision for entity start span = 0.92942
# Epoch  13: Valid f1_score for entity end span = 0.91433
# Epoch  13: Valid Acurracy for entity end span = 0.91433
# Epoch  13: Valid Recall for entity end span = 0.91433
# Epoch  13: Valid Precision for entity end span = 0.91433
# trigger times: 1
# Epoch  14: Train Loss = 12.66422
# Epoch  14: Valid Loss = 12.17105
# Epoch  14: Valid f1_score for entity start span = 0.93153
# Epoch  14: Valid Acurracy for entity start span = 0.93153
# Epoch  14: Valid Recall for entity start span = 0.93153
# Epoch  14: Valid Precision for entity start span = 0.93153
# Epoch  14: Valid f1_score for entity end span = 0.91608
# Epoch  14: Valid Acurracy for entity end span = 0.91608
# Epoch  14: Valid Recall for entity end span = 0.91608
# Epoch  14: Valid Precision for entity end span = 0.91608
# The current f1 score for entity start: 0.9315308988764045
# The current f1 score for entity end: 0.9160814606741573
# Epoch  15: Train Loss = 12.66682
# Epoch  15: Valid Loss = 12.16374
# Epoch  15: Valid f1_score for entity start span = 0.93434
# Epoch  15: Valid Acurracy for entity start span = 0.93434
# Epoch  15: Valid Recall for entity start span = 0.93434
# Epoch  15: Valid Precision for entity start span = 0.93434
# Epoch  15: Valid f1_score for entity end span = 0.91735
# Epoch  15: Valid Acurracy for entity end span = 0.91735
# Epoch  15: Valid Recall for entity end span = 0.91735
# Epoch  15: Valid Precision for entity end span = 0.91735
# The current f1 score for entity start: 0.9343398876404494
# The current f1 score for entity end: 0.9173455056179775
# Epoch  16: Train Loss = 12.66676
# Epoch  16: Valid Loss = 12.16361
# Epoch  16: Valid f1_score for entity start span = 0.93610
# Epoch  16: Valid Acurracy for entity start span = 0.93610
# Epoch  16: Valid Recall for entity start span = 0.93610
# Epoch  16: Valid Precision for entity start span = 0.93610
# Epoch  16: Valid f1_score for entity end span = 0.91489
# Epoch  16: Valid Acurracy for entity end span = 0.91489
# Epoch  16: Valid Recall for entity end span = 0.91489
# Epoch  16: Valid Precision for entity end span = 0.91489
# Epoch  17: Train Loss = 12.65762
# Epoch  17: Valid Loss = 12.15787
# Epoch  17: Valid f1_score for entity start span = 0.93504
# Epoch  17: Valid Acurracy for entity start span = 0.93504
# Epoch  17: Valid Recall for entity start span = 0.93504
# Epoch  17: Valid Precision for entity start span = 0.93504
# Epoch  17: Valid f1_score for entity end span = 0.91889
# Epoch  17: Valid Acurracy for entity end span = 0.91889
# Epoch  17: Valid Recall for entity end span = 0.91889
# Epoch  17: Valid Precision for entity end span = 0.91889
# The current f1 score for entity start: 0.9350421348314607
# The current f1 score for entity end: 0.9188904494382022
# Epoch  18: Train Loss = 12.66046
# Epoch  18: Valid Loss = 12.15616
# Epoch  18: Valid f1_score for entity start span = 0.93610
# Epoch  18: Valid Acurracy for entity start span = 0.93610
# Epoch  18: Valid Recall for entity start span = 0.93610
# Epoch  18: Valid Precision for entity start span = 0.93610
# Epoch  18: Valid f1_score for entity end span = 0.92065
# Epoch  18: Valid Acurracy for entity end span = 0.92065
# Epoch  18: Valid Recall for entity end span = 0.92065
# Epoch  18: Valid Precision for entity end span = 0.92065
# The current f1 score for entity start: 0.9360955056179775
# The current f1 score for entity end: 0.9206460674157303
# Epoch  19: Train Loss = 12.67462
# Epoch  19: Valid Loss = 12.15541
# Epoch  19: Valid f1_score for entity start span = 0.93610
# Epoch  19: Valid Acurracy for entity start span = 0.93610
# Epoch  19: Valid Recall for entity start span = 0.93610
# Epoch  19: Valid Precision for entity start span = 0.93610
# Epoch  19: Valid f1_score for entity end span = 0.92065
# Epoch  19: Valid Acurracy for entity end span = 0.92065
# Epoch  19: Valid Recall for entity end span = 0.92065
# Epoch  19: Valid Precision for entity end span = 0.92065
# The current f1 score for entity start: 0.9360955056179775
# The current f1 score for entity end: 0.9206460674157303
# 0.9360955056179775 0.9206460674157303
# The best parameters are saved for the activation function: ELU

# %%
list_entity_loss_train_softplus, list_entity_loss_valid_softplus, list_epochs_softplus = get_entity_results("Softplus", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): Softplus(beta=1, threshold=20)
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Softplus(beta=1, threshold=20)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Softplus(beta=1, threshold=20)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.65091
# Epoch   0: Valid Loss = 13.36144
# Epoch   0: Valid f1_score for entity start span = 0.44572
# Epoch   0: Valid Acurracy for entity start span = 0.44572
# Epoch   0: Valid Recall for entity start span = 0.44572
# Epoch   0: Valid Precision for entity start span = 0.44572
# Epoch   0: Valid f1_score for entity end span = 0.30316
# Epoch   0: Valid Acurracy for entity end span = 0.30316
# Epoch   0: Valid Recall for entity end span = 0.30316
# Epoch   0: Valid Precision for entity end span = 0.30316
# The current f1 score for entity start: 0.4457162921348315
# The current f1 score for entity end: 0.30316011235955054
# Epoch   1: Train Loss = 13.24780
# Epoch   1: Valid Loss = 12.92684
# Epoch   1: Valid f1_score for entity start span = 0.70688
# Epoch   1: Valid Acurracy for entity start span = 0.70688
# Epoch   1: Valid Recall for entity start span = 0.70688
# Epoch   1: Valid Precision for entity start span = 0.70688
# Epoch   1: Valid f1_score for entity end span = 0.51699
# Epoch   1: Valid Acurracy for entity end span = 0.51699
# Epoch   1: Valid Recall for entity end span = 0.51699
# Epoch   1: Valid Precision for entity end span = 0.51699
# The current f1 score for entity start: 0.7068820224719101
# The current f1 score for entity end: 0.5169943820224719
# Epoch   2: Train Loss = 13.00211
# Epoch   2: Valid Loss = 12.62623
# Epoch   2: Valid f1_score for entity start span = 0.82409
# Epoch   2: Valid Acurracy for entity start span = 0.82409
# Epoch   2: Valid Recall for entity start span = 0.82409
# Epoch   2: Valid Precision for entity start span = 0.82409
# Epoch   2: Valid f1_score for entity end span = 0.67612
# Epoch   2: Valid Acurracy for entity end span = 0.67612
# Epoch   2: Valid Recall for entity end span = 0.67612
# Epoch   2: Valid Precision for entity end span = 0.67612
# The current f1 score for entity start: 0.8240870786516854
# The current f1 score for entity end: 0.676123595505618
# Epoch   3: Train Loss = 12.87972
# Epoch   3: Valid Loss = 12.48892
# Epoch   3: Valid f1_score for entity start span = 0.84937
# Epoch   3: Valid Acurracy for entity start span = 0.84937
# Epoch   3: Valid Recall for entity start span = 0.84937
# Epoch   3: Valid Precision for entity start span = 0.84937
# Epoch   3: Valid f1_score for entity end span = 0.78111
# Epoch   3: Valid Acurracy for entity end span = 0.78111
# Epoch   3: Valid Recall for entity end span = 0.78111
# Epoch   3: Valid Precision for entity end span = 0.78111
# The current f1 score for entity start: 0.8493679775280899
# The current f1 score for entity end: 0.7811095505617978
# Epoch   4: Train Loss = 12.82063
# Epoch   4: Valid Loss = 12.40927
# Epoch   4: Valid f1_score for entity start span = 0.86468
# Epoch   4: Valid Acurracy for entity start span = 0.86468
# Epoch   4: Valid Recall for entity start span = 0.86468
# Epoch   4: Valid Precision for entity start span = 0.86468
# Epoch   4: Valid f1_score for entity end span = 0.82254
# Epoch   4: Valid Acurracy for entity end span = 0.82254
# Epoch   4: Valid Recall for entity end span = 0.82254
# Epoch   4: Valid Precision for entity end span = 0.82254
# The current f1 score for entity start: 0.8646769662921348
# The current f1 score for entity end: 0.8225421348314607
# Epoch   5: Train Loss = 12.77306
# Epoch   5: Valid Loss = 12.32336
# Epoch   5: Valid f1_score for entity start span = 0.88996
# Epoch   5: Valid Acurracy for entity start span = 0.88996
# Epoch   5: Valid Recall for entity start span = 0.88996
# Epoch   5: Valid Precision for entity start span = 0.88996
# Epoch   5: Valid f1_score for entity end span = 0.85765
# Epoch   5: Valid Acurracy for entity end span = 0.85765
# Epoch   5: Valid Recall for entity end span = 0.85765
# Epoch   5: Valid Precision for entity end span = 0.85765
# The current f1 score for entity start: 0.8899578651685393
# The current f1 score for entity end: 0.8576544943820225
# Epoch   6: Train Loss = 12.75134
# Epoch   6: Valid Loss = 12.31028
# Epoch   6: Valid f1_score for entity start span = 0.89537
# Epoch   6: Valid Acurracy for entity start span = 0.89537
# Epoch   6: Valid Recall for entity start span = 0.89537
# Epoch   6: Valid Precision for entity start span = 0.89537
# Epoch   6: Valid f1_score for entity end span = 0.85000
# Epoch   6: Valid Acurracy for entity end span = 0.85000
# Epoch   6: Valid Recall for entity end span = 0.85000
# Epoch   6: Valid Precision for entity end span = 0.85000
# Epoch   7: Train Loss = 12.74239
# Epoch   7: Valid Loss = 12.27787
# Epoch   7: Valid f1_score for entity start span = 0.90976
# Epoch   7: Valid Acurracy for entity start span = 0.90976
# Epoch   7: Valid Recall for entity start span = 0.90976
# Epoch   7: Valid Precision for entity start span = 0.90976
# Epoch   7: Valid f1_score for entity end span = 0.86692
# Epoch   7: Valid Acurracy for entity end span = 0.86692
# Epoch   7: Valid Recall for entity end span = 0.86692
# Epoch   7: Valid Precision for entity end span = 0.86692
# The current f1 score for entity start: 0.9097612359550562
# The current f1 score for entity end: 0.8669241573033708
# Epoch   8: Train Loss = 12.71642
# Epoch   8: Valid Loss = 12.27121
# Epoch   8: Valid f1_score for entity start span = 0.91046
# Epoch   8: Valid Acurracy for entity start span = 0.91046
# Epoch   8: Valid Recall for entity start span = 0.91046
# Epoch   8: Valid Precision for entity start span = 0.91046
# Epoch   8: Valid f1_score for entity end span = 0.86433
# Epoch   8: Valid Acurracy for entity end span = 0.86433
# Epoch   8: Valid Recall for entity end span = 0.86433
# Epoch   8: Valid Precision for entity end span = 0.86433
# Epoch   9: Train Loss = 12.70433
# Epoch   9: Valid Loss = 12.24677
# Epoch   9: Valid f1_score for entity start span = 0.91805
# Epoch   9: Valid Acurracy for entity start span = 0.91805
# Epoch   9: Valid Recall for entity start span = 0.91805
# Epoch   9: Valid Precision for entity start span = 0.91805
# Epoch   9: Valid f1_score for entity end span = 0.87430
# Epoch   9: Valid Acurracy for entity end span = 0.87430
# Epoch   9: Valid Recall for entity end span = 0.87430
# Epoch   9: Valid Precision for entity end span = 0.87430
# The current f1 score for entity start: 0.9180477528089888
# The current f1 score for entity end: 0.8742977528089888
# Epoch  10: Train Loss = 12.69763
# Epoch  10: Valid Loss = 12.23284
# Epoch  10: Valid f1_score for entity start span = 0.91889
# Epoch  10: Valid Acurracy for entity start span = 0.91889
# Epoch  10: Valid Recall for entity start span = 0.91889
# Epoch  10: Valid Precision for entity start span = 0.91889
# Epoch  10: Valid f1_score for entity end span = 0.88294
# Epoch  10: Valid Acurracy for entity end span = 0.88294
# Epoch  10: Valid Recall for entity end span = 0.88294
# Epoch  10: Valid Precision for entity end span = 0.88294
# The current f1 score for entity start: 0.9188904494382022
# The current f1 score for entity end: 0.882935393258427
# Epoch  11: Train Loss = 12.69083
# Epoch  11: Valid Loss = 12.21956
# Epoch  11: Valid f1_score for entity start span = 0.92135
# Epoch  11: Valid Acurracy for entity start span = 0.92135
# Epoch  11: Valid Recall for entity start span = 0.92135
# Epoch  11: Valid Precision for entity start span = 0.92135
# Epoch  11: Valid f1_score for entity end span = 0.89712
# Epoch  11: Valid Acurracy for entity end span = 0.89712
# Epoch  11: Valid Recall for entity end span = 0.89712
# Epoch  11: Valid Precision for entity end span = 0.89712
# The current f1 score for entity start: 0.9213483146067416
# The current f1 score for entity end: 0.8971207865168539
# Epoch  12: Train Loss = 12.68506
# Epoch  12: Valid Loss = 12.20026
# Epoch  12: Valid f1_score for entity start span = 0.92521
# Epoch  12: Valid Acurracy for entity start span = 0.92521
# Epoch  12: Valid Recall for entity start span = 0.92521
# Epoch  12: Valid Precision for entity start span = 0.92521
# Epoch  12: Valid f1_score for entity end span = 0.91187
# Epoch  12: Valid Acurracy for entity end span = 0.91187
# Epoch  12: Valid Recall for entity end span = 0.91187
# Epoch  12: Valid Precision for entity end span = 0.91187
# The current f1 score for entity start: 0.9252106741573034
# The current f1 score for entity end: 0.9118679775280899
# Epoch  13: Train Loss = 12.67382
# Epoch  13: Valid Loss = 12.19371
# Epoch  13: Valid f1_score for entity start span = 0.92626
# Epoch  13: Valid Acurracy for entity start span = 0.92626
# Epoch  13: Valid Recall for entity start span = 0.92626
# Epoch  13: Valid Precision for entity start span = 0.92626
# Epoch  13: Valid f1_score for entity end span = 0.91327
# Epoch  13: Valid Acurracy for entity end span = 0.91327
# Epoch  13: Valid Recall for entity end span = 0.91327
# Epoch  13: Valid Precision for entity end span = 0.91327
# The current f1 score for entity start: 0.9262640449438202
# The current f1 score for entity end: 0.9132724719101124
# Epoch  14: Train Loss = 12.66609
# Epoch  14: Valid Loss = 12.18393
# Epoch  14: Valid f1_score for entity start span = 0.92802
# Epoch  14: Valid Acurracy for entity start span = 0.92802
# Epoch  14: Valid Recall for entity start span = 0.92802
# Epoch  14: Valid Precision for entity start span = 0.92802
# Epoch  14: Valid f1_score for entity end span = 0.91924
# Epoch  14: Valid Acurracy for entity end span = 0.91924
# Epoch  14: Valid Recall for entity end span = 0.91924
# Epoch  14: Valid Precision for entity end span = 0.91924
# The current f1 score for entity start: 0.9280196629213483
# The current f1 score for entity end: 0.9192415730337079
# Epoch  15: Train Loss = 12.66804
# Epoch  15: Valid Loss = 12.17820
# Epoch  15: Valid f1_score for entity start span = 0.93048
# Epoch  15: Valid Acurracy for entity start span = 0.93048
# Epoch  15: Valid Recall for entity start span = 0.93048
# Epoch  15: Valid Precision for entity start span = 0.93048
# Epoch  15: Valid f1_score for entity end span = 0.91924
# Epoch  15: Valid Acurracy for entity end span = 0.91924
# Epoch  15: Valid Recall for entity end span = 0.91924
# Epoch  15: Valid Precision for entity end span = 0.91924
# The current f1 score for entity start: 0.9304775280898876
# The current f1 score for entity end: 0.9192415730337079
# Epoch  16: Train Loss = 12.66665
# Epoch  16: Valid Loss = 12.17800
# Epoch  16: Valid f1_score for entity start span = 0.92872
# Epoch  16: Valid Acurracy for entity start span = 0.92872
# Epoch  16: Valid Recall for entity start span = 0.92872
# Epoch  16: Valid Precision for entity start span = 0.92872
# Epoch  16: Valid f1_score for entity end span = 0.92051
# Epoch  16: Valid Acurracy for entity end span = 0.92051
# Epoch  16: Valid Recall for entity end span = 0.92051
# Epoch  16: Valid Precision for entity end span = 0.92051
# Epoch  17: Train Loss = 12.65630
# Epoch  17: Valid Loss = 12.17341
# Epoch  17: Valid f1_score for entity start span = 0.92942
# Epoch  17: Valid Acurracy for entity start span = 0.92942
# Epoch  17: Valid Recall for entity start span = 0.92942
# Epoch  17: Valid Precision for entity start span = 0.92942
# Epoch  17: Valid f1_score for entity end span = 0.92310
# Epoch  17: Valid Acurracy for entity end span = 0.92310
# Epoch  17: Valid Recall for entity end span = 0.92310
# Epoch  17: Valid Precision for entity end span = 0.92310
# Epoch  18: Train Loss = 12.65940
# Epoch  18: Valid Loss = 12.16869
# Epoch  18: Valid f1_score for entity start span = 0.93083
# Epoch  18: Valid Acurracy for entity start span = 0.93083
# Epoch  18: Valid Recall for entity start span = 0.93083
# Epoch  18: Valid Precision for entity start span = 0.93083
# Epoch  18: Valid f1_score for entity end span = 0.92591
# Epoch  18: Valid Acurracy for entity end span = 0.92591
# Epoch  18: Valid Recall for entity end span = 0.92591
# Epoch  18: Valid Precision for entity end span = 0.92591
# The current f1 score for entity start: 0.9308286516853933
# The current f1 score for entity end: 0.9259129213483146
# Epoch  19: Train Loss = 12.67311
# Epoch  19: Valid Loss = 12.16905
# Epoch  19: Valid f1_score for entity start span = 0.93048
# Epoch  19: Valid Acurracy for entity start span = 0.93048
# Epoch  19: Valid Recall for entity start span = 0.93048
# Epoch  19: Valid Precision for entity start span = 0.93048
# Epoch  19: Valid f1_score for entity end span = 0.92521
# Epoch  19: Valid Acurracy for entity end span = 0.92521
# Epoch  19: Valid Recall for entity end span = 0.92521
# Epoch  19: Valid Precision for entity end span = 0.92521
# trigger times: 1
# 0.9308286516853933 0.9259129213483146
# The best parameters are saved for the activation function: Softplus

# %%
list_entity_training_losses.append(list_entity_loss_train_leakyrelu)
list_entity_validation_losses.append(list_entity_loss_valid_leakyrelu)
list_entity_epochs.append(list_epochs_leakyrelu)
list_entity_training_losses.append(list_entity_loss_train_tanhshrink)
list_entity_validation_losses.append(list_entity_loss_valid_tanhshrink)
list_entity_epochs.append(list_epochs_tanhshrink)
list_entity_training_losses.append(list_entity_loss_train_softplus)
list_entity_validation_losses.append(list_entity_loss_valid_softplus)
list_entity_epochs.append(list_epochs_softplus)
list_entity_training_losses.append(list_entity_loss_train_elu)
list_entity_validation_losses.append(list_entity_loss_valid_elu)
list_entity_epochs.append(list_epochs_elu)

# %%
plot_losses(list_entity_epochs, list_entity_training_losses, list_entity_validation_losses, activations, learning_rate, dropout_prob)
