# %% [markdown]
# **I import some useful libraries in python.**

# %%
import difflib
import operator as op
import random
import numpy as np
import pandas as pd
import torch
import torch.backends.cudnn
from numpy.random import MT19937
from numpy.random import RandomState, SeedSequence
from torch.optim import Adam
from transformers import get_linear_schedule_with_warmup
import os
from google.colab import drive
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt
import torch.nn as nn
from transformers import BertModel
from transformers import BertTokenizerFast

# %% [markdown]
# **I mount google drive because all the files (for example .csv) that i used for the implementation of my thesis are saved on my google drive.**

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Check of the device that it is used for the implementation of the notebooks of this thesis, that is determined from google colab.**

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Device available for running: ")
print(device)
# Out:
# Device available for running:
# cuda

# %% [markdown]
# **Reading of the created datasets (for both the SimpleQuestions dataset that includes all training and validation questions and the SimpleQuestions subset that includes only answerable over wikidata questions) as .csv file.**

# %%
train_dataset = pd.read_csv("drive/MyDrive/train_dataset.csv", sep = ',')
validation_dataset = pd.read_csv("drive/MyDrive/valid_dataset.csv", sep = ',')
print(train_dataset)
print(validation_dataset)
# Out:
#        entity_id      entity_label relation_id  \
# 0        Q126399       Warner Bros        R272
# 1         Q12439           Detroit         R19
# 2       Q7370831          Q7370831        P162
# 3       Q6817891       Mera Shikar        P364
# 4          Q1297           Chicago        R276
# ...          ...               ...         ...
# 34369  Q16093542    Anthony Bailey         P27
# 34370    Q325741     Homi K Bhabha        P737
# 34371   Q1062702  video game music        R136
# 34372    Q926822  Gaston Filgueira         P21
# 34373    Q336286          defender        R413
#
#                                                 Question
# 0                  what movie is produced by warner bros
# 1                      who is a musician born in detroit
# 2                who produced the film rough house rosie
# 3      what is the language in which mera shikar was ...
# 4      Whats the name of a battle that happened in ch...
# ...                                                  ...
# 34369          What is the nationality of anthony bailey
# 34370    who was homi k bhabha especially influenced by
# 34371             which artist composes video game music
# 34372                    What gender is gaston filgueira
# 34373                      what player played a defender
#
# [34374 rows x 4 columns]
#      entity_id            entity_label relation_id  \
# 0     Q3541144      JW Marriott Panama        P138
# 1      Q318926           Sasha Vujacic         P19
# 2     Q2568216       Wiebke Carolsfeld         R57
# 3     Q2275923  Seymour Parker Gilbert        P106
# 4     Q2856873        Antoine de Fevin         P20
# ...        ...                     ...         ...
# 4862  Q3709870          Herby Fortunat        P413
# 4863   Q150804             The Pianist        P136
# 4864  Q1343857                Jon Seda         P19
# 4865  Q2981169       Nikolaj Frobenius        P106
# 4866      Q174               Sao Paulo         R19
#
#                                                Question
# 0     Who was the trump ocean club international hot...
# 1                          where was sasha vujacic born
# 2          What is a film directed by wiebke carolsfeld
# 3            What was Seymour Parker Gilbert profession
# 4         in what french city did antoine de fevin die
# ...                                                 ...
# 4862  which position did herby fortunat play in foot...
# 4863       what kind of film is the pianist (2002 film)
# 4864                     where was jon seda given birth
# 4865               What is nikolaj frobenius profession
# 4866         who is a person that was born in sao paulo
#
# [4867 rows x 4 columns]

# %% [markdown]
# **Check if  the SimpleQuestions training and validation dataset have at least one line with null value. This issues both for SimpleQuestions dataset that includes only answerable over wikidata questions and for the corresponding dataset that includes all the questions.**

# %%
train_dataset.dropna(inplace = True)
validation_dataset.dropna(inplace = True)
print(train_dataset)
print(validation_dataset)
# Out:
#        entity_id      entity_label relation_id  \
# 0        Q126399       Warner Bros        R272
# 1         Q12439           Detroit         R19
# 2       Q7370831          Q7370831        P162
# 3       Q6817891       Mera Shikar        P364
# 4          Q1297           Chicago        R276
# ...          ...               ...         ...
# 34369  Q16093542    Anthony Bailey         P27
# 34370    Q325741     Homi K Bhabha        P737
# 34371   Q1062702  video game music        R136
# 34372    Q926822  Gaston Filgueira         P21
# 34373    Q336286          defender        R413
#
#                                                 Question
# 0                  what movie is produced by warner bros
# 1                      who is a musician born in detroit
# 2                who produced the film rough house rosie
# 3      what is the language in which mera shikar was ...
# 4      Whats the name of a battle that happened in ch...
# ...                                                  ...
# 34369          What is the nationality of anthony bailey
# 34370    who was homi k bhabha especially influenced by
# 34371             which artist composes video game music
# 34372                    What gender is gaston filgueira
# 34373                      what player played a defender
#
# [34373 rows x 4 columns]
#      entity_id            entity_label relation_id  \
# 0     Q3541144      JW Marriott Panama        P138
# 1      Q318926           Sasha Vujacic         P19
# 2     Q2568216       Wiebke Carolsfeld         R57
# 3     Q2275923  Seymour Parker Gilbert        P106
# 4     Q2856873        Antoine de Fevin         P20
# ...        ...                     ...         ...
# 4862  Q3709870          Herby Fortunat        P413
# 4863   Q150804             The Pianist        P136
# 4864  Q1343857                Jon Seda         P19
# 4865  Q2981169       Nikolaj Frobenius        P106
# 4866      Q174               Sao Paulo         R19
#
#                                                Question
# 0     Who was the trump ocean club international hot...
# 1                          where was sasha vujacic born
# 2          What is a film directed by wiebke carolsfeld
# 3            What was Seymour Parker Gilbert profession
# 4         in what french city did antoine de fevin die
# ...                                                 ...
# 4862  which position did herby fortunat play in foot...
# 4863       what kind of film is the pianist (2002 film)
# 4864                     where was jon seda given birth
# 4865               What is nikolaj frobenius profession
# 4866         who is a person that was born in sao paulo
#
# [4867 rows x 4 columns]

# %% [markdown]
# **Creation of the corresponding lists containing the questions, the entity labels, the relation ids and the entity ids of the corresponding SimpleQuestions datasets (training, validation), either this dataset includes answerable and answerable questions over wikidata questions or only answerable questions over wikidata.**

# %%
train_entity_labels = train_dataset['entity_label'].to_list()
validation_entity_labels = validation_dataset['entity_label'].to_list()
train_entityids = train_dataset['entity_id'].to_list()
validation_entityids = validation_dataset['entity_id'].to_list()
train_questions = train_dataset['Question'].to_list()
validation_questions = validation_dataset['Question'].to_list()
train_relationids = train_dataset['relation_id'].to_list()
validation_relationids = validation_dataset['relation_id'].to_list()
print(len(train_entity_labels), len(train_entityids), len(train_relationids), len(train_questions))
# Out:
# 34373 34373 34373 34373

# %% [markdown]
# **Installation of the library of Sentence Transformers and loading of their models.**

# %%
# !pip install sentence-transformers
from sentence_transformers import SentenceTransformer, util
similarity_model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.6.1-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.3/163.3 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.38.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.13.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.11.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.4.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, sentence-transformers
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 sentence-transformers-2.6.1
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# **The maximum question length that is observed in SimpleQuestions training and validation dataset is found below.**

# %%
#Below the max questions length is found for all questions.
quests = train_questions + validation_questions
print(len(quests), len(train_questions), len(validation_questions))
# Printing concatenated list
q_lengths = []
for s in range(len(quests)): #padding
    q_lengths.append(len(quests[s].split()))
max_question_length = max(q_lengths)
print(max_question_length)#Max question length
# Out:
# 39240 34373 4867
# 33

# %% [markdown]
# **Creation of the relation vocabulary that includes all the unique entity ids of the SimpleQuestions training and validation dataset through function relation_vocabulary. Also the index of each unique relation id of the relation vocabulary in this vocabulary is found through the function find_relations_index.**

# %%
#Create relation vocabulary for each question of train and validation dataset
def relation_vocabulary(relation_column_dataset):
  relation_vocabulary = []
   #In order to have the unique relation ids it is important to check if an relation id is already in the relation_vocabulary
  for relation in range(len(relation_column_dataset)):
    g = 0
    for i in range(len(relation_vocabulary)):
      if relation_column_dataset[relation] != relation_vocabulary[i]: #relation is not found yet
        g += 1
      else:
       continue
    if g == len(relation_vocabulary) and relation_column_dataset[relation] not in relation_vocabulary:
      relation_vocabulary.append(relation_column_dataset[relation]) #The relation id is not inside the relation vocabulary
      #which has some relations already or the relation vocaulary has no relations
  return relation_vocabulary

def find_relation_index(relation_vocabulary,relation_ids_column):
  relations_count = []
  for relation in range(len(relation_ids_column)):
        relations_count.append(relation_vocabulary.index(relation_ids_column[relation]))

  return relations_count
#relation_ids = pd.concat([train_dataset["relation_id"], validation_dataset["relation_id"]], ignore_index = True)
relation_ids = train_relationids + validation_relationids
print(len(relation_ids))
rel_vocab = relation_vocabulary(relation_ids)
rel_vocab_length = len(rel_vocab)
print(rel_vocab, rel_vocab_length)
train_relations_index = find_relation_index(rel_vocab, train_relationids)
validation_relations_index = find_relation_index(rel_vocab, validation_relationids)
# Out:
# 39240
# ['R272', 'R19', 'P162', 'P364', 'R276', 'R413', 'R607', 'P413', 'R136', 'P27', 'P21', 'P136', 'P738', 'R106', 'P196', 'P175', 'R175', 'R50', 'P344', 'P641', 'P19', 'P421', 'R421', 'R57', 'P170', 'R17', 'P287', 'P86', 'R58', 'R86', 'P1142', 'P20', 'P58', 'P264', 'P131', 'P106', 'P172', 'P495', 'P150', 'R131', 'R509', 'P119', 'R1303', 'P50', 'R40', 'P1303', 'P61', 'R172', 'P57', 'P140', 'P179', 'R344', 'P1040', 'P509', 'P138', 'P397', 'P407', 'P398', 'P272', 'R264', 'P403', 'P31', 'P607', 'R287', 'R162', 'R641', 'R404', 'P1408', 'R178', 'R279', 'P123', 'P59', 'P40', 'P276', 'P1431', 'P178', 'P737', 'R179', 'P17', 'P171', 'R170', 'P144', 'P112', 'R105', 'R676', 'R59', 'P113', 'P155', 'P289', 'R149', 'P404', 'P710', 'P676', 'P149', 'R1040', 'R177', 'R119', 'P279', 'R21', 'R112', 'R31', 'R138', 'P53', 'R123', 'P65', 'P156', 'P177', 'R144', 'R1431', 'P81', 'P115', 'P105', 'P800', 'R171', 'P1029', 'R115', 'P84', 'R1142', 'P376', 'R376', 'P1308', 'P826', 'R161', 'R289', 'R176', 'P189', 'P176', 'P361', 'R361'] 129

# %% [markdown]
# **The function create\_question\_parts, takes as arguments the splitted question splitted into words and the entity label also splitted into words.
# Essentially in this function each question, as well as the corresponding entity label, is splitted into words using python method split() and then, using python method join(), parts of the query are created equal in length to that of their splitted entity label in words.**
#
# **These parts are stored in a list as well as the indexes of the initial word and final word of these question parts are stored in dictionaries with keys the question parts and values the indexes(positions) of the initial words and final words for each question. Finally this function returns the list of question parts and dictionaries containing the indexes(positions) of the initial words and final words for each question part.**

# %%
def create_question_parts(question_splitted, entity_splited_length):
  Quests_Parts = []
  Quest_Parts_Start = {}
  Quest_Parts_End = {}
  for i in range(len(question_splitted)-entity_splited_length+1):
    quest_part = " ".join(question_splitted[i:i+entity_splited_length])
    Quests_Parts.append(quest_part)
    Quest_Parts_Start[quest_part] = i
    Quest_Parts_End[quest_part] = i+entity_splited_length-1
  return Quests_Parts, Quest_Parts_Start, Quest_Parts_End

# %% [markdown]
# **Custom function for the cosine similarity metric between two encodings.**

# %%
def cosine_similarity(encoding1, encoding2):
  return np.dot(encoding1, encoding2) / (np.linalg.norm(encoding1) * np.linalg.norm(encoding2)) if np.linalg.norm(encoding1) * np.linalg.norm(encoding2) != 0 else 0

# %% [markdown]
# **The function through which the embeddings are created via Sentence Transformer and uses the cosine similarity function is the function best_match_with_cosine_similarity, which takes as arguments the entity label, the list of query segments, the dictionaries containing the indexes(positions) of the start words and end words for each question part mentioned above, as well as the similarity model of Sentence Transformer and returns the question part that has the highest similarity and the position of the initial and final word of that question part, otherwise if there is no such question part it returns None as the question part and as the index and for the initial and final word of the entity label the value -1.**

# %%
# Finds best match based on their similarity
def best_match_with_cosine_similarity(entity, question_parts, Start_Indexes, End_Indexes, similarity_model):
           similarity_scores = {}
           entity_vector = similarity_model.encode(entity)
           for q in range(len(question_parts)):
    # Find similarity scores between entity and each question part in question
            quest = similarity_model.encode(question_parts[q])
            similarity_scores[question_parts[q]] = cosine_similarity(entity_vector, quest)
    # Return the highest similarity score from all question parts as a list
           if similarity_scores == {}:
            return None, -1, -1
           Q = dict(sorted(similarity_scores.items(), key = lambda x: x[1], reverse = True))
           EntitiesList = [key for key in Q]
           return EntitiesList[0], Start_Indexes[EntitiesList[0]], End_Indexes[EntitiesList[0]]

# %% [markdown]
# **The entity_span function where the entity span start and entity span end indexes are found for each question, takes as arguments the list of all questions of SimpleQuestions training or validation dataset, the list of all entity labels of SimpleQuestions training or validation dataset in question and the similarity model of Sentence Transformer.**
#
# **This function calls the functions create_question_parts and best_match_with_cosine_similarity in order to create the parts of each question and find the question part that is equal to the entity label of the question with its start word index and end word index and returns the list of indexes (positions) of the initial words of the entity labels within the query (entity span start indexes) and the list of indexes (positions) of the final words of the entity labels within the query (entity span end indexes).**
#
# **Finally for the questions where no question part identical or similar to the corresponding entity label has been found, the positions (indices) of the penultimate (question length-2) and the last word (question length-1) are set as entity start index and entity end index respectively.**

# %%
def entity_span(question_column, entity_label_column, similarity_model):
  entity_start_column = []
  entity_end_column = []
  #Count for how many questions there is no question part that is equal or similar(finding with difflib.get_close_matches() or SentenceTransformer)
  #to the corresponding entity label.
  count_entity_with_no_similarity = 0
  for q in range(len(question_column)):
    # Find the word that performs the biggest similarity
      quest = question_column[q].lower().split()
      entity_label = entity_label_column[q].lower()
      ent_label = entity_label.split()
      entity_label_splitted_length = len(ent_label)
      Quests_Parts, Quest_Parts_Start, Quest_Parts_End = create_question_parts(quest, entity_label_splitted_length)
      Entity = difflib.get_close_matches(entity_label, Quests_Parts, 1)
      if (Entity != []):
        # Beginning and end of span
        Entity_start_index = Quest_Parts_Start[Entity[0]]
        Entity_end_index = Quest_Parts_End[Entity[0]]
        entity_start_column.append(Entity_start_index)
        entity_end_column.append(Entity_end_index)
      else:
        Entity, Entity_start_index, Entity_end_index = best_match_with_cosine_similarity(entity_label, Quests_Parts, Quest_Parts_Start, Quest_Parts_End, similarity_model)
        if Entity is None:
        # Beginning and end of span
         entity_start_column.append(len(quest)-2)
         entity_end_column.append(len(quest)-1)
         count_entity_with_no_similarity += 1
        else:
         entity_start_column.append(Entity_start_index)
         entity_end_column.append(Entity_end_index)
  print(count_entity_with_no_similarity)
  return entity_start_column, entity_end_column

# %%
train_entity_span_start, train_entity_span_end = entity_span(train_questions, train_entity_labels, similarity_model)
# Out:
# 17

# %%
validation_entity_span_start, validation_entity_span_end = entity_span(validation_questions, validation_entity_labels, similarity_model)
# Out:
# 2

# %% [markdown]
# **Loading of the Transformers BERT tokenizer BertTokenizerFast.**

# %%
tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased')
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %% [markdown]
# **Creation of a custom dataset for the SimpleQuestions dataset (either for the dataset with only answerable over wikidata questions or for the corresponding dataset including answerable and non-answerable over wikidata questions) through a python class, where its questions are encoded through BertTokenizerFast method encode\_plus(). This custom dataset includes the entity span indexes (start, end), the relation indexes, the questions, the ids and the attention mask occurred from encoding of questions.**
#
# **Also since the span start and end correspond to actual words, but here I use the fast version of BERT tokenizer BertTokenizerFast, i need to locate the corresponding start and end tokens in the BERT tokenized question for each entity.**
#
# **Also in order to create this custom dataset i used the lists of questions, relation, entity span start, entity span end indexes, the maximum question length of all SimpleQuestions training and validation dataset questions.**

# %%
g = torch.Generator()
print(g.device)
# Out:
# cpu

# %%
class BertQuestionAnsweringDataset:
  def __init__(self, questions, tokenizer, entity_starts, entity_ends, relation_indexes, length, generator, shuffle=True):
        self.questions = questions
        self.max_length = length
        self.tokenizer = tokenizer
        self.relation_indexes = relation_indexes
        self.g = generator
        self.shuffle = shuffle
        ids = []
        masks = []
        start_ent = []
        end_ent = []
        # Encode questions
        for question in range(len(self.questions)):
          encoding = self.tokenizer.encode_plus(
             text = self.questions[question],
             max_length=self.max_length,
             truncation=True,
             pad_to_max_length=True,
             return_attention_mask=True,
             padding='max_length',
             add_special_tokens=False
          )
          Question = self.questions[question].split()
          # Locate the corresponding start in the BERT tokenized question
          start_token = tokenizer.encode_plus(
            text = Question[entity_starts[question]],
            return_attention_mask=True,
            add_special_tokens=False
        )
          # Locate the corresponding end in the BERT tokenized question
          end_token = tokenizer.encode_plus(
            text = Question[entity_ends[question]],
            return_attention_mask=True,
            add_special_tokens=False
        )
          ids.append(encoding['input_ids'])
          masks.append(encoding['attention_mask'])
          start_ent.append(encoding['input_ids'].index(start_token['input_ids'][0]))
          end_ent.append(encoding['input_ids'].index(end_token['input_ids'][-1]))
        self.input_ids = ids
        self.attention_masks = masks
        self.entity_start_indexes = start_ent
        self.entity_end_indexes = end_ent

  def __len__(self):
        return len(self.questions)

  def __getitem__(self, idx):
        return { 'input_ids': torch.tensor(self.input_ids[idx]),
                'attention_mask':  torch.tensor(self.attention_masks[idx]),
                'relation_indexes': torch.tensor(self.relation_indexes[idx]),
                'entity_start': torch.tensor(self.entity_start_indexes[idx], dtype = torch.long),
                'entity_end': torch.tensor(self.entity_end_indexes[idx], dtype = torch.long)
               }

  def set_epoch(self, epoch):
      self.epoch = epoch
      if self.shuffle:
         self.g.manual_seed(123456789 + self.epoch)

# %% [markdown]
# **In the above custom dataset class i reseed the workers using worker\_init\_fn() to preserve reproducibility through by creating the following function seed\_worker.**

# %%
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# %% [markdown]
# **Creation of the dataloader through the created custom dataset from pytorch for the training and validation dataset of SimpleQuestions dataset. The batch size is equal to 32.**

# %%
print(len(train_questions), len(train_entity_span_start), len(train_entity_span_end), len(train_relations_index))
train_bert_dataset = BertQuestionAnsweringDataset(train_questions, tokenizer, train_entity_span_start, train_entity_span_end, train_relations_index, max(q_lengths), g)
valid_bert_dataset = BertQuestionAnsweringDataset(validation_questions, tokenizer, validation_entity_span_start, validation_entity_span_end, validation_relations_index, max(q_lengths), g)
train_dataloader = torch.utils.data.DataLoader(train_bert_dataset, batch_size = 32, num_workers = 0, worker_init_fn=seed_worker, shuffle=True, generator = train_bert_dataset.g)
val_dataloader = torch.utils.data.DataLoader(valid_bert_dataset, batch_size= 32, num_workers = 0, worker_init_fn=seed_worker, shuffle=True, generator = valid_bert_dataset.g)
# Out:
# 34373 34373 34373 34373

# %% [markdown]
# **Function that contributes to the preservation of the reproducibility.**

# %%
#To preserve reproducibility
SEED = 42
def set_seed(SEED):
 random.seed(SEED)# Set python seed for custom operators.
 torch.manual_seed(SEED)
 np.random.seed(SEED)
 torch.cuda.manual_seed_all(SEED)
 torch.backends.cudnn.benchmark = False
 torch.backends.cudnn.deterministic = True

# %% [markdown]
# **Through the create\_file function, is created a file in .pt, in which the parameters for each model are stored. This function takes as an argument a name for the folder where the model will be saved (e.g. "drive/MyDrive/") and a name for the name of the file where each model is saved (e.g. "relation\_prediction.pt").**

# %%
def create_file(model_dir, model_save_name):
 if not os.path.exists(model_dir):
    os.makedirs(model_dir)
 model_save_path = os.path.join(model_dir, model_save_name)
 return model_save_path

# %% [markdown]
# ****Construction and initialization of the neural network for the prediction of the relation for each question.****

# %%
class BertRelationsClassifier(nn.Module):
  def __init__(self, activation, dropout_prob, rel_vocab_len):
    super(BertRelationsClassifier, self).__init__()
    activations = {
        "ELU" : nn.ELU,
        "LeakyReLU"    : nn.LeakyReLU,
        "Softplus"     : nn.Softplus,
        "Tanhshrink"     : nn.Tanhshrink
 }
    self.bert_model = BertModel.from_pretrained('bert-base-uncased')
    self.rel_vocab_len = rel_vocab_len
    self.fc = nn.Linear(768, self.rel_vocab_len)
    self.activation_type = activation
    self.dropout_probability = dropout_prob
    self.activation = activations[self.activation_type]()
    self.dropout = nn.Dropout(self.dropout_probability)
    self.softmax = nn.Softmax(dim=1)

  def forward(self, input_ids, attention_mask):
        out = self.bert_model(input_ids, attention_mask)
        out = self.fc(out[1])#CLS token-pooled output
        out = self.activation(out)
        out = self.dropout(out)
        out = self.softmax(out)
        return out

# %% [markdown]
# **Through the function named relation_prediction_function the best possible parameters for the best possible prediction of the relation are found. This function has as arguments the training dataloader, the validation dataloader, the number of epochs, the optimizer, the scheduler, the learning rate, the relation prediction neural network model, the loss function and the dropout probability value.**
#
# **This function returns the best possible model, the list including numbers from 0 to number of training epochs-1, the lists including the values of training losses and validation losses for all epochs respectively and the largest value of f1.**
#
# **The length of the relation vocabulary in the case of training and validating the full SimpleQuestions dataset is equal to 129 and the length of the relation vocabulary for the case of training and validating the SimpleQuestions subset that includes only questions that are answerable over wikidata is equal to 125.
# So the predicted relation index as a number must be either between 0 and 128 or between 0 and 124, where this number correspond to the position of the unique relation ids in the corresponding relation vocabulary.**

# %%
def relation_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, lr, dropout_prob):
 list_loss_train = []
 list_epochs = []
 list_loss = []
 the_last_f1_score = 0
 patience = 3
 max_f1 = -1
 trigger_times = 0
 for epoch in range(epochs):
   train_dataset.set_epoch(epoch)
   valid_dataset.set_epoch(epoch)
   model.train()
   batch_losses = []
   F1 = []
   precision = []
   recall = []
   accuracy = []
   for batch in train_dataloader:
    ids = batch['input_ids'].to(device)
    attention_masks = batch['attention_mask'].to(device)
    relation_indexes = batch['relation_indexes'].to(device)
    y_pred = model(ids, attention_masks)
    loss = loss_func(y_pred.cpu(),relation_indexes.cpu())
    batch_losses.append(loss.detach().numpy())
    #Delete previously stored gradients
    optimizer.zero_grad()

    #Perform backpropagation starting from the loss calculated in this epoch
    loss.backward()
    nn.utils.clip_grad_norm_(model.parameters(), 0.7)
    #Update model's weights based on the gradients calculated during backprop
    optimizer.step()
    scheduler.step()
   print(f"Epoch {epoch:3}: Train Loss = {sum(batch_losses)/len(train_dataloader):.5f}")
   list_loss_train.append(sum(batch_losses)/len(train_dataloader))
   with torch.no_grad():
     model.eval()
     batch_F1 = []
     batch_precision = []
     batch_recall = []
     batch_accuracy = []
     batch_losses_val = []
     for batch in val_dataloader:
       ids = batch['input_ids'].to(device)
       attention_masks = batch['attention_mask'].to(device)
       relation_indexes = batch['relation_indexes'].to(device)
       y_predict = model(ids, attention_masks)
       val_loss = loss_func(y_predict.cpu(),relation_indexes.cpu())
       batch_losses_val.append(val_loss)
       y_pr = torch.argmax(y_predict, dim=1).squeeze()
       Y_p = y_pr.tolist()
       y_val = relation_indexes.tolist()
       batch_F1.append(f1_score(y_val, Y_p, average = 'micro'))
       batch_precision.append(precision_score(y_val, Y_p, average = 'micro'))
       batch_recall.append(recall_score(y_val, Y_p, average = 'micro'))
       batch_accuracy.append(accuracy_score(y_val,Y_p))
     Valid_f1 = sum(batch_F1)/len(val_dataloader)
     Valid_accuracy = sum(batch_accuracy)/len(val_dataloader)
     print(f"Epoch {epoch:3}: Valid Loss = {sum(batch_losses_val)/len(val_dataloader):.5f}")
     print(f"Epoch {epoch:3}: Valid f1_score = {Valid_f1:.5f}")
     print(f"Epoch {epoch:3}: Valid Acurracy = {Valid_accuracy:.5f}")
     print(f"Epoch {epoch:3}: Valid Recall score = {sum(batch_recall)/len(val_dataloader):.5f}")
     print(f"Epoch {epoch:3}: Valid Precision score = {sum(batch_precision)/len(val_dataloader):.5f}")
     #list_f1_scores.append(sum(F1)/len(val_dataloader))
     list_loss.append(sum(batch_losses_val)/len(val_dataloader))
     list_epochs.append(epoch)
     if Valid_f1 > max_f1:
       max_f1 = Valid_f1
       best_model = model
       print('The current f1 score:', Valid_f1)
     if Valid_f1 < the_last_f1_score:
       trigger_times += 1
       print('trigger times:', trigger_times)
       if trigger_times >= patience:
         print('Early stopping!\nStart to test process.')
         break;
     the_last_f1_score = Valid_f1
 return max_f1, list_loss_train, list_loss, list_epochs, best_model

# %% [markdown]
# **The function named get_relation_results finds results for the neural networks concerning the relation index and the entity span indexes (start,end). These functions have as arguments the corresponding training dataloader, the corresponding validation dataloader, the number of epochs ,the optimizer, the scheduler get_linear_schedule_with_warmup, the corresponding relation prediction neural network model, the loss function, the learning rate and the SEED number.**
#
# **This function returns the list of training losses, the list of validation losses, and the list of how many epochs each model with each activation function needs to be fully trained.**

# %%
learning_rate  = 2e-5
dropout_prob = 0.3
epochs = 20
list_relation_training_losses = []
list_relation_validation_losses = []
list_relation_epochs = []
loss_func = nn.CrossEntropyLoss()
optimizer_name = "Adam"
def get_relation_results(activation, rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_dataset, valid_dataset, train_dataloader, val_dataloader, SEED):
 set_seed(SEED)
 model = BertRelationsClassifier(activation, dropout_prob, rel_vocab_length).to(device)
 print(model)
 loss_func = loss_func.to(device)
 optimizer = getattr(torch.optim, optimizer_name)(model.parameters(), lr=learning_rate)
 scheduler = get_linear_schedule_with_warmup(optimizer, 0, len(train_dataloader)*epochs)
 f1, list_loss_train, list_loss_valid, list_epochs, best_relation_model = relation_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, learning_rate, dropout_prob)
 print(f1)
 torch.save(best_relation_model.state_dict(), create_file(f"drive/MyDrive/Relation_indexes_models_best_parameters/All_Questions/{activation}",f"relation_prediction_cosine_similarity_{activation}.pt") )
 print(f"The best parameters are saved for the activation function: {activation}")
 return list_loss_train, list_loss_valid, list_epochs

# %%
list_relation_loss_train_leakyrelu, list_relation_loss_valid_leakyrelu, list_epochs_leakyrelu = get_relation_results("LeakyReLU", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=129, bias=True)
#   (activation): LeakyReLU(negative_slope=0.01)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.58177
# Epoch   0: Valid Loss = 4.28928
# Epoch   0: Valid f1_score = 0.61370
# Epoch   0: Valid Acurracy = 0.61370
# Epoch   0: Valid Recall score = 0.61370
# Epoch   0: Valid Precision score = 0.61370
# The current f1 score: 0.61369825708061
# Epoch   1: Train Loss = 4.38843
# Epoch   1: Valid Loss = 4.14519
# Epoch   1: Valid f1_score = 0.76185
# Epoch   1: Valid Acurracy = 0.76185
# Epoch   1: Valid Recall score = 0.76185
# Epoch   1: Valid Precision score = 0.76185
# The current f1 score: 0.7618464052287581
# Epoch   2: Train Loss = 4.31823
# Epoch   2: Valid Loss = 4.08194
# Epoch   2: Valid f1_score = 0.82598
# Epoch   2: Valid Acurracy = 0.82598
# Epoch   2: Valid Recall score = 0.82598
# Epoch   2: Valid Precision score = 0.82598
# The current f1 score: 0.8259803921568627
# Epoch   3: Train Loss = 4.27763
# Epoch   3: Valid Loss = 4.02405
# Epoch   3: Valid f1_score = 0.87949
# Epoch   3: Valid Acurracy = 0.87949
# Epoch   3: Valid Recall score = 0.87949
# Epoch   3: Valid Precision score = 0.87949
# The current f1 score: 0.8794934640522876
# Epoch   4: Train Loss = 4.24278
# Epoch   4: Valid Loss = 3.99530
# Epoch   4: Valid f1_score = 0.90237
# Epoch   4: Valid Acurracy = 0.90237
# Epoch   4: Valid Recall score = 0.90237
# Epoch   4: Valid Precision score = 0.90237
# The current f1 score: 0.9023692810457516
# Epoch   5: Train Loss = 4.23357
# Epoch   5: Valid Loss = 3.98529
# Epoch   5: Valid f1_score = 0.91156
# Epoch   5: Valid Acurracy = 0.91156
# Epoch   5: Valid Recall score = 0.91156
# Epoch   5: Valid Precision score = 0.91156
# The current f1 score: 0.9115604575163399
# Epoch   6: Train Loss = 4.22214
# Epoch   6: Valid Loss = 3.96573
# Epoch   6: Valid f1_score = 0.92674
# Epoch   6: Valid Acurracy = 0.92674
# Epoch   6: Valid Recall score = 0.92674
# Epoch   6: Valid Precision score = 0.92674
# The current f1 score: 0.9267429193899781
# Epoch   7: Train Loss = 4.21742
# Epoch   7: Valid Loss = 3.96087
# Epoch   7: Valid f1_score = 0.92790
# Epoch   7: Valid Acurracy = 0.92790
# Epoch   7: Valid Recall score = 0.92790
# Epoch   7: Valid Precision score = 0.92790
# The current f1 score: 0.9279003267973857
# Epoch   8: Train Loss = 4.21168
# Epoch   8: Valid Loss = 3.95159
# Epoch   8: Valid f1_score = 0.93423
# Epoch   8: Valid Acurracy = 0.93423
# Epoch   8: Valid Recall score = 0.93423
# Epoch   8: Valid Precision score = 0.93423
# The current f1 score: 0.9342320261437909
# Epoch   9: Train Loss = 4.20859
# Epoch   9: Valid Loss = 3.94781
# Epoch   9: Valid f1_score = 0.93668
# Epoch   9: Valid Acurracy = 0.93668
# Epoch   9: Valid Recall score = 0.93668
# Epoch   9: Valid Precision score = 0.93668
# The current f1 score: 0.9366830065359477
# Epoch  10: Train Loss = 4.20676
# Epoch  10: Valid Loss = 3.94336
# Epoch  10: Valid f1_score = 0.94158
# Epoch  10: Valid Acurracy = 0.94158
# Epoch  10: Valid Recall score = 0.94158
# Epoch  10: Valid Precision score = 0.94158
# The current f1 score: 0.9415849673202614
# Epoch  11: Train Loss = 4.20326
# Epoch  11: Valid Loss = 3.94012
# Epoch  11: Valid f1_score = 0.94383
# Epoch  11: Valid Acurracy = 0.94383
# Epoch  11: Valid Recall score = 0.94383
# Epoch  11: Valid Precision score = 0.94383
# The current f1 score: 0.9438316993464052
# Epoch  12: Train Loss = 4.19756
# Epoch  12: Valid Loss = 3.93696
# Epoch  12: Valid f1_score = 0.94710
# Epoch  12: Valid Acurracy = 0.94710
# Epoch  12: Valid Recall score = 0.94710
# Epoch  12: Valid Precision score = 0.94710
# The current f1 score: 0.9470996732026143
# Epoch  13: Train Loss = 4.20097
# Epoch  13: Valid Loss = 3.93641
# Epoch  13: Valid f1_score = 0.94594
# Epoch  13: Valid Acurracy = 0.94594
# Epoch  13: Valid Recall score = 0.94594
# Epoch  13: Valid Precision score = 0.94594
# trigger times: 1
# Epoch  14: Train Loss = 4.19494
# Epoch  14: Valid Loss = 3.93364
# Epoch  14: Valid f1_score = 0.94894
# Epoch  14: Valid Acurracy = 0.94894
# Epoch  14: Valid Recall score = 0.94894
# Epoch  14: Valid Precision score = 0.94894
# The current f1 score: 0.948937908496732
# Epoch  15: Train Loss = 4.19588
# Epoch  15: Valid Loss = 3.93304
# Epoch  15: Valid f1_score = 0.95118
# Epoch  15: Valid Acurracy = 0.95118
# Epoch  15: Valid Recall score = 0.95118
# Epoch  15: Valid Precision score = 0.95118
# The current f1 score: 0.9511846405228758
# Epoch  16: Train Loss = 4.19288
# Epoch  16: Valid Loss = 3.93275
# Epoch  16: Valid f1_score = 0.94982
# Epoch  16: Valid Acurracy = 0.94982
# Epoch  16: Valid Recall score = 0.94982
# Epoch  16: Valid Precision score = 0.94982
# trigger times: 2
# Epoch  17: Train Loss = 4.19166
# Epoch  17: Valid Loss = 3.92972
# Epoch  17: Valid f1_score = 0.95241
# Epoch  17: Valid Acurracy = 0.95241
# Epoch  17: Valid Recall score = 0.95241
# Epoch  17: Valid Precision score = 0.95241
# The current f1 score: 0.9524101307189542
# Epoch  18: Train Loss = 4.19091
# Epoch  18: Valid Loss = 3.92996
# Epoch  18: Valid f1_score = 0.95159
# Epoch  18: Valid Acurracy = 0.95159
# Epoch  18: Valid Recall score = 0.95159
# Epoch  18: Valid Precision score = 0.95159
# trigger times: 3
# Early stopping!
# Start to test process.
# 0.9524101307189542
# The best parameters are saved for the activation function: LeakyReLU

# %%
list_relation_loss_train_tanhshrink, list_relation_loss_valid_tanhshrink, list_epochs_tanhshrink = get_relation_results("Tanhshrink", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=129, bias=True)
#   (activation): Tanhshrink()
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.62767
# Epoch   0: Valid Loss = 4.35202
# Epoch   0: Valid f1_score = 0.53853
# Epoch   0: Valid Acurracy = 0.53853
# Epoch   0: Valid Recall score = 0.53853
# Epoch   0: Valid Precision score = 0.53853
# The current f1 score: 0.5385348583877996
# Epoch   1: Train Loss = 4.45339
# Epoch   1: Valid Loss = 4.22871
# Epoch   1: Valid f1_score = 0.67320
# Epoch   1: Valid Acurracy = 0.67320
# Epoch   1: Valid Recall score = 0.67320
# Epoch   1: Valid Precision score = 0.67320
# The current f1 score: 0.673202614379085
# Epoch   2: Train Loss = 4.35552
# Epoch   2: Valid Loss = 4.11948
# Epoch   2: Valid f1_score = 0.78418
# Epoch   2: Valid Acurracy = 0.78418
# Epoch   2: Valid Recall score = 0.78418
# Epoch   2: Valid Precision score = 0.78418
# The current f1 score: 0.7841775599128541
# Epoch   3: Train Loss = 4.30754
# Epoch   3: Valid Loss = 4.05771
# Epoch   3: Valid f1_score = 0.84681
# Epoch   3: Valid Acurracy = 0.84681
# Epoch   3: Valid Recall score = 0.84681
# Epoch   3: Valid Precision score = 0.84681
# The current f1 score: 0.8468137254901961
# Epoch   4: Train Loss = 4.26189
# Epoch   4: Valid Loss = 4.01586
# Epoch   4: Valid f1_score = 0.88583
# Epoch   4: Valid Acurracy = 0.88583
# Epoch   4: Valid Recall score = 0.88583
# Epoch   4: Valid Precision score = 0.88583
# The current f1 score: 0.8858251633986928
# Epoch   5: Train Loss = 4.24432
# Epoch   5: Valid Loss = 3.99164
# Epoch   5: Valid f1_score = 0.90829
# Epoch   5: Valid Acurracy = 0.90829
# Epoch   5: Valid Recall score = 0.90829
# Epoch   5: Valid Precision score = 0.90829
# The current f1 score: 0.9082924836601307
# Epoch   6: Train Loss = 4.22957
# Epoch   6: Valid Loss = 3.98157
# Epoch   6: Valid f1_score = 0.91020
# Epoch   6: Valid Acurracy = 0.91020
# Epoch   6: Valid Recall score = 0.91020
# Epoch   6: Valid Precision score = 0.91020
# The current f1 score: 0.9101988017429193
# Epoch   7: Train Loss = 4.22612
# Epoch   7: Valid Loss = 3.97392
# Epoch   7: Valid f1_score = 0.91360
# Epoch   7: Valid Acurracy = 0.91360
# Epoch   7: Valid Recall score = 0.91360
# Epoch   7: Valid Precision score = 0.91360
# The current f1 score: 0.9136029411764706
# Epoch   8: Train Loss = 4.21755
# Epoch   8: Valid Loss = 3.96153
# Epoch   8: Valid f1_score = 0.92994
# Epoch   8: Valid Acurracy = 0.92994
# Epoch   8: Valid Recall score = 0.92994
# Epoch   8: Valid Precision score = 0.92994
# The current f1 score: 0.9299428104575164
# Epoch   9: Train Loss = 4.21032
# Epoch   9: Valid Loss = 3.95236
# Epoch   9: Valid f1_score = 0.93505
# Epoch   9: Valid Acurracy = 0.93505
# Epoch   9: Valid Recall score = 0.93505
# Epoch   9: Valid Precision score = 0.93505
# The current f1 score: 0.9350490196078431
# Epoch  10: Train Loss = 4.20783
# Epoch  10: Valid Loss = 3.94748
# Epoch  10: Valid f1_score = 0.93934
# Epoch  10: Valid Acurracy = 0.93934
# Epoch  10: Valid Recall score = 0.93934
# Epoch  10: Valid Precision score = 0.93934
# The current f1 score: 0.9393382352941176
# Epoch  11: Train Loss = 4.20396
# Epoch  11: Valid Loss = 3.94252
# Epoch  11: Valid f1_score = 0.94485
# Epoch  11: Valid Acurracy = 0.94485
# Epoch  11: Valid Recall score = 0.94485
# Epoch  11: Valid Precision score = 0.94485
# The current f1 score: 0.9448529411764706
# Epoch  12: Train Loss = 4.19707
# Epoch  12: Valid Loss = 3.94065
# Epoch  12: Valid f1_score = 0.94404
# Epoch  12: Valid Acurracy = 0.94404
# Epoch  12: Valid Recall score = 0.94404
# Epoch  12: Valid Precision score = 0.94404
# trigger times: 1
# Epoch  13: Train Loss = 4.19990
# Epoch  13: Valid Loss = 3.93925
# Epoch  13: Valid f1_score = 0.94465
# Epoch  13: Valid Acurracy = 0.94465
# Epoch  13: Valid Recall score = 0.94465
# Epoch  13: Valid Precision score = 0.94465
# Epoch  14: Train Loss = 4.19207
# Epoch  14: Valid Loss = 3.93423
# Epoch  14: Valid f1_score = 0.95200
# Epoch  14: Valid Acurracy = 0.95200
# Epoch  14: Valid Recall score = 0.95200
# Epoch  14: Valid Precision score = 0.95200
# The current f1 score: 0.952001633986928
# Epoch  15: Train Loss = 4.19337
# Epoch  15: Valid Loss = 3.93160
# Epoch  15: Valid f1_score = 0.95323
# Epoch  15: Valid Acurracy = 0.95323
# Epoch  15: Valid Recall score = 0.95323
# Epoch  15: Valid Precision score = 0.95323
# The current f1 score: 0.9532271241830066
# Epoch  16: Train Loss = 4.19045
# Epoch  16: Valid Loss = 3.93265
# Epoch  16: Valid f1_score = 0.95261
# Epoch  16: Valid Acurracy = 0.95261
# Epoch  16: Valid Recall score = 0.95261
# Epoch  16: Valid Precision score = 0.95261
# trigger times: 2
# Epoch  17: Train Loss = 4.18869
# Epoch  17: Valid Loss = 3.93106
# Epoch  17: Valid f1_score = 0.95221
# Epoch  17: Valid Acurracy = 0.95221
# Epoch  17: Valid Recall score = 0.95221
# Epoch  17: Valid Precision score = 0.95221
# trigger times: 3
# Early stopping!
# Start to test process.
# 0.9532271241830066
# The best parameters are saved for the activation function: Tanhshrink

# %%
list_relation_loss_train_elu, list_relation_loss_valid_elu, list_epochs_elu = get_relation_results("ELU", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=129, bias=True)
#   (activation): ELU(alpha=1.0)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.55268
# Epoch   0: Valid Loss = 4.26572
# Epoch   0: Valid f1_score = 0.64372
# Epoch   0: Valid Acurracy = 0.64372
# Epoch   0: Valid Recall score = 0.64372
# Epoch   0: Valid Precision score = 0.64372
# The current f1 score: 0.6437227668845316
# Epoch   1: Train Loss = 4.36453
# Epoch   1: Valid Loss = 4.11020
# Epoch   1: Valid f1_score = 0.81924
# Epoch   1: Valid Acurracy = 0.81924
# Epoch   1: Valid Recall score = 0.81924
# Epoch   1: Valid Precision score = 0.81924
# The current f1 score: 0.8192401960784313
# Epoch   2: Train Loss = 4.28451
# Epoch   2: Valid Loss = 4.04692
# Epoch   2: Valid f1_score = 0.85968
# Epoch   2: Valid Acurracy = 0.85968
# Epoch   2: Valid Recall score = 0.85968
# Epoch   2: Valid Precision score = 0.85968
# The current f1 score: 0.8596813725490197
# Epoch   3: Train Loss = 4.25876
# Epoch   3: Valid Loss = 4.00520
# Epoch   3: Valid f1_score = 0.89992
# Epoch   3: Valid Acurracy = 0.89992
# Epoch   3: Valid Recall score = 0.89992
# Epoch   3: Valid Precision score = 0.89992
# The current f1 score: 0.8999183006535948
# Epoch   4: Train Loss = 4.22944
# Epoch   4: Valid Loss = 3.98377
# Epoch   4: Valid f1_score = 0.91258
# Epoch   4: Valid Acurracy = 0.91258
# Epoch   4: Valid Recall score = 0.91258
# Epoch   4: Valid Precision score = 0.91258
# The current f1 score: 0.9125816993464052
# Epoch   5: Train Loss = 4.22215
# Epoch   5: Valid Loss = 3.96231
# Epoch   5: Valid f1_score = 0.93219
# Epoch   5: Valid Acurracy = 0.93219
# Epoch   5: Valid Recall score = 0.93219
# Epoch   5: Valid Precision score = 0.93219
# The current f1 score: 0.9321895424836601
# Epoch   6: Train Loss = 4.21261
# Epoch   6: Valid Loss = 3.96158
# Epoch   6: Valid f1_score = 0.92674
# Epoch   6: Valid Acurracy = 0.92674
# Epoch   6: Valid Recall score = 0.92674
# Epoch   6: Valid Precision score = 0.92674
# trigger times: 1
# Epoch   7: Train Loss = 4.21015
# Epoch   7: Valid Loss = 3.95143
# Epoch   7: Valid f1_score = 0.93546
# Epoch   7: Valid Acurracy = 0.93546
# Epoch   7: Valid Recall score = 0.93546
# Epoch   7: Valid Precision score = 0.93546
# The current f1 score: 0.9354575163398693
# Epoch   8: Train Loss = 4.20633
# Epoch   8: Valid Loss = 3.94560
# Epoch   8: Valid f1_score = 0.94158
# Epoch   8: Valid Acurracy = 0.94158
# Epoch   8: Valid Recall score = 0.94158
# Epoch   8: Valid Precision score = 0.94158
# The current f1 score: 0.9415849673202614
# Epoch   9: Train Loss = 4.20236
# Epoch   9: Valid Loss = 3.93966
# Epoch   9: Valid f1_score = 0.94608
# Epoch   9: Valid Acurracy = 0.94608
# Epoch   9: Valid Recall score = 0.94608
# Epoch   9: Valid Precision score = 0.94608
# The current f1 score: 0.946078431372549
# Epoch  10: Train Loss = 4.19950
# Epoch  10: Valid Loss = 3.93569
# Epoch  10: Valid f1_score = 0.95037
# Epoch  10: Valid Acurracy = 0.95037
# Epoch  10: Valid Recall score = 0.95037
# Epoch  10: Valid Precision score = 0.95037
# The current f1 score: 0.9503676470588235
# Epoch  11: Train Loss = 4.19668
# Epoch  11: Valid Loss = 3.93236
# Epoch  11: Valid f1_score = 0.95282
# Epoch  11: Valid Acurracy = 0.95282
# Epoch  11: Valid Recall score = 0.95282
# Epoch  11: Valid Precision score = 0.95282
# The current f1 score: 0.9528186274509803
# Epoch  12: Train Loss = 4.19129
# Epoch  12: Valid Loss = 3.93227
# Epoch  12: Valid f1_score = 0.95261
# Epoch  12: Valid Acurracy = 0.95261
# Epoch  12: Valid Recall score = 0.95261
# Epoch  12: Valid Precision score = 0.95261
# trigger times: 2
# Epoch  13: Train Loss = 4.19475
# Epoch  13: Valid Loss = 3.93031
# Epoch  13: Valid f1_score = 0.95364
# Epoch  13: Valid Acurracy = 0.95364
# Epoch  13: Valid Recall score = 0.95364
# Epoch  13: Valid Precision score = 0.95364
# The current f1 score: 0.9536356209150327
# Epoch  14: Train Loss = 4.18741
# Epoch  14: Valid Loss = 3.92920
# Epoch  14: Valid f1_score = 0.95466
# Epoch  14: Valid Acurracy = 0.95466
# Epoch  14: Valid Recall score = 0.95466
# Epoch  14: Valid Precision score = 0.95466
# The current f1 score: 0.9546568627450981
# Epoch  15: Train Loss = 4.18848
# Epoch  15: Valid Loss = 3.92690
# Epoch  15: Valid f1_score = 0.95690
# Epoch  15: Valid Acurracy = 0.95690
# Epoch  15: Valid Recall score = 0.95690
# Epoch  15: Valid Precision score = 0.95690
# The current f1 score: 0.9569035947712419
# Epoch  16: Train Loss = 4.18573
# Epoch  16: Valid Loss = 3.92565
# Epoch  16: Valid f1_score = 0.95895
# Epoch  16: Valid Acurracy = 0.95895
# Epoch  16: Valid Recall score = 0.95895
# Epoch  16: Valid Precision score = 0.95895
# The current f1 score: 0.9589460784313726
# Epoch  17: Train Loss = 4.18406
# Epoch  17: Valid Loss = 3.92409
# Epoch  17: Valid f1_score = 0.96058
# Epoch  17: Valid Acurracy = 0.96058
# Epoch  17: Valid Recall score = 0.96058
# Epoch  17: Valid Precision score = 0.96058
# The current f1 score: 0.9605800653594772
# Epoch  18: Train Loss = 4.18348
# Epoch  18: Valid Loss = 3.92403
# Epoch  18: Valid f1_score = 0.96038
# Epoch  18: Valid Acurracy = 0.96038
# Epoch  18: Valid Recall score = 0.96038
# Epoch  18: Valid Precision score = 0.96038
# trigger times: 3
# Early stopping!
# Start to test process.
# 0.9605800653594772
# The best parameters are saved for the activation function: ELU

# %%
list_relation_loss_train_softplus, list_relation_loss_valid_softplus, list_epochs_softplus = get_relation_results("Softplus", rel_vocab_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# BertRelationsClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=768, out_features=129, bias=True)
#   (activation): Softplus(beta=1, threshold=20)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (softmax): Softmax(dim=1)
# )
# Epoch   0: Train Loss = 4.58354
# Epoch   0: Valid Loss = 4.29041
# Epoch   0: Valid f1_score = 0.61676
# Epoch   0: Valid Acurracy = 0.61676
# Epoch   0: Valid Recall score = 0.61676
# Epoch   0: Valid Precision score = 0.61676
# The current f1 score: 0.616761982570806
# Epoch   1: Train Loss = 4.38090
# Epoch   1: Valid Loss = 4.13784
# Epoch   1: Valid f1_score = 0.77655
# Epoch   1: Valid Acurracy = 0.77655
# Epoch   1: Valid Recall score = 0.77655
# Epoch   1: Valid Precision score = 0.77655
# The current f1 score: 0.7765522875816994
# Epoch   2: Train Loss = 4.30190
# Epoch   2: Valid Loss = 4.06504
# Epoch   2: Valid f1_score = 0.85029
# Epoch   2: Valid Acurracy = 0.85029
# Epoch   2: Valid Recall score = 0.85029
# Epoch   2: Valid Precision score = 0.85029
# The current f1 score: 0.8502859477124183
# Epoch   3: Train Loss = 4.26632
# Epoch   3: Valid Loss = 4.01815
# Epoch   3: Valid f1_score = 0.88644
# Epoch   3: Valid Acurracy = 0.88644
# Epoch   3: Valid Recall score = 0.88644
# Epoch   3: Valid Precision score = 0.88644
# The current f1 score: 0.886437908496732
# Epoch   4: Train Loss = 4.23693
# Epoch   4: Valid Loss = 3.99596
# Epoch   4: Valid f1_score = 0.90952
# Epoch   4: Valid Acurracy = 0.90952
# Epoch   4: Valid Recall score = 0.90952
# Epoch   4: Valid Precision score = 0.90952
# The current f1 score: 0.9095179738562091
# Epoch   5: Train Loss = 4.22899
# Epoch   5: Valid Loss = 3.97717
# Epoch   5: Valid f1_score = 0.92014
# Epoch   5: Valid Acurracy = 0.92014
# Epoch   5: Valid Recall score = 0.92014
# Epoch   5: Valid Precision score = 0.92014
# The current f1 score: 0.9201388888888888
# Epoch   6: Train Loss = 4.22022
# Epoch   6: Valid Loss = 3.96668
# Epoch   6: Valid f1_score = 0.92531
# Epoch   6: Valid Acurracy = 0.92531
# Epoch   6: Valid Recall score = 0.92531
# Epoch   6: Valid Precision score = 0.92531
# The current f1 score: 0.9253131808278866
# Epoch   7: Train Loss = 4.21608
# Epoch   7: Valid Loss = 3.95849
# Epoch   7: Valid f1_score = 0.92994
# Epoch   7: Valid Acurracy = 0.92994
# Epoch   7: Valid Recall score = 0.92994
# Epoch   7: Valid Precision score = 0.92994
# The current f1 score: 0.9299428104575164
# Epoch   8: Train Loss = 4.20850
# Epoch   8: Valid Loss = 3.95223
# Epoch   8: Valid f1_score = 0.93750
# Epoch   8: Valid Acurracy = 0.93750
# Epoch   8: Valid Recall score = 0.93750
# Epoch   8: Valid Precision score = 0.93750
# The current f1 score: 0.9375
# Epoch   9: Train Loss = 4.20482
# Epoch   9: Valid Loss = 3.94753
# Epoch   9: Valid f1_score = 0.93920
# Epoch   9: Valid Acurracy = 0.93920
# Epoch   9: Valid Recall score = 0.93920
# Epoch   9: Valid Precision score = 0.93920
# The current f1 score: 0.9392020697167756
# Epoch  10: Train Loss = 4.20345
# Epoch  10: Valid Loss = 3.94390
# Epoch  10: Valid f1_score = 0.94158
# Epoch  10: Valid Acurracy = 0.94158
# Epoch  10: Valid Recall score = 0.94158
# Epoch  10: Valid Precision score = 0.94158
# The current f1 score: 0.9415849673202614
# Epoch  11: Train Loss = 4.20119
# Epoch  11: Valid Loss = 3.93953
# Epoch  11: Valid f1_score = 0.94751
# Epoch  11: Valid Acurracy = 0.94751
# Epoch  11: Valid Recall score = 0.94751
# Epoch  11: Valid Precision score = 0.94751
# The current f1 score: 0.9475081699346405
# Epoch  12: Train Loss = 4.19525
# Epoch  12: Valid Loss = 3.93629
# Epoch  12: Valid f1_score = 0.94792
# Epoch  12: Valid Acurracy = 0.94792
# Epoch  12: Valid Recall score = 0.94792
# Epoch  12: Valid Precision score = 0.94792
# The current f1 score: 0.9479166666666666
# Epoch  13: Train Loss = 4.19770
# Epoch  13: Valid Loss = 3.93400
# Epoch  13: Valid f1_score = 0.95146
# Epoch  13: Valid Acurracy = 0.95146
# Epoch  13: Valid Recall score = 0.95146
# Epoch  13: Valid Precision score = 0.95146
# The current f1 score: 0.9514569716775598
# Epoch  14: Train Loss = 4.19014
# Epoch  14: Valid Loss = 3.93037
# Epoch  14: Valid f1_score = 0.95466
# Epoch  14: Valid Acurracy = 0.95466
# Epoch  14: Valid Recall score = 0.95466
# Epoch  14: Valid Precision score = 0.95466
# The current f1 score: 0.9546568627450981
# Epoch  15: Train Loss = 4.19183
# Epoch  15: Valid Loss = 3.92838
# Epoch  15: Valid f1_score = 0.95568
# Epoch  15: Valid Acurracy = 0.95568
# Epoch  15: Valid Recall score = 0.95568
# Epoch  15: Valid Precision score = 0.95568
# The current f1 score: 0.9556781045751634
# Epoch  16: Train Loss = 4.18919
# Epoch  16: Valid Loss = 3.93046
# Epoch  16: Valid f1_score = 0.95370
# Epoch  16: Valid Acurracy = 0.95370
# Epoch  16: Valid Recall score = 0.95370
# Epoch  16: Valid Precision score = 0.95370
# trigger times: 1
# Epoch  17: Train Loss = 4.18819
# Epoch  17: Valid Loss = 3.92680
# Epoch  17: Valid f1_score = 0.95650
# Epoch  17: Valid Acurracy = 0.95650
# Epoch  17: Valid Recall score = 0.95650
# Epoch  17: Valid Precision score = 0.95650
# The current f1 score: 0.9564950980392157
# Epoch  18: Train Loss = 4.18711
# Epoch  18: Valid Loss = 3.92614
# Epoch  18: Valid f1_score = 0.95854
# Epoch  18: Valid Acurracy = 0.95854
# Epoch  18: Valid Recall score = 0.95854
# Epoch  18: Valid Precision score = 0.95854
# The current f1 score: 0.9585375816993464
# Epoch  19: Train Loss = 4.18843
# Epoch  19: Valid Loss = 3.92626
# Epoch  19: Valid f1_score = 0.95833
# Epoch  19: Valid Acurracy = 0.95833
# Epoch  19: Valid Recall score = 0.95833
# Epoch  19: Valid Precision score = 0.95833
# trigger times: 2
# 0.9585375816993464
# The best parameters are saved for the activation function: Softplus

# %%
list_relation_training_losses.append(list_relation_loss_train_leakyrelu)
list_relation_validation_losses.append(list_relation_loss_valid_leakyrelu)
list_relation_epochs.append(list_epochs_leakyrelu)
list_relation_training_losses.append(list_relation_loss_train_tanhshrink)
list_relation_validation_losses.append(list_relation_loss_valid_tanhshrink)
list_relation_epochs.append(list_epochs_tanhshrink)
list_relation_training_losses.append(list_relation_loss_train_softplus)
list_relation_validation_losses.append(list_relation_loss_valid_softplus)
list_relation_epochs.append(list_epochs_softplus)
list_relation_training_losses.append(list_relation_loss_train_elu)
list_relation_validation_losses.append(list_relation_loss_valid_elu)
list_relation_epochs.append(list_epochs_elu)

# %% [markdown]
# **Through the function plot_losses the learning curves for losses (relation prediction losses, entity span prediction losses) are plotted.**

# %%
def plot_losses(list_epochs, list_training_losses, list_validation_losses, activations, lr, dropout_prob):
 for activation in range(len(activations)):
  plt.plot(list_epochs[activation], list_training_losses[activation], label = f"{activations[activation]},{lr},{dropout_prob}-Training")
  plt.plot(list_epochs[activation], list_validation_losses[activation], label = f"{activations[activation]},{lr},{dropout_prob}-Validation")
  plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize = 'small')
  plt.title("loss-score")
  plt.xlabel("Number of epochs")
  plt.ylabel("Loss")
  plt.ylim(ymin = 3.5)
activations = ['LeakyReLU','Tanhshrink', 'Softplus','ELU']

# %%
plot_losses(list_relation_epochs, list_relation_training_losses, list_relation_validation_losses, activations, learning_rate, dropout_prob)

# %% [markdown]
# ****Construction and initialization of the neural network for the prediction of the entity span start and entity span end indexes for each question.****

# %%
class BertEntitySpanClassifier(nn.Module):
  def __init__(self, activation, dropout_prob, max_quest_len):
    super(BertEntitySpanClassifier, self).__init__()
    self.bert_model = BertModel.from_pretrained('bert-base-uncased')
    activations = {
        "ELU" : nn.ELU,
        "LeakyReLU"    : nn.LeakyReLU,
        "Softplus"     : nn.Softplus,
        "Tanhshrink"     : nn.Tanhshrink
 }
    self.activation_type = activation
    self.activation = activations[self.activation_type]()
    self.max_length = max_quest_len
    self.dropout_probability = dropout_prob
    self.start_head = nn.Sequential(
          nn.Linear(768, self.max_length),
          self.activation,
          nn.Dropout(p=self.dropout_probability),
          nn.Flatten(),
          nn.Softmax(dim=1)
    )

    self.end_head = nn.Sequential(
          nn.Linear(768, self.max_length),
          self.activation,
          nn.Dropout(p=self.dropout_probability),
          nn.Flatten(),
          nn.Softmax(dim=1)
    )

  def forward(self, input_ids, att_mask):
    out = self.bert_model(input_ids, att_mask)
    out = out[0]
    out_start = self.start_head(out)
    out_end = self.end_head(out)
    return out_start , out_end

# %% [markdown]
# **Through the function named entity_prediction_function the best possible parameters for the best possible prediction of the entity span are found. This function has as arguments the corresponding training dataloader, the corresponding validation dataloader, the number of epochs, the optimizer, the scheduler, the learning rate, the entity span prediction neural network model, the loss function and the dropout probability value.**
#
# **This function returns the best possible model, the list including numbers from 0 to number of training epochs-1, the lists including the values of training losses and validation losses for all epochs respectively, the largest value of f1 for entity span start and the largest value of f1 for entity span end.**
#
# **The biggest length of a question in words that is observed in SimpleQuestions dataset is equal to 33. Thus these predicted indexes as numbers must be either between 0 and 32, where these numbers correspond to the position of these words in their question for each question.**

# %%
def entity_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, lr, dropout_prob):
 list_loss_train = []
 list_loss = []
 list_epochs = []
 the_last_f1_start_score = 0
 the_last_f1_end_score = 0
 patience = 3
 max_f1_start = -1
 max_f1_end = -1
 trigger_times = 0
 for epoch in range(epochs):
  train_dataset.set_epoch(epoch)
  valid_dataset.set_epoch(epoch)
  model.train()
  batch_losses = []
  for batch in train_dataloader:
   input_ids = batch['input_ids'].to(device)
   attention_masks = batch['attention_mask'].to(device)
   entity_span_start_indexes = batch['entity_start'].to(device)
   entity_span_end_indexes = batch['entity_end'].to(device)
   y_pred_start, y_pred_end = model(input_ids, attention_masks)
   y_pred_start = y_pred_start.squeeze()
   y_pred_end = y_pred_end.squeeze()
   loss = loss_func(y_pred_start.cpu(),entity_span_start_indexes.cpu())+loss_func(y_pred_end.cpu(),entity_span_end_indexes.cpu())
   batch_losses.append(loss.detach().numpy())
   #Delete previously stored gradients
   nn.utils.clip_grad_norm_(model.parameters(), 0.7)
   optimizer.zero_grad()

    #Perform backpropagation starting from the loss calculated in this epoch
   loss.backward()

    #Update model's weights based on the gradients calculated during backprop
   optimizer.step()
   scheduler.step()
  print(f"Epoch {epoch:3}: Train Loss = {sum(batch_losses)/len(train_dataloader):.5f}")
  list_loss_train.append(sum(batch_losses)/len(train_dataloader))
  with torch.no_grad():
    model.eval()
    F1_start = []
    F1_end = []
    accuracy_start = []
    accuracy_end = []
    precision_start = []
    precision_end = []
    recall_start = []
    recall_end = []
    batch_losses_val = []
    for batch in val_dataloader:
      input_ids = batch['input_ids'].to(device)
      attention_masks = batch['attention_mask'].to(device)
      entity_span_start_indexes = batch['entity_start'].to(device)
      entity_span_end_indexes = batch['entity_end'].to(device)
      y_predict_start, y_predict_end = model(input_ids, attention_masks)
      y_predict_start = y_predict_start.squeeze()
      y_predict_end = y_predict_end.squeeze()
      val_loss = loss_func(y_predict_start.cpu(),entity_span_start_indexes.cpu())+loss_func(y_predict_end.cpu(),entity_span_end_indexes.cpu())
      batch_losses_val.append(val_loss)
      y_pr_start = torch.argmax(y_predict_start, dim=1)
      y_pr_end = torch.argmax(y_predict_end, dim=1)
      Y_p_start = y_pr_start.tolist()
      Y_p_end = y_pr_end.tolist()
      y_val_start = entity_span_start_indexes.tolist()
      y_val_end = entity_span_end_indexes.tolist()
      F1_start.append(f1_score(y_val_start, Y_p_start, average = 'micro'))
      F1_end.append(f1_score(y_val_end, Y_p_end, average = 'micro'))
      precision_start.append(precision_score(y_val_start, Y_p_start, average = 'micro'))
      precision_end.append(precision_score(y_val_end, Y_p_end, average = 'micro'))
      recall_start.append(recall_score(y_val_start, Y_p_start, average = 'micro'))
      recall_end.append(recall_score(y_val_end, Y_p_end, average = 'micro'))
      accuracy_start.append(accuracy_score(y_val_start, Y_p_start))
      accuracy_end.append(accuracy_score(y_val_end, Y_p_end))
    Valid_f1_start = sum(F1_start)/len(val_dataloader)
    Valid_f1_end = sum(F1_end)/len(val_dataloader)
    print(f"Epoch {epoch:3}: Valid Loss = {sum(batch_losses_val)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid f1_score for entity start span = {Valid_f1_start:.5f}")
    print(f"Epoch {epoch:3}: Valid Acurracy for entity start span = {sum(accuracy_start)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Recall for entity start span = {sum(recall_start)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Precision for entity start span = {sum(precision_start)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid f1_score for entity end span = {Valid_f1_end:.5f}")
    print(f"Epoch {epoch:3}: Valid Acurracy for entity end span = {sum(accuracy_end)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Recall for entity end span = {sum(recall_end)/len(val_dataloader):.5f}")
    print(f"Epoch {epoch:3}: Valid Precision for entity end span = {sum(precision_end)/len(val_dataloader):.5f}")
    list_loss.append(sum(batch_losses_val)/len(val_dataloader))
    list_epochs.append(epoch)
    if Valid_f1_start >= max_f1_start and Valid_f1_end >= max_f1_end:
      max_f1_start = Valid_f1_start
      max_f1_end = Valid_f1_end
      best_model = model
      print('The current f1 score for entity start:', Valid_f1_start)
      print('The current f1 score for entity end:', Valid_f1_end)
    if Valid_f1_start < the_last_f1_start_score and Valid_f1_end < the_last_f1_end_score:
      trigger_times += 1
      print('trigger times:', trigger_times)
      if trigger_times >= patience:
        print('Early stopping!\nStart to test process.')
        break;
    the_last_f1_start_score = Valid_f1_start
    the_last_f1_end_score = Valid_f1_end

 return max_f1_start, max_f1_end, list_loss_train, list_loss, list_epochs, best_model

# %% [markdown]
# **The function named get_entity_results finds results for the neural networks concerning the relation index and the entity span indexes (start,end). These functions have as arguments the corresponding training dataloader, the corresponding validation dataloader, the number of epochs ,the optimizer, the scheduler get_linear_schedule_with_warmup, the corresponding entity span prediction neural network model, the loss function, the learning rate and the SEED number.**
#
# **This function returns the list of training losses, the list of validation losses, and the list of how many epochs each model with each activation function needs to be fully trained.**

# %%
learning_rate  = 2e-5
dropout_prob = 0.3
epochs = 20
list_entity_training_losses = []
list_entity_validation_losses = []
list_entity_epochs = []
loss_func = nn.CrossEntropyLoss()
optimizer_name = "Adam"
activations_list = ['LeakyReLU','Tanhshrink', 'Softplus','ELU']
def get_entity_results(activation, max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_dataset, valid_dataset, train_dataloader, val_dataloader, SEED):
 set_seed(SEED)
 model = BertEntitySpanClassifier(activation, dropout_prob, max_question_length).to(device)
 print(model)
 loss_func = loss_func.to(device)
 optimizer = getattr(torch.optim, optimizer_name)(model.parameters(), lr=learning_rate)
 scheduler = get_linear_schedule_with_warmup(optimizer, 0, len(train_dataloader)*epochs)
 f1_start, f1_end, list_loss_train, list_loss_valid, list_epochs, best_entity_model = entity_prediction_function(train_dataset, valid_dataset, train_dataloader, val_dataloader, model, loss_func, optimizer, scheduler, epochs, activation, learning_rate, dropout_prob)
 print(f1_start,f1_end)
 torch.save(best_entity_model.state_dict(), create_file(f"drive/MyDrive/Entity_span_indexes_models_best_parameters/All_Questions/{activation}", f"entity_span_prediction_cosine_similarity_{activation}.pt") )
 print(f"The best parameters are saved for the activation function: {activation}")
 return list_loss_train, list_loss_valid, list_epochs

# %%
list_entity_loss_train_leakyrelu, list_entity_loss_valid_leakyrelu, list_epochs_leakyrelu = get_entity_results("LeakyReLU", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): LeakyReLU(negative_slope=0.01)
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.52589
# Epoch   0: Valid Loss = 13.13916
# Epoch   0: Valid f1_score for entity start span = 0.67559
# Epoch   0: Valid Acurracy for entity start span = 0.67559
# Epoch   0: Valid Recall for entity start span = 0.67559
# Epoch   0: Valid Precision for entity start span = 0.67559
# Epoch   0: Valid f1_score for entity end span = 0.29017
# Epoch   0: Valid Acurracy for entity end span = 0.29017
# Epoch   0: Valid Recall for entity end span = 0.29017
# Epoch   0: Valid Precision for entity end span = 0.29017
# The current f1 score for entity start: 0.6755855119825708
# The current f1 score for entity end: 0.29016884531590414
# Epoch   1: Train Loss = 13.15658
# Epoch   1: Valid Loss = 12.77020
# Epoch   1: Valid f1_score for entity start span = 0.69737
# Epoch   1: Valid Acurracy for entity start span = 0.69737
# Epoch   1: Valid Recall for entity start span = 0.69737
# Epoch   1: Valid Precision for entity start span = 0.69737
# Epoch   1: Valid f1_score for entity end span = 0.65822
# Epoch   1: Valid Acurracy for entity end span = 0.65822
# Epoch   1: Valid Recall for entity end span = 0.65822
# Epoch   1: Valid Precision for entity end span = 0.65822
# The current f1 score for entity start: 0.6973720043572985
# The current f1 score for entity end: 0.6582244008714596
# Epoch   2: Train Loss = 12.93156
# Epoch   2: Valid Loss = 12.48222
# Epoch   2: Valid f1_score for entity start span = 0.81475
# Epoch   2: Valid Acurracy for entity start span = 0.81475
# Epoch   2: Valid Recall for entity start span = 0.81475
# Epoch   2: Valid Precision for entity start span = 0.81475
# Epoch   2: Valid f1_score for entity end span = 0.77539
# Epoch   2: Valid Acurracy for entity end span = 0.77539
# Epoch   2: Valid Recall for entity end span = 0.77539
# Epoch   2: Valid Precision for entity end span = 0.77539
# The current f1 score for entity start: 0.8147467320261438
# The current f1 score for entity end: 0.7753948801742919
# Epoch   3: Train Loss = 12.84543
# Epoch   3: Valid Loss = 12.40472
# Epoch   3: Valid f1_score for entity start span = 0.83095
# Epoch   3: Valid Acurracy for entity start span = 0.83095
# Epoch   3: Valid Recall for entity start span = 0.83095
# Epoch   3: Valid Precision for entity start span = 0.83095
# Epoch   3: Valid f1_score for entity end span = 0.80372
# Epoch   3: Valid Acurracy for entity end span = 0.80372
# Epoch   3: Valid Recall for entity end span = 0.80372
# Epoch   3: Valid Precision for entity end span = 0.80372
# The current f1 score for entity start: 0.8309504357298475
# The current f1 score for entity end: 0.8037173202614379
# Epoch   4: Train Loss = 12.80300
# Epoch   4: Valid Loss = 12.34331
# Epoch   4: Valid f1_score for entity start span = 0.85376
# Epoch   4: Valid Acurracy for entity start span = 0.85376
# Epoch   4: Valid Recall for entity start span = 0.85376
# Epoch   4: Valid Precision for entity start span = 0.85376
# Epoch   4: Valid f1_score for entity end span = 0.84007
# Epoch   4: Valid Acurracy for entity end span = 0.84007
# Epoch   4: Valid Recall for entity end span = 0.84007
# Epoch   4: Valid Precision for entity end span = 0.84007
# The current f1 score for entity start: 0.8537581699346405
# The current f1 score for entity end: 0.8400735294117647
# Epoch   5: Train Loss = 12.78534
# Epoch   5: Valid Loss = 12.31756
# Epoch   5: Valid f1_score for entity start span = 0.86111
# Epoch   5: Valid Acurracy for entity start span = 0.86111
# Epoch   5: Valid Recall for entity start span = 0.86111
# Epoch   5: Valid Precision for entity start span = 0.86111
# Epoch   5: Valid f1_score for entity end span = 0.84947
# Epoch   5: Valid Acurracy for entity end span = 0.84947
# Epoch   5: Valid Recall for entity end span = 0.84947
# Epoch   5: Valid Precision for entity end span = 0.84947
# The current f1 score for entity start: 0.8611111111111112
# The current f1 score for entity end: 0.849468954248366
# Epoch   6: Train Loss = 12.76951
# Epoch   6: Valid Loss = 12.30245
# Epoch   6: Valid f1_score for entity start span = 0.86908
# Epoch   6: Valid Acurracy for entity start span = 0.86908
# Epoch   6: Valid Recall for entity start span = 0.86908
# Epoch   6: Valid Precision for entity start span = 0.86908
# Epoch   6: Valid f1_score for entity end span = 0.84988
# Epoch   6: Valid Acurracy for entity end span = 0.84988
# Epoch   6: Valid Recall for entity end span = 0.84988
# Epoch   6: Valid Precision for entity end span = 0.84988
# The current f1 score for entity start: 0.8690767973856209
# The current f1 score for entity end: 0.8498774509803921
# Epoch   7: Train Loss = 12.75838
# Epoch   7: Valid Loss = 12.28697
# Epoch   7: Valid f1_score for entity start span = 0.88133
# Epoch   7: Valid Acurracy for entity start span = 0.88133
# Epoch   7: Valid Recall for entity start span = 0.88133
# Epoch   7: Valid Precision for entity start span = 0.88133
# Epoch   7: Valid f1_score for entity end span = 0.85437
# Epoch   7: Valid Acurracy for entity end span = 0.85437
# Epoch   7: Valid Recall for entity end span = 0.85437
# Epoch   7: Valid Precision for entity end span = 0.85437
# The current f1 score for entity start: 0.8813316993464052
# The current f1 score for entity end: 0.8543709150326797
# Epoch   8: Train Loss = 12.74518
# Epoch   8: Valid Loss = 12.25625
# Epoch   8: Valid f1_score for entity start span = 0.88991
# Epoch   8: Valid Acurracy for entity start span = 0.88991
# Epoch   8: Valid Recall for entity start span = 0.88991
# Epoch   8: Valid Precision for entity start span = 0.88991
# Epoch   8: Valid f1_score for entity end span = 0.87439
# Epoch   8: Valid Acurracy for entity end span = 0.87439
# Epoch   8: Valid Recall for entity end span = 0.87439
# Epoch   8: Valid Precision for entity end span = 0.87439
# The current f1 score for entity start: 0.8899101307189542
# The current f1 score for entity end: 0.8743872549019608
# Epoch   9: Train Loss = 12.72543
# Epoch   9: Valid Loss = 12.23567
# Epoch   9: Valid f1_score for entity start span = 0.89052
# Epoch   9: Valid Acurracy for entity start span = 0.89052
# Epoch   9: Valid Recall for entity start span = 0.89052
# Epoch   9: Valid Precision for entity start span = 0.89052
# Epoch   9: Valid f1_score for entity end span = 0.88971
# Epoch   9: Valid Acurracy for entity end span = 0.88971
# Epoch   9: Valid Recall for entity end span = 0.88971
# Epoch   9: Valid Precision for entity end span = 0.88971
# The current f1 score for entity start: 0.8905228758169934
# The current f1 score for entity end: 0.8897058823529411
# Epoch  10: Train Loss = 12.70320
# Epoch  10: Valid Loss = 12.21787
# Epoch  10: Valid f1_score for entity start span = 0.90421
# Epoch  10: Valid Acurracy for entity start span = 0.90421
# Epoch  10: Valid Recall for entity start span = 0.90421
# Epoch  10: Valid Precision for entity start span = 0.90421
# Epoch  10: Valid f1_score for entity end span = 0.89767
# Epoch  10: Valid Acurracy for entity end span = 0.89767
# Epoch  10: Valid Recall for entity end span = 0.89767
# Epoch  10: Valid Precision for entity end span = 0.89767
# The current f1 score for entity start: 0.9042075163398693
# The current f1 score for entity end: 0.897671568627451
# Epoch  11: Train Loss = 12.70217
# Epoch  11: Valid Loss = 12.20638
# Epoch  11: Valid f1_score for entity start span = 0.90060
# Epoch  11: Valid Acurracy for entity start span = 0.90060
# Epoch  11: Valid Recall for entity start span = 0.90060
# Epoch  11: Valid Precision for entity start span = 0.90060
# Epoch  11: Valid f1_score for entity end span = 0.90305
# Epoch  11: Valid Acurracy for entity end span = 0.90305
# Epoch  11: Valid Recall for entity end span = 0.90305
# Epoch  11: Valid Precision for entity end span = 0.90305
# Epoch  12: Train Loss = 12.69248
# Epoch  12: Valid Loss = 12.18804
# Epoch  12: Valid f1_score for entity start span = 0.91204
# Epoch  12: Valid Acurracy for entity start span = 0.91204
# Epoch  12: Valid Recall for entity start span = 0.91204
# Epoch  12: Valid Precision for entity start span = 0.91204
# Epoch  12: Valid f1_score for entity end span = 0.90856
# Epoch  12: Valid Acurracy for entity end span = 0.90856
# Epoch  12: Valid Recall for entity end span = 0.90856
# Epoch  12: Valid Precision for entity end span = 0.90856
# The current f1 score for entity start: 0.912037037037037
# The current f1 score for entity end: 0.9085648148148148
# Epoch  13: Train Loss = 12.68854
# Epoch  13: Valid Loss = 12.17645
# Epoch  13: Valid f1_score for entity start span = 0.91789
# Epoch  13: Valid Acurracy for entity start span = 0.91789
# Epoch  13: Valid Recall for entity start span = 0.91789
# Epoch  13: Valid Precision for entity start span = 0.91789
# Epoch  13: Valid f1_score for entity end span = 0.91850
# Epoch  13: Valid Acurracy for entity end span = 0.91850
# Epoch  13: Valid Recall for entity end span = 0.91850
# Epoch  13: Valid Precision for entity end span = 0.91850
# The current f1 score for entity start: 0.9178921568627451
# The current f1 score for entity end: 0.9185049019607843
# Epoch  14: Train Loss = 12.68841
# Epoch  14: Valid Loss = 12.17128
# Epoch  14: Valid f1_score for entity start span = 0.91912
# Epoch  14: Valid Acurracy for entity start span = 0.91912
# Epoch  14: Valid Recall for entity start span = 0.91912
# Epoch  14: Valid Precision for entity start span = 0.91912
# Epoch  14: Valid f1_score for entity end span = 0.92279
# Epoch  14: Valid Acurracy for entity end span = 0.92279
# Epoch  14: Valid Recall for entity end span = 0.92279
# Epoch  14: Valid Precision for entity end span = 0.92279
# The current f1 score for entity start: 0.9191176470588235
# The current f1 score for entity end: 0.9227941176470589
# Epoch  15: Train Loss = 12.67811
# Epoch  15: Valid Loss = 12.16712
# Epoch  15: Valid f1_score for entity start span = 0.92041
# Epoch  15: Valid Acurracy for entity start span = 0.92041
# Epoch  15: Valid Recall for entity start span = 0.92041
# Epoch  15: Valid Precision for entity start span = 0.92041
# Epoch  15: Valid f1_score for entity end span = 0.92286
# Epoch  15: Valid Acurracy for entity end span = 0.92286
# Epoch  15: Valid Recall for entity end span = 0.92286
# Epoch  15: Valid Precision for entity end span = 0.92286
# The current f1 score for entity start: 0.9204112200435729
# The current f1 score for entity end: 0.9228622004357298
# Epoch  16: Train Loss = 12.68284
# Epoch  16: Valid Loss = 12.16257
# Epoch  16: Valid f1_score for entity start span = 0.92266
# Epoch  16: Valid Acurracy for entity start span = 0.92266
# Epoch  16: Valid Recall for entity start span = 0.92266
# Epoch  16: Valid Precision for entity start span = 0.92266
# Epoch  16: Valid f1_score for entity end span = 0.92422
# Epoch  16: Valid Acurracy for entity end span = 0.92422
# Epoch  16: Valid Recall for entity end span = 0.92422
# Epoch  16: Valid Precision for entity end span = 0.92422
# The current f1 score for entity start: 0.9226579520697167
# The current f1 score for entity end: 0.9242238562091504
# Epoch  17: Train Loss = 12.67261
# Epoch  17: Valid Loss = 12.15677
# Epoch  17: Valid f1_score for entity start span = 0.92361
# Epoch  17: Valid Acurracy for entity start span = 0.92361
# Epoch  17: Valid Recall for entity start span = 0.92361
# Epoch  17: Valid Precision for entity start span = 0.92361
# Epoch  17: Valid f1_score for entity end span = 0.92708
# Epoch  17: Valid Acurracy for entity end span = 0.92708
# Epoch  17: Valid Recall for entity end span = 0.92708
# Epoch  17: Valid Precision for entity end span = 0.92708
# The current f1 score for entity start: 0.9236111111111112
# The current f1 score for entity end: 0.9270833333333334
# Epoch  18: Train Loss = 12.67179
# Epoch  18: Valid Loss = 12.15761
# Epoch  18: Valid f1_score for entity start span = 0.92307
# Epoch  18: Valid Acurracy for entity start span = 0.92307
# Epoch  18: Valid Recall for entity start span = 0.92307
# Epoch  18: Valid Precision for entity start span = 0.92307
# Epoch  18: Valid f1_score for entity end span = 0.92627
# Epoch  18: Valid Acurracy for entity end span = 0.92627
# Epoch  18: Valid Recall for entity end span = 0.92627
# Epoch  18: Valid Precision for entity end span = 0.92627
# trigger times: 1
# Epoch  19: Train Loss = 12.67071
# Epoch  19: Valid Loss = 12.15420
# Epoch  19: Valid f1_score for entity start span = 0.92463
# Epoch  19: Valid Acurracy for entity start span = 0.92463
# Epoch  19: Valid Recall for entity start span = 0.92463
# Epoch  19: Valid Precision for entity start span = 0.92463
# Epoch  19: Valid f1_score for entity end span = 0.92667
# Epoch  19: Valid Acurracy for entity end span = 0.92667
# Epoch  19: Valid Recall for entity end span = 0.92667
# Epoch  19: Valid Precision for entity end span = 0.92667
# 0.9236111111111112 0.9270833333333334
# The best parameters are saved for the activation function: LeakyReLU

# %%
list_entity_loss_train_tahnshrink, list_entity_loss_valid_tahnshrink, list_epochs_tahnshrink = get_entity_results("Tanhshrink", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): Tanhshrink()
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Tanhshrink()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Tanhshrink()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.52707
# Epoch   0: Valid Loss = 13.10165
# Epoch   0: Valid f1_score for entity start span = 0.68621
# Epoch   0: Valid Acurracy for entity start span = 0.68621
# Epoch   0: Valid Recall for entity start span = 0.68621
# Epoch   0: Valid Precision for entity start span = 0.68621
# Epoch   0: Valid f1_score for entity end span = 0.23380
# Epoch   0: Valid Acurracy for entity end span = 0.23380
# Epoch   0: Valid Recall for entity end span = 0.23380
# Epoch   0: Valid Precision for entity end span = 0.23380
# The current f1 score for entity start: 0.6862064270152505
# The current f1 score for entity end: 0.2337962962962963
# Epoch   1: Train Loss = 13.10604
# Epoch   1: Valid Loss = 12.65997
# Epoch   1: Valid f1_score for entity start span = 0.80984
# Epoch   1: Valid Acurracy for entity start span = 0.80984
# Epoch   1: Valid Recall for entity start span = 0.80984
# Epoch   1: Valid Precision for entity start span = 0.80984
# Epoch   1: Valid f1_score for entity end span = 0.58817
# Epoch   1: Valid Acurracy for entity end span = 0.58817
# Epoch   1: Valid Recall for entity end span = 0.58817
# Epoch   1: Valid Precision for entity end span = 0.58817
# The current f1 score for entity start: 0.8098447712418301
# The current f1 score for entity end: 0.588167211328976
# Epoch   2: Train Loss = 12.89768
# Epoch   2: Valid Loss = 12.40865
# Epoch   2: Valid f1_score for entity start span = 0.85315
# Epoch   2: Valid Acurracy for entity start span = 0.85315
# Epoch   2: Valid Recall for entity start span = 0.85315
# Epoch   2: Valid Precision for entity start span = 0.85315
# Epoch   2: Valid f1_score for entity end span = 0.79051
# Epoch   2: Valid Acurracy for entity end span = 0.79051
# Epoch   2: Valid Recall for entity end span = 0.79051
# Epoch   2: Valid Precision for entity end span = 0.79051
# The current f1 score for entity start: 0.8531454248366013
# The current f1 score for entity end: 0.7905092592592593
# Epoch   3: Train Loss = 12.80875
# Epoch   3: Valid Loss = 12.32258
# Epoch   3: Valid f1_score for entity start span = 0.87602
# Epoch   3: Valid Acurracy for entity start span = 0.87602
# Epoch   3: Valid Recall for entity start span = 0.87602
# Epoch   3: Valid Precision for entity start span = 0.87602
# Epoch   3: Valid f1_score for entity end span = 0.83272
# Epoch   3: Valid Acurracy for entity end span = 0.83272
# Epoch   3: Valid Recall for entity end span = 0.83272
# Epoch   3: Valid Precision for entity end span = 0.83272
# The current f1 score for entity start: 0.8760212418300654
# The current f1 score for entity end: 0.8327205882352942
# Epoch   4: Train Loss = 12.76135
# Epoch   4: Valid Loss = 12.25915
# Epoch   4: Valid f1_score for entity start span = 0.88235
# Epoch   4: Valid Acurracy for entity start span = 0.88235
# Epoch   4: Valid Recall for entity start span = 0.88235
# Epoch   4: Valid Precision for entity start span = 0.88235
# Epoch   4: Valid f1_score for entity end span = 0.87398
# Epoch   4: Valid Acurracy for entity end span = 0.87398
# Epoch   4: Valid Recall for entity end span = 0.87398
# Epoch   4: Valid Precision for entity end span = 0.87398
# The current f1 score for entity start: 0.8823529411764706
# The current f1 score for entity end: 0.8739787581699346
# Epoch   5: Train Loss = 12.74749
# Epoch   5: Valid Loss = 12.23653
# Epoch   5: Valid f1_score for entity start span = 0.88725
# Epoch   5: Valid Acurracy for entity start span = 0.88725
# Epoch   5: Valid Recall for entity start span = 0.88725
# Epoch   5: Valid Precision for entity start span = 0.88725
# Epoch   5: Valid f1_score for entity end span = 0.88909
# Epoch   5: Valid Acurracy for entity end span = 0.88909
# Epoch   5: Valid Recall for entity end span = 0.88909
# Epoch   5: Valid Precision for entity end span = 0.88909
# The current f1 score for entity start: 0.8872549019607843
# The current f1 score for entity end: 0.8890931372549019
# Epoch   6: Train Loss = 12.72796
# Epoch   6: Valid Loss = 12.21190
# Epoch   6: Valid f1_score for entity start span = 0.90359
# Epoch   6: Valid Acurracy for entity start span = 0.90359
# Epoch   6: Valid Recall for entity start span = 0.90359
# Epoch   6: Valid Precision for entity start span = 0.90359
# Epoch   6: Valid f1_score for entity end span = 0.89522
# Epoch   6: Valid Acurracy for entity end span = 0.89522
# Epoch   6: Valid Recall for entity end span = 0.89522
# Epoch   6: Valid Precision for entity end span = 0.89522
# The current f1 score for entity start: 0.9035947712418301
# The current f1 score for entity end: 0.8952205882352942
# Epoch   7: Train Loss = 12.71500
# Epoch   7: Valid Loss = 12.19783
# Epoch   7: Valid f1_score for entity start span = 0.91136
# Epoch   7: Valid Acurracy for entity start span = 0.91136
# Epoch   7: Valid Recall for entity start span = 0.91136
# Epoch   7: Valid Precision for entity start span = 0.91136
# Epoch   7: Valid f1_score for entity end span = 0.89890
# Epoch   7: Valid Acurracy for entity end span = 0.89890
# Epoch   7: Valid Recall for entity end span = 0.89890
# Epoch   7: Valid Precision for entity end span = 0.89890
# The current f1 score for entity start: 0.9113562091503268
# The current f1 score for entity end: 0.8988970588235294
# Epoch   8: Train Loss = 12.70477
# Epoch   8: Valid Loss = 12.19358
# Epoch   8: Valid f1_score for entity start span = 0.91422
# Epoch   8: Valid Acurracy for entity start span = 0.91422
# Epoch   8: Valid Recall for entity start span = 0.91422
# Epoch   8: Valid Precision for entity start span = 0.91422
# Epoch   8: Valid f1_score for entity end span = 0.90564
# Epoch   8: Valid Acurracy for entity end span = 0.90564
# Epoch   8: Valid Recall for entity end span = 0.90564
# Epoch   8: Valid Precision for entity end span = 0.90564
# The current f1 score for entity start: 0.9142156862745098
# The current f1 score for entity end: 0.9056372549019608
# Epoch   9: Train Loss = 12.69278
# Epoch   9: Valid Loss = 12.16798
# Epoch   9: Valid f1_score for entity start span = 0.91993
# Epoch   9: Valid Acurracy for entity start span = 0.91993
# Epoch   9: Valid Recall for entity start span = 0.91993
# Epoch   9: Valid Precision for entity start span = 0.91993
# Epoch   9: Valid f1_score for entity end span = 0.91626
# Epoch   9: Valid Acurracy for entity end span = 0.91626
# Epoch   9: Valid Recall for entity end span = 0.91626
# Epoch   9: Valid Precision for entity end span = 0.91626
# The current f1 score for entity start: 0.9199346405228758
# The current f1 score for entity end: 0.9162581699346405
# Epoch  10: Train Loss = 12.67670
# Epoch  10: Valid Loss = 12.17301
# Epoch  10: Valid f1_score for entity start span = 0.92041
# Epoch  10: Valid Acurracy for entity start span = 0.92041
# Epoch  10: Valid Recall for entity start span = 0.92041
# Epoch  10: Valid Precision for entity start span = 0.92041
# Epoch  10: Valid f1_score for entity end span = 0.91142
# Epoch  10: Valid Acurracy for entity end span = 0.91142
# Epoch  10: Valid Recall for entity end span = 0.91142
# Epoch  10: Valid Precision for entity end span = 0.91142
# Epoch  11: Train Loss = 12.68218
# Epoch  11: Valid Loss = 12.16601
# Epoch  11: Valid f1_score for entity start span = 0.91878
# Epoch  11: Valid Acurracy for entity start span = 0.91878
# Epoch  11: Valid Recall for entity start span = 0.91878
# Epoch  11: Valid Precision for entity start span = 0.91878
# Epoch  11: Valid f1_score for entity end span = 0.91776
# Epoch  11: Valid Acurracy for entity end span = 0.91776
# Epoch  11: Valid Recall for entity end span = 0.91776
# Epoch  11: Valid Precision for entity end span = 0.91776
# Epoch  12: Train Loss = 12.67526
# Epoch  12: Valid Loss = 12.15819
# Epoch  12: Valid f1_score for entity start span = 0.92606
# Epoch  12: Valid Acurracy for entity start span = 0.92606
# Epoch  12: Valid Recall for entity start span = 0.92606
# Epoch  12: Valid Precision for entity start span = 0.92606
# Epoch  12: Valid f1_score for entity end span = 0.91551
# Epoch  12: Valid Acurracy for entity end span = 0.91551
# Epoch  12: Valid Recall for entity end span = 0.91551
# Epoch  12: Valid Precision for entity end span = 0.91551
# Epoch  13: Train Loss = 12.67643
# Epoch  13: Valid Loss = 12.15504
# Epoch  13: Valid f1_score for entity start span = 0.92361
# Epoch  13: Valid Acurracy for entity start span = 0.92361
# Epoch  13: Valid Recall for entity start span = 0.92361
# Epoch  13: Valid Precision for entity start span = 0.92361
# Epoch  13: Valid f1_score for entity end span = 0.92096
# Epoch  13: Valid Acurracy for entity end span = 0.92096
# Epoch  13: Valid Recall for entity end span = 0.92096
# Epoch  13: Valid Precision for entity end span = 0.92096
# The current f1 score for entity start: 0.9236111111111112
# The current f1 score for entity end: 0.9209558823529411
# Epoch  14: Train Loss = 12.68025
# Epoch  14: Valid Loss = 12.15256
# Epoch  14: Valid f1_score for entity start span = 0.92422
# Epoch  14: Valid Acurracy for entity start span = 0.92422
# Epoch  14: Valid Recall for entity start span = 0.92422
# Epoch  14: Valid Precision for entity start span = 0.92422
# Epoch  14: Valid f1_score for entity end span = 0.92259
# Epoch  14: Valid Acurracy for entity end span = 0.92259
# Epoch  14: Valid Recall for entity end span = 0.92259
# Epoch  14: Valid Precision for entity end span = 0.92259
# The current f1 score for entity start: 0.9242238562091504
# The current f1 score for entity end: 0.9225898692810458
# Epoch  15: Train Loss = 12.67096
# Epoch  15: Valid Loss = 12.15530
# Epoch  15: Valid f1_score for entity start span = 0.92470
# Epoch  15: Valid Acurracy for entity start span = 0.92470
# Epoch  15: Valid Recall for entity start span = 0.92470
# Epoch  15: Valid Precision for entity start span = 0.92470
# Epoch  15: Valid f1_score for entity end span = 0.92062
# Epoch  15: Valid Acurracy for entity end span = 0.92062
# Epoch  15: Valid Recall for entity end span = 0.92062
# Epoch  15: Valid Precision for entity end span = 0.92062
# Epoch  16: Train Loss = 12.67609
# Epoch  16: Valid Loss = 12.14981
# Epoch  16: Valid f1_score for entity start span = 0.92409
# Epoch  16: Valid Acurracy for entity start span = 0.92409
# Epoch  16: Valid Recall for entity start span = 0.92409
# Epoch  16: Valid Precision for entity start span = 0.92409
# Epoch  16: Valid f1_score for entity end span = 0.92429
# Epoch  16: Valid Acurracy for entity end span = 0.92429
# Epoch  16: Valid Recall for entity end span = 0.92429
# Epoch  16: Valid Precision for entity end span = 0.92429
# Epoch  17: Train Loss = 12.66566
# Epoch  17: Valid Loss = 12.14351
# Epoch  17: Valid f1_score for entity start span = 0.92688
# Epoch  17: Valid Acurracy for entity start span = 0.92688
# Epoch  17: Valid Recall for entity start span = 0.92688
# Epoch  17: Valid Precision for entity start span = 0.92688
# Epoch  17: Valid f1_score for entity end span = 0.92749
# Epoch  17: Valid Acurracy for entity end span = 0.92749
# Epoch  17: Valid Recall for entity end span = 0.92749
# Epoch  17: Valid Precision for entity end span = 0.92749
# The current f1 score for entity start: 0.9268790849673203
# The current f1 score for entity end: 0.9274918300653595
# Epoch  18: Train Loss = 12.66500
# Epoch  18: Valid Loss = 12.14519
# Epoch  18: Valid f1_score for entity start span = 0.92511
# Epoch  18: Valid Acurracy for entity start span = 0.92511
# Epoch  18: Valid Recall for entity start span = 0.92511
# Epoch  18: Valid Precision for entity start span = 0.92511
# Epoch  18: Valid f1_score for entity end span = 0.92606
# Epoch  18: Valid Acurracy for entity end span = 0.92606
# Epoch  18: Valid Recall for entity end span = 0.92606
# Epoch  18: Valid Precision for entity end span = 0.92606
# trigger times: 1
# Epoch  19: Train Loss = 12.66380
# Epoch  19: Valid Loss = 12.14277
# Epoch  19: Valid f1_score for entity start span = 0.92851
# Epoch  19: Valid Acurracy for entity start span = 0.92851
# Epoch  19: Valid Recall for entity start span = 0.92851
# Epoch  19: Valid Precision for entity start span = 0.92851
# Epoch  19: Valid f1_score for entity end span = 0.92606
# Epoch  19: Valid Acurracy for entity end span = 0.92606
# Epoch  19: Valid Recall for entity end span = 0.92606
# Epoch  19: Valid Precision for entity end span = 0.92606
# 0.9268790849673203 0.9274918300653595
# The best parameters are saved for the activation function: Tanhshrink

# %%
list_entity_loss_train_elu, list_entity_loss_valid_elu, list_epochs_elu = get_entity_results("ELU", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): ELU(alpha=1.0)
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.44975
# Epoch   0: Valid Loss = 12.89907
# Epoch   0: Valid f1_score for entity start span = 0.72038
# Epoch   0: Valid Acurracy for entity start span = 0.72038
# Epoch   0: Valid Recall for entity start span = 0.72038
# Epoch   0: Valid Precision for entity start span = 0.72038
# Epoch   0: Valid f1_score for entity end span = 0.54378
# Epoch   0: Valid Acurracy for entity end span = 0.54378
# Epoch   0: Valid Recall for entity end span = 0.54378
# Epoch   0: Valid Precision for entity end span = 0.54378
# The current f1 score for entity start: 0.7203839869281046
# The current f1 score for entity end: 0.5437772331154684
# Epoch   1: Train Loss = 12.96842
# Epoch   1: Valid Loss = 12.54352
# Epoch   1: Valid f1_score for entity start span = 0.81740
# Epoch   1: Valid Acurracy for entity start span = 0.81740
# Epoch   1: Valid Recall for entity start span = 0.81740
# Epoch   1: Valid Precision for entity start span = 0.81740
# Epoch   1: Valid f1_score for entity end span = 0.71705
# Epoch   1: Valid Acurracy for entity end span = 0.71705
# Epoch   1: Valid Recall for entity end span = 0.71705
# Epoch   1: Valid Precision for entity end span = 0.71705
# The current f1 score for entity start: 0.8174019607843137
# The current f1 score for entity end: 0.7170479302832243
# Epoch   2: Train Loss = 12.84893
# Epoch   2: Valid Loss = 12.37517
# Epoch   2: Valid f1_score for entity start span = 0.85131
# Epoch   2: Valid Acurracy for entity start span = 0.85131
# Epoch   2: Valid Recall for entity start span = 0.85131
# Epoch   2: Valid Precision for entity start span = 0.85131
# Epoch   2: Valid f1_score for entity end span = 0.83681
# Epoch   2: Valid Acurracy for entity end span = 0.83681
# Epoch   2: Valid Recall for entity end span = 0.83681
# Epoch   2: Valid Precision for entity end span = 0.83681
# The current f1 score for entity start: 0.8513071895424836
# The current f1 score for entity end: 0.8368055555555556
# Epoch   3: Train Loss = 12.79590
# Epoch   3: Valid Loss = 12.32746
# Epoch   3: Valid f1_score for entity start span = 0.86275
# Epoch   3: Valid Acurracy for entity start span = 0.86275
# Epoch   3: Valid Recall for entity start span = 0.86275
# Epoch   3: Valid Precision for entity start span = 0.86275
# Epoch   3: Valid f1_score for entity end span = 0.85335
# Epoch   3: Valid Acurracy for entity end span = 0.85335
# Epoch   3: Valid Recall for entity end span = 0.85335
# Epoch   3: Valid Precision for entity end span = 0.85335
# The current f1 score for entity start: 0.8627450980392157
# The current f1 score for entity end: 0.8533496732026143
# Epoch   4: Train Loss = 12.75704
# Epoch   4: Valid Loss = 12.28298
# Epoch   4: Valid f1_score for entity start span = 0.88215
# Epoch   4: Valid Acurracy for entity start span = 0.88215
# Epoch   4: Valid Recall for entity start span = 0.88215
# Epoch   4: Valid Precision for entity start span = 0.88215
# Epoch   4: Valid f1_score for entity end span = 0.86744
# Epoch   4: Valid Acurracy for entity end span = 0.86744
# Epoch   4: Valid Recall for entity end span = 0.86744
# Epoch   4: Valid Precision for entity end span = 0.86744
# The current f1 score for entity start: 0.8821486928104575
# The current f1 score for entity end: 0.8674428104575164
# Epoch   5: Train Loss = 12.74692
# Epoch   5: Valid Loss = 12.27276
# Epoch   5: Valid f1_score for entity start span = 0.88705
# Epoch   5: Valid Acurracy for entity start span = 0.88705
# Epoch   5: Valid Recall for entity start span = 0.88705
# Epoch   5: Valid Precision for entity start span = 0.88705
# Epoch   5: Valid f1_score for entity end span = 0.87459
# Epoch   5: Valid Acurracy for entity end span = 0.87459
# Epoch   5: Valid Recall for entity end span = 0.87459
# Epoch   5: Valid Precision for entity end span = 0.87459
# The current f1 score for entity start: 0.8870506535947712
# The current f1 score for entity end: 0.8745915032679739
# Epoch   6: Train Loss = 12.72952
# Epoch   6: Valid Loss = 12.22021
# Epoch   6: Valid f1_score for entity start span = 0.90625
# Epoch   6: Valid Acurracy for entity start span = 0.90625
# Epoch   6: Valid Recall for entity start span = 0.90625
# Epoch   6: Valid Precision for entity start span = 0.90625
# Epoch   6: Valid f1_score for entity end span = 0.88971
# Epoch   6: Valid Acurracy for entity end span = 0.88971
# Epoch   6: Valid Recall for entity end span = 0.88971
# Epoch   6: Valid Precision for entity end span = 0.88971
# The current f1 score for entity start: 0.90625
# The current f1 score for entity end: 0.8897058823529411
# Epoch   7: Train Loss = 12.71598
# Epoch   7: Valid Loss = 12.20381
# Epoch   7: Valid f1_score for entity start span = 0.91136
# Epoch   7: Valid Acurracy for entity start span = 0.91136
# Epoch   7: Valid Recall for entity start span = 0.91136
# Epoch   7: Valid Precision for entity start span = 0.91136
# Epoch   7: Valid f1_score for entity end span = 0.89767
# Epoch   7: Valid Acurracy for entity end span = 0.89767
# Epoch   7: Valid Recall for entity end span = 0.89767
# Epoch   7: Valid Precision for entity end span = 0.89767
# The current f1 score for entity start: 0.9113562091503268
# The current f1 score for entity end: 0.897671568627451
# Epoch   8: Train Loss = 12.70520
# Epoch   8: Valid Loss = 12.18262
# Epoch   8: Valid f1_score for entity start span = 0.91483
# Epoch   8: Valid Acurracy for entity start span = 0.91483
# Epoch   8: Valid Recall for entity start span = 0.91483
# Epoch   8: Valid Precision for entity start span = 0.91483
# Epoch   8: Valid f1_score for entity end span = 0.91626
# Epoch   8: Valid Acurracy for entity end span = 0.91626
# Epoch   8: Valid Recall for entity end span = 0.91626
# Epoch   8: Valid Precision for entity end span = 0.91626
# The current f1 score for entity start: 0.914828431372549
# The current f1 score for entity end: 0.9162581699346405
# Epoch   9: Train Loss = 12.69361
# Epoch   9: Valid Loss = 12.17732
# Epoch   9: Valid f1_score for entity start span = 0.91442
# Epoch   9: Valid Acurracy for entity start span = 0.91442
# Epoch   9: Valid Recall for entity start span = 0.91442
# Epoch   9: Valid Precision for entity start span = 0.91442
# Epoch   9: Valid f1_score for entity end span = 0.91728
# Epoch   9: Valid Acurracy for entity end span = 0.91728
# Epoch   9: Valid Recall for entity end span = 0.91728
# Epoch   9: Valid Precision for entity end span = 0.91728
# Epoch  10: Train Loss = 12.68000
# Epoch  10: Valid Loss = 12.17993
# Epoch  10: Valid f1_score for entity start span = 0.91245
# Epoch  10: Valid Acurracy for entity start span = 0.91245
# Epoch  10: Valid Recall for entity start span = 0.91245
# Epoch  10: Valid Precision for entity start span = 0.91245
# Epoch  10: Valid f1_score for entity end span = 0.91769
# Epoch  10: Valid Acurracy for entity end span = 0.91769
# Epoch  10: Valid Recall for entity end span = 0.91769
# Epoch  10: Valid Precision for entity end span = 0.91769
# Epoch  11: Train Loss = 12.68467
# Epoch  11: Valid Loss = 12.17639
# Epoch  11: Valid f1_score for entity start span = 0.91571
# Epoch  11: Valid Acurracy for entity start span = 0.91571
# Epoch  11: Valid Recall for entity start span = 0.91571
# Epoch  11: Valid Precision for entity start span = 0.91571
# Epoch  11: Valid f1_score for entity end span = 0.91490
# Epoch  11: Valid Acurracy for entity end span = 0.91490
# Epoch  11: Valid Recall for entity end span = 0.91490
# Epoch  11: Valid Precision for entity end span = 0.91490
# Epoch  12: Train Loss = 12.67788
# Epoch  12: Valid Loss = 12.17023
# Epoch  12: Valid f1_score for entity start span = 0.92239
# Epoch  12: Valid Acurracy for entity start span = 0.92239
# Epoch  12: Valid Recall for entity start span = 0.92239
# Epoch  12: Valid Precision for entity start span = 0.92239
# Epoch  12: Valid f1_score for entity end span = 0.91769
# Epoch  12: Valid Acurracy for entity end span = 0.91769
# Epoch  12: Valid Recall for entity end span = 0.91769
# Epoch  12: Valid Precision for entity end span = 0.91769
# The current f1 score for entity start: 0.9223856209150327
# The current f1 score for entity end: 0.917687908496732
# Epoch  13: Train Loss = 12.67697
# Epoch  13: Valid Loss = 12.15704
# Epoch  13: Valid f1_score for entity start span = 0.92307
# Epoch  13: Valid Acurracy for entity start span = 0.92307
# Epoch  13: Valid Recall for entity start span = 0.92307
# Epoch  13: Valid Precision for entity start span = 0.92307
# Epoch  13: Valid f1_score for entity end span = 0.92368
# Epoch  13: Valid Acurracy for entity end span = 0.92368
# Epoch  13: Valid Recall for entity end span = 0.92368
# Epoch  13: Valid Precision for entity end span = 0.92368
# The current f1 score for entity start: 0.9230664488017428
# The current f1 score for entity end: 0.923679193899782
# Epoch  14: Train Loss = 12.68020
# Epoch  14: Valid Loss = 12.15266
# Epoch  14: Valid f1_score for entity start span = 0.92382
# Epoch  14: Valid Acurracy for entity start span = 0.92382
# Epoch  14: Valid Recall for entity start span = 0.92382
# Epoch  14: Valid Precision for entity start span = 0.92382
# Epoch  14: Valid f1_score for entity end span = 0.92565
# Epoch  14: Valid Acurracy for entity end span = 0.92565
# Epoch  14: Valid Recall for entity end span = 0.92565
# Epoch  14: Valid Precision for entity end span = 0.92565
# The current f1 score for entity start: 0.9238153594771242
# The current f1 score for entity end: 0.9256535947712419
# Epoch  15: Train Loss = 12.67116
# Epoch  15: Valid Loss = 12.15293
# Epoch  15: Valid f1_score for entity start span = 0.92347
# Epoch  15: Valid Acurracy for entity start span = 0.92347
# Epoch  15: Valid Recall for entity start span = 0.92347
# Epoch  15: Valid Precision for entity start span = 0.92347
# Epoch  15: Valid f1_score for entity end span = 0.92552
# Epoch  15: Valid Acurracy for entity end span = 0.92552
# Epoch  15: Valid Recall for entity end span = 0.92552
# Epoch  15: Valid Precision for entity end span = 0.92552
# trigger times: 1
# Epoch  16: Train Loss = 12.67744
# Epoch  16: Valid Loss = 12.14808
# Epoch  16: Valid f1_score for entity start span = 0.92470
# Epoch  16: Valid Acurracy for entity start span = 0.92470
# Epoch  16: Valid Recall for entity start span = 0.92470
# Epoch  16: Valid Precision for entity start span = 0.92470
# Epoch  16: Valid f1_score for entity end span = 0.92810
# Epoch  16: Valid Acurracy for entity end span = 0.92810
# Epoch  16: Valid Recall for entity end span = 0.92810
# Epoch  16: Valid Precision for entity end span = 0.92810
# The current f1 score for entity start: 0.9247004357298474
# The current f1 score for entity end: 0.9281045751633987
# Epoch  17: Train Loss = 12.66739
# Epoch  17: Valid Loss = 12.14850
# Epoch  17: Valid f1_score for entity start span = 0.92586
# Epoch  17: Valid Acurracy for entity start span = 0.92586
# Epoch  17: Valid Recall for entity start span = 0.92586
# Epoch  17: Valid Precision for entity start span = 0.92586
# Epoch  17: Valid f1_score for entity end span = 0.92831
# Epoch  17: Valid Acurracy for entity end span = 0.92831
# Epoch  17: Valid Recall for entity end span = 0.92831
# Epoch  17: Valid Precision for entity end span = 0.92831
# The current f1 score for entity start: 0.9258578431372549
# The current f1 score for entity end: 0.9283088235294118
# Epoch  18: Train Loss = 12.66740
# Epoch  18: Valid Loss = 12.14526
# Epoch  18: Valid f1_score for entity start span = 0.92525
# Epoch  18: Valid Acurracy for entity start span = 0.92525
# Epoch  18: Valid Recall for entity start span = 0.92525
# Epoch  18: Valid Precision for entity start span = 0.92525
# Epoch  18: Valid f1_score for entity end span = 0.92913
# Epoch  18: Valid Acurracy for entity end span = 0.92913
# Epoch  18: Valid Recall for entity end span = 0.92913
# Epoch  18: Valid Precision for entity end span = 0.92913
# Epoch  19: Train Loss = 12.66585
# Epoch  19: Valid Loss = 12.14501
# Epoch  19: Valid f1_score for entity start span = 0.92688
# Epoch  19: Valid Acurracy for entity start span = 0.92688
# Epoch  19: Valid Recall for entity start span = 0.92688
# Epoch  19: Valid Precision for entity start span = 0.92688
# Epoch  19: Valid f1_score for entity end span = 0.92872
# Epoch  19: Valid Acurracy for entity end span = 0.92872
# Epoch  19: Valid Recall for entity end span = 0.92872
# Epoch  19: Valid Precision for entity end span = 0.92872
# The current f1 score for entity start: 0.9268790849673203
# The current f1 score for entity end: 0.9287173202614379
# 0.9268790849673203 0.9287173202614379
# The best parameters are saved for the activation function: ELU

# %%
list_entity_loss_train_softplus, list_entity_loss_valid_softplus, list_epochs_softplus = get_entity_results("Softplus", max_question_length, learning_rate, optimizer_name, epochs, dropout_prob, loss_func, train_bert_dataset, valid_bert_dataset, train_dataloader, val_dataloader, SEED)
# Out:
# BertEntitySpanClassifier(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (activation): Softplus(beta=1, threshold=20)
#   (start_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Softplus(beta=1, threshold=20)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
#   (end_head): Sequential(
#     (0): Linear(in_features=768, out_features=33, bias=True)
#     (1): Softplus(beta=1, threshold=20)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Flatten(start_dim=1, end_dim=-1)
#     (4): Softmax(dim=1)
#   )
# )
# Epoch   0: Train Loss = 13.52035
# Epoch   0: Valid Loss = 13.19899
# Epoch   0: Valid f1_score for entity start span = 0.60859
# Epoch   0: Valid Acurracy for entity start span = 0.60859
# Epoch   0: Valid Recall for entity start span = 0.60859
# Epoch   0: Valid Precision for entity start span = 0.60859
# Epoch   0: Valid f1_score for entity end span = 0.38794
# Epoch   0: Valid Acurracy for entity end span = 0.38794
# Epoch   0: Valid Recall for entity end span = 0.38794
# Epoch   0: Valid Precision for entity end span = 0.38794
# The current f1 score for entity start: 0.6085920479302832
# The current f1 score for entity end: 0.3879357298474945
# Epoch   1: Train Loss = 13.04490
# Epoch   1: Valid Loss = 12.59917
# Epoch   1: Valid f1_score for entity start span = 0.80964
# Epoch   1: Valid Acurracy for entity start span = 0.80964
# Epoch   1: Valid Recall for entity start span = 0.80964
# Epoch   1: Valid Precision for entity start span = 0.80964
# Epoch   1: Valid f1_score for entity end span = 0.70173
# Epoch   1: Valid Acurracy for entity end span = 0.70173
# Epoch   1: Valid Recall for entity end span = 0.70173
# Epoch   1: Valid Precision for entity end span = 0.70173
# The current f1 score for entity start: 0.809640522875817
# The current f1 score for entity end: 0.701729302832244
# Epoch   2: Train Loss = 12.87344
# Epoch   2: Valid Loss = 12.43173
# Epoch   2: Valid f1_score for entity start span = 0.84681
# Epoch   2: Valid Acurracy for entity start span = 0.84681
# Epoch   2: Valid Recall for entity start span = 0.84681
# Epoch   2: Valid Precision for entity start span = 0.84681
# Epoch   2: Valid f1_score for entity end span = 0.79092
# Epoch   2: Valid Acurracy for entity end span = 0.79092
# Epoch   2: Valid Recall for entity end span = 0.79092
# Epoch   2: Valid Precision for entity end span = 0.79092
# The current f1 score for entity start: 0.8468137254901961
# The current f1 score for entity end: 0.7909177559912854
# Epoch   3: Train Loss = 12.81960
# Epoch   3: Valid Loss = 12.37155
# Epoch   3: Valid f1_score for entity start span = 0.84525
# Epoch   3: Valid Acurracy for entity start span = 0.84525
# Epoch   3: Valid Recall for entity start span = 0.84525
# Epoch   3: Valid Precision for entity start span = 0.84525
# Epoch   3: Valid f1_score for entity end span = 0.83047
# Epoch   3: Valid Acurracy for entity end span = 0.83047
# Epoch   3: Valid Recall for entity end span = 0.83047
# Epoch   3: Valid Precision for entity end span = 0.83047
# Epoch   4: Train Loss = 12.77783
# Epoch   4: Valid Loss = 12.32715
# Epoch   4: Valid f1_score for entity start span = 0.86724
# Epoch   4: Valid Acurracy for entity start span = 0.86724
# Epoch   4: Valid Recall for entity start span = 0.86724
# Epoch   4: Valid Precision for entity start span = 0.86724
# Epoch   4: Valid f1_score for entity end span = 0.84252
# Epoch   4: Valid Acurracy for entity end span = 0.84252
# Epoch   4: Valid Recall for entity end span = 0.84252
# Epoch   4: Valid Precision for entity end span = 0.84252
# The current f1 score for entity start: 0.8672385620915033
# The current f1 score for entity end: 0.8425245098039216
# Epoch   5: Train Loss = 12.76999
# Epoch   5: Valid Loss = 12.28900
# Epoch   5: Valid f1_score for entity start span = 0.87214
# Epoch   5: Valid Acurracy for entity start span = 0.87214
# Epoch   5: Valid Recall for entity start span = 0.87214
# Epoch   5: Valid Precision for entity start span = 0.87214
# Epoch   5: Valid f1_score for entity end span = 0.86642
# Epoch   5: Valid Acurracy for entity end span = 0.86642
# Epoch   5: Valid Recall for entity end span = 0.86642
# Epoch   5: Valid Precision for entity end span = 0.86642
# The current f1 score for entity start: 0.872140522875817
# The current f1 score for entity end: 0.866421568627451
# Epoch   6: Train Loss = 12.75580
# Epoch   6: Valid Loss = 12.26996
# Epoch   6: Valid f1_score for entity start span = 0.88276
# Epoch   6: Valid Acurracy for entity start span = 0.88276
# Epoch   6: Valid Recall for entity start span = 0.88276
# Epoch   6: Valid Precision for entity start span = 0.88276
# Epoch   6: Valid f1_score for entity end span = 0.87030
# Epoch   6: Valid Acurracy for entity end span = 0.87030
# Epoch   6: Valid Recall for entity end span = 0.87030
# Epoch   6: Valid Precision for entity end span = 0.87030
# The current f1 score for entity start: 0.8827614379084967
# The current f1 score for entity end: 0.8703022875816994
# Epoch   7: Train Loss = 12.74208
# Epoch   7: Valid Loss = 12.25495
# Epoch   7: Valid f1_score for entity start span = 0.88950
# Epoch   7: Valid Acurracy for entity start span = 0.88950
# Epoch   7: Valid Recall for entity start span = 0.88950
# Epoch   7: Valid Precision for entity start span = 0.88950
# Epoch   7: Valid f1_score for entity end span = 0.87480
# Epoch   7: Valid Acurracy for entity end span = 0.87480
# Epoch   7: Valid Recall for entity end span = 0.87480
# Epoch   7: Valid Precision for entity end span = 0.87480
# The current f1 score for entity start: 0.889501633986928
# The current f1 score for entity end: 0.8747957516339869
# Epoch   8: Train Loss = 12.72886
# Epoch   8: Valid Loss = 12.23130
# Epoch   8: Valid f1_score for entity start span = 0.90911
# Epoch   8: Valid Acurracy for entity start span = 0.90911
# Epoch   8: Valid Recall for entity start span = 0.90911
# Epoch   8: Valid Precision for entity start span = 0.90911
# Epoch   8: Valid f1_score for entity end span = 0.87704
# Epoch   8: Valid Acurracy for entity end span = 0.87704
# Epoch   8: Valid Recall for entity end span = 0.87704
# Epoch   8: Valid Precision for entity end span = 0.87704
# The current f1 score for entity start: 0.909109477124183
# The current f1 score for entity end: 0.8770424836601307
# Epoch   9: Train Loss = 12.71690
# Epoch   9: Valid Loss = 12.21777
# Epoch   9: Valid f1_score for entity start span = 0.91319
# Epoch   9: Valid Acurracy for entity start span = 0.91319
# Epoch   9: Valid Recall for entity start span = 0.91319
# Epoch   9: Valid Precision for entity start span = 0.91319
# Epoch   9: Valid f1_score for entity end span = 0.87663
# Epoch   9: Valid Acurracy for entity end span = 0.87663
# Epoch   9: Valid Recall for entity end span = 0.87663
# Epoch   9: Valid Precision for entity end span = 0.87663
# Epoch  10: Train Loss = 12.70269
# Epoch  10: Valid Loss = 12.20557
# Epoch  10: Valid f1_score for entity start span = 0.92116
# Epoch  10: Valid Acurracy for entity start span = 0.92116
# Epoch  10: Valid Recall for entity start span = 0.92116
# Epoch  10: Valid Precision for entity start span = 0.92116
# Epoch  10: Valid f1_score for entity end span = 0.88113
# Epoch  10: Valid Acurracy for entity end span = 0.88113
# Epoch  10: Valid Recall for entity end span = 0.88113
# Epoch  10: Valid Precision for entity end span = 0.88113
# The current f1 score for entity start: 0.9211601307189542
# The current f1 score for entity end: 0.8811274509803921
# Epoch  11: Train Loss = 12.70587
# Epoch  11: Valid Loss = 12.20416
# Epoch  11: Valid f1_score for entity start span = 0.92021
# Epoch  11: Valid Acurracy for entity start span = 0.92021
# Epoch  11: Valid Recall for entity start span = 0.92021
# Epoch  11: Valid Precision for entity start span = 0.92021
# Epoch  11: Valid f1_score for entity end span = 0.88875
# Epoch  11: Valid Acurracy for entity end span = 0.88875
# Epoch  11: Valid Recall for entity end span = 0.88875
# Epoch  11: Valid Precision for entity end span = 0.88875
# Epoch  12: Train Loss = 12.69329
# Epoch  12: Valid Loss = 12.18971
# Epoch  12: Valid f1_score for entity start span = 0.92157
# Epoch  12: Valid Acurracy for entity start span = 0.92157
# Epoch  12: Valid Recall for entity start span = 0.92157
# Epoch  12: Valid Precision for entity start span = 0.92157
# Epoch  12: Valid f1_score for entity end span = 0.89897
# Epoch  12: Valid Acurracy for entity end span = 0.89897
# Epoch  12: Valid Recall for entity end span = 0.89897
# Epoch  12: Valid Precision for entity end span = 0.89897
# The current f1 score for entity start: 0.9215686274509803
# The current f1 score for entity end: 0.8989651416122004
# Epoch  13: Train Loss = 12.68908
# Epoch  13: Valid Loss = 12.17953
# Epoch  13: Valid f1_score for entity start span = 0.92409
# Epoch  13: Valid Acurracy for entity start span = 0.92409
# Epoch  13: Valid Recall for entity start span = 0.92409
# Epoch  13: Valid Precision for entity start span = 0.92409
# Epoch  13: Valid f1_score for entity end span = 0.90387
# Epoch  13: Valid Acurracy for entity end span = 0.90387
# Epoch  13: Valid Recall for entity end span = 0.90387
# Epoch  13: Valid Precision for entity end span = 0.90387
# The current f1 score for entity start: 0.9240876906318082
# The current f1 score for entity end: 0.9038671023965141
# Epoch  14: Train Loss = 12.69243
# Epoch  14: Valid Loss = 12.17279
# Epoch  14: Valid f1_score for entity start span = 0.92341
# Epoch  14: Valid Acurracy for entity start span = 0.92341
# Epoch  14: Valid Recall for entity start span = 0.92341
# Epoch  14: Valid Precision for entity start span = 0.92341
# Epoch  14: Valid f1_score for entity end span = 0.91054
# Epoch  14: Valid Acurracy for entity end span = 0.91054
# Epoch  14: Valid Recall for entity end span = 0.91054
# Epoch  14: Valid Precision for entity end span = 0.91054
# Epoch  15: Train Loss = 12.68171
# Epoch  15: Valid Loss = 12.16759
# Epoch  15: Valid f1_score for entity start span = 0.92307
# Epoch  15: Valid Acurracy for entity start span = 0.92307
# Epoch  15: Valid Recall for entity start span = 0.92307
# Epoch  15: Valid Precision for entity start span = 0.92307
# Epoch  15: Valid f1_score for entity end span = 0.91653
# Epoch  15: Valid Acurracy for entity end span = 0.91653
# Epoch  15: Valid Recall for entity end span = 0.91653
# Epoch  15: Valid Precision for entity end span = 0.91653
# Epoch  16: Train Loss = 12.68612
# Epoch  16: Valid Loss = 12.16026
# Epoch  16: Valid f1_score for entity start span = 0.92593
# Epoch  16: Valid Acurracy for entity start span = 0.92593
# Epoch  16: Valid Recall for entity start span = 0.92593
# Epoch  16: Valid Precision for entity start span = 0.92593
# Epoch  16: Valid f1_score for entity end span = 0.92177
# Epoch  16: Valid Acurracy for entity end span = 0.92177
# Epoch  16: Valid Recall for entity end span = 0.92177
# Epoch  16: Valid Precision for entity end span = 0.92177
# The current f1 score for entity start: 0.9259259259259258
# The current f1 score for entity end: 0.9217728758169934
# Epoch  17: Train Loss = 12.67437
# Epoch  17: Valid Loss = 12.15966
# Epoch  17: Valid f1_score for entity start span = 0.92606
# Epoch  17: Valid Acurracy for entity start span = 0.92606
# Epoch  17: Valid Recall for entity start span = 0.92606
# Epoch  17: Valid Precision for entity start span = 0.92606
# Epoch  17: Valid f1_score for entity end span = 0.91912
# Epoch  17: Valid Acurracy for entity end span = 0.91912
# Epoch  17: Valid Recall for entity end span = 0.91912
# Epoch  17: Valid Precision for entity end span = 0.91912
# Epoch  18: Train Loss = 12.67361
# Epoch  18: Valid Loss = 12.16046
# Epoch  18: Valid f1_score for entity start span = 0.92511
# Epoch  18: Valid Acurracy for entity start span = 0.92511
# Epoch  18: Valid Recall for entity start span = 0.92511
# Epoch  18: Valid Precision for entity start span = 0.92511
# Epoch  18: Valid f1_score for entity end span = 0.91953
# Epoch  18: Valid Acurracy for entity end span = 0.91953
# Epoch  18: Valid Recall for entity end span = 0.91953
# Epoch  18: Valid Precision for entity end span = 0.91953
# Epoch  19: Train Loss = 12.67163
# Epoch  19: Valid Loss = 12.15681
# Epoch  19: Valid f1_score for entity start span = 0.92770
# Epoch  19: Valid Acurracy for entity start span = 0.92770
# Epoch  19: Valid Recall for entity start span = 0.92770
# Epoch  19: Valid Precision for entity start span = 0.92770
# Epoch  19: Valid f1_score for entity end span = 0.92096
# Epoch  19: Valid Acurracy for entity end span = 0.92096
# Epoch  19: Valid Recall for entity end span = 0.92096
# Epoch  19: Valid Precision for entity end span = 0.92096
# 0.9259259259259258 0.9217728758169934
# The best parameters are saved for the activation function: Softplus

# %%
list_entity_training_losses.append(list_entity_loss_train_leakyrelu)
list_entity_validation_losses.append(list_entity_loss_valid_leakyrelu)
list_entity_epochs.append(list_epochs_leakyrelu)
list_entity_training_losses.append(list_entity_loss_train_tahnshrink)
list_entity_validation_losses.append(list_entity_loss_valid_tahnshrink)
list_entity_epochs.append(list_epochs_tahnshrink)
list_entity_training_losses.append(list_entity_loss_train_softplus)
list_entity_validation_losses.append(list_entity_loss_valid_softplus)
list_entity_epochs.append(list_epochs_softplus)
list_entity_training_losses.append(list_entity_loss_train_elu)
list_entity_validation_losses.append(list_entity_loss_valid_elu)
list_entity_epochs.append(list_epochs_elu)

# %%
plot_losses(list_entity_epochs, list_entity_training_losses, list_entity_validation_losses, activations, learning_rate, dropout_prob)
